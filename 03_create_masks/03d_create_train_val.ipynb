# %% [markdown]
# <a href="https://colab.research.google.com/github/benedikt-korbach/remote-sensing-of-parking-areas/blob/main/03d_create_train_val.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import packages, mount drive, set wd

# %%
import os
import cv2
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import datetime
import random
import shutil

# %%
#from google.colab import drive
#drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Set wd
#os.chdir("/Users/benediktkorbach/Documents/GitHub/remote-sensing-of-parking-areas")
#os.chdir("/content/drive/MyDrive/Master Thesis")

# Set wd
os.chdir('/Users/benediktkorbach/Documents/GitHub/remote-sensing-of-parking-areas')

print("Working directory:", os.getcwd())
# Out:
# Working directory: /Users/benediktkorbach/Documents/GitHub/remote-sensing-of-parking-areas

# %% [markdown]
# # Check train_validate_512

# %%
def count_files_in_folder(folder_path):
    """Counts the number of files in the specified folder."""
    # List all entries in the folder
    entries = os.listdir(folder_path)

    # Count only files
    file_count = sum(os.path.isfile(os.path.join(folder_path, entry)) for entry in entries)

    return file_count

# %%
# Count images and masks
mask_path = "03_create_masks/train_validate_512_incl_quick/masks"
image_path = "03_create_masks/train_validate_512_incl_quick/images"

num_masks = count_files_in_folder(mask_path)
num_images = count_files_in_folder(image_path)

print(f"There are {num_images} images and {num_masks} masks in the folders {image_path} and {mask_path} respectively.")
# Out:
# There are 5793 images and 5793 masks in the folders 03_create_masks/train_validate_512_incl_quick/images and 03_create_masks/train_validate_512_incl_quick/masks respectively.

# %% [markdown]
# There are 5,793 images/masks in the train_validate_512_incl_quick folder.

# %% [markdown]
# # Reduce background images/masks

# %%
def create_target_dirs(target_dir):
    """Create target directories for images and masks."""
    os.makedirs(target_dir, exist_ok=True)
    os.makedirs(os.path.join(target_dir, "images"), exist_ok=True)
    os.makedirs(os.path.join(target_dir, "masks"), exist_ok=True)

def reduce_background_images(image_folder, mask_folder, target_folder, black_mask_inclusion_prob=0.2):
    """
    Reduces the number of pure background images by selecting black_mask_inclusion_prob percent of pure background images.
    """
    # Create target directory
    create_target_dirs(target_folder)

    # Initialize counters for sanity check
    image_counter = 0
    parking_images_copied = 0
    background_images_copied = 0
    background_images_discarded = 0

    # Initialize start time
    start_time = datetime.datetime.now()
    print(f"Copying started at {start_time.strftime('%Y-%m-%d %H:%M:%S')}")

    # Loop through every image/mask
    for img_name in sorted(os.listdir(image_folder)):
        if not img_name.lower().endswith(".png"):
            continue

        image_counter += 1

        img_path = os.path.join(image_folder, img_name)
        mask_path = os.path.join(mask_folder, img_name)

        # Check if the mask is completely black (background)
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
        if np.unique(mask).size == 1 and np.unique(mask)[0] == 0:
            # Include the black mask with a certain probability
            if random.random() < black_mask_inclusion_prob:
                shutil.copy(img_path, os.path.join(target_folder, "images", img_name))
                shutil.copy(mask_path, os.path.join(target_folder, "masks", img_name))
                print(f"Background added: {img_name}")
                background_images_copied += 1
            else:
                background_images_discarded += 1
        else:
            # Include every non-background image
            shutil.copy(img_path, os.path.join(target_folder, "images", img_name))
            shutil.copy(mask_path, os.path.join(target_folder, "masks", img_name))
            print(f"Parking added: {img_name}")
            parking_images_copied += 1

    # Stop time and calculate total copied
    now = datetime.datetime.now()
    duration = (now - start_time).total_seconds()
    total_copied = background_images_copied + parking_images_copied

    # Output copies made by category
    print(f"Finished copying at {now.strftime('%Y-%m-%d %H:%M:%S')} in {duration:.2f} seconds.")
    print(f"Total evaluated: {image_counter}")
    print(f"Total background discarded: {background_images_discarded}")
    print(f"Total copied: {total_copied}")
    print(f"thereof parking: {parking_images_copied}")
    print(f"thereof background: {background_images_copied}")

# %%
# Reduce the number of pure background images and save them in the target folder

image_folder = "03_create_masks/train_validate_512_incl_quick/images"
mask_folder = "03_create_masks/train_validate_512_incl_quick/masks"
target_folder = "03_create_masks/train_validate_512_incl_quick/train_validate_512_incl_quick_reduced_background"
reduce_background_images(image_folder, mask_folder, target_folder)
# Out:
# Copying started at 2024-03-24 13:38:06
# Background added: lon_10.0214344_lat_54.2446698_Rumohr_0_1.png
# Parking added: lon_10.0214344_lat_54.2446698_Rumohr_0_3.png
# Background added: lon_10.0214344_lat_54.2446698_Rumohr_0_4.png
# Background added: lon_10.0214344_lat_54.2446698_Rumohr_1_0.png
# Parking added: lon_10.0214344_lat_54.2446698_Rumohr_1_3.png
# Background added: lon_10.0214344_lat_54.2446698_Rumohr_4_0.png
# Background added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_0_2.png
# Background added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_0_4.png
# Parking added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_1_1.png
# Parking added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_1_2.png
# Parking added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_2_1.png
# Parking added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_2_2.png
# Background added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_3_4.png
# Parking added: lon_10.0338812_lat_51.7811423_Am Bierberg_1_1.png
# Parking added: lon_10.0338812_lat_51.7811423_Am Bierberg_1_2.png
# Parking added: lon_10.0338812_lat_51.7811423_Am Bierberg_2_0.png
# Parking added: lon_10.0338812_lat_51.7811423_Am Bierberg_2_1.png
# Parking added: lon_10.0338812_lat_51.7811423_Am Bierberg_2_2.png
# Parking added: lon_10.0338812_lat_51.7811423_Am Bierberg_3_0.png
# Parking added: lon_10.0338812_lat_51.7811423_Am Bierberg_3_1.png
# Background added: lon_10.0338812_lat_51.7811423_Am Bierberg_3_2.png
# Parking added: lon_10.0385684_lat_53.3493845_Seevetal_0_2.png
# Background added: lon_10.0385684_lat_53.3493845_Seevetal_0_3.png
# Background added: lon_10.0385684_lat_53.3493845_Seevetal_1_0.png
# Parking added: lon_10.0385684_lat_53.3493845_Seevetal_1_2.png
# Background added: lon_10.0385684_lat_53.3493845_Seevetal_2_0.png
# Parking added: lon_10.0385684_lat_53.3493845_Seevetal_2_2.png
# Background added: lon_10.0385684_lat_53.3493845_Seevetal_3_1.png
# Parking added: lon_10.0385684_lat_53.3493845_Seevetal_3_2.png
# Background added: lon_10.0385684_lat_53.3493845_Seevetal_4_0.png
# Background added: lon_10.0385684_lat_53.3493845_Seevetal_4_2.png
# Parking added: lon_10.0413714_lat_53.3330705_Hasselhöhe_0_0.png
# Parking added: lon_10.0413714_lat_53.3330705_Hasselhöhe_0_1.png
# Background added: lon_10.0413714_lat_53.3330705_Hasselhöhe_0_4.png
# Parking added: lon_10.0413714_lat_53.3330705_Hasselhöhe_1_0.png
# Parking added: lon_10.0413714_lat_53.3330705_Hasselhöhe_1_1.png
# Background added: lon_10.0413714_lat_53.3330705_Hasselhöhe_1_4.png
# Parking added: lon_10.0413714_lat_53.3330705_Hasselhöhe_2_1.png
# Parking added: lon_10.0413714_lat_53.3330705_Hasselhöhe_2_2.png
# Parking added: lon_10.0413714_lat_53.3330705_Hasselhöhe_3_1.png
# Parking added: lon_10.0413714_lat_53.3330705_Hasselhöhe_3_2.png
# Parking added: lon_10.0413714_lat_53.3330705_Hasselhöhe_3_3.png
# Background added: lon_10.0413714_lat_53.3330705_Hasselhöhe_4_0.png
# Parking added: lon_10.0413714_lat_53.3330705_Hasselhöhe_4_2.png
# Parking added: lon_10.0413714_lat_53.3330705_Hasselhöhe_4_3.png
# Background added: lon_10.0752917_lat_53.2253978_Garlstorfer Wald_0_0.png
# Background added: lon_10.0752917_lat_53.2253978_Garlstorfer Wald_0_2.png
# Parking added: lon_10.0752917_lat_53.2253978_Garlstorfer Wald_1_0.png
# Background added: lon_10.0752917_lat_53.2253978_Garlstorfer Wald_1_1.png
# Background added: lon_10.0752917_lat_53.2253978_Garlstorfer Wald_1_2.png
# Parking added: lon_10.0752917_lat_53.2253978_Garlstorfer Wald_2_0.png
# Parking added: lon_10.0752917_lat_53.2253978_Garlstorfer Wald_3_0.png
# Background added: lon_10.0752917_lat_53.2253978_Garlstorfer Wald_4_3.png
# Background added: lon_10.0774066_lat_53.2322212_Schaapskaben_0_1.png
# Background added: lon_10.0774066_lat_53.2322212_Schaapskaben_0_4.png
# Parking added: lon_10.0774066_lat_53.2322212_Schaapskaben_1_3.png
# Parking added: lon_10.0774066_lat_53.2322212_Schaapskaben_1_4.png
# Background added: lon_10.0774066_lat_53.2322212_Schaapskaben_2_2.png
# Parking added: lon_10.0774066_lat_53.2322212_Schaapskaben_2_3.png
# Parking added: lon_10.0774066_lat_53.2322212_Schaapskaben_2_4.png
# Background added: lon_10.0774066_lat_53.2322212_Schaapskaben_3_1.png
# Parking added: lon_10.0774066_lat_53.2322212_Schaapskaben_3_3.png
# Background added: lon_10.0774066_lat_53.2322212_Schaapskaben_4_0.png
# Background added: lon_10.0774066_lat_53.2322212_Schaapskaben_4_3.png
# Background added: lon_10.1230601_lat_51.8561527_Schwalenberg-West_0_2.png
# Parking added: lon_10.1230601_lat_51.8561527_Schwalenberg-West_1_2.png
# Parking added: lon_10.1230601_lat_51.8561527_Schwalenberg-West_2_1.png
# Parking added: lon_10.1230601_lat_51.8561527_Schwalenberg-West_2_2.png
# Parking added: lon_10.1230601_lat_51.8561527_Schwalenberg-West_3_1.png
# Parking added: lon_10.1230601_lat_51.8561527_Schwalenberg-West_3_2.png
# Background added: lon_10.1230601_lat_51.8561527_Schwalenberg-West_4_0.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_0_2.png
# Background added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_0_4.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_1_2.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_2_2.png
# Background added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_2_4.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_3_2.png
# Background added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_4_1.png
# Background added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_4_3.png
# Parking added: lon_10.151289_lat_51.9784844_Ambergau_0_3.png
# Background added: lon_10.151289_lat_51.9784844_Ambergau_1_1.png
# Background added: lon_10.151289_lat_51.9784844_Ambergau_1_2.png
# Parking added: lon_10.151289_lat_51.9784844_Ambergau_1_3.png
# Parking added: lon_10.151289_lat_51.9784844_Ambergau_2_3.png
# Background added: lon_10.151289_lat_51.9784844_Ambergau_3_2.png
# Background added: lon_10.151289_lat_51.9784844_Ambergau_3_3.png
# Background added: lon_10.151289_lat_51.9784844_Ambergau_4_0.png
# Background added: lon_10.1521298_lat_51.9786026_Ambergau_0_0.png
# Background added: lon_10.1521298_lat_51.9786026_Ambergau_2_1.png
# Background added: lon_10.1521298_lat_51.9786026_Ambergau_3_1.png
# Parking added: lon_10.1521298_lat_51.9786026_Ambergau_3_4.png
# Parking added: lon_10.1521298_lat_51.9786026_Ambergau_4_3.png
# Background added: lon_10.1521298_lat_51.9786026_Ambergau_4_4.png
# Background added: lon_10.1538882_lat_52.3604733_Röhrse Süd_0_0.png
# Background added: lon_10.1538882_lat_52.3604733_Röhrse Süd_0_1.png
# Background added: lon_10.1538882_lat_52.3604733_Röhrse Süd_1_1.png
# Background added: lon_10.1538882_lat_52.3604733_Röhrse Süd_1_2.png
# Background added: lon_10.1538882_lat_52.3604733_Röhrse Süd_2_0.png
# Background added: lon_10.1538882_lat_52.3604733_Röhrse Süd_2_4.png
# Parking added: lon_10.1538882_lat_52.3604733_Röhrse Süd_3_2.png
# Parking added: lon_10.1538882_lat_52.3604733_Röhrse Süd_3_3.png
# Parking added: lon_10.1538882_lat_52.3604733_Röhrse Süd_3_4.png
# Parking added: lon_10.1538882_lat_52.3604733_Röhrse Süd_4_2.png
# Parking added: lon_10.1538882_lat_52.3604733_Röhrse Süd_4_3.png
# Parking added: lon_10.1538882_lat_52.3604733_Röhrse Süd_4_4.png
# Background added: lon_10.16857_lat_53.3461669_Grevelau_0_1.png
# Background added: lon_10.16857_lat_53.3461669_Grevelau_0_3.png
# Background added: lon_10.16857_lat_53.3461669_Grevelau_1_0.png
# Parking added: lon_10.16857_lat_53.3461669_Grevelau_3_2.png
# Parking added: lon_10.16857_lat_53.3461669_Grevelau_3_3.png
# Parking added: lon_10.16857_lat_53.3461669_Grevelau_4_4.png
# Background added: lon_10.1688328_lat_53.3457924_Luhewiesen_0_4.png
# Parking added: lon_10.1688328_lat_53.3457924_Luhewiesen_2_2.png
# Background added: lon_10.1688328_lat_53.3457924_Luhewiesen_3_1.png
# Parking added: lon_10.1688328_lat_53.3457924_Luhewiesen_3_3.png
# Background added: lon_10.1688328_lat_53.3457924_Luhewiesen_4_2.png
# Background added: lon_10.1688328_lat_53.3457924_Luhewiesen_4_3.png
# Parking added: lon_10.1726923_lat_51.0086765_Burgberg_1_0.png
# Parking added: lon_10.1726923_lat_51.0086765_Burgberg_1_1.png
# Parking added: lon_10.1726923_lat_51.0086765_Burgberg_1_2.png
# Background added: lon_10.1726923_lat_51.0086765_Burgberg_1_3.png
# Parking added: lon_10.1726923_lat_51.0086765_Burgberg_2_0.png
# Parking added: lon_10.1726923_lat_51.0086765_Burgberg_2_1.png
# Parking added: lon_10.1726923_lat_51.0086765_Burgberg_2_2.png
# Parking added: lon_10.1726923_lat_51.0086765_Burgberg_2_3.png
# Background added: lon_10.1726923_lat_51.0086765_Burgberg_4_3.png
# Parking added: lon_10.1793156_lat_51.408897_Leinetal_1_1.png
# Parking added: lon_10.1793156_lat_51.408897_Leinetal_1_2.png
# Background added: lon_10.1793156_lat_51.408897_Leinetal_1_4.png
# Background added: lon_10.1793156_lat_51.408897_Leinetal_2_0.png
# Parking added: lon_10.1793156_lat_51.408897_Leinetal_2_1.png
# Parking added: lon_10.1793156_lat_51.408897_Leinetal_2_2.png
# Background added: lon_10.1793156_lat_51.408897_Leinetal_2_3.png
# Background added: lon_10.1793156_lat_51.408897_Leinetal_3_3.png
# Background added: lon_10.1793156_lat_51.408897_Leinetal_4_2.png
# Background added: lon_10.1793156_lat_51.408897_Leinetal_4_4.png
# Parking added: lon_10.1798889_lat_51.0057808_Werratal_2_0.png
# Parking added: lon_10.1798889_lat_51.0057808_Werratal_2_1.png
# Parking added: lon_10.1798889_lat_51.0057808_Werratal_2_2.png
# Parking added: lon_10.1798889_lat_51.0057808_Werratal_2_3.png
# Parking added: lon_10.1798889_lat_51.0057808_Werratal_2_4.png
# Parking added: lon_10.1798889_lat_51.0057808_Werratal_3_1.png
# Parking added: lon_10.1798889_lat_51.0057808_Werratal_3_2.png
# Background added: lon_10.1798889_lat_51.0057808_Werratal_4_1.png
# Background added: lon_10.1798889_lat_51.0057808_Werratal_4_4.png
# Background added: lon_10.2127333_lat_54.1387697_Depenauer Moor_0_2.png
# Parking added: lon_10.2127333_lat_54.1387697_Depenauer Moor_1_1.png
# Parking added: lon_10.2127333_lat_54.1387697_Depenauer Moor_1_2.png
# Background added: lon_10.2127333_lat_54.1387697_Depenauer Moor_1_3.png
# Background added: lon_10.2127333_lat_54.1387697_Depenauer Moor_2_0.png
# Parking added: lon_10.2127333_lat_54.1387697_Depenauer Moor_2_2.png
# Background added: lon_10.2127333_lat_54.1387697_Depenauer Moor_3_2.png
# Background added: lon_10.2493842_lat_53.6299917_Ellerbrook_1_4.png
# Parking added: lon_10.2493842_lat_53.6299917_Ellerbrook_2_1.png
# Parking added: lon_10.2493842_lat_53.6299917_Ellerbrook_2_2.png
# Parking added: lon_10.2493842_lat_53.6299917_Ellerbrook_3_1.png
# Background added: lon_10.2493842_lat_53.6299917_Ellerbrook_4_4.png
# Parking added: lon_10.2594398_lat_53.6359541_Ohlendieck_0_0.png
# Parking added: lon_10.2594398_lat_53.6359541_Ohlendieck_0_1.png
# Parking added: lon_10.2594398_lat_53.6359541_Ohlendieck_1_0.png
# Parking added: lon_10.2594398_lat_53.6359541_Ohlendieck_1_1.png
# Background added: lon_10.2594398_lat_53.6359541_Ohlendieck_1_2.png
# Background added: lon_10.2594398_lat_53.6359541_Ohlendieck_1_4.png
# Background added: lon_10.2594398_lat_53.6359541_Ohlendieck_2_2.png
# Background added: lon_10.2712414_lat_53.331074_Roddau_0_0.png
# Parking added: lon_10.2712414_lat_53.331074_Roddau_0_2.png
# Parking added: lon_10.2712414_lat_53.331074_Roddau_0_3.png
# Parking added: lon_10.2712414_lat_53.331074_Roddau_1_2.png
# Parking added: lon_10.2712414_lat_53.331074_Roddau_1_3.png
# Background added: lon_10.2712414_lat_53.331074_Roddau_2_0.png
# Background added: lon_10.2712414_lat_53.331074_Roddau_4_4.png
# Background added: lon_10.3229911_lat_53.7357901_Rehbrook West_0_2.png
# Background added: lon_10.3229911_lat_53.7357901_Rehbrook West_1_3.png
# Parking added: lon_10.3229911_lat_53.7357901_Rehbrook West_2_1.png
# Background added: lon_10.3229911_lat_53.7357901_Rehbrook West_3_3.png
# Background added: lon_10.3229911_lat_53.7357901_Rehbrook West_3_4.png
# Background added: lon_10.3839933_lat_53.9180845_Kronberg_0_1.png
# Background added: lon_10.3839933_lat_53.9180845_Kronberg_0_3.png
# Background added: lon_10.3839933_lat_53.9180845_Kronberg_0_4.png
# Background added: lon_10.3839933_lat_53.9180845_Kronberg_2_3.png
# Parking added: lon_10.3839933_lat_53.9180845_Kronberg_3_0.png
# Parking added: lon_10.3839933_lat_53.9180845_Kronberg_3_1.png
# Parking added: lon_10.3839933_lat_53.9180845_Kronberg_3_2.png
# Background added: lon_10.3839933_lat_53.9180845_Kronberg_4_3.png
# Background added: lon_10.3887051_lat_53.9187746_Kronberg_0_0.png
# Background added: lon_10.3887051_lat_53.9187746_Kronberg_0_1.png
# Background added: lon_10.3887051_lat_53.9187746_Kronberg_1_0.png
# Parking added: lon_10.3887051_lat_53.9187746_Kronberg_1_2.png
# Parking added: lon_10.3887051_lat_53.9187746_Kronberg_1_3.png
# Parking added: lon_10.3887051_lat_53.9187746_Kronberg_1_4.png
# Background added: lon_10.3887051_lat_53.9187746_Kronberg_3_1.png
# Background added: lon_10.3887051_lat_53.9187746_Kronberg_3_4.png
# Background added: lon_10.3887051_lat_53.9187746_Kronberg_4_0.png
# Parking added: lon_10.4530068_lat_50.4711034_Thüringer Tor_2_0.png
# Background added: lon_10.4530068_lat_50.4711034_Thüringer Tor_2_1.png
# Background added: lon_10.4530068_lat_50.4711034_Thüringer Tor_2_2.png
# Background added: lon_10.4530068_lat_50.4711034_Thüringer Tor_2_4.png
# Parking added: lon_10.4530068_lat_50.4711034_Thüringer Tor_3_0.png
# Background added: lon_10.4530068_lat_50.4711034_Thüringer Tor_3_3.png
# Background added: lon_10.4530068_lat_50.4711034_Thüringer Tor_4_0.png
# Background added: lon_10.4530068_lat_50.4711034_Thüringer Tor_4_1.png
# Background added: lon_10.4530068_lat_50.4711034_Thüringer Tor_4_2.png
# Background added: lon_10.4530068_lat_50.4711034_Thüringer Tor_4_3.png
# Background added: lon_10.4537487_lat_50.4697772_Thüringer Tor_1_0.png
# Parking added: lon_10.4537487_lat_50.4697772_Thüringer Tor_2_0.png
# Parking added: lon_10.4537487_lat_50.4697772_Thüringer Tor_2_1.png
# Parking added: lon_10.4537487_lat_50.4697772_Thüringer Tor_3_1.png
# Background added: lon_10.4537487_lat_50.4697772_Thüringer Tor_3_2.png
# Background added: lon_10.4537487_lat_50.4697772_Thüringer Tor_3_3.png
# Background added: lon_10.4537487_lat_50.4697772_Thüringer Tor_3_4.png
# Background added: lon_10.4537487_lat_50.4697772_Thüringer Tor_4_4.png
# Background added: lon_10.5080423_lat_52.0491815_Werla_0_0.png
# Background added: lon_10.5080423_lat_52.0491815_Werla_0_2.png
# Parking added: lon_10.5080423_lat_52.0491815_Werla_0_3.png
# Background added: lon_10.5080423_lat_52.0491815_Werla_1_1.png
# Parking added: lon_10.5080423_lat_52.0491815_Werla_1_3.png
# Background added: lon_10.5080423_lat_52.0491815_Werla_1_4.png
# Background added: lon_10.5080423_lat_52.0491815_Werla_2_2.png
# Parking added: lon_10.5080423_lat_52.0491815_Werla_2_3.png
# Background added: lon_10.5080423_lat_52.0491815_Werla_3_4.png
# Background added: lon_10.5080423_lat_52.0491815_Werla_4_1.png
# Background added: lon_10.5152409_lat_52.0369274_Ziegenberg_0_1.png
# Parking added: lon_10.5152409_lat_52.0369274_Ziegenberg_1_0.png
# Parking added: lon_10.5152409_lat_52.0369274_Ziegenberg_1_1.png
# Background added: lon_10.5152409_lat_52.0369274_Ziegenberg_1_3.png
# Parking added: lon_10.5152409_lat_52.0369274_Ziegenberg_2_0.png
# Parking added: lon_10.5152409_lat_52.0369274_Ziegenberg_2_1.png
# Background added: lon_10.5152409_lat_52.0369274_Ziegenberg_3_1.png
# Background added: lon_10.5152409_lat_52.0369274_Ziegenberg_4_4.png
# Background added: lon_10.5316238_lat_50.5995636_Dolmar_0_2.png
# Background added: lon_10.5316238_lat_50.5995636_Dolmar_0_3.png
# Parking added: lon_10.5316238_lat_50.5995636_Dolmar_1_1.png
# Parking added: lon_10.5316238_lat_50.5995636_Dolmar_2_1.png
# Background added: lon_10.5316238_lat_50.5995636_Dolmar_4_2.png
# Parking added: lon_10.6158177_lat_53.5536922_Tramm_1_1.png
# Parking added: lon_10.6158177_lat_53.5536922_Tramm_1_2.png
# Background added: lon_10.6158177_lat_53.5536922_Tramm_2_0.png
# Parking added: lon_10.6158177_lat_53.5536922_Tramm_2_1.png
# Parking added: lon_10.6158177_lat_53.5536922_Tramm_2_2.png
# Background added: lon_10.6158177_lat_53.5536922_Tramm_2_3.png
# Background added: lon_10.6158177_lat_53.5536922_Tramm_4_3.png
# Background added: lon_10.6222227_lat_51.4346456_None_1_2.png
# Background added: lon_10.6222227_lat_51.4346456_None_2_0.png
# Background added: lon_10.6222227_lat_51.4346456_None_2_2.png
# Parking added: lon_10.6222227_lat_51.4346456_None_3_1.png
# Parking added: lon_10.6222227_lat_51.4346456_None_3_2.png
# Background added: lon_10.6222227_lat_51.4346456_None_3_3.png
# Parking added: lon_10.6222227_lat_51.4346456_None_4_2.png
# Background added: lon_10.6320454_lat_52.2513501_Herzogsberge_0_4.png
# Parking added: lon_10.6320454_lat_52.2513501_Herzogsberge_1_2.png
# Parking added: lon_10.6320454_lat_52.2513501_Herzogsberge_2_1.png
# Parking added: lon_10.6320454_lat_52.2513501_Herzogsberge_2_2.png
# Parking added: lon_10.6320454_lat_52.2513501_Herzogsberge_2_3.png
# Background added: lon_10.6320454_lat_52.2513501_Herzogsberge_3_1.png
# Background added: lon_10.6320454_lat_52.2513501_Herzogsberge_4_0.png
# Background added: lon_10.6320454_lat_52.2513501_Herzogsberge_4_1.png
# Background added: lon_10.6320454_lat_52.2513501_Herzogsberge_4_3.png
# Background added: lon_10.6333468_lat_52.2512109_Herzogsberge_1_3.png
# Parking added: lon_10.6333468_lat_52.2512109_Herzogsberge_2_3.png
# Parking added: lon_10.6333468_lat_52.2512109_Herzogsberge_3_2.png
# Parking added: lon_10.6333468_lat_52.2512109_Herzogsberge_3_3.png
# Parking added: lon_10.6333468_lat_52.2512109_Herzogsberge_3_4.png
# Background added: lon_10.6333468_lat_52.2512109_Herzogsberge_4_4.png
# Background added: lon_10.6559369_lat_52.3098001_Essehof Nord_0_1.png
# Background added: lon_10.6559369_lat_52.3098001_Essehof Nord_0_3.png
# Background added: lon_10.6559369_lat_52.3098001_Essehof Nord_1_4.png
# Background added: lon_10.6559369_lat_52.3098001_Essehof Nord_2_0.png
# Parking added: lon_10.6559369_lat_52.3098001_Essehof Nord_2_2.png
# Parking added: lon_10.6559369_lat_52.3098001_Essehof Nord_2_3.png
# Parking added: lon_10.6559369_lat_52.3098001_Essehof Nord_2_4.png
# Background added: lon_10.6559369_lat_52.3098001_Essehof Nord_3_4.png
# Background added: lon_10.6559369_lat_52.3098001_Essehof Nord_4_1.png
# Background added: lon_10.6690769_lat_53.8037285_Auf dem Karkfeld_0_1.png
# Background added: lon_10.6690769_lat_53.8037285_Auf dem Karkfeld_0_4.png
# Parking added: lon_10.6690769_lat_53.8037285_Auf dem Karkfeld_1_1.png
# Parking added: lon_10.6690769_lat_53.8037285_Auf dem Karkfeld_2_1.png
# Parking added: lon_10.6690769_lat_53.8037285_Auf dem Karkfeld_2_2.png
# Background added: lon_10.6690769_lat_53.8037285_Auf dem Karkfeld_3_0.png
# Background added: lon_10.6690769_lat_53.8037285_Auf dem Karkfeld_4_0.png
# Background added: lon_10.6690769_lat_53.8037285_Auf dem Karkfeld_4_4.png
# Parking added: lon_10.675298_lat_53.8007703_Auf dem Karkfeld_1_2.png
# Parking added: lon_10.675298_lat_53.8007703_Auf dem Karkfeld_1_3.png
# Parking added: lon_10.675298_lat_53.8007703_Auf dem Karkfeld_2_3.png
# Background added: lon_10.675298_lat_53.8007703_Auf dem Karkfeld_3_3.png
# Background added: lon_10.7298729_lat_50.5605634_Adlersberg_1_1.png
# Background added: lon_10.7298729_lat_50.5605634_Adlersberg_1_4.png
# Background added: lon_10.7298729_lat_50.5605634_Adlersberg_2_0.png
# Parking added: lon_10.7298729_lat_50.5605634_Adlersberg_2_1.png
# Parking added: lon_10.7298729_lat_50.5605634_Adlersberg_3_1.png
# Background added: lon_10.7298729_lat_50.5605634_Adlersberg_3_4.png
# Background added: lon_10.7298729_lat_50.5605634_Adlersberg_4_4.png
# Background added: lon_10.7306355_lat_50.559048_Adlersberg_0_1.png
# Background added: lon_10.7306355_lat_50.559048_Adlersberg_0_2.png
# Background added: lon_10.7306355_lat_50.559048_Adlersberg_0_3.png
# Background added: lon_10.7306355_lat_50.559048_Adlersberg_1_4.png
# Background added: lon_10.7306355_lat_50.559048_Adlersberg_2_2.png
# Parking added: lon_10.7306355_lat_50.559048_Adlersberg_2_4.png
# Background added: lon_10.7306355_lat_50.559048_Adlersberg_3_0.png
# Parking added: lon_10.7306355_lat_50.559048_Adlersberg_3_4.png
# Background added: lon_10.7306355_lat_50.559048_Adlersberg_4_2.png
# Background added: lon_10.7814825_lat_51.4714133_Rastplatz Kesselberg-Nord_0_0.png
# Background added: lon_10.7814825_lat_51.4714133_Rastplatz Kesselberg-Nord_0_2.png
# Background added: lon_10.7814825_lat_51.4714133_Rastplatz Kesselberg-Nord_1_3.png
# Background added: lon_10.7814825_lat_51.4714133_Rastplatz Kesselberg-Nord_1_4.png
# Parking added: lon_10.7814825_lat_51.4714133_Rastplatz Kesselberg-Nord_2_1.png
# Parking added: lon_10.7814825_lat_51.4714133_Rastplatz Kesselberg-Nord_2_2.png
# Parking added: lon_10.7814825_lat_51.4714133_Rastplatz Kesselberg-Nord_3_1.png
# Parking added: lon_10.7814825_lat_51.4714133_Rastplatz Kesselberg-Nord_3_2.png
# Parking added: lon_10.7814825_lat_51.4714133_Rastplatz Kesselberg-Nord_3_3.png
# Parking added: lon_10.7814825_lat_51.4714133_Rastplatz Kesselberg-Nord_4_3.png
# Background added: lon_10.8080134_lat_50.8782277_Drei Gleichen_1_2.png
# Background added: lon_10.8080134_lat_50.8782277_Drei Gleichen_2_0.png
# Parking added: lon_10.8080134_lat_50.8782277_Drei Gleichen_2_1.png
# Parking added: lon_10.8080134_lat_50.8782277_Drei Gleichen_2_2.png
# Background added: lon_10.8080134_lat_50.8782277_Drei Gleichen_2_4.png
# Parking added: lon_10.8080134_lat_50.8782277_Drei Gleichen_3_1.png
# Parking added: lon_10.8080134_lat_50.8782277_Drei Gleichen_3_2.png
# Background added: lon_10.8414075_lat_52.3057505_Uhry_0_0.png
# Parking added: lon_10.8414075_lat_52.3057505_Uhry_2_1.png
# Parking added: lon_10.8414075_lat_52.3057505_Uhry_2_2.png
# Parking added: lon_10.8414075_lat_52.3057505_Uhry_2_3.png
# Parking added: lon_10.8414075_lat_52.3057505_Uhry_3_1.png
# Parking added: lon_10.8414075_lat_52.3057505_Uhry_3_2.png
# Parking added: lon_10.8414075_lat_52.3057505_Uhry_3_3.png
# Background added: lon_10.856376_lat_54.1551497_Hasselburger Mühle_0_0.png
# Background added: lon_10.856376_lat_54.1551497_Hasselburger Mühle_0_1.png
# Parking added: lon_10.856376_lat_54.1551497_Hasselburger Mühle_2_2.png
# Background added: lon_10.856376_lat_54.1551497_Hasselburger Mühle_2_3.png
# Background added: lon_10.856376_lat_54.1551497_Hasselburger Mühle_3_1.png
# Background added: lon_10.856376_lat_54.1551497_Hasselburger Mühle_3_3.png
# Background added: lon_10.856376_lat_54.1551497_Hasselburger Mühle_4_4.png
# Parking added: lon_10.891129_lat_54.2412856_Damlos_0_0.png
# Parking added: lon_10.891129_lat_54.2412856_Damlos_0_1.png
# Parking added: lon_10.891129_lat_54.2412856_Damlos_1_0.png
# Parking added: lon_10.891129_lat_54.2412856_Damlos_1_1.png
# Background added: lon_10.891129_lat_54.2412856_Damlos_2_1.png
# Background added: lon_10.891129_lat_54.2412856_Damlos_2_4.png
# Parking added: lon_10.9544554_lat_50.9407623_Erfurter Becken - Ost_2_1.png
# Background added: lon_10.9544554_lat_50.9407623_Erfurter Becken - Ost_3_2.png
# Background added: lon_10.9544554_lat_50.9407623_Erfurter Becken - Ost_4_1.png
# Background added: lon_10.9549595_lat_50.9380515_Erfurter Becken - West_0_4.png
# Parking added: lon_10.9549595_lat_50.9380515_Erfurter Becken - West_1_2.png
# Parking added: lon_10.9549595_lat_50.9380515_Erfurter Becken - West_2_1.png
# Parking added: lon_10.9549595_lat_50.9380515_Erfurter Becken - West_2_2.png
# Background added: lon_10.9549595_lat_50.9380515_Erfurter Becken - West_4_1.png
# Background added: lon_10.9810513_lat_54.3627005_Ostseeblick_0_1.png
# Background added: lon_10.9810513_lat_54.3627005_Ostseeblick_0_4.png
# Parking added: lon_10.9810513_lat_54.3627005_Ostseeblick_3_3.png
# Parking added: lon_10.9810513_lat_54.3627005_Ostseeblick_3_4.png
# Background added: lon_10.9814416_lat_54.3623714_Ostseeblick_0_0.png
# Background added: lon_10.9814416_lat_54.3623714_Ostseeblick_0_3.png
# Parking added: lon_10.9814416_lat_54.3623714_Ostseeblick_1_0.png
# Parking added: lon_10.9814416_lat_54.3623714_Ostseeblick_2_0.png
# Parking added: lon_10.9814416_lat_54.3623714_Ostseeblick_2_1.png
# Parking added: lon_10.9814416_lat_54.3623714_Ostseeblick_2_2.png
# Background added: lon_11.0100226_lat_50.8366037_Dornheimer Rieth_0_3.png
# Background added: lon_11.0100226_lat_50.8366037_Dornheimer Rieth_1_1.png
# Background added: lon_11.0100226_lat_50.8366037_Dornheimer Rieth_1_2.png
# Parking added: lon_11.0100226_lat_50.8366037_Dornheimer Rieth_2_0.png
# Background added: lon_11.0100226_lat_50.8366037_Dornheimer Rieth_3_1.png
# Background added: lon_11.0100226_lat_50.8366037_Dornheimer Rieth_3_4.png
# Background added: lon_11.0100226_lat_50.8366037_Dornheimer Rieth_4_2.png
# Background added: lon_11.0100226_lat_50.8366037_Dornheimer Rieth_4_3.png
# Parking added: lon_11.0102562_lat_50.8353109_Dornheimer Rieth_1_4.png
# Background added: lon_11.0102562_lat_50.8353109_Dornheimer Rieth_2_2.png
# Parking added: lon_11.0102562_lat_50.8353109_Dornheimer Rieth_2_3.png
# Parking added: lon_11.0102562_lat_50.8353109_Dornheimer Rieth_2_4.png
# Background added: lon_11.0102562_lat_50.8353109_Dornheimer Rieth_3_2.png
# Background added: lon_11.0102562_lat_50.8353109_Dornheimer Rieth_3_3.png
# Background added: lon_11.0102562_lat_50.8353109_Dornheimer Rieth_3_4.png
# Background added: lon_11.042875_lat_51.4666501_Goldene Aue_0_0.png
# Background added: lon_11.042875_lat_51.4666501_Goldene Aue_0_3.png
# Background added: lon_11.042875_lat_51.4666501_Goldene Aue_0_4.png
# Background added: lon_11.042875_lat_51.4666501_Goldene Aue_2_0.png
# Background added: lon_11.042875_lat_51.4666501_Goldene Aue_2_4.png
# Parking added: lon_11.042875_lat_51.4666501_Goldene Aue_3_3.png
# Background added: lon_11.042875_lat_51.4666501_Goldene Aue_4_0.png
# Parking added: lon_11.042875_lat_51.4666501_Goldene Aue_4_2.png
# Parking added: lon_11.042875_lat_51.4666501_Goldene Aue_4_3.png
# Background added: lon_11.042875_lat_51.4666501_Goldene Aue_4_4.png
# Background added: lon_11.0467665_lat_51.4688222_Goldene Aue_0_4.png
# Parking added: lon_11.0467665_lat_51.4688222_Goldene Aue_1_2.png
# Parking added: lon_11.0467665_lat_51.4688222_Goldene Aue_1_3.png
# Background added: lon_11.0467665_lat_51.4688222_Goldene Aue_2_0.png
# Background added: lon_11.0467665_lat_51.4688222_Goldene Aue_3_0.png
# Background added: lon_11.0467665_lat_51.4688222_Goldene Aue_4_0.png
# Parking added: lon_11.0524687_lat_52.2204778_Waldkater_0_0.png
# Parking added: lon_11.0524687_lat_52.2204778_Waldkater_0_1.png
# Parking added: lon_11.0524687_lat_52.2204778_Waldkater_1_0.png
# Parking added: lon_11.0524687_lat_52.2204778_Waldkater_1_1.png
# Parking added: lon_11.0524687_lat_52.2204778_Waldkater_2_2.png
# Parking added: lon_11.0524687_lat_52.2204778_Waldkater_2_3.png
# Parking added: lon_11.0524687_lat_52.2204778_Waldkater_3_4.png
# Background added: lon_11.0708191_lat_50.9099067_Willroder Forst_1_1.png
# Parking added: lon_11.0708191_lat_50.9099067_Willroder Forst_1_2.png
# Parking added: lon_11.0708191_lat_50.9099067_Willroder Forst_1_3.png
# Parking added: lon_11.0708191_lat_50.9099067_Willroder Forst_1_4.png
# Parking added: lon_11.0708191_lat_50.9099067_Willroder Forst_2_2.png
# Background added: lon_11.0708191_lat_50.9099067_Willroder Forst_2_4.png
# Background added: lon_11.0708191_lat_50.9099067_Willroder Forst_3_0.png
# Background added: lon_11.0708191_lat_50.9099067_Willroder Forst_3_4.png
# Background added: lon_11.070887_lat_50.9105953_Willroder Forst_0_0.png
# Background added: lon_11.070887_lat_50.9105953_Willroder Forst_0_1.png
# Background added: lon_11.070887_lat_50.9105953_Willroder Forst_1_0.png
# Background added: lon_11.070887_lat_50.9105953_Willroder Forst_1_3.png
# Background added: lon_11.070887_lat_50.9105953_Willroder Forst_1_4.png
# Parking added: lon_11.070887_lat_50.9105953_Willroder Forst_3_2.png
# Parking added: lon_11.070887_lat_50.9105953_Willroder Forst_3_3.png
# Background added: lon_11.070887_lat_50.9105953_Willroder Forst_4_4.png
# Background added: lon_11.1650168_lat_51.1280879_Thüringer Becken West_0_1.png
# Parking added: lon_11.1650168_lat_51.1280879_Thüringer Becken West_0_3.png
# Background added: lon_11.1650168_lat_51.1280879_Thüringer Becken West_0_4.png
# Background added: lon_11.1650168_lat_51.1280879_Thüringer Becken West_1_1.png
# Background added: lon_11.1650168_lat_51.1280879_Thüringer Becken West_1_2.png
# Parking added: lon_11.1650168_lat_51.1280879_Thüringer Becken West_1_3.png
# Background added: lon_11.1650168_lat_51.1280879_Thüringer Becken West_4_1.png
# Background added: lon_11.1650168_lat_51.1280879_Thüringer Becken West_4_2.png
# Background added: lon_11.1650168_lat_51.1280879_Thüringer Becken West_4_3.png
# Background added: lon_11.1650168_lat_51.1280879_Thüringer Becken West_4_4.png
# Parking added: lon_11.165322_lat_51.1277215_Thüringer Becken Ost_2_2.png
# Parking added: lon_11.165322_lat_51.1277215_Thüringer Becken Ost_3_1.png
# Parking added: lon_11.165322_lat_51.1277215_Thüringer Becken Ost_3_2.png
# Background added: lon_11.165322_lat_51.1277215_Thüringer Becken Ost_4_3.png
# Background added: lon_11.2514815_lat_51.3300061_Hohe Schrecke Ost_1_0.png
# Background added: lon_11.2514815_lat_51.3300061_Hohe Schrecke Ost_1_1.png
# Parking added: lon_11.2514815_lat_51.3300061_Hohe Schrecke Ost_1_2.png
# Parking added: lon_11.2514815_lat_51.3300061_Hohe Schrecke Ost_1_3.png
# Parking added: lon_11.2514815_lat_51.3300061_Hohe Schrecke Ost_2_1.png
# Parking added: lon_11.2514815_lat_51.3300061_Hohe Schrecke Ost_2_2.png
# Parking added: lon_11.2514815_lat_51.3300061_Hohe Schrecke Ost_2_3.png
# Background added: lon_11.2514815_lat_51.3300061_Hohe Schrecke Ost_4_0.png
# Background added: lon_11.2514815_lat_51.3300061_Hohe Schrecke Ost_4_1.png
# Background added: lon_11.2514815_lat_51.3300061_Hohe Schrecke Ost_4_3.png
# Background added: lon_11.2514815_lat_51.3300061_Hohe Schrecke Ost_4_4.png
# Background added: lon_11.3531491_lat_50.9378362_Habichtsfang_0_4.png
# Background added: lon_11.3531491_lat_50.9378362_Habichtsfang_1_0.png
# Background added: lon_11.3531491_lat_50.9378362_Habichtsfang_1_2.png
# Background added: lon_11.3531491_lat_50.9378362_Habichtsfang_2_0.png
# Background added: lon_11.3531491_lat_50.9378362_Habichtsfang_3_0.png
# Parking added: lon_11.3531491_lat_50.9378362_Habichtsfang_3_1.png
# Parking added: lon_11.3531491_lat_50.9378362_Habichtsfang_3_2.png
# Parking added: lon_11.3531491_lat_50.9378362_Habichtsfang_3_3.png
# Background added: lon_11.3570959_lat_50.9374444_Habichtsfang_0_4.png
# Background added: lon_11.3570959_lat_50.9374444_Habichtsfang_1_0.png
# Parking added: lon_11.3570959_lat_50.9374444_Habichtsfang_4_1.png
# Parking added: lon_11.3570959_lat_50.9374444_Habichtsfang_4_2.png
# Parking added: lon_11.3570959_lat_50.9374444_Habichtsfang_4_3.png
# Background added: lon_11.6915015_lat_51.9435264_Dreihöhenberg_0_2.png
# Background added: lon_11.6915015_lat_51.9435264_Dreihöhenberg_0_4.png
# Background added: lon_11.6915015_lat_51.9435264_Dreihöhenberg_2_0.png
# Parking added: lon_11.6915015_lat_51.9435264_Dreihöhenberg_2_3.png
# Parking added: lon_11.6915015_lat_51.9435264_Dreihöhenberg_3_3.png
# Parking added: lon_11.6915015_lat_51.9435264_Dreihöhenberg_3_4.png
# Background added: lon_11.6940307_lat_51.9416459_Dreihöhenberg_0_0.png
# Background added: lon_11.6940307_lat_51.9416459_Dreihöhenberg_0_3.png
# Background added: lon_11.6940307_lat_51.9416459_Dreihöhenberg_1_3.png
# Parking added: lon_11.6940307_lat_51.9416459_Dreihöhenberg_2_4.png
# Background added: lon_11.6940307_lat_51.9416459_Dreihöhenberg_3_0.png
# Parking added: lon_11.6940307_lat_51.9416459_Dreihöhenberg_3_4.png
# Parking added: lon_11.6940307_lat_51.9416459_Dreihöhenberg_4_4.png
# Parking added: lon_11.7099428_lat_50.8741147_Rodablick_0_1.png
# Parking added: lon_11.7099428_lat_50.8741147_Rodablick_0_2.png
# Parking added: lon_11.7099428_lat_50.8741147_Rodablick_0_3.png
# Background added: lon_11.7099428_lat_50.8741147_Rodablick_0_4.png
# Parking added: lon_11.7099428_lat_50.8741147_Rodablick_1_2.png
# Background added: lon_11.7099428_lat_50.8741147_Rodablick_2_3.png
# Background added: lon_11.721026_lat_51.4012188_Querfurter Platte Nord_0_1.png
# Background added: lon_11.721026_lat_51.4012188_Querfurter Platte Nord_0_2.png
# Background added: lon_11.721026_lat_51.4012188_Querfurter Platte Nord_0_4.png
# Background added: lon_11.721026_lat_51.4012188_Querfurter Platte Nord_1_0.png
# Background added: lon_11.721026_lat_51.4012188_Querfurter Platte Nord_1_3.png
# Background added: lon_11.721026_lat_51.4012188_Querfurter Platte Nord_2_0.png
# Parking added: lon_11.721026_lat_51.4012188_Querfurter Platte Nord_2_1.png
# Parking added: lon_11.721026_lat_51.4012188_Querfurter Platte Nord_2_2.png
# Parking added: lon_11.721026_lat_51.4012188_Querfurter Platte Nord_3_1.png
# Parking added: lon_11.721026_lat_51.4012188_Querfurter Platte Nord_3_2.png
# Background added: lon_11.721026_lat_51.4012188_Querfurter Platte Nord_3_3.png
# Background added: lon_11.721026_lat_51.4012188_Querfurter Platte Nord_3_4.png
# Background added: lon_11.8452583_lat_50.957723_Kuhberg_1_1.png
# Background added: lon_11.8452583_lat_50.957723_Kuhberg_1_3.png
# Parking added: lon_11.8452583_lat_50.957723_Kuhberg_2_2.png
# Parking added: lon_11.8452583_lat_50.957723_Kuhberg_2_3.png
# Parking added: lon_11.8452583_lat_50.957723_Kuhberg_3_1.png
# Parking added: lon_11.8452583_lat_50.957723_Kuhberg_3_2.png
# Background added: lon_11.8511459_lat_50.9610243_Kuhberg_0_0.png
# Background added: lon_11.8511459_lat_50.9610243_Kuhberg_0_1.png
# Background added: lon_11.8511459_lat_50.9610243_Kuhberg_0_3.png
# Parking added: lon_11.8511459_lat_50.9610243_Kuhberg_1_3.png
# Background added: lon_11.8511459_lat_50.9610243_Kuhberg_2_1.png
# Parking added: lon_11.8511459_lat_50.9610243_Kuhberg_2_2.png
# Parking added: lon_11.8511459_lat_50.9610243_Kuhberg_2_3.png
# Background added: lon_11.8511459_lat_50.9610243_Kuhberg_2_4.png
# Background added: lon_11.8511459_lat_50.9610243_Kuhberg_3_2.png
# Background added: lon_11.8511459_lat_50.9610243_Kuhberg_4_3.png
# Background added: lon_11.8562646_lat_51.4660138_Pappelgrund_1_1.png
# Background added: lon_11.8562646_lat_51.4660138_Pappelgrund_2_0.png
# Background added: lon_11.8562646_lat_51.4660138_Pappelgrund_3_0.png
# Parking added: lon_11.8562646_lat_51.4660138_Pappelgrund_3_3.png
# Background added: lon_11.8562646_lat_51.4660138_Pappelgrund_4_1.png
# Parking added: lon_11.8562646_lat_51.4660138_Pappelgrund_4_3.png
# Background added: lon_11.857285_lat_51.4667145_Pappelgrund_0_1.png
# Parking added: lon_11.857285_lat_51.4667145_Pappelgrund_1_3.png
# Parking added: lon_11.857285_lat_51.4667145_Pappelgrund_1_4.png
# Parking added: lon_11.857285_lat_51.4667145_Pappelgrund_2_4.png
# Parking added: lon_11.8732122_lat_50.759018_Rodaborn_0_3.png
# Background added: lon_11.8732122_lat_50.759018_Rodaborn_1_1.png
# Parking added: lon_11.8732122_lat_50.759018_Rodaborn_1_2.png
# Parking added: lon_11.8732122_lat_50.759018_Rodaborn_1_3.png
# Background added: lon_11.8732122_lat_50.759018_Rodaborn_2_0.png
# Parking added: lon_11.8732122_lat_50.759018_Rodaborn_2_1.png
# Parking added: lon_11.8732122_lat_50.759018_Rodaborn_2_2.png
# Background added: lon_11.8732122_lat_50.759018_Rodaborn_3_0.png
# Background added: lon_11.8732122_lat_50.759018_Rodaborn_3_1.png
# Background added: lon_11.8748503_lat_50.7596459_Rodaborn_1_3.png
# Parking added: lon_11.8748503_lat_50.7596459_Rodaborn_2_2.png
# Background added: lon_11.8748503_lat_50.7596459_Rodaborn_2_4.png
# Parking added: lon_11.8748503_lat_50.7596459_Rodaborn_3_2.png
# Parking added: lon_11.922428_lat_51.3459818_Geiseltal_0_0.png
# Parking added: lon_11.922428_lat_51.3459818_Geiseltal_1_0.png
# Background added: lon_11.922428_lat_51.3459818_Geiseltal_2_2.png
# Background added: lon_11.922428_lat_51.3459818_Geiseltal_3_0.png
# Background added: lon_11.922428_lat_51.3459818_Geiseltal_3_4.png
# Background added: lon_11.922428_lat_51.3459818_Geiseltal_4_3.png
# Parking added: lon_11.9228882_lat_51.346147_Geiseltal_0_2.png
# Parking added: lon_11.9228882_lat_51.346147_Geiseltal_1_3.png
# Background added: lon_11.9228882_lat_51.346147_Geiseltal_2_3.png
# Background added: lon_11.9228882_lat_51.346147_Geiseltal_3_1.png
# Background added: lon_11.997727_lat_51.2571166_Saaletal_0_0.png
# Background added: lon_11.997727_lat_51.2571166_Saaletal_0_4.png
# Background added: lon_11.997727_lat_51.2571166_Saaletal_2_0.png
# Parking added: lon_11.997727_lat_51.2571166_Saaletal_2_2.png
# Background added: lon_11.997727_lat_51.2571166_Saaletal_3_0.png
# Background added: lon_11.997727_lat_51.2571166_Saaletal_4_2.png
# Background added: lon_11.9979819_lat_51.2573447_Saaletal_0_1.png
# Background added: lon_11.9979819_lat_51.2573447_Saaletal_1_2.png
# Background added: lon_11.9979819_lat_51.2573447_Saaletal_1_4.png
# Parking added: lon_11.9979819_lat_51.2573447_Saaletal_3_2.png
# Parking added: lon_11.9979819_lat_51.2573447_Saaletal_3_3.png
# Background added: lon_11.9979819_lat_51.2573447_Saaletal_4_0.png
# Background added: lon_12.0026469_lat_51.5585101_Petersberg_0_3.png
# Parking added: lon_12.0026469_lat_51.5585101_Petersberg_1_3.png
# Background added: lon_12.0026469_lat_51.5585101_Petersberg_2_1.png
# Parking added: lon_12.0026469_lat_51.5585101_Petersberg_2_3.png
# Background added: lon_12.0026469_lat_51.5585101_Petersberg_3_2.png
# Background added: lon_12.0026469_lat_51.5585101_Petersberg_3_3.png
# Background added: lon_12.0055212_lat_51.5564663_Petersberg_0_0.png
# Parking added: lon_12.0055212_lat_51.5564663_Petersberg_0_3.png
# Parking added: lon_12.0055212_lat_51.5564663_Petersberg_0_4.png
# Background added: lon_12.0055212_lat_51.5564663_Petersberg_1_1.png
# Parking added: lon_12.0055212_lat_51.5564663_Petersberg_1_4.png
# Parking added: lon_12.0055212_lat_51.5564663_Petersberg_2_4.png
# Background added: lon_12.0055212_lat_51.5564663_Petersberg_3_1.png
# Background added: lon_12.0055212_lat_51.5564663_Petersberg_4_3.png
# Background added: lon_12.0315302_lat_51.2103528_Pörstental_0_2.png
# Background added: lon_12.0315302_lat_51.2103528_Pörstental_1_0.png
# Parking added: lon_12.0315302_lat_51.2103528_Pörstental_1_2.png
# Parking added: lon_12.0315302_lat_51.2103528_Pörstental_1_3.png
# Parking added: lon_12.0315302_lat_51.2103528_Pörstental_2_2.png
# Background added: lon_12.0315302_lat_51.2103528_Pörstental_3_1.png
# Background added: lon_12.0315302_lat_51.2103528_Pörstental_4_1.png
# Parking added: lon_12.0320348_lat_51.2100148_Pörstental_0_3.png
# Background added: lon_12.0320348_lat_51.2100148_Pörstental_1_0.png
# Parking added: lon_12.0320348_lat_51.2100148_Pörstental_1_3.png
# Background added: lon_12.0320348_lat_51.2100148_Pörstental_1_4.png
# Parking added: lon_12.0320348_lat_51.2100148_Pörstental_2_2.png
# Parking added: lon_12.0320348_lat_51.2100148_Pörstental_2_3.png
# Background added: lon_12.0320348_lat_51.2100148_Pörstental_4_0.png
# Parking added: lon_12.1076965_lat_51.4562754_Kabelsketal_0_2.png
# Parking added: lon_12.1076965_lat_51.4562754_Kabelsketal_0_3.png
# Parking added: lon_12.1076965_lat_51.4562754_Kabelsketal_1_2.png
# Parking added: lon_12.1076965_lat_51.4562754_Kabelsketal_1_3.png
# Background added: lon_12.1076965_lat_51.4562754_Kabelsketal_2_4.png
# Background added: lon_12.1076965_lat_51.4562754_Kabelsketal_3_3.png
# Background added: lon_12.1076965_lat_51.4562754_Kabelsketal_3_4.png
# Parking added: lon_12.1106921_lat_51.4564157_Kabelsketal_0_1.png
# Background added: lon_12.1106921_lat_51.4564157_Kabelsketal_0_4.png
# Parking added: lon_12.1106921_lat_51.4564157_Kabelsketal_1_1.png
# Background added: lon_12.1106921_lat_51.4564157_Kabelsketal_1_2.png
# Background added: lon_12.1106921_lat_51.4564157_Kabelsketal_2_2.png
# Background added: lon_12.1106921_lat_51.4564157_Kabelsketal_3_0.png
# Background added: lon_12.1106921_lat_51.4564157_Kabelsketal_3_2.png
# Background added: lon_12.1106921_lat_51.4564157_Kabelsketal_4_0.png
# Background added: lon_12.1106921_lat_51.4564157_Kabelsketal_4_4.png
# Background added: lon_12.2151522_lat_51.7240882_Mosigkauer Heide_0_4.png
# Parking added: lon_12.2151522_lat_51.7240882_Mosigkauer Heide_2_3.png
# Parking added: lon_12.2151522_lat_51.7240882_Mosigkauer Heide_3_3.png
# Background added: lon_12.2151522_lat_51.7240882_Mosigkauer Heide_4_0.png
# Parking added: lon_12.2160563_lat_51.7230405_Mosigkauer Heide_1_3.png
# Parking added: lon_12.2160563_lat_51.7230405_Mosigkauer Heide_2_3.png
# Parking added: lon_12.2160563_lat_51.7230405_Mosigkauer Heide_3_2.png
# Parking added: lon_12.2160563_lat_51.7230405_Mosigkauer Heide_3_3.png
# Background added: lon_12.2160563_lat_51.7230405_Mosigkauer Heide_4_4.png
# Background added: lon_12.274776_lat_53.1981473_Blesenberg_0_4.png
# Background added: lon_12.274776_lat_53.1981473_Blesenberg_1_0.png
# Parking added: lon_12.274776_lat_53.1981473_Blesenberg_1_1.png
# Parking added: lon_12.274776_lat_53.1981473_Blesenberg_1_2.png
# Background added: lon_12.274776_lat_53.1981473_Blesenberg_2_0.png
# Parking added: lon_12.274776_lat_53.1981473_Blesenberg_2_2.png
# Background added: lon_12.274776_lat_53.1981473_Blesenberg_4_3.png
# Background added: lon_12.276264_lat_53.1954521_Parkplatz Kiebitzberg_0_3.png
# Parking added: lon_12.276264_lat_53.1954521_Parkplatz Kiebitzberg_1_0.png
# Background added: lon_12.276264_lat_53.1954521_Parkplatz Kiebitzberg_1_2.png
# Background added: lon_12.276264_lat_53.1954521_Parkplatz Kiebitzberg_1_4.png
# Parking added: lon_12.276264_lat_53.1954521_Parkplatz Kiebitzberg_2_0.png
# Parking added: lon_12.276264_lat_53.1954521_Parkplatz Kiebitzberg_2_1.png
# Background added: lon_12.276264_lat_53.1954521_Parkplatz Kiebitzberg_2_4.png
# Parking added: lon_12.276264_lat_53.1954521_Parkplatz Kiebitzberg_3_1.png
# Background added: lon_12.3708436_lat_51.8676138_Kliekener Aue_0_1.png
# Parking added: lon_12.3708436_lat_51.8676138_Kliekener Aue_2_2.png
# Parking added: lon_12.3708436_lat_51.8676138_Kliekener Aue_2_3.png
# Parking added: lon_12.3708436_lat_51.8676138_Kliekener Aue_3_1.png
# Background added: lon_12.484777_lat_51.9700491_Rosselquelle_0_2.png
# Parking added: lon_12.484777_lat_51.9700491_Rosselquelle_1_4.png
# Parking added: lon_12.484777_lat_51.9700491_Rosselquelle_2_3.png
# Parking added: lon_12.484777_lat_51.9700491_Rosselquelle_2_4.png
# Background added: lon_12.484777_lat_51.9700491_Rosselquelle_3_1.png
# Parking added: lon_12.484777_lat_51.9700491_Rosselquelle_3_2.png
# Background added: lon_12.484777_lat_51.9700491_Rosselquelle_4_3.png
# Background added: lon_12.4887602_lat_51.9716412_Rosselquelle_1_4.png
# Background added: lon_12.4887602_lat_51.9716412_Rosselquelle_2_2.png
# Background added: lon_12.4887602_lat_51.9716412_Rosselquelle_2_3.png
# Parking added: lon_12.4887602_lat_51.9716412_Rosselquelle_3_2.png
# Parking added: lon_12.4887602_lat_51.9716412_Rosselquelle_3_3.png
# Parking added: lon_12.4887602_lat_51.9716412_Rosselquelle_4_1.png
# Background added: lon_12.516355_lat_52.3415843_Temnitz_0_3.png
# Background added: lon_12.516355_lat_52.3415843_Temnitz_1_0.png
# Background added: lon_12.516355_lat_52.3415843_Temnitz_1_4.png
# Parking added: lon_12.516355_lat_52.3415843_Temnitz_2_4.png
# Parking added: lon_12.516355_lat_52.3415843_Temnitz_3_3.png
# Parking added: lon_12.516355_lat_52.3415843_Temnitz_3_4.png
# Background added: lon_12.516355_lat_52.3415843_Temnitz_4_1.png
# Background added: lon_12.5174451_lat_52.3423742_Wendgräben_1_0.png
# Background added: lon_12.5174451_lat_52.3423742_Wendgräben_1_3.png
# Background added: lon_12.5174451_lat_52.3423742_Wendgräben_1_4.png
# Parking added: lon_12.5174451_lat_52.3423742_Wendgräben_2_1.png
# Parking added: lon_12.5174451_lat_52.3423742_Wendgräben_2_2.png
# Parking added: lon_12.5174451_lat_52.3423742_Wendgräben_3_1.png
# Background added: lon_12.5174451_lat_52.3423742_Wendgräben_3_4.png
# Background added: lon_12.5320732_lat_53.0701823_Autohof Herzsprung_0_0.png
# Parking added: lon_12.5320732_lat_53.0701823_Autohof Herzsprung_0_1.png
# Parking added: lon_12.5320732_lat_53.0701823_Autohof Herzsprung_0_2.png
# Parking added: lon_12.5320732_lat_53.0701823_Autohof Herzsprung_1_0.png
# Parking added: lon_12.5320732_lat_53.0701823_Autohof Herzsprung_1_1.png
# Parking added: lon_12.5320732_lat_53.0701823_Autohof Herzsprung_1_2.png
# Parking added: lon_12.5320732_lat_53.0701823_Autohof Herzsprung_1_3.png
# Background added: lon_12.5320732_lat_53.0701823_Autohof Herzsprung_1_4.png
# Parking added: lon_12.5320732_lat_53.0701823_Autohof Herzsprung_2_0.png
# Parking added: lon_12.5320732_lat_53.0701823_Autohof Herzsprung_2_1.png
# Background added: lon_12.5320732_lat_53.0701823_Autohof Herzsprung_2_4.png
# Parking added: lon_12.5320732_lat_53.0701823_Autohof Herzsprung_3_0.png
# Parking added: lon_12.5320732_lat_53.0701823_Autohof Herzsprung_3_1.png
# Parking added: lon_12.5320732_lat_53.0701823_Autohof Herzsprung_3_2.png
# Background added: lon_12.5320732_lat_53.0701823_Autohof Herzsprung_4_1.png
# Background added: lon_12.5905719_lat_53.0085503_Rossower Heide_0_3.png
# Parking added: lon_12.5905719_lat_53.0085503_Rossower Heide_1_1.png
# Parking added: lon_12.5905719_lat_53.0085503_Rossower Heide_1_2.png
# Parking added: lon_12.5905719_lat_53.0085503_Rossower Heide_2_1.png
# Parking added: lon_12.5905719_lat_53.0085503_Rossower Heide_2_2.png
# Background added: lon_12.5905719_lat_53.0085503_Rossower Heide_2_3.png
# Background added: lon_12.5905719_lat_53.0085503_Rossower Heide_2_4.png
# Background added: lon_12.5905719_lat_53.0085503_Rossower Heide_3_3.png
# Background added: lon_12.5905719_lat_53.0085503_Rossower Heide_3_4.png
# Background added: lon_12.6092758_lat_52.9913176_None_0_3.png
# Background added: lon_12.6092758_lat_52.9913176_None_3_0.png
# Background added: lon_12.6092758_lat_52.9913176_None_3_3.png
# Parking added: lon_12.6092758_lat_52.9913176_None_3_4.png
# Background added: lon_12.6092758_lat_52.9913176_None_4_2.png
# Parking added: lon_12.6092758_lat_52.9913176_None_4_3.png
# Parking added: lon_12.6092758_lat_52.9913176_None_4_4.png
# Parking added: lon_12.6186218_lat_52.0343636_Rabenstein_1_2.png
# Parking added: lon_12.6186218_lat_52.0343636_Rabenstein_1_3.png
# Parking added: lon_12.6186218_lat_52.0343636_Rabenstein_2_2.png
# Background added: lon_12.6186218_lat_52.0343636_Rabenstein_2_4.png
# Background added: lon_12.6186218_lat_52.0343636_Rabenstein_4_1.png
# Background added: lon_12.6186218_lat_52.0343636_Rabenstein_4_3.png
# Background added: lon_12.6186218_lat_52.0343636_Rabenstein_4_4.png
# Background added: lon_12.6318286_lat_52.0445002_Hagen_0_2.png
# Background added: lon_12.6318286_lat_52.0445002_Hagen_2_3.png
# Parking added: lon_12.6318286_lat_52.0445002_Hagen_3_0.png
# Parking added: lon_12.6318286_lat_52.0445002_Hagen_3_1.png
# Parking added: lon_12.6318286_lat_52.0445002_Hagen_4_0.png
# Parking added: lon_12.6318286_lat_52.0445002_Hagen_4_1.png
# Parking added: lon_12.6432698_lat_52.3390277_Grebser Heide_2_1.png
# Parking added: lon_12.6432698_lat_52.3390277_Grebser Heide_2_2.png
# Background added: lon_12.6432698_lat_52.3390277_Grebser Heide_2_4.png
# Parking added: lon_12.6432698_lat_52.3390277_Grebser Heide_3_1.png
# Parking added: lon_12.6432698_lat_52.3390277_Grebser Heide_3_2.png
# Parking added: lon_12.6432698_lat_52.3390277_Grebser Heide_3_3.png
# Background added: lon_12.6432698_lat_52.3390277_Grebser Heide_4_0.png
# Background added: lon_12.6446278_lat_52.3391265_Rietzer See_0_0.png
# Background added: lon_12.6446278_lat_52.3391265_Rietzer See_1_0.png
# Parking added: lon_12.6446278_lat_52.3391265_Rietzer See_1_1.png
# Parking added: lon_12.6446278_lat_52.3391265_Rietzer See_1_2.png
# Parking added: lon_12.6446278_lat_52.3391265_Rietzer See_2_1.png
# Parking added: lon_12.6446278_lat_52.3391265_Rietzer See_2_2.png
# Background added: lon_12.6446278_lat_52.3391265_Rietzer See_2_4.png
# Background added: lon_12.6446278_lat_52.3391265_Rietzer See_4_1.png
# Background added: lon_12.6446278_lat_52.3391265_Rietzer See_4_2.png
# Background added: lon_12.7580653_lat_52.8778128_Am Rhinluch_0_4.png
# Parking added: lon_12.7580653_lat_52.8778128_Am Rhinluch_1_2.png
# Parking added: lon_12.7580653_lat_52.8778128_Am Rhinluch_2_2.png
# Background added: lon_12.7580653_lat_52.8778128_Am Rhinluch_3_0.png
# Background added: lon_12.7580653_lat_52.8778128_Am Rhinluch_3_3.png
# Background added: lon_12.7580653_lat_52.8778128_Am Rhinluch_4_1.png
# Background added: lon_12.7580653_lat_52.8778128_Am Rhinluch_4_3.png
# Background added: lon_12.7592133_lat_52.8776048_Ruppiner See_0_0.png
# Background added: lon_12.7592133_lat_52.8776048_Ruppiner See_0_2.png
# Background added: lon_12.7592133_lat_52.8776048_Ruppiner See_1_3.png
# Parking added: lon_12.7592133_lat_52.8776048_Ruppiner See_2_4.png
# Background added: lon_12.7592133_lat_52.8776048_Ruppiner See_3_0.png
# Background added: lon_12.7592133_lat_52.8776048_Ruppiner See_3_1.png
# Parking added: lon_12.7592133_lat_52.8776048_Ruppiner See_3_4.png
# Background added: lon_12.7592133_lat_52.8776048_Ruppiner See_4_2.png
# Background added: lon_12.7592133_lat_52.8776048_Ruppiner See_4_4.png
# Background added: lon_12.8828606_lat_52.1997595_Zauche_0_0.png
# Background added: lon_12.8828606_lat_52.1997595_Zauche_0_4.png
# ...
# Parking added: lon_9.7123388_lat_50.4733475_Steinhauk_3_1.png
# Background added: lon_9.7123388_lat_50.4733475_Steinhauk_3_2.png
# Background added: lon_9.7123388_lat_50.4733475_Steinhauk_3_3.png
# Background added: lon_9.7123388_lat_50.4733475_Steinhauk_4_3.png
# Background added: lon_9.7216043_lat_50.461791_Riederberg_0_2.png
# Parking added: lon_9.7216043_lat_50.461791_Riederberg_2_2.png
# Background added: lon_9.7216043_lat_50.461791_Riederberg_3_1.png
# Parking added: lon_9.7216043_lat_50.461791_Riederberg_3_2.png
# Background added: lon_9.7216043_lat_50.461791_Riederberg_4_0.png
# Parking added: lon_9.7305344_lat_50.5458187_Rastplatz Röther Tannen_1_0.png
# Parking added: lon_9.7305344_lat_50.5458187_Rastplatz Röther Tannen_2_0.png
# Parking added: lon_9.7305344_lat_50.5458187_Rastplatz Röther Tannen_3_0.png
# Parking added: lon_9.7308396_lat_50.557363_Rastplatz Petersberg_1_1.png
# Parking added: lon_9.7308396_lat_50.557363_Rastplatz Petersberg_2_1.png
# Background added: lon_9.7308396_lat_50.557363_Rastplatz Petersberg_2_3.png
# Parking added: lon_9.7308396_lat_50.557363_Rastplatz Petersberg_3_1.png
# Background added: lon_9.7308396_lat_50.557363_Rastplatz Petersberg_4_1.png
# Background added: lon_9.7308396_lat_50.557363_Rastplatz Petersberg_4_3.png
# Background added: lon_9.7314325_lat_50.4012351_Rastplatz Rhöneiche_0_1.png
# Background added: lon_9.7314325_lat_50.4012351_Rastplatz Rhöneiche_0_3.png
# Background added: lon_9.7314325_lat_50.4012351_Rastplatz Rhöneiche_1_1.png
# Background added: lon_9.7314325_lat_50.4012351_Rastplatz Rhöneiche_1_2.png
# Parking added: lon_9.7314325_lat_50.4012351_Rastplatz Rhöneiche_1_4.png
# Parking added: lon_9.7314325_lat_50.4012351_Rastplatz Rhöneiche_2_4.png
# Parking added: lon_9.7314325_lat_50.4012351_Rastplatz Rhöneiche_3_4.png
# Background added: lon_9.7335412_lat_50.3854139_Rastplatz Am Forsthaus_0_0.png
# Background added: lon_9.7335412_lat_50.3854139_Rastplatz Am Forsthaus_0_3.png
# Background added: lon_9.7335412_lat_50.3854139_Rastplatz Am Forsthaus_1_2.png
# Parking added: lon_9.7335412_lat_50.3854139_Rastplatz Am Forsthaus_2_1.png
# Background added: lon_9.7335412_lat_50.3854139_Rastplatz Am Forsthaus_3_0.png
# Parking added: lon_9.7335412_lat_50.3854139_Rastplatz Am Forsthaus_3_1.png
# Background added: lon_9.7335412_lat_50.3854139_Rastplatz Am Forsthaus_3_3.png
# Background added: lon_9.7335412_lat_50.3854139_Rastplatz Am Forsthaus_3_4.png
# Parking added: lon_9.7394653_lat_50.5111262_Rastplatz Pilgerzell_0_1.png
# Background added: lon_9.7394653_lat_50.5111262_Rastplatz Pilgerzell_1_0.png
# Parking added: lon_9.7394653_lat_50.5111262_Rastplatz Pilgerzell_1_1.png
# Parking added: lon_9.7394653_lat_50.5111262_Rastplatz Pilgerzell_2_1.png
# Parking added: lon_9.7394653_lat_50.5111262_Rastplatz Pilgerzell_3_0.png
# Parking added: lon_9.7394653_lat_50.5111262_Rastplatz Pilgerzell_3_1.png
# Background added: lon_9.7447582_lat_50.4360417_Lohmühle_1_0.png
# Background added: lon_9.7447582_lat_50.4360417_Lohmühle_1_2.png
# Parking added: lon_9.7447582_lat_50.4360417_Lohmühle_1_4.png
# Background added: lon_9.7447582_lat_50.4360417_Lohmühle_2_1.png
# Parking added: lon_9.7447582_lat_50.4360417_Lohmühle_2_4.png
# Background added: lon_9.7447582_lat_50.4360417_Lohmühle_3_2.png
# Background added: lon_9.7447582_lat_50.4360417_Lohmühle_4_0.png
# Parking added: lon_9.7597687_lat_52.8860299_Steinbach_1_1.png
# Parking added: lon_9.7597687_lat_52.8860299_Steinbach_1_2.png
# Background added: lon_9.7597687_lat_52.8860299_Steinbach_1_3.png
# Parking added: lon_9.7597687_lat_52.8860299_Steinbach_2_1.png
# Background added: lon_9.7597687_lat_52.8860299_Steinbach_3_2.png
# Background added: lon_9.7685523_lat_53.7077592_Forst Rantzau_0_3.png
# Background added: lon_9.7685523_lat_53.7077592_Forst Rantzau_0_4.png
# Parking added: lon_9.7685523_lat_53.7077592_Forst Rantzau_1_1.png
# Background added: lon_9.7685523_lat_53.7077592_Forst Rantzau_1_4.png
# Parking added: lon_9.7685523_lat_53.7077592_Forst Rantzau_2_1.png
# Parking added: lon_9.7685523_lat_53.7077592_Forst Rantzau_2_2.png
# Background added: lon_9.7685523_lat_53.7077592_Forst Rantzau_3_1.png
# Parking added: lon_9.7685523_lat_53.7077592_Forst Rantzau_3_2.png
# Background added: lon_9.7685523_lat_53.7077592_Forst Rantzau_4_0.png
# Background added: lon_9.7685523_lat_53.7077592_Forst Rantzau_4_1.png
# Background added: lon_9.7695159_lat_52.5102873_Rastplatz Bissendorf Süd_0_1.png
# Background added: lon_9.7695159_lat_52.5102873_Rastplatz Bissendorf Süd_0_2.png
# Background added: lon_9.7695159_lat_52.5102873_Rastplatz Bissendorf Süd_0_4.png
# Background added: lon_9.7695159_lat_52.5102873_Rastplatz Bissendorf Süd_3_0.png
# Parking added: lon_9.7695159_lat_52.5102873_Rastplatz Bissendorf Süd_3_1.png
# Parking added: lon_9.7695159_lat_52.5102873_Rastplatz Bissendorf Süd_3_2.png
# Background added: lon_9.7695159_lat_52.5102873_Rastplatz Bissendorf Süd_3_3.png
# Background added: lon_9.7695159_lat_52.5102873_Rastplatz Bissendorf Süd_4_3.png
# Parking added: lon_9.7695186_lat_54.2841989_Ohe Ost_0_1.png
# Background added: lon_9.7695186_lat_54.2841989_Ohe Ost_0_2.png
# Background added: lon_9.7695186_lat_54.2841989_Ohe Ost_0_4.png
# Parking added: lon_9.7695186_lat_54.2841989_Ohe Ost_1_1.png
# Parking added: lon_9.7695186_lat_54.2841989_Ohe Ost_1_2.png
# Background added: lon_9.7695186_lat_54.2841989_Ohe Ost_1_3.png
# Parking added: lon_9.7695186_lat_54.2841989_Ohe Ost_2_1.png
# Parking added: lon_9.7695186_lat_54.2841989_Ohe Ost_2_2.png
# Background added: lon_9.7731665_lat_53.7040762_Forst Rantzau_0_1.png
# Parking added: lon_9.7731665_lat_53.7040762_Forst Rantzau_0_3.png
# Background added: lon_9.7731665_lat_53.7040762_Forst Rantzau_1_2.png
# Parking added: lon_9.7731665_lat_53.7040762_Forst Rantzau_1_3.png
# Parking added: lon_9.7731665_lat_53.7040762_Forst Rantzau_1_4.png
# Background added: lon_9.7731665_lat_53.7040762_Forst Rantzau_2_2.png
# Parking added: lon_9.7731665_lat_53.7040762_Forst Rantzau_2_3.png
# Parking added: lon_9.7731665_lat_53.7040762_Forst Rantzau_2_4.png
# Background added: lon_9.7731665_lat_53.7040762_Forst Rantzau_3_0.png
# Background added: lon_9.7731665_lat_53.7040762_Forst Rantzau_4_1.png
# Background added: lon_9.7749645_lat_52.577053_Up´n Bummelskampe_0_4.png
# Background added: lon_9.7749645_lat_52.577053_Up´n Bummelskampe_1_0.png
# Parking added: lon_9.7749645_lat_52.577053_Up´n Bummelskampe_1_2.png
# Parking added: lon_9.7749645_lat_52.577053_Up´n Bummelskampe_1_3.png
# Parking added: lon_9.7749645_lat_52.577053_Up´n Bummelskampe_2_3.png
# Parking added: lon_9.7749645_lat_52.577053_Up´n Bummelskampe_2_4.png
# Parking added: lon_9.7749645_lat_52.577053_Up´n Bummelskampe_3_3.png
# Parking added: lon_9.7749645_lat_52.577053_Up´n Bummelskampe_3_4.png
# Background added: lon_9.7749645_lat_52.577053_Up´n Bummelskampe_4_0.png
# Parking added: lon_9.7749645_lat_52.577053_Up´n Bummelskampe_4_4.png
# Background added: lon_9.7769111_lat_52.5742903_Osterriehe_0_2.png
# Background added: lon_9.7769111_lat_52.5742903_Osterriehe_0_3.png
# Background added: lon_9.7769111_lat_52.5742903_Osterriehe_1_0.png
# Parking added: lon_9.7769111_lat_52.5742903_Osterriehe_1_1.png
# Parking added: lon_9.7769111_lat_52.5742903_Osterriehe_2_0.png
# Parking added: lon_9.7769111_lat_52.5742903_Osterriehe_2_1.png
# Parking added: lon_9.7769111_lat_52.5742903_Osterriehe_3_1.png
# Parking added: lon_9.7769111_lat_52.5742903_Osterriehe_3_2.png
# Background added: lon_9.7769111_lat_52.5742903_Osterriehe_4_2.png
# Parking added: lon_9.7800847_lat_51.3955138_Hackelberg_0_1.png
# Parking added: lon_9.7800847_lat_51.3955138_Hackelberg_0_2.png
# Background added: lon_9.7800847_lat_51.3955138_Hackelberg_1_3.png
# Background added: lon_9.7800847_lat_51.3955138_Hackelberg_3_2.png
# Background added: lon_9.7800847_lat_51.3955138_Hackelberg_3_4.png
# Background added: lon_9.7910429_lat_52.9061454_Dorfmark_0_2.png
# Background added: lon_9.7910429_lat_52.9061454_Dorfmark_1_1.png
# Background added: lon_9.7910429_lat_52.9061454_Dorfmark_2_0.png
# Parking added: lon_9.7910429_lat_52.9061454_Dorfmark_3_1.png
# Parking added: lon_9.7910429_lat_52.9061454_Dorfmark_3_2.png
# Background added: lon_9.7910429_lat_52.9061454_Dorfmark_4_0.png
# Parking added: lon_9.7910429_lat_52.9061454_Dorfmark_4_1.png
# Parking added: lon_9.7910429_lat_52.9061454_Dorfmark_4_2.png
# Background added: lon_9.7910429_lat_52.9061454_Dorfmark_4_3.png
# Parking added: lon_9.8233956_lat_52.5072277_Springhorst_2_1.png
# Parking added: lon_9.8233956_lat_52.5072277_Springhorst_2_2.png
# Parking added: lon_9.8233956_lat_52.5072277_Springhorst_3_1.png
# Parking added: lon_9.8233956_lat_52.5072277_Springhorst_3_2.png
# Background added: lon_9.8233956_lat_52.5072277_Springhorst_3_4.png
# Background added: lon_9.8774063_lat_50.9046737_Seulingswald_1_1.png
# Background added: lon_9.8774063_lat_50.9046737_Seulingswald_1_4.png
# Parking added: lon_9.8774063_lat_50.9046737_Seulingswald_2_1.png
# Parking added: lon_9.8774063_lat_50.9046737_Seulingswald_3_0.png
# Parking added: lon_9.8774063_lat_50.9046737_Seulingswald_3_1.png
# Background added: lon_9.8774063_lat_50.9046737_Seulingswald_3_4.png
# Parking added: lon_9.8774063_lat_50.9046737_Seulingswald_4_0.png
# Parking added: lon_9.8798749_lat_53.3889549_Rosengarten_0_3.png
# Parking added: lon_9.8798749_lat_53.3889549_Rosengarten_1_2.png
# Parking added: lon_9.8798749_lat_53.3889549_Rosengarten_1_3.png
# Background added: lon_9.8798749_lat_53.3889549_Rosengarten_2_1.png
# Parking added: lon_9.8798749_lat_53.3889549_Rosengarten_2_2.png
# Background added: lon_9.8798749_lat_53.3889549_Rosengarten_2_3.png
# Background added: lon_9.8798749_lat_53.3889549_Rosengarten_3_1.png
# Background added: lon_9.8798749_lat_53.3889549_Rosengarten_4_1.png
# Background added: lon_9.8969787_lat_52.4106715_Altwarmbüchener Moor_0_2.png
# Background added: lon_9.8969787_lat_52.4106715_Altwarmbüchener Moor_0_4.png
# Parking added: lon_9.8969787_lat_52.4106715_Altwarmbüchener Moor_1_0.png
# Parking added: lon_9.8969787_lat_52.4106715_Altwarmbüchener Moor_1_1.png
# Background added: lon_9.8969787_lat_52.4106715_Altwarmbüchener Moor_1_4.png
# Parking added: lon_9.8969787_lat_52.4106715_Altwarmbüchener Moor_2_1.png
# Background added: lon_9.8969787_lat_52.4106715_Altwarmbüchener Moor_4_4.png
# Parking added: lon_9.9017252_lat_52.9620913_Abelbeck-Kuhbusch_2_1.png
# Parking added: lon_9.9017252_lat_52.9620913_Abelbeck-Kuhbusch_2_2.png
# Parking added: lon_9.9017252_lat_52.9620913_Abelbeck-Kuhbusch_3_0.png
# Parking added: lon_9.9017252_lat_52.9620913_Abelbeck-Kuhbusch_3_1.png
# Parking added: lon_9.9017252_lat_52.9620913_Abelbeck-Kuhbusch_3_2.png
# Background added: lon_9.9017252_lat_52.9620913_Abelbeck-Kuhbusch_4_1.png
# Background added: lon_9.9017252_lat_52.9620913_Abelbeck-Kuhbusch_4_3.png
# Background added: lon_9.9017252_lat_52.9620913_Abelbeck-Kuhbusch_4_4.png
# Background added: lon_9.9052624_lat_51.601567_Leineholz_0_1.png
# Background added: lon_9.9052624_lat_51.601567_Leineholz_1_1.png
# Parking added: lon_9.9052624_lat_51.601567_Leineholz_1_2.png
# Parking added: lon_9.9052624_lat_51.601567_Leineholz_1_3.png
# Background added: lon_9.9052624_lat_51.601567_Leineholz_2_0.png
# Parking added: lon_9.9052624_lat_51.601567_Leineholz_2_2.png
# Parking added: lon_9.9052624_lat_51.601567_Leineholz_2_3.png
# Parking added: lon_9.9052624_lat_51.601567_Leineholz_3_2.png
# Background added: lon_9.9052624_lat_51.601567_Leineholz_3_3.png
# Background added: lon_9.9052624_lat_51.601567_Leineholz_3_4.png
# Background added: lon_9.9052624_lat_51.601567_Leineholz_4_0.png
# Background added: lon_9.9052624_lat_51.601567_Leineholz_4_4.png
# Parking added: lon_9.9061758_lat_51.6070521_Leineholz_0_3.png
# Background added: lon_9.9061758_lat_51.6070521_Leineholz_0_4.png
# Background added: lon_9.9061758_lat_51.6070521_Leineholz_1_2.png
# Parking added: lon_9.9061758_lat_51.6070521_Leineholz_1_3.png
# Parking added: lon_9.9061758_lat_51.6070521_Leineholz_2_2.png
# Parking added: lon_9.9061758_lat_51.6070521_Leineholz_2_3.png
# Background added: lon_9.9208466_lat_53.8213382_Moorkaten-West_0_0.png
# Background added: lon_9.9208466_lat_53.8213382_Moorkaten-West_0_1.png
# Background added: lon_9.9208466_lat_53.8213382_Moorkaten-West_0_3.png
# Background added: lon_9.9208466_lat_53.8213382_Moorkaten-West_1_1.png
# Parking added: lon_9.9208466_lat_53.8213382_Moorkaten-West_2_2.png
# Parking added: lon_9.9208466_lat_53.8213382_Moorkaten-West_2_3.png
# Parking added: lon_9.9208466_lat_53.8213382_Moorkaten-West_3_3.png
# Parking added: lon_9.9242982_lat_53.8199638_Moorkaten-Ost_1_2.png
# Parking added: lon_9.9242982_lat_53.8199638_Moorkaten-Ost_1_3.png
# Background added: lon_9.9242982_lat_53.8199638_Moorkaten-Ost_1_4.png
# Background added: lon_9.9242982_lat_53.8199638_Moorkaten-Ost_2_0.png
# Parking added: lon_9.9242982_lat_53.8199638_Moorkaten-Ost_2_2.png
# Parking added: lon_9.9242982_lat_53.8199638_Moorkaten-Ost_2_3.png
# Background added: lon_9.9242982_lat_53.8199638_Moorkaten-Ost_3_0.png
# Parking added: lon_9.9242982_lat_53.8199638_Moorkaten-Ost_3_3.png
# Parking added: lon_9.9242982_lat_53.8199638_Moorkaten-Ost_3_4.png
# Parking added: lon_9.9242982_lat_53.8199638_Moorkaten-Ost_4_3.png
# Background added: lon_9.9242982_lat_53.8199638_Moorkaten-Ost_4_4.png
# Parking added: lon_9.9386962_lat_53.6678072_Bönningstedt_0_1.png
# Parking added: lon_9.9386962_lat_53.6678072_Bönningstedt_0_2.png
# Parking added: lon_9.9386962_lat_53.6678072_Bönningstedt_1_1.png
# Parking added: lon_9.9386962_lat_53.6678072_Bönningstedt_1_2.png
# Background added: lon_9.9386962_lat_53.6678072_Bönningstedt_2_3.png
# Background added: lon_9.9397588_lat_53.6702339_Bönningstedt_1_3.png
# Background added: lon_9.9397588_lat_53.6702339_Bönningstedt_1_4.png
# Parking added: lon_9.9397588_lat_53.6702339_Bönningstedt_2_0.png
# Parking added: lon_9.9397588_lat_53.6702339_Bönningstedt_2_1.png
# Background added: lon_9.9397588_lat_53.6702339_Bönningstedt_2_3.png
# Background added: lon_9.9397588_lat_53.6702339_Bönningstedt_2_4.png
# Parking added: lon_9.9397588_lat_53.6702339_Bönningstedt_3_0.png
# Parking added: lon_9.9397588_lat_53.6702339_Bönningstedt_3_1.png
# Background added: lon_9.9397588_lat_53.6702339_Bönningstedt_4_1.png
# Background added: lon_9.9397588_lat_53.6702339_Bönningstedt_4_2.png
# Background added: lon_9.9397588_lat_53.6702339_Bönningstedt_4_3.png
# Background added: lon_9.9398139_lat_53.9224456_Sielsbrook_0_0.png
# Parking added: lon_9.9398139_lat_53.9224456_Sielsbrook_0_1.png
# Parking added: lon_9.9398139_lat_53.9224456_Sielsbrook_1_0.png
# Parking added: lon_9.9398139_lat_53.9224456_Sielsbrook_1_1.png
# Background added: lon_9.9398139_lat_53.9224456_Sielsbrook_1_2.png
# Parking added: lon_9.9398139_lat_53.9224456_Sielsbrook_2_0.png
# Parking added: lon_9.9398139_lat_53.9224456_Sielsbrook_2_1.png
# Background added: lon_9.9398139_lat_53.9224456_Sielsbrook_2_4.png
# Parking added: lon_9.9398139_lat_53.9224456_Sielsbrook_3_0.png
# Background added: lon_9.9398139_lat_53.9224456_Sielsbrook_3_3.png
# Background added: lon_9.9423746_lat_51.7161249_Schlochau-Ost_0_2.png
# Parking added: lon_9.9423746_lat_51.7161249_Schlochau-Ost_2_1.png
# Parking added: lon_9.9423746_lat_51.7161249_Schlochau-Ost_3_0.png
# Parking added: lon_9.9423746_lat_51.7161249_Schlochau-Ost_3_1.png
# Parking added: lon_9.9423746_lat_51.7161249_Schlochau-Ost_4_1.png
# Parking added: lon_9.9534437_lat_53.3780392_Sunderblick_2_0.png
# Parking added: lon_9.9534437_lat_53.3780392_Sunderblick_2_1.png
# Parking added: lon_9.9534437_lat_53.3780392_Sunderblick_2_2.png
# Background added: lon_9.9534437_lat_53.3780392_Sunderblick_2_4.png
# Background added: lon_9.9534437_lat_53.3780392_Sunderblick_4_0.png
# Parking added: lon_9.9577331_lat_53.3781014_Hittfeld_0_0.png
# Parking added: lon_9.9577331_lat_53.3781014_Hittfeld_0_1.png
# Parking added: lon_9.9577331_lat_53.3781014_Hittfeld_0_2.png
# Background added: lon_9.9577331_lat_53.3781014_Hittfeld_0_4.png
# Parking added: lon_9.9577331_lat_53.3781014_Hittfeld_1_1.png
# Parking added: lon_9.9577331_lat_53.3781014_Hittfeld_1_2.png
# Background added: lon_9.9577331_lat_53.3781014_Hittfeld_2_3.png
# Finished copying at 2024-03-24 13:38:28 in 21.77 seconds.
# Total evaluated: 5793
# Total background discarded: 3871
# Total copied: 1922
# thereof parking: 921
# thereof background: 1001

# %% [markdown]
# From the 5,793 evaluated images, 3,871 were discarded as pure background images. The final dataset contains 1,922 images, of which 921 include parking spaces (both truck and car) as well as 1001 pure background images.

# %% [markdown]
# # Create train/val folder

# %%
def split_and_copy_data(base_input_path, test_size=0.2, random_seed=42):
    """
    Splits data into training and validation and copies images/masks to respective folders.
    """
    # Define directories
    images_dir = os.path.join(base_input_path, "images")
    masks_dir = os.path.join(base_input_path, "masks")
    train_image_dir = os.path.join(base_input_path, "train", "images")
    train_mask_dir = os.path.join(base_input_path, "train", "masks")
    val_image_dir = os.path.join(base_input_path, "val", "images")
    val_mask_dir = os.path.join(base_input_path, "val", "masks")

    # Create directories
    os.makedirs(train_image_dir, exist_ok=True)
    os.makedirs(train_mask_dir, exist_ok=True)
    os.makedirs(val_image_dir, exist_ok=True)
    os.makedirs(val_mask_dir, exist_ok=True)

    # Retrieve and sort filenames
    image_files = [f for f in os.listdir(images_dir) if f.endswith('.png')]
    mask_files = [f for f in os.listdir(masks_dir) if f.endswith('.png')]
    image_files.sort()
    mask_files.sort()

    # Split data into training and validation sets
    image_train, image_val, mask_train, mask_val = train_test_split(
        image_files, mask_files, test_size=test_size, random_state=random_seed)

    # Function to copy files
    def copy_files(file_list, src_dir, dest_dir):
        for file in file_list:
            src_file_path = os.path.join(src_dir, file)
            dest_file_path = os.path.join(dest_dir, file)
            shutil.copy(src_file_path, dest_file_path)

    # Copy files to respective directories
    copy_files(image_train, images_dir, train_image_dir)
    copy_files(mask_train, masks_dir, train_mask_dir)
    copy_files(image_val, images_dir, val_image_dir)
    copy_files(mask_val, masks_dir, val_mask_dir)

    print(f"Data successfully split and copied.\nTraining images: {len(image_train)}, Validation images: {len(image_val)}")

# %%
# Create training and validation folders
base_input_path = "03_create_masks/train_validate_512_incl_quick/train_validate_512_incl_quick_reduced_background"
split_and_copy_data(base_input_path, test_size=0.2, random_seed=42)
# Out:
# Data successfully split and copied.
# Training images: 1537, Validation images: 385

# %% [markdown]
# The training folder contains 1,537 images while the validation folder includes 385 images.

# %%
def count_image_intensities(folder_dir):
    """
    Count car, truck and pure background masks in folder.
    """
    count_all_zero = 0
    count_include_100 = 0
    count_include_200 = 0
    count_include_250 = 0
    count_include_100_200_250 = 0

    # Iterate through all image files in the folder
    for filename in os.listdir(folder_dir):
        if filename.lower().endswith('.png'):
            img_path = os.path.join(folder_dir, filename)
            img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)

            # Check if the entire image is black
            if np.all(img == 0):
                count_all_zero += 1

            # Check if the image includes pixel intensities of 100
            if np.any(img == 100):
                count_include_100 += 1

            # Check if the image includes pixel intensities of 200
            if np.any(img == 200):
                count_include_200 += 1

            # Check if the image includes pixel intensities of 250
            if np.any(img == 250):
                count_include_250 += 1

            # Check if the image includes pixel intensities of 100 or 200
            if np.any(img == 100) or np.any(img == 200) or np.any(img == 250):
                count_include_100_200_250 += 1

            total_count = count_all_zero + count_include_100_200_250

    return total_count, count_all_zero, count_include_100, count_include_200, count_include_250, count_include_100_200_250

# %%
# Count the instances of car and truck parking as well as background in the train/val folder
train_dir = "03_create_masks/train_validate_512_incl_quick/train_validate_512_incl_quick_reduced_background/train/masks"
val_dir = "03_create_masks/train_validate_512_incl_quick/train_validate_512_incl_quick_reduced_background/val/masks"

total_count, count_all_zero, count_include_100, count_include_200, count_include_250, count_include_100_200_250 = count_image_intensities(val_dir)

print(f"Total count: {total_count}")
print(f"Background images: {count_all_zero}")
print(f"Images including car parking: {count_include_100}")
print(f"Images including truck parking: {count_include_200}")
print(f"Images including quick parking: {count_include_250}")
print(f"Images including car, truck or quick parking: {count_include_100_200_250}")
# Out:
# Total count: 385
# Background images: 201
# Images including car parking: 117
# Images including truck parking: 125
# Images including quick parking: 58
# Images including car, truck or quick parking: 184

# %% [markdown]
# The training set includes 1,537 images, of which 415 include car parking, 461 include truck parking, 304 include quick parking and 737 include car, truck or quick parking. 800 images are pure background images.
#
# The validation set includes 385 images, of which 117 include car parking, 125 include truck parking, 58 include quick parking and 184 include car, truck or quick parking. 117 images are pure background images.
