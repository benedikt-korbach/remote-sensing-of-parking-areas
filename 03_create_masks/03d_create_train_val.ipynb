# %% [markdown]
# <a href="https://colab.research.google.com/github/benedikt-korbach/remote-sensing-of-parking-areas/blob/main/03d_create_train_val.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import packages, mount drive, set wd

# %%
 # %pip install segmentation_models
# Out:
# Collecting segmentation_models
#   Downloading segmentation_models-1.0.1-py3-none-any.whl (33 kB)
# Collecting keras-applications<=1.0.8,>=1.0.7 (from segmentation_models)
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 2.5 MB/s eta 0:00:00
# Collecting image-classifiers==1.0.0 (from segmentation_models)
#   Downloading image_classifiers-1.0.0-py3-none-any.whl (19 kB)
# Collecting efficientnet==1.0.0 (from segmentation_models)
#   Downloading efficientnet-1.0.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from efficientnet==1.0.0->segmentation_models) (0.19.3)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation_models) (1.23.5)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation_models) (3.9.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (1.11.4)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (3.2.1)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (9.4.0)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (2.31.6)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (2024.2.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation_models) (23.2)
# Installing collected packages: keras-applications, image-classifiers, efficientnet, segmentation_models
# Successfully installed efficientnet-1.0.0 image-classifiers-1.0.0 keras-applications-1.0.8 segmentation_models-1.0.1

# %%
import os
import cv2
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import datetime
import random
import shutil
# Out:
# Segmentation Models: using `tf.keras` framework.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Set wd
#os.chdir("/Users/benediktkorbach/Documents/GitHub/remote-sensing-of-parking-areas")
os.chdir("/content/drive/MyDrive/Master Thesis")

print("Working directory:", os.getcwd())
# Out:
# Working directory: /content/drive/MyDrive/Master Thesis

# %% [markdown]
# # Check train_validate_512

# %%
def count_files_in_folder(folder_path):
    """Counts the number of files in the specified folder."""
    # List all entries in the folder
    entries = os.listdir(folder_path)

    # Count only files
    file_count = sum(os.path.isfile(os.path.join(folder_path, entry)) for entry in entries)

    return file_count

# %%
# Count images and masks
mask_path = "03 Model Training/train_validate_512/masks"
image_path = "03 Model Training/train_validate_512/images"

num_masks = count_files_in_folder(mask_path)
num_images = count_files_in_folder(image_path)

print(f"There are {num_images} images and {num_masks} masks in the folders {image_path} and {mask_path} respectively.")
# Out:
# There are 5206 images and 5206 masks in the folders 03 Model Training/train_validate_512/images and 03 Model Training/train_validate_512/masks respectively.

# %% [markdown]
# There are 5,206 images/masks in the train_validate_512 folder.

# %% [markdown]
# # Reduce background images/masks

# %%
def create_target_dirs(target_dir):
    """Create target directories for images and masks."""
    os.makedirs(target_dir, exist_ok=True)
    os.makedirs(os.path.join(target_dir, "images"), exist_ok=True)
    os.makedirs(os.path.join(target_dir, "masks"), exist_ok=True)

def reduce_background_images(image_folder, mask_folder, target_folder, black_mask_inclusion_prob=0.2):
    """
    Reduces the number of pure background images by selecting black_mask_inclusion_prob percent of pure background images.
    """
    # Create target directory
    create_target_dirs(target_folder)

    # Initialize counters for sanity check
    image_counter = 0
    parking_images_copied = 0
    background_images_copied = 0
    background_images_discarded = 0

    # Initialize start time
    start_time = datetime.datetime.now()
    print(f"Copying started at {start_time.strftime('%Y-%m-%d %H:%M:%S')}")

    # Loop through every image/mask
    for img_name in sorted(os.listdir(image_folder)):
        if not img_name.lower().endswith(".png"):
            continue

        image_counter += 1

        img_path = os.path.join(image_folder, img_name)
        mask_path = os.path.join(mask_folder, img_name)

        # Check if the mask is completely black (background)
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
        if np.unique(mask).size == 1 and np.unique(mask)[0] == 0:
            # Include the black mask with a certain probability
            if random.random() < black_mask_inclusion_prob:
                shutil.copy(img_path, os.path.join(target_folder, "images", img_name))
                shutil.copy(mask_path, os.path.join(target_folder, "masks", img_name))
                print(f"Background added: {img_name}")
                background_images_copied += 1
            else:
                background_images_discarded += 1
        else:
            # Include every non-background image
            shutil.copy(img_path, os.path.join(target_folder, "images", img_name))
            shutil.copy(mask_path, os.path.join(target_folder, "masks", img_name))
            print(f"Parking added: {img_name}")
            parking_images_copied += 1

    # Stop time and calculate total copied
    now = datetime.datetime.now()
    duration = (now - start_time).total_seconds()
    total_copied = background_images_copied + parking_images_copied

    # Output copies made by category
    print(f"Finished copying at {now.strftime('%Y-%m-%d %H:%M:%S')} in {duration:.2f} seconds.")
    print(f"Total evaluated: {image_counter}")
    print(f"Total background discarded: {background_images_discarded}")
    print(f"Total copied: {total_copied}")
    print(f"thereof parking: {parking_images_copied}")
    print(f"thereof background: {background_images_copied}")

# %%
# Reduce the number of pure background images and save them in the target folder

image_folder = "03 Model Training/train_validate_512/images"
mask_folder = "03 Model Training/train_validate_512/masks"
target_folder = "03 Model Training/train_validate_512/train_validate_512_selected_background"
reduce_background_images(image_folder, mask_folder, target_folder)
# Out:
# Copying started at 2024-03-05 11:11:14
# Background added: lon_10.0214344_lat_54.2446698_Rumohr_0_1.png
# Background added: lon_10.0214344_lat_54.2446698_Rumohr_1_1.png
# Parking added: lon_10.0214344_lat_54.2446698_Rumohr_1_2.png
# Parking added: lon_10.0214344_lat_54.2446698_Rumohr_2_2.png
# Background added: lon_10.0214344_lat_54.2446698_Rumohr_3_2.png
# Background added: lon_10.0214344_lat_54.2446698_Rumohr_4_1.png
# Background added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_0_1.png
# Background added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_0_2.png
# Background added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_1_3.png
# Background added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_1_4.png
# Parking added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_2_0.png
# Parking added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_2_1.png
# Parking added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_3_0.png
# Parking added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_3_1.png
# Background added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_4_0.png
# Background added: lon_10.0338812_lat_51.7811423_Am Bierberg_0_0.png
# Parking added: lon_10.0338812_lat_51.7811423_Am Bierberg_0_4.png
# Parking added: lon_10.0338812_lat_51.7811423_Am Bierberg_1_2.png
# Parking added: lon_10.0338812_lat_51.7811423_Am Bierberg_1_3.png
# Parking added: lon_10.0338812_lat_51.7811423_Am Bierberg_1_4.png
# Background added: lon_10.0338812_lat_51.7811423_Am Bierberg_2_0.png
# Parking added: lon_10.0338812_lat_51.7811423_Am Bierberg_2_2.png
# Parking added: lon_10.0338812_lat_51.7811423_Am Bierberg_2_3.png
# Background added: lon_10.0338812_lat_51.7811423_Am Bierberg_3_4.png
# Background added: lon_10.0338812_lat_51.7811423_Am Bierberg_4_3.png
# Parking added: lon_10.0385684_lat_53.3493845_Seevetal_0_1.png
# Parking added: lon_10.0385684_lat_53.3493845_Seevetal_1_1.png
# Parking added: lon_10.0385684_lat_53.3493845_Seevetal_2_1.png
# Background added: lon_10.0385684_lat_53.3493845_Seevetal_2_3.png
# Parking added: lon_10.0385684_lat_53.3493845_Seevetal_3_1.png
# Background added: lon_10.0385684_lat_53.3493845_Seevetal_3_2.png
# Parking added: lon_10.0413714_lat_53.3330705_Hasselhöhe_0_0.png
# Background added: lon_10.0413714_lat_53.3330705_Hasselhöhe_0_1.png
# Parking added: lon_10.0413714_lat_53.3330705_Hasselhöhe_1_0.png
# Parking added: lon_10.0413714_lat_53.3330705_Hasselhöhe_1_1.png
# Parking added: lon_10.0413714_lat_53.3330705_Hasselhöhe_2_0.png
# Parking added: lon_10.0413714_lat_53.3330705_Hasselhöhe_2_1.png
# Background added: lon_10.0413714_lat_53.3330705_Hasselhöhe_3_0.png
# Parking added: lon_10.0413714_lat_53.3330705_Hasselhöhe_3_1.png
# Parking added: lon_10.0413714_lat_53.3330705_Hasselhöhe_3_2.png
# Parking added: lon_10.0413714_lat_53.3330705_Hasselhöhe_4_2.png
# Background added: lon_10.0752917_lat_53.2253978_Garlstorfer Wald_1_2.png
# Parking added: lon_10.0752917_lat_53.2253978_Garlstorfer Wald_1_4.png
# Background added: lon_10.0752917_lat_53.2253978_Garlstorfer Wald_2_0.png
# Parking added: lon_10.0752917_lat_53.2253978_Garlstorfer Wald_2_4.png
# Parking added: lon_10.0752917_lat_53.2253978_Garlstorfer Wald_3_4.png
# Background added: lon_10.0774066_lat_53.2322212_Schaapskaben_0_1.png
# Background added: lon_10.0774066_lat_53.2322212_Schaapskaben_0_2.png
# Background added: lon_10.0774066_lat_53.2322212_Schaapskaben_0_4.png
# Background added: lon_10.0774066_lat_53.2322212_Schaapskaben_2_0.png
# Parking added: lon_10.0774066_lat_53.2322212_Schaapskaben_2_1.png
# Background added: lon_10.0774066_lat_53.2322212_Schaapskaben_2_2.png
# Background added: lon_10.0774066_lat_53.2322212_Schaapskaben_2_3.png
# Background added: lon_10.0774066_lat_53.2322212_Schaapskaben_2_4.png
# Parking added: lon_10.0774066_lat_53.2322212_Schaapskaben_3_0.png
# Parking added: lon_10.0774066_lat_53.2322212_Schaapskaben_3_1.png
# Parking added: lon_10.0774066_lat_53.2322212_Schaapskaben_4_0.png
# Parking added: lon_10.0774066_lat_53.2322212_Schaapskaben_4_1.png
# Background added: lon_10.0774066_lat_53.2322212_Schaapskaben_4_4.png
# Background added: lon_10.1230601_lat_51.8561527_Schwalenberg-West_0_0.png
# Background added: lon_10.1230601_lat_51.8561527_Schwalenberg-West_0_2.png
# Parking added: lon_10.1230601_lat_51.8561527_Schwalenberg-West_1_4.png
# Background added: lon_10.1230601_lat_51.8561527_Schwalenberg-West_2_1.png
# Parking added: lon_10.1230601_lat_51.8561527_Schwalenberg-West_2_3.png
# Parking added: lon_10.1230601_lat_51.8561527_Schwalenberg-West_2_4.png
# Parking added: lon_10.1230601_lat_51.8561527_Schwalenberg-West_3_3.png
# Parking added: lon_10.1230601_lat_51.8561527_Schwalenberg-West_4_3.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_0_2.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_1_2.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_2_2.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_3_1.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_3_2.png
# Background added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_4_1.png
# Parking added: lon_10.151289_lat_51.9784844_Ambergau_1_3.png
# Background added: lon_10.151289_lat_51.9784844_Ambergau_2_2.png
# Parking added: lon_10.151289_lat_51.9784844_Ambergau_2_3.png
# Parking added: lon_10.151289_lat_51.9784844_Ambergau_3_3.png
# Parking added: lon_10.1521298_lat_51.9786026_Ambergau_1_3.png
# Background added: lon_10.1521298_lat_51.9786026_Ambergau_3_0.png
# Parking added: lon_10.16857_lat_53.3461669_Grevelau_1_2.png
# Parking added: lon_10.16857_lat_53.3461669_Grevelau_1_3.png
# Background added: lon_10.16857_lat_53.3461669_Grevelau_1_4.png
# Background added: lon_10.16857_lat_53.3461669_Grevelau_2_1.png
# Parking added: lon_10.1688328_lat_53.3457924_Luhewiesen
# Background added: lon_9.9386962_lat_53.6678072_Bönningstedt_1_4.png
# Parking added: lon_9.9386962_lat_53.6678072_Bönningstedt_2_0.png
# Parking added: lon_9.9386962_lat_53.6678072_Bönningstedt_2_1.png
# Background added: lon_9.9386962_lat_53.6678072_Bönningstedt_2_2.png
# Parking added: lon_9.9386962_lat_53.6678072_Bönningstedt_3_0.png
# Parking added: lon_9.9386962_lat_53.6678072_Bönningstedt_3_1.png
# Background added: lon_9.9386962_lat_53.6678072_Bönningstedt_3_3.png
# Background added: lon_9.9386962_lat_53.6678072_Bönningstedt_3_4.png
# Background added: lon_9.9386962_lat_53.6678072_Bönningstedt_4_0.png
# Background added: lon_9.9397588_lat_53.6702339_Bönningstedt_1_4.png
# Parking added: lon_9.9397588_lat_53.6702339_Bönningstedt_2_2.png
# Background added: lon_9.9397588_lat_53.6702339_Bönningstedt_3_0.png
# Parking added: lon_9.9397588_lat_53.6702339_Bönningstedt_3_1.png
# Parking added: lon_9.9397588_lat_53.6702339_Bönningstedt_3_2.png
# Background added: lon_9.9397588_lat_53.6702339_Bönningstedt_3_3.png
# Parking added: lon_9.9397588_lat_53.6702339_Bönningstedt_4_2.png
# Parking added: lon_9.9398139_lat_53.9224456_Sielsbrook_0_3.png
# Parking added: lon_9.9398139_lat_53.9224456_Sielsbrook_1_2.png
# Parking added: lon_9.9398139_lat_53.9224456_Sielsbrook_1_3.png
# Background added: lon_9.9398139_lat_53.9224456_Sielsbrook_2_1.png
# Parking added: lon_9.9398139_lat_53.9224456_Sielsbrook_2_2.png
# Parking added: lon_9.9398139_lat_53.9224456_Sielsbrook_2_3.png
# Background added: lon_9.9398139_lat_53.9224456_Sielsbrook_4_3.png
# Parking added: lon_9.9423746_lat_51.7161249_Schlochau-Ost_1_1.png
# Parking added: lon_9.9423746_lat_51.7161249_Schlochau-Ost_1_2.png
# Parking added: lon_9.9423746_lat_51.7161249_Schlochau-Ost_2_1.png
# Parking added: lon_9.9423746_lat_51.7161249_Schlochau-Ost_2_2.png
# Background added: lon_9.9423746_lat_51.7161249_Schlochau-Ost_2_4.png
# Parking added: lon_9.9423746_lat_51.7161249_Schlochau-Ost_3_1.png
# Parking added: lon_9.9423746_lat_51.7161249_Schlochau-Ost_3_2.png
# Background added: lon_9.9423746_lat_51.7161249_Schlochau-Ost_3_4.png
# Parking added: lon_9.946725_lat_53.9405503_Bimöhlen_1_2.png
# Background added: lon_9.946725_lat_53.9405503_Bimöhlen_1_3.png
# Parking added: lon_9.946725_lat_53.9405503_Bimöhlen_2_2.png
# Background added: lon_9.946725_lat_53.9405503_Bimöhlen_2_4.png
# Background added: lon_9.946725_lat_53.9405503_Bimöhlen_3_1.png
# Parking added: lon_9.946725_lat_53.9405503_Bimöhlen_3_2.png
# Background added: lon_9.946725_lat_53.9405503_Bimöhlen_4_1.png
# Background added: lon_9.9534437_lat_53.3780392_Sunderblick_0_4.png
# Parking added: lon_9.9534437_lat_53.3780392_Sunderblick_1_2.png
# Parking added: lon_9.9534437_lat_53.3780392_Sunderblick_1_3.png
# Background added: lon_9.9534437_lat_53.3780392_Sunderblick_2_1.png
# Background added: lon_9.9534437_lat_53.3780392_Sunderblick_2_4.png
# Background added: lon_9.9534437_lat_53.3780392_Sunderblick_3_1.png
# Background added: lon_9.9534437_lat_53.3780392_Sunderblick_3_4.png
# Background added: lon_9.9534437_lat_53.3780392_Sunderblick_4_0.png
# Background added: lon_9.9534437_lat_53.3780392_Sunderblick_4_1.png
# Background added: lon_9.9577331_lat_53.3781014_Hittfeld_0_4.png
# Background added: lon_9.9577331_lat_53.3781014_Hittfeld_1_1.png
# Background added: lon_9.9577331_lat_53.3781014_Hittfeld_2_2.png
# Parking added: lon_9.9577331_lat_53.3781014_Hittfeld_3_1.png
# Parking added: lon_9.9577331_lat_53.3781014_Hittfeld_3_2.png
# Parking added: lon_9.9577331_lat_53.3781014_Hittfeld_3_3.png
# Background added: lon_9.9577331_lat_53.3781014_Hittfeld_4_2.png
# Background added: lon_9.9577331_lat_53.3781014_Hittfeld_4_3.png
# Finished copying at 2024-03-05 11:14:25 in 191.07 seconds.
# Total evaluated: 5206
# Total background discarded: 3506
# Total copied: 1700
# thereof parking: 834
# thereof background: 866

# %% [markdown]
# From the 5,206 evaluated images, 3,506 were discarded as pure background images. The final dataset contains 1,700 images, of which 834 include parking spaces (both truck and car) as well as 866 pure background images.

# %% [markdown]
# # Create train/val folder

# %%
def split_and_copy_data(base_input_path, test_size=0.2, random_seed=42):
    """
    Splits data into training and validation and copies images/masks to respective folders.
    """
    # Define directories
    images_dir = os.path.join(base_input_path, "images")
    masks_dir = os.path.join(base_input_path, "masks")
    train_image_dir = os.path.join(base_input_path, "train", "images")
    train_mask_dir = os.path.join(base_input_path, "train", "masks")
    val_image_dir = os.path.join(base_input_path, "val", "images")
    val_mask_dir = os.path.join(base_input_path, "val", "masks")

    # Create directories
    os.makedirs(train_image_dir, exist_ok=True)
    os.makedirs(train_mask_dir, exist_ok=True)
    os.makedirs(val_image_dir, exist_ok=True)
    os.makedirs(val_mask_dir, exist_ok=True)

    # Retrieve and sort filenames
    image_files = [f for f in os.listdir(images_dir) if f.endswith('.png')]
    mask_files = [f for f in os.listdir(masks_dir) if f.endswith('.png')]
    image_files.sort()
    mask_files.sort()

    # Split data into training and validation sets
    image_train, image_val, mask_train, mask_val = train_test_split(
        image_files, mask_files, test_size=test_size, random_state=random_seed)

    # Function to copy files
    def copy_files(file_list, src_dir, dest_dir):
        for file in file_list:
            src_file_path = os.path.join(src_dir, file)
            dest_file_path = os.path.join(dest_dir, file)
            shutil.copy(src_file_path, dest_file_path)

    # Copy files to respective directories
    copy_files(image_train, images_dir, train_image_dir)
    copy_files(mask_train, masks_dir, train_mask_dir)
    copy_files(image_val, images_dir, val_image_dir)
    copy_files(mask_val, masks_dir, val_mask_dir)

    print(f"Data successfully split and copied.\nTraining images: {len(image_train)}, Validation images: {len(image_val)}")

# %%
# Create training and validation folders
base_input_path = "03 Model Training/train_validate_512/train_validate_512_selected_background"
split_and_copy_data(base_input_path, test_size=0.2, random_seed=42)
# Out:
# Data successfully split and copied.
# Training images: 1360, Validation images: 340

# %% [markdown]
# The training folder contains 1360 images while the validation folder includes 340 images.

# %%
def count_image_intensities(folder_dir):
    """
    Count car, truck and pure background masks in folder.
    """
    count_all_zero = 0
    count_include_100 = 0
    count_include_200 = 0
    count_include_100_200 = 0

    # Iterate through all image files in the folder
    for filename in os.listdir(folder_dir):
        if filename.lower().endswith('.png'):
            img_path = os.path.join(folder_dir, filename)
            img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)

            # Check if the entire image is black
            if np.all(img == 0):
                count_all_zero += 1

            # Check if the image includes pixel intensities of 100
            if np.any(img == 100):
                count_include_100 += 1

            # Check if the image includes pixel intensities of 200
            if np.any(img == 200):
                count_include_200 += 1

            # Check if the image includes pixel intensities of 100 or 200
            if np.any(img == 100) or np.any(img == 200):
                count_include_100_200 += 1

            total_count = count_all_zero + count_include_100_200

    return total_count, count_all_zero, count_include_100, count_include_200, count_include_100_200

# %%
# Count the instances of car and truck parking as well as background in the train/val folder
train_dir = "03 Model Training/train_validate_512/train_validate_512_selected_background/train/masks"
val_dir = "03 Model Training/train_validate_512/train_validate_512_selected_background/val/masks"

total_count, count_all_zero, count_include_100, count_include_200, count_include_100_200 = count_image_intensities(val_dir)

print(f"Total count: {total_count}")
print(f"Background images: {count_all_zero}")
print(f"Images including car parking: {count_include_100}")
print(f"Images including truck parking: {count_include_200}")
print(f"Images including car or truck parking: {count_include_100_200}")
# Out:
# Total count: 340
# Background images: 180
# Images including car parking: 91
# Images including truck parking: 136
# Images including car or truck parking: 160

# %% [markdown]
# The training set includes 1,360 images, of which 432 include car parking, 548 include truck parking and 674 include car or truck parking. 686 images are pure background images.
#
# The validation set includes 340 images, of which 91 include car parking, 136 include truck parking and 160 include car or truck parking. 180 images are pure background images.
