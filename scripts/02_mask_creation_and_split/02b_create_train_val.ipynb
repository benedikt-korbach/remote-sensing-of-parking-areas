# %% [markdown]
# # Description

# %% [markdown]
# This script reduced the number of pure-background tiles and details the split of the training/validation tiles into a training and a validation set in a stratisfied fashion.
#
# Input:
#
# - masks from train_validate_images_masks
# - images from train_validate_images_masks
#
# and other masks and images for other tile sizes (256, 128).

# %% [markdown]
# # Import packages, mount drive, set wd

# %%
import os
import cv2
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import datetime
import random
import shutil
from PIL import Image
from collections import Counter

# %%
# Set wd
os.chdir("/Users/benediktkorbach/Documents/GitHub/remote-sensing-of-parking-areas/scripts")
print("Working directory:", os.getcwd())
# Out:
# Working directory: /Users/benediktkorbach/Documents/GitHub/remote-sensing-of-parking-areas/scripts

# %% [markdown]
# # Check train_validate_images_masks

# %%
def count_files_in_folder(folder_path):
    """Counts the number of files in the specified folder."""
    # List all entries in the folder
    entries = os.listdir(folder_path)

    # Count only files
    file_count = sum(os.path.isfile(os.path.join(folder_path, entry)) for entry in entries)

    return file_count

# %%
# Count images and masks
mask_path = "02_mask_creation_and_split/train_validate_images_masks/128/masks"
image_path = "02_mask_creation_and_split/train_validate_images_masks/128/images"

num_masks = count_files_in_folder(mask_path)
num_images = count_files_in_folder(image_path)

print(f"There are {num_images} images and {num_masks} masks in the folders {image_path} and {mask_path} respectively.")
# Out:
# There are 75828 images and 75828 masks in the folders 02_mask_creation_and_split/train_validate_images_masks_128/images and 02_mask_creation_and_split/train_validate_images_masks_128/masks respectively.

# %% [markdown]
# - 512x512: 4,516 images/masks in the train_validate_images_masks folder.
# - 256x256: 18,663 images/masks in the train_validate_images_masks_256 folder.
# - 128x128: 75,828 images/masks in the train_validate_images_masks_128 folder.

# %% [markdown]
# # Reduce background images/masks

# %%
def create_target_dirs(target_dir):
    """Create target directories for images and masks."""
    os.makedirs(target_dir, exist_ok=True)
    os.makedirs(os.path.join(target_dir, "images"), exist_ok=True)
    os.makedirs(os.path.join(target_dir, "masks"), exist_ok=True)

def reduce_background_images(image_folder, mask_folder, target_folder, black_mask_inclusion_prob=0.061117):
    """
    Reduce number of pure background images by selecting black_mask_inclusion_prob percent of pure background images.
    """
    # Create target directory
    create_target_dirs(target_folder)

    # Initialize counters for sanity check
    image_counter = 0
    parking_images_copied = 0
    background_images_copied = 0
    background_images_discarded = 0

    # Initialize start time
    start_time = datetime.datetime.now()
    print(f"Copying started at {start_time.strftime('%Y-%m-%d %H:%M:%S')}")

    # Loop through every image/mask
    for img_name in sorted(os.listdir(image_folder)):
        if not img_name.lower().endswith(".png"):
            continue

        image_counter += 1

        img_path = os.path.join(image_folder, img_name)
        mask_path = os.path.join(mask_folder, img_name)

        # Check if the mask is completely black (background)
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
        if np.unique(mask).size == 1 and np.unique(mask)[0] == 0:
            # Include the black mask with a certain probability
            if random.random() < black_mask_inclusion_prob:
                shutil.copy(img_path, os.path.join(target_folder, "images", img_name))
                shutil.copy(mask_path, os.path.join(target_folder, "masks", img_name))
                print(f"Background added: {img_name}")
                background_images_copied += 1
            else:
                background_images_discarded += 1
        else:
            # Include every non-background image
            shutil.copy(img_path, os.path.join(target_folder, "images", img_name))
            shutil.copy(mask_path, os.path.join(target_folder, "masks", img_name))
            print(f"Parking added: {img_name}")
            parking_images_copied += 1

    # Stop time and calculate total copied
    now = datetime.datetime.now()
    duration = (now - start_time).total_seconds()
    total_copied = background_images_copied + parking_images_copied

    # Output copies made by category
    print(f"Finished copying at {now.strftime('%Y-%m-%d %H:%M:%S')} in {duration:.2f} seconds.")
    print(f"Total evaluated: {image_counter}")
    print(f"Total background discarded: {background_images_discarded}")
    print(f"Total copied: {total_copied}")
    print(f"thereof parking: {parking_images_copied}")
    print(f"thereof background: {background_images_copied}")

# %%
# Reduce number of pure background images and save them

image_folder = "02_mask_creation_and_split/train_validate_images_masks_128/images"
mask_folder = "02_mask_creation_and_split/train_validate_images_masks_128/masks"
target_folder = "02_mask_creation_and_split/train_validate_images_masks_reduced_128"
reduce_background_images(image_folder, mask_folder, target_folder)
# Out:
# Copying started at 2024-04-23 16:04:20
# Background added: lon_10.0214344_lat_54.2446698_Rumohr_0_6.png
# Background added: lon_10.0214344_lat_54.2446698_Rumohr_11_12.png
# Background added: lon_10.0214344_lat_54.2446698_Rumohr_11_13.png
# Background added: lon_10.0214344_lat_54.2446698_Rumohr_11_15.png
# Background added: lon_10.0214344_lat_54.2446698_Rumohr_13_9.png
# Background added: lon_10.0214344_lat_54.2446698_Rumohr_15_16.png
# Background added: lon_10.0214344_lat_54.2446698_Rumohr_15_7.png
# Background added: lon_10.0214344_lat_54.2446698_Rumohr_16_11.png
# Background added: lon_10.0214344_lat_54.2446698_Rumohr_16_17.png
# Background added: lon_10.0214344_lat_54.2446698_Rumohr_17_2.png
# Background added: lon_10.0214344_lat_54.2446698_Rumohr_17_4.png
# Background added: lon_10.0214344_lat_54.2446698_Rumohr_17_7.png
# Parking added: lon_10.0214344_lat_54.2446698_Rumohr_1_13.png
# Parking added: lon_10.0214344_lat_54.2446698_Rumohr_1_14.png
# Parking added: lon_10.0214344_lat_54.2446698_Rumohr_2_14.png
# Parking added: lon_10.0214344_lat_54.2446698_Rumohr_2_15.png
# Background added: lon_10.0214344_lat_54.2446698_Rumohr_2_18.png
# Parking added: lon_10.0214344_lat_54.2446698_Rumohr_3_14.png
# Parking added: lon_10.0214344_lat_54.2446698_Rumohr_3_15.png
# Background added: lon_10.0214344_lat_54.2446698_Rumohr_3_5.png
# Background added: lon_10.0214344_lat_54.2446698_Rumohr_3_8.png
# Background added: lon_10.0214344_lat_54.2446698_Rumohr_4_1.png
# Background added: lon_10.0214344_lat_54.2446698_Rumohr_4_12.png
# Parking added: lon_10.0214344_lat_54.2446698_Rumohr_4_14.png
# Parking added: lon_10.0214344_lat_54.2446698_Rumohr_4_15.png
# Parking added: lon_10.0214344_lat_54.2446698_Rumohr_5_14.png
# Parking added: lon_10.0214344_lat_54.2446698_Rumohr_5_15.png
# Background added: lon_10.0214344_lat_54.2446698_Rumohr_5_8.png
# Background added: lon_10.0214344_lat_54.2446698_Rumohr_6_17.png
# Background added: lon_10.0214344_lat_54.2446698_Rumohr_7_14.png
# Background added: lon_10.0214344_lat_54.2446698_Rumohr_7_4.png
# Background added: lon_10.0214344_lat_54.2446698_Rumohr_8_14.png
# Background added: lon_10.0214344_lat_54.2446698_Rumohr_8_17.png
# Background added: lon_10.0214344_lat_54.2446698_Rumohr_8_19.png
# Background added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_0_6.png
# Parking added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_10_1.png
# Parking added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_10_2.png
# Parking added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_10_3.png
# Parking added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_10_7.png
# Parking added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_10_8.png
# Parking added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_11_1.png
# Background added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_11_13.png
# Parking added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_11_2.png
# Parking added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_11_3.png
# Parking added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_12_0.png
# Parking added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_12_1.png
# Parking added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_12_2.png
# Parking added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_13_0.png
# Parking added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_13_1.png
# Parking added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_14_0.png
# Parking added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_14_1.png
# Background added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_14_15.png
# Background added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_14_16.png
# Parking added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_15_0.png
# Background added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_15_10.png
# Background added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_15_5.png
# Background added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_16_0.png
# Background added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_16_11.png
# Background added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_16_5.png
# Background added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_17_8.png
# Background added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_19_7.png
# Background added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_2_10.png
# Background added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_2_14.png
# Background added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_4_10.png
# Background added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_4_17.png
# Background added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_4_7.png
# Parking added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_5_10.png
# Background added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_5_12.png
# Parking added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_6_10.png
# Parking added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_6_11.png
# Parking added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_6_12.png
# Background added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_6_7.png
# Parking added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_6_9.png
# Parking added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_7_10.png
# Parking added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_7_11.png
# Parking added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_7_12.png
# Parking added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_7_8.png
# Parking added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_7_9.png
# Background added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_8_0.png
# Background added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_8_18.png
# Parking added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_8_3.png
# Parking added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_8_8.png
# Parking added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_8_9.png
# Parking added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_9_2.png
# Parking added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_9_3.png
# Parking added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_9_7.png
# Parking added: lon_10.0335813_lat_51.7803957_Am Bierberg-Ost_9_8.png
# Background added: lon_10.0338812_lat_51.7811423_Am Bierberg_0_1.png
# Parking added: lon_10.0338812_lat_51.7811423_Am Bierberg_10_6.png
# Parking added: lon_10.0338812_lat_51.7811423_Am Bierberg_10_7.png
# Background added: lon_10.0338812_lat_51.7811423_Am Bierberg_12_0.png
# Background added: lon_10.0338812_lat_51.7811423_Am Bierberg_14_16.png
# Background added: lon_10.0338812_lat_51.7811423_Am Bierberg_14_17.png
# Background added: lon_10.0338812_lat_51.7811423_Am Bierberg_16_17.png
# Background added: lon_10.0338812_lat_51.7811423_Am Bierberg_18_12.png
# Background added: lon_10.0338812_lat_51.7811423_Am Bierberg_18_4.png
# Background added: lon_10.0338812_lat_51.7811423_Am Bierberg_19_0.png
# Background added: lon_10.0338812_lat_51.7811423_Am Bierberg_19_3.png
# Background added: lon_10.0338812_lat_51.7811423_Am Bierberg_1_0.png
# Background added: lon_10.0338812_lat_51.7811423_Am Bierberg_1_1.png
# Background added: lon_10.0338812_lat_51.7811423_Am Bierberg_2_6.png
# Background added: lon_10.0338812_lat_51.7811423_Am Bierberg_3_7.png
# Background added: lon_10.0338812_lat_51.7811423_Am Bierberg_4_7.png
# Background added: lon_10.0338812_lat_51.7811423_Am Bierberg_5_6.png
# Parking added: lon_10.0338812_lat_51.7811423_Am Bierberg_6_7.png
# Parking added: lon_10.0338812_lat_51.7811423_Am Bierberg_6_8.png
# Background added: lon_10.0338812_lat_51.7811423_Am Bierberg_7_0.png
# Background added: lon_10.0338812_lat_51.7811423_Am Bierberg_7_2.png
# Parking added: lon_10.0338812_lat_51.7811423_Am Bierberg_7_6.png
# Parking added: lon_10.0338812_lat_51.7811423_Am Bierberg_7_7.png
# Parking added: lon_10.0338812_lat_51.7811423_Am Bierberg_7_8.png
# Parking added: lon_10.0338812_lat_51.7811423_Am Bierberg_8_5.png
# Parking added: lon_10.0338812_lat_51.7811423_Am Bierberg_8_6.png
# Parking added: lon_10.0338812_lat_51.7811423_Am Bierberg_8_8.png
# Parking added: lon_10.0338812_lat_51.7811423_Am Bierberg_9_5.png
# Parking added: lon_10.0338812_lat_51.7811423_Am Bierberg_9_6.png
# Parking added: lon_10.0338812_lat_51.7811423_Am Bierberg_9_8.png
# Background added: lon_10.0385684_lat_53.3493845_Seevetal_0_19.png
# Parking added: lon_10.0385684_lat_53.3493845_Seevetal_10_1.png
# Parking added: lon_10.0385684_lat_53.3493845_Seevetal_10_2.png
# Parking added: lon_10.0385684_lat_53.3493845_Seevetal_11_1.png
# Parking added: lon_10.0385684_lat_53.3493845_Seevetal_11_2.png
# Parking added: lon_10.0385684_lat_53.3493845_Seevetal_11_3.png
# Background added: lon_10.0385684_lat_53.3493845_Seevetal_11_4.png
# Background added: lon_10.0385684_lat_53.3493845_Seevetal_11_6.png
# Parking added: lon_10.0385684_lat_53.3493845_Seevetal_12_1.png
# Parking added: lon_10.0385684_lat_53.3493845_Seevetal_12_2.png
# Parking added: lon_10.0385684_lat_53.3493845_Seevetal_12_3.png
# Parking added: lon_10.0385684_lat_53.3493845_Seevetal_13_1.png
# Parking added: lon_10.0385684_lat_53.3493845_Seevetal_13_2.png
# Parking added: lon_10.0385684_lat_53.3493845_Seevetal_13_3.png
# Parking added: lon_10.0385684_lat_53.3493845_Seevetal_14_1.png
# Parking added: lon_10.0385684_lat_53.3493845_Seevetal_14_2.png
# Parking added: lon_10.0385684_lat_53.3493845_Seevetal_14_3.png
# Background added: lon_10.0385684_lat_53.3493845_Seevetal_14_4.png
# Background added: lon_10.0385684_lat_53.3493845_Seevetal_14_7.png
# Parking added: lon_10.0385684_lat_53.3493845_Seevetal_15_2.png
# Background added: lon_10.0385684_lat_53.3493845_Seevetal_16_11.png
# Background added: lon_10.0385684_lat_53.3493845_Seevetal_19_10.png
# Background added: lon_10.0385684_lat_53.3493845_Seevetal_2_15.png
# Parking added: lon_10.0385684_lat_53.3493845_Seevetal_3_1.png
# Parking added: lon_10.0385684_lat_53.3493845_Seevetal_3_2.png
# Background added: lon_10.0385684_lat_53.3493845_Seevetal_3_6.png
# Parking added: lon_10.0385684_lat_53.3493845_Seevetal_4_1.png
# Background added: lon_10.0385684_lat_53.3493845_Seevetal_4_17.png
# Parking added: lon_10.0385684_lat_53.3493845_Seevetal_4_2.png
# Parking added: lon_10.0385684_lat_53.3493845_Seevetal_5_1.png
# Parking added: lon_10.0385684_lat_53.3493845_Seevetal_5_2.png
# Parking added: lon_10.0385684_lat_53.3493845_Seevetal_6_1.png
# Parking added: lon_10.0385684_lat_53.3493845_Seevetal_6_2.png
# Parking added: lon_10.0385684_lat_53.3493845_Seevetal_6_3.png
# Parking added: lon_10.0385684_lat_53.3493845_Seevetal_7_1.png
# Parking added: lon_10.0385684_lat_53.3493845_Seevetal_7_2.png
# Parking added: lon_10.0385684_lat_53.3493845_Seevetal_7_3.png
# Background added: lon_10.0385684_lat_53.3493845_Seevetal_7_7.png
# Parking added: lon_10.0385684_lat_53.3493845_Seevetal_8_1.png
# Background added: lon_10.0385684_lat_53.3493845_Seevetal_8_16.png
# Parking added: lon_10.0385684_lat_53.3493845_Seevetal_8_2.png
# Parking added: lon_10.0385684_lat_53.3493845_Seevetal_8_3.png
# Background added: lon_10.0385684_lat_53.3493845_Seevetal_8_7.png
# Parking added: lon_10.0385684_lat_53.3493845_Seevetal_9_1.png
# Parking added: lon_10.0385684_lat_53.3493845_Seevetal_9_2.png
# Parking added: lon_10.0385684_lat_53.3493845_Seevetal_9_3.png
# Background added: lon_10.0385684_lat_53.3493845_Seevetal_9_4.png
# Background added: lon_10.0413714_lat_53.3330705_Hasselhöhe_0_0.png
# Background added: lon_10.0413714_lat_53.3330705_Hasselhöhe_0_12.png
# Background added: lon_10.0413714_lat_53.3330705_Hasselhöhe_0_14.png
# Background added: lon_10.0413714_lat_53.3330705_Hasselhöhe_0_15.png
# Background added: lon_10.0413714_lat_53.3330705_Hasselhöhe_0_18.png
# Background added: lon_10.0413714_lat_53.3330705_Hasselhöhe_10_15.png
# Background added: lon_10.0413714_lat_53.3330705_Hasselhöhe_10_17.png
# Parking added: lon_10.0413714_lat_53.3330705_Hasselhöhe_10_5.png
# Parking added: lon_10.0413714_lat_53.3330705_Hasselhöhe_10_6.png
# Parking added: lon_10.0413714_lat_53.3330705_Hasselhöhe_10_7.png
# Parking added: lon_10.0413714_lat_53.3330705_Hasselhöhe_11_5.png
# Parking added: lon_10.0413714_lat_53.3330705_Hasselhöhe_11_6.png
# Parking added: lon_10.0413714_lat_53.3330705_Hasselhöhe_11_7.png
# Parking added: lon_10.0413714_lat_53.3330705_Hasselhöhe_11_8.png
# Background added: lon_10.0413714_lat_53.3330705_Hasselhöhe_12_14.png
# Background added: lon_10.0413714_lat_53.3330705_Hasselhöhe_12_2.png
# Parking added: lon_10.0413714_lat_53.3330705_Hasselhöhe_12_6.png
# Parking added: lon_10.0413714_lat_53.3330705_Hasselhöhe_12_7.png
# Parking added: lon_10.0413714_lat_53.3330705_Hasselhöhe_12_8.png
# Background added: lon_10.0413714_lat_53.3330705_Hasselhöhe_13_18.png
# Background added: lon_10.0413714_lat_53.3330705_Hasselhöhe_13_3.png
# Parking added: lon_10.0413714_lat_53.3330705_Hasselhöhe_13_6.png
# Parking added: lon_10.0413714_lat_53.3330705_Hasselhöhe_13_7.png
# Parking added: lon_10.0413714_lat_53.3330705_Hasselhöhe_13_8.png
# Parking added: lon_10.0413714_lat_53.3330705_Hasselhöhe_13_9.png
# Parking added: lon_10.0413714_lat_53.3330705_Hasselhöhe_14_10.png
# Background added: lon_10.0413714_lat_53.3330705_Hasselhöhe_14_13.png
# Parking added: lon_10.0413714_lat_53.3330705_Hasselhöhe_14_7.png
# Parking added: lon_10.0413714_lat_53.3330705_Hasselhöhe_14_8.png
# Parking added: lon_10.0413714_lat_53.3330705_Hasselhöhe_14_9.png
# Parking added: lon_10.0413714_lat_53.3330705_Hasselhöhe_15_10.png
# Parking added: lon_10.0413714_lat_53.3330705_Hasselhöhe_15_11.png
# Background added: lon_10.0413714_lat_53.3330705_Hasselhöhe_15_6.png
# Parking added: lon_10.0413714_lat_53.3330705_Hasselhöhe_15_8.png
# Parking added: lon_10.0413714_lat_53.3330705_Hasselhöhe_15_9.png
# Parking added: lon_10.0413714_lat_53.3330705_Hasselhöhe_16_10.png
# Parking added: lon_10.0413714_lat_53.3330705_Hasselhöhe_16_11.png
# Parking added: lon_10.0413714_lat_53.3330705_Hasselhöhe_16_9.png
# Background added: lon_10.0413714_lat_53.3330705_Hasselhöhe_17_5.png
# Background added: lon_10.0413714_lat_53.3330705_Hasselhöhe_17_6.png
# Background added: lon_10.0413714_lat_53.3330705_Hasselhöhe_18_0.png
# Background added: lon_10.0413714_lat_53.3330705_Hasselhöhe_18_17.png
# Background added: lon_10.0413714_lat_53.3330705_Hasselhöhe_19_7.png
# Background added: lon_10.0413714_lat_53.3330705_Hasselhöhe_1_8.png
# Background added: lon_10.0413714_lat_53.3330705_Hasselhöhe_2_11.png
# Background added: lon_10.0413714_lat_53.3330705_Hasselhöhe_3_3.png
# Parking added: lon_10.0413714_lat_53.3330705_Hasselhöhe_4_2.png
# Parking added: lon_10.0413714_lat_53.3330705_Hasselhöhe_4_3.png
# Parking added: lon_10.0413714_lat_53.3330705_Hasselhöhe_4_4.png
# Parking added: lon_10.0413714_lat_53.3330705_Hasselhöhe_5_2.png
# Parking added: lon_10.0413714_lat_53.3330705_Hasselhöhe_5_3.png
# Parking added: lon_10.0413714_lat_53.3330705_Hasselhöhe_5_4.png
# Background added: lon_10.0413714_lat_53.3330705_Hasselhöhe_6_17.png
# Parking added: lon_10.0413714_lat_53.3330705_Hasselhöhe_6_3.png
# Parking added: lon_10.0413714_lat_53.3330705_Hasselhöhe_6_4.png
# Parking added: lon_10.0413714_lat_53.3330705_Hasselhöhe_6_5.png
# Parking added: lon_10.0413714_lat_53.3330705_Hasselhöhe_7_3.png
# Parking added: lon_10.0413714_lat_53.3330705_Hasselhöhe_7_4.png
# Parking added: lon_10.0413714_lat_53.3330705_Hasselhöhe_7_5.png
# Background added: lon_10.0413714_lat_53.3330705_Hasselhöhe_8_18.png
# Parking added: lon_10.0413714_lat_53.3330705_Hasselhöhe_8_4.png
# Parking added: lon_10.0413714_lat_53.3330705_Hasselhöhe_8_5.png
# Parking added: lon_10.0413714_lat_53.3330705_Hasselhöhe_8_6.png
# Parking added: lon_10.0413714_lat_53.3330705_Hasselhöhe_9_4.png
# Parking added: lon_10.0413714_lat_53.3330705_Hasselhöhe_9_5.png
# Parking added: lon_10.0413714_lat_53.3330705_Hasselhöhe_9_6.png
# Background added: lon_10.0752917_lat_53.2253978_Garlstorfer Wald_0_2.png
# Background added: lon_10.0752917_lat_53.2253978_Garlstorfer Wald_0_8.png
# Parking added: lon_10.0752917_lat_53.2253978_Garlstorfer Wald_10_4.png
# Background added: lon_10.0752917_lat_53.2253978_Garlstorfer Wald_10_6.png
# Parking added: lon_10.0752917_lat_53.2253978_Garlstorfer Wald_11_4.png
# Parking added: lon_10.0752917_lat_53.2253978_Garlstorfer Wald_11_5.png
# Background added: lon_10.0752917_lat_53.2253978_Garlstorfer Wald_11_6.png
# Background added: lon_10.0752917_lat_53.2253978_Garlstorfer Wald_12_10.png
# Background added: lon_10.0752917_lat_53.2253978_Garlstorfer Wald_12_17.png
# Parking added: lon_10.0752917_lat_53.2253978_Garlstorfer Wald_12_4.png
# Parking added: lon_10.0752917_lat_53.2253978_Garlstorfer Wald_12_5.png
# Background added: lon_10.0752917_lat_53.2253978_Garlstorfer Wald_12_6.png
# Background added: lon_10.0752917_lat_53.2253978_Garlstorfer Wald_13_12.png
# Parking added: lon_10.0752917_lat_53.2253978_Garlstorfer Wald_13_4.png
# Background added: lon_10.0752917_lat_53.2253978_Garlstorfer Wald_14_0.png
# Background added: lon_10.0752917_lat_53.2253978_Garlstorfer Wald_16_17.png
# Background added: lon_10.0752917_lat_53.2253978_Garlstorfer Wald_17_13.png
# Background added: lon_10.0752917_lat_53.2253978_Garlstorfer Wald_17_15.png
# Background added: lon_10.0752917_lat_53.2253978_Garlstorfer Wald_18_15.png
# Background added: lon_10.0752917_lat_53.2253978_Garlstorfer Wald_19_5.png
# Background added: lon_10.0752917_lat_53.2253978_Garlstorfer Wald_4_10.png
# Background added: lon_10.0752917_lat_53.2253978_Garlstorfer Wald_4_18.png
# Background added: lon_10.0752917_lat_53.2253978_Garlstorfer Wald_4_2.png
# Background added: lon_10.0752917_lat_53.2253978_Garlstorfer Wald_5_8.png
# Background added: lon_10.0752917_lat_53.2253978_Garlstorfer Wald_7_2.png
# Parking added: lon_10.0752917_lat_53.2253978_Garlstorfer Wald_7_3.png
# Parking added: lon_10.0752917_lat_53.2253978_Garlstorfer Wald_7_4.png
# Parking added: lon_10.0752917_lat_53.2253978_Garlstorfer Wald_8_3.png
# Parking added: lon_10.0752917_lat_53.2253978_Garlstorfer Wald_8_4.png
# Parking added: lon_10.0752917_lat_53.2253978_Garlstorfer Wald_9_4.png
# Background added: lon_10.0752917_lat_53.2253978_Garlstorfer Wald_9_5.png
# Background added: lon_10.0774066_lat_53.2322212_Schaapskaben_0_16.png
# Background added: lon_10.0774066_lat_53.2322212_Schaapskaben_0_18.png
# Parking added: lon_10.0774066_lat_53.2322212_Schaapskaben_10_13.png
# Parking added: lon_10.0774066_lat_53.2322212_Schaapskaben_10_14.png
# Parking added: lon_10.0774066_lat_53.2322212_Schaapskaben_10_15.png
# Parking added: lon_10.0774066_lat_53.2322212_Schaapskaben_10_16.png
# Parking added: lon_10.0774066_lat_53.2322212_Schaapskaben_11_12.png
# Parking added: lon_10.0774066_lat_53.2322212_Schaapskaben_11_13.png
# Parking added: lon_10.0774066_lat_53.2322212_Schaapskaben_11_14.png
# Parking added: lon_10.0774066_lat_53.2322212_Schaapskaben_11_15.png
# Parking added: lon_10.0774066_lat_53.2322212_Schaapskaben_11_16.png
# Background added: lon_10.0774066_lat_53.2322212_Schaapskaben_11_4.png
# Parking added: lon_10.0774066_lat_53.2322212_Schaapskaben_12_13.png
# Parking added: lon_10.0774066_lat_53.2322212_Schaapskaben_12_14.png
# Background added: lon_10.0774066_lat_53.2322212_Schaapskaben_12_5.png
# Background added: lon_10.0774066_lat_53.2322212_Schaapskaben_14_4.png
# Background added: lon_10.0774066_lat_53.2322212_Schaapskaben_16_6.png
# Background added: lon_10.0774066_lat_53.2322212_Schaapskaben_18_16.png
# Background added: lon_10.0774066_lat_53.2322212_Schaapskaben_18_17.png
# Background added: lon_10.0774066_lat_53.2322212_Schaapskaben_19_11.png
# Background added: lon_10.0774066_lat_53.2322212_Schaapskaben_19_2.png
# Background added: lon_10.0774066_lat_53.2322212_Schaapskaben_19_9.png
# Background added: lon_10.0774066_lat_53.2322212_Schaapskaben_1_0.png
# Background added: lon_10.0774066_lat_53.2322212_Schaapskaben_2_7.png
# Background added: lon_10.0774066_lat_53.2322212_Schaapskaben_3_3.png
# Background added: lon_10.0774066_lat_53.2322212_Schaapskaben_3_7.png
# Background added: lon_10.0774066_lat_53.2322212_Schaapskaben_4_16.png
# Background added: lon_10.0774066_lat_53.2322212_Schaapskaben_4_18.png
# Parking added: lon_10.0774066_lat_53.2322212_Schaapskaben_5_14.png
# Parking added: lon_10.0774066_lat_53.2322212_Schaapskaben_5_15.png
# Parking added: lon_10.0774066_lat_53.2322212_Schaapskaben_5_16.png
# Background added: lon_10.0774066_lat_53.2322212_Schaapskaben_5_17.png
# Background added: lon_10.0774066_lat_53.2322212_Schaapskaben_6_1.png
# Parking added: lon_10.0774066_lat_53.2322212_Schaapskaben_6_14.png
# Parking added: lon_10.0774066_lat_53.2322212_Schaapskaben_6_15.png
# Parking added: lon_10.0774066_lat_53.2322212_Schaapskaben_6_16.png
# Background added: lon_10.0774066_lat_53.2322212_Schaapskaben_6_17.png
# Background added: lon_10.0774066_lat_53.2322212_Schaapskaben_6_6.png
# Parking added: lon_10.0774066_lat_53.2322212_Schaapskaben_7_13.png
# Parking added: lon_10.0774066_lat_53.2322212_Schaapskaben_7_16.png
# Background added: lon_10.0774066_lat_53.2322212_Schaapskaben_7_19.png
# Background added: lon_10.0774066_lat_53.2322212_Schaapskaben_8_10.png
# Parking added: lon_10.0774066_lat_53.2322212_Schaapskaben_8_13.png
# Parking added: lon_10.0774066_lat_53.2322212_Schaapskaben_8_14.png
# Parking added: lon_10.0774066_lat_53.2322212_Schaapskaben_8_15.png
# Parking added: lon_10.0774066_lat_53.2322212_Schaapskaben_8_16.png
# Parking added: lon_10.0774066_lat_53.2322212_Schaapskaben_9_13.png
# Parking added: lon_10.0774066_lat_53.2322212_Schaapskaben_9_14.png
# Parking added: lon_10.0774066_lat_53.2322212_Schaapskaben_9_15.png
# Parking added: lon_10.0774066_lat_53.2322212_Schaapskaben_9_16.png
# Background added: lon_10.0774066_lat_53.2322212_Schaapskaben_9_19.png
# Background added: lon_10.1230601_lat_51.8561527_Schwalenberg-West_0_12.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_10_10.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_10_11.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_10_12.png
# Background added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_10_2.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_10_3.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_10_4.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_10_5.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_10_6.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_10_9.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_11_10.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_11_11.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_11_12.png
# Background added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_11_18.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_11_3.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_11_4.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_11_5.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_11_6.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_11_9.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_12_10.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_12_11.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_12_3.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_12_4.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_12_5.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_12_6.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_12_8.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_12_9.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_13_10.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_13_11.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_13_12.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_13_4.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_13_5.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_13_6.png
# Background added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_13_7.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_13_8.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_13_9.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_14_10.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_14_11.png
# Background added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_14_16.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_14_5.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_14_6.png
# Background added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_15_3.png
# Background added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_15_4.png
# Background added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_16_14.png
# Background added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_16_18.png
# Background added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_17_9.png
# Background added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_19_11.png
# Background added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_19_4.png
# Background added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_19_8.png
# Background added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_1_12.png
# Background added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_1_17.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_2_10.png
# Background added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_2_11.png
# Background added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_3_0.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_3_10.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_3_11.png
# Background added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_3_14.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_3_5.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_3_6.png
# Background added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_4_0.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_4_10.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_4_11.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_4_12.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_4_13.png
# Background added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_4_4.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_4_5.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_4_6.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_4_7.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_4_9.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_5_10.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_5_11.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_5_12.png
# Background added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_5_15.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_5_5.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_5_6.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_5_7.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_5_9.png
# Background added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_6_0.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_6_10.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_6_11.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_6_12.png
# Background added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_6_19.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_6_5.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_6_6.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_6_7.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_6_9.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_7_10.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_7_11.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_7_12.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_7_4.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_7_5.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_7_6.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_7_7.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_7_9.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_8_10.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_8_11.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_8_12.png
# Background added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_8_13.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_8_4.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_8_6.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_8_9.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_9_10.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_9_11.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_9_12.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_9_3.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_9_4.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_9_5.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_9_6.png
# Parking added: lon_10.1268892_lat_51.8569148_Schwalenberg-Ost_9_9.png
# Background added: lon_10.151289_lat_51.9784844_Ambergau_0_5.png
# Parking added: lon_10.151289_lat_51.9784844_Ambergau_10_15.png
# Parking added: lon_10.151289_lat_51.9784844_Ambergau_10_16.png
# Parking added: lon_10.151289_lat_51.9784844_Ambergau_10_18.png
# Parking added: lon_10.151289_lat_51.9784844_Ambergau_10_19.png
# Background added: lon_10.151289_lat_51.9784844_Ambergau_10_6.png
# Background added: lon_10.151289_lat_51.9784844_Ambergau_11_11.png
# Parking added: lon_10.151289_lat_51.9784844_Ambergau_11_15.png
# Parking added: lon_10.151289_lat_51.9784844_Ambergau_11_16.png
# Parking added: lon_10.151289_lat_51.9784844_Ambergau_11_18.png
# Parking added: lon_10.151289_lat_51.9784844_Ambergau_11_19.png
# Background added: lon_10.151289_lat_51.9784844_Ambergau_12_11.png
# Background added: lon_10.151289_lat_51.9784844_Ambergau_12_13.png
# Parking added: lon_10.151289_lat_51.9784844_Ambergau_12_14.png
# Parking added: lon_10.151289_lat_51.9784844_Ambergau_12_15.png
# Parking added: lon_10.151289_lat_51.9784844_Ambergau_12_17.png
# Parking added: lon_10.151289_lat_51.9784844_Ambergau_12_18.png
# Parking added: lon_10.151289_lat_51.9784844_Ambergau_12_19.png
# Parking added: lon_10.151289_lat_51.9784844_Ambergau_13_14.png
# Parking added: lon_10.151289_lat_51.9784844_Ambergau_13_15.png
# Parking added: lon_10.151289_lat_51.9784844_Ambergau_13_17.png
# Parking added: lon_10.151289_lat_51.9784844_Ambergau_13_18.png
# Parking added: lon_10.151289_lat_51.9784844_Ambergau_14_14.png
# Parking added: lon_10.151289_lat_51.9784844_Ambergau_14_17.png
# Parking added: lon_10.151289_lat_51.9784844_Ambergau_14_18.png
# Parking added: lon_10.151289_lat_51.9784844_Ambergau_15_13.png
# Parking added: lon_10.151289_lat_51.9784844_Ambergau_15_14.png
# Background added: lon_10.151289_lat_51.9784844_Ambergau_15_16.png
# Parking added: lon_10.151289_lat_51.9784844_Ambergau_15_17.png
# Parking added: lon_10.151289_lat_51.9784844_Ambergau_15_18.png
# Parking added: lon_10.151289_lat_51.9784844_Ambergau_16_13.png
# Parking added: lon_10.151289_lat_51.9784844_Ambergau_16_14.png
# Parking added: lon_10.151289_lat_51.9784844_Ambergau_17_13.png
# Background added: lon_10.151289_lat_51.9784844_Ambergau_18_16.png
# Background added: lon_10.151289_lat_51.9784844_Ambergau_18_2.png
# Background added: lon_10.151289_lat_51.9784844_Ambergau_19_1.png
# Background added: lon_10.151289_lat_51.9784844_Ambergau_1_3.png
# Background added: lon_10.151289_lat_51.9784844_Ambergau_2_0.png
# Background added: lon_10.151289_lat_51.9784844_Ambergau_2_5.png
# Background added: lon_10.151289_lat_51.9784844_Ambergau_4_6.png
# Background added: lon_10.151289_lat_51.9784844_Ambergau_5_5.png
# Background added: lon_10.151289_lat_51.9784844_Ambergau_7_14.png
# Background added: lon_10.151289_lat_51.9784844_Ambergau_7_18.png
# Background added: lon_10.151289_lat_51.9784844_Ambergau_7_6.png
# Background added: lon_10.151289_lat_51.9784844_Ambergau_8_13.png
# Background added: lon_10.151289_lat_51.9784844_Ambergau_9_0.png
# Parking added: lon_10.151289_lat_51.9784844_Ambergau_9_19.png
# Background added: lon_10.1521298_lat_51.9786026_Ambergau_10_6.png
# Background added: lon_10.1521298_lat_51.9786026_Ambergau_10_9.png
# Background added: lon_10.1521298_lat_51.9786026_Ambergau_11_19.png
# Background added: lon_10.1521298_lat_51.9786026_Ambergau_12_6.png
# Background added: lon_10.1521298_lat_51.9786026_Ambergau_12_8.png
# Background added: lon_10.1521298_lat_51.9786026_Ambergau_13_14.png
# Background added: lon_10.1521298_lat_51.9786026_Ambergau_14_6.png
# Background added: lon_10.1521298_lat_51.9786026_Ambergau_15_6.png
# Background added: lon_10.1521298_lat_51.9786026_Ambergau_17_19.png
# Background added: lon_10.1521298_lat_51.9786026_Ambergau_3_8.png
# Background added: lon_10.1521298_lat_51.9786026_Ambergau_4_12.png
# Background added: lon_10.1521298_lat_51.9786026_Ambergau_4_18.png
# Background added: lon_10.1521298_lat_51.9786026_Ambergau_5_11.png
# Background added: lon_10.1521298_lat_51.9786026_Ambergau_7_14.png
# Background added: lon_10.1521298_lat_51.9786026_Ambergau_8_13.png
# Background added: lon_10.1521298_lat_51.9786026_Ambergau_8_15.png
# Background added: lon_10.1521298_lat_51.9786026_Ambergau_8_9.png
# Background added: lon_10.1521298_lat_51.9786026_Ambergau_9_15.png
# Background added: lon_10.1521298_lat_51.9786026_Ambergau_9_7.png
# Background added: lon_10.1538882_lat_52.3604733_Röhrse Süd_0_0.png
# Background added: lon_10.1538882_lat_52.3604733_Röhrse Süd_0_13.png
# Parking added: lon_10.1538882_lat_52.3604733_Röhrse Süd_10_1.png
# Background added: lon_10.1538882_lat_52.3604733_Röhrse Süd_10_11.png
# Parking added: lon_10.1538882_lat_52.3604733_Röhrse Süd_10_2.png
# Parking added: lon_10.1538882_lat_52.3604733_Röhrse Süd_10_3.png
# Parking added: lon_10.1538882_lat_52.3604733_Röhrse Süd_10_4.png
# Parking added: lon_10.1538882_lat_52.3604733_Röhrse Süd_10_5.png
# Parking added: lon_10.1538882_lat_52.3604733_Röhrse Süd_10_6.png
# Parking added: lon_10.1538882_lat_52.3604733_Röhrse Süd_10_7.png
# Parking added: lon_10.1538882_lat_52.3604733_Röhrse Süd_10_8.png
# Parking added: lon_10.1538882_lat_52.3604733_Röhrse Süd_10_9.png
# Parking added: lon_10.1538882_lat_52.3604733_Röhrse Süd_11_1.png
# Parking added: lon_10.1538882_lat_52.3604733_Röhrse Süd_11_2.png
# Parking added: lon_10.1538882_lat_52.3604733_Röhrse Süd_11_3.png
# Parking added: lon_10.1538882_lat_52.3604733_Röhrse Süd_11_4.png
# Parking added: lon_10.1538882_lat_52.3604733_Röhrse Süd_11_5.png
# Parking added: lon_10.1538882_lat_52.3604733_Röhrse Süd_11_6.png
# Parking added: lon_10.1538882_lat_52.3604733_Röhrse Süd_11_7.png
# Parking added: lon_10.1538882_lat_52.3604733_Röhrse Süd_11_8.png
# Parking added: lon_10.1538882_lat_52.3604733_Röhrse Süd_11_9.png
# Parking added: lon_10.1538882_lat_52.3604733_Röhrse Süd_12_1.png
# Parking added: lon_10.1538882_lat_52.3604733_Röhrse Süd_12_2.png
# Parking added: lon_10.1538882_lat_52.3604733_Röhrse Süd_12_3.png
# Parking added: lon_10.1538882_lat_52.3604733_Röhrse Süd_12_4.png
# Parking added: lon_10.1538882_lat_52.3604733_Röhrse Süd_12_5.png
# Parking added: lon_10.1538882_lat_52.3604733_Röhrse Süd_12_6.png
# Parking added: lon_10.1538882_lat_52.3604733_Röhrse Süd_12_7.png
# Parking added: lon_10.1538882_lat_52.3604733_Röhrse Süd_12_8.png
# Parking added: lon_10.1538882_lat_52.3604733_Röhrse Süd_13_4.png
# Parking added: lon_10.1538882_lat_52.3604733_Röhrse Süd_13_5.png
# Parking added: lon_10.1538882_lat_52.3604733_Röhrse Süd_13_6.png
# Parking added: lon_10.1538882_lat_52.3604733_Röhrse Süd_13_7.png
# Background added: lon_10.1538882_lat_52.3604733_Röhrse Süd_14_5.png
# Background added: lon_10.1538882_lat_52.3604733_Röhrse Süd_15_8.png
# Background added: lon_10.1538882_lat_52.3604733_Röhrse Süd_19_3.png
# Background added: lon_10.1538882_lat_52.3604733_Röhrse Süd_2_8.png
# Background added: lon_10.1538882_lat_52.3604733_Röhrse Süd_3_9.png
# Background added: lon_10.1538882_lat_52.3604733_Röhrse Süd_4_18.png
# Background added: lon_10.1538882_lat_52.3604733_Röhrse Süd_4_19.png
# Background added: lon_10.1538882_lat_52.3604733_Röhrse Süd_4_2.png
# Background added: lon_10.1538882_lat_52.3604733_Röhrse Süd_4_7.png
# Background added: lon_10.1538882_lat_52.3604733_Röhrse Süd_6_13.png
# Background added: lon_10.1538882_lat_52.3604733_Röhrse Süd_7_13.png
# Background added: lon_10.1538882_lat_52.3604733_Röhrse Süd_8_0.png
# Background added: lon_10.1538882_lat_52.3604733_Röhrse Süd_8_6.png
# Parking added: lon_10.1538882_lat_52.3604733_Röhrse Süd_9_1.png
# Background added: lon_10.1538882_lat_52.3604733_Röhrse Süd_9_16.png
# Parking added: lon_10.1538882_lat_52.3604733_Röhrse Süd_9_2.png
# Parking added: lon_10.1538882_lat_52.3604733_Röhrse Süd_9_3.png
# Parking added: lon_10.1538882_lat_52.3604733_Röhrse Süd_9_4.png
# Parking added: lon_10.1538882_lat_52.3604733_Röhrse Süd_9_5.png
# Parking added: lon_10.1538882_lat_52.3604733_Röhrse Süd_9_6.png
# Background added: lon_10.16857_lat_53.3461669_Grevelau_0_9.png
# Background added: lon_10.16857_lat_53.3461669_Grevelau_14_19.png
# Background added: lon_10.16857_lat_53.3461669_Grevelau_1_19.png
# Background added: lon_10.16857_lat_53.3461669_Grevelau_3_1.png
# Background added: lon_10.16857_lat_53.3461669_Grevelau_3_4.png
# Background added: lon_10.16857_lat_53.3461669_Grevelau_3_5.png
# Background added: lon_10.16857_lat_53.3461669_Grevelau_4_17.png
# Background added: lon_10.16857_lat_53.3461669_Grevelau_4_8.png
# Background added: lon_10.16857_lat_53.3461669_Grevelau_5_14.png
# Background added: lon_10.16857_lat_53.3461669_Grevelau_5_5.png
# Background added: lon_10.16857_lat_53.3461669_Grevelau_7_19.png
# Background added: lon_10.16857_lat_53.3461669_Grevelau_8_10.png
# Background added: lon_10.16857_lat_53.3461669_Grevelau_8_6.png
# Background added: lon_10.1688328_lat_53.3457924_Luhewiesen_0_9.png
# Parking added: lon_10.1688328_lat_53.3457924_Luhewiesen_10_11.png
# Parking added: lon_10.1688328_lat_53.3457924_Luhewiesen_10_12.png
# Parking added: lon_10.1688328_lat_53.3457924_Luhewiesen_10_13.png
# Parking added: lon_10.1688328_lat_53.3457924_Luhewiesen_10_14.png
# Parking added: lon_10.1688328_lat_53.3457924_Luhewiesen_10_15.png
# Background added: lon_10.1688328_lat_53.3457924_Luhewiesen_10_19.png
# Parking added: lon_10.1688328_lat_53.3457924_Luhewiesen_11_11.png
# Parking added: lon_10.1688328_lat_53.3457924_Luhewiesen_11_12.png
# Parking added: lon_10.1688328_lat_53.3457924_Luhewiesen_11_13.png
# Parking added: lon_10.1688328_lat_53.3457924_Luhewiesen_11_14.png
# Parking added: lon_10.1688328_lat_53.3457924_Luhewiesen_11_15.png
# Background added: lon_10.1688328_lat_53.3457924_Luhewiesen_11_5.png
# Background added: lon_10.1688328_lat_53.3457924_Luhewiesen_12_1.png
# Parking added: lon_10.1688328_lat_53.3457924_Luhewiesen_12_13.png
# Parking added: lon_10.1688328_lat_53.3457924_Luhewiesen_12_14.png
# Background added: lon_10.1688328_lat_53.3457924_Luhewiesen_12_16.png
# Background added: lon_10.1688328_lat_53.3457924_Luhewiesen_12_6.png
# Background added: lon_10.1688328_lat_53.3457924_Luhewiesen_12_9.png
# Background added: lon_10.1688328_lat_53.3457924_Luhewiesen_13_15.png
# Background added: lon_10.1688328_lat_53.3457924_Luhewiesen_14_13.png
# Background added: lon_10.1688328_lat_53.3457924_Luhewiesen_16_1.png
# Background added: lon_10.1688328_lat_53.3457924_Luhewiesen_18_3.png
# Background added: lon_10.1688328_lat_53.3457924_Luhewiesen_19_8.png
# Background added: lon_10.1688328_lat_53.3457924_Luhewiesen_1_7.png
# Background added: lon_10.1688328_lat_53.3457924_Luhewiesen_1_9.png
# Background added: lon_10.1688328_lat_53.3457924_Luhewiesen_2_1.png
# Background added: lon_10.1688328_lat_53.3457924_Luhewiesen_3_0.png
# Background added: lon_10.1688328_lat_53.3457924_Luhewiesen_3_9.png
# Background added: lon_10.1688328_lat_53.3457924_Luhewiesen_4_12.png
# Parking added: lon_10.1688328_lat_53.3457924_Luhewiesen_5_13.png
# Parking added: lon_10.1688328_lat_53.3457924_Luhewiesen_5_14.png
# Parking added: lon_10.1688328_lat_53.3457924_Luhewiesen_5_15.png
# Parking added: lon_10.1688328_lat_53.3457924_Luhewiesen_5_16.png
# Parking added: lon_10.1688328_lat_53.3457924_Luhewiesen_6_12.png
# Parking added: lon_10.1688328_lat_53.3457924_Luhewiesen_6_13.png
# Parking added: lon_10.1688328_lat_53.3457924_Luhewiesen_6_14.png
# Parking added: lon_10.1688328_lat_53.3457924_Luhewiesen_6_15.png
# Parking added: lon_10.1688328_lat_53.3457924_Luhewiesen_6_16.png
# Parking added: lon_10.1688328_lat_53.3457924_Luhewiesen_6_17.png
# Parking added: lon_10.1688328_lat_53.3457924_Luhewiesen_7_13.png
# Parking added: lon_10.1688328_lat_53.3457924_Luhewiesen_7_14.png
# Parking added: lon_10.1688328_lat_53.3457924_Luhewiesen_7_15.png
# Parking added: lon_10.1688328_lat_53.3457924_Luhewiesen_7_16.png
# Parking added: lon_10.1688328_lat_53.3457924_Luhewiesen_7_17.png
# Background added: lon_10.1688328_lat_53.3457924_Luhewiesen_7_2.png
# Parking added: lon_10.1688328_lat_53.3457924_Luhewiesen_8_15.png
# Parking added: lon_10.1688328_lat_53.3457924_Luhewiesen_8_16.png
# Parking added: lon_10.1688328_lat_53.3457924_Luhewiesen_8_17.png
# Background added: lon_10.1688328_lat_53.3457924_Luhewiesen_8_7.png
# Background added: lon_10.1688328_lat_53.3457924_Luhewiesen_8_9.png
# Parking added: lon_10.1688328_lat_53.3457924_Luhewiesen_9_11.png
# Parking added: lon_10.1688328_lat_53.3457924_Luhewiesen_9_12.png
# Parking added: lon_10.1688328_lat_53.3457924_Luhewiesen_9_13.png
# Background added: lon_10.1688328_lat_53.3457924_Luhewiesen_9_6.png
# Parking added: lon_10.1793156_lat_51.408897_Leinetal_10_10.png
# Parking added: lon_10.1793156_lat_51.408897_Leinetal_10_11.png
# Parking added: lon_10.1793156_lat_51.408897_Leinetal_10_12.png
# Parking added: lon_10.1793156_lat_51.408897_Leinetal_10_13.png
# Background added: lon_10.1793156_lat_51.408897_Leinetal_11_0.png
# Background added: lon_10.1793156_lat_51.408897_Leinetal_12_7.png
# Background added: lon_10.1793156_lat_51.408897_Leinetal_13_12.png
# Background added: lon_10.1793156_lat_51.408897_Leinetal_13_19.png
# Background added: lon_10.1793156_lat_51.408897_Leinetal_14_15.png
# Background added: lon_10.1793156_lat_51.408897_Leinetal_14_17.png
# Background added: lon_10.1793156_lat_51.408897_Leinetal_15_17.png
# Background added: lon_10.1793156_lat_51.408897_Leinetal_15_4.png
# Background added: lon_10.1793156_lat_51.408897_Leinetal_16_2.png
# Background added: lon_10.1793156_lat_51.408897_Leinetal_16_3.png
# Background added: lon_10.1793156_lat_51.408897_Leinetal_17_0.png
# Background added: lon_10.1793156_lat_51.408897_Leinetal_19_6.png
# Background added: lon_10.1793156_lat_51.408897_Leinetal_1_4.png
# Background added: lon_10.1793156_lat_51.408897_Leinetal_2_17.png
# Background added: lon_10.1793156_lat_51.408897_Leinetal_3_2.png
# Background added: lon_10.1793156_lat_51.408897_Leinetal_3_3.png
# Background added: lon_10.1793156_lat_51.408897_Leinetal_4_19.png
# Background added: lon_10.1793156_lat_51.408897_Leinetal_4_3.png
# Background added: lon_10.1793156_lat_51.408897_Leinetal_5_17.png
# Background added: lon_10.1793156_lat_51.408897_Leinetal_5_5.png
# Background added: lon_10.1793156_lat_51.408897_Leinetal_6_1.png
# Background added: lon_10.1793156_lat_51.408897_Leinetal_6_4.png
# Background added: lon_10.1793156_lat_51.408897_Leinetal_6_8.png
# Parking added: lon_10.1793156_lat_51.408897_Leinetal_7_10.png
# Parking added: lon_10.1793156_lat_51.408897_Leinetal_7_11.png
# Background added: lon_10.1793156_lat_51.408897_Leinetal_7_12.png
# Background added: lon_10.1793156_lat_51.408897_Leinetal_7_16.png
# Background added: lon_10.1793156_lat_51.408897_Leinetal_7_19.png
# Background added: lon_10.1793156_lat_51.408897_Leinetal_7_7.png
# Parking added: lon_10.1793156_lat_51.408897_Leinetal_7_8.png
# Parking added: lon_10.1793156_lat_51.408897_Leinetal_7_9.png
# Parking added: lon_10.1793156_lat_51.408897_Leinetal_8_10.png
# Parking added: lon_10.1793156_lat_51.408897_Leinetal_8_11.png
# Parking added: lon_10.1793156_lat_51.408897_Leinetal_8_12.png
# Parking added: lon_10.1793156_lat_51.408897_Leinetal_8_13.png
# Parking added: lon_10.1793156_lat_51.408897_Leinetal_8_14.png
# Parking added: lon_10.1793156_lat_51.408897_Leinetal_8_9.png
# Parking added: lon_10.1793156_lat_51.408897_Leinetal_9_10.png
# Parking added: lon_10.1793156_lat_51.408897_Leinetal_9_11.png
# Parking added: lon_10.1793156_lat_51.408897_Leinetal_9_12.png
# Parking added: lon_10.1793156_lat_51.408897_Leinetal_9_13.png
# Parking added: lon_10.1793156_lat_51.408897_Leinetal_9_14.png
# Background added: lon_10.1793156_lat_51.408897_Leinetal_9_19.png
# Background added: lon_10.1793156_lat_51.408897_Leinetal_9_6.png
# Parking added: lon_10.1793156_lat_51.408897_Leinetal_9_9.png
# Background added: lon_10.2493842_lat_53.6299917_Ellerbrook_0_9.png
# Background added: lon_10.2493842_lat_53.6299917_Ellerbrook_10_17.png
# Parking added: lon_10.2493842_lat_53.6299917_Ellerbrook_10_4.png
# Parking added: lon_10.2493842_lat_53.6299917_Ellerbrook_10_5.png
# Background added: lon_10.2493842_lat_53.6299917_Ellerbrook_13_10.png
# Background added: lon_10.2493842_lat_53.6299917_Ellerbrook_13_4.png
# Background added: lon_10.2493842_lat_53.6299917_Ellerbrook_13_7.png
# Background added: lon_10.2493842_lat_53.6299917_Ellerbrook_13_9.png
# Background added: lon_10.2493842_lat_53.6299917_Ellerbrook_14_4.png
# Background added: lon_10.2493842_lat_53.6299917_Ellerbrook_15_6.png
# Background added: lon_10.2493842_lat_53.6299917_Ellerbrook_16_17.png
# Background added: lon_10.2493842_lat_53.6299917_Ellerbrook_17_15.png
# Background added: lon_10.2493842_lat_53.6299917_Ellerbrook_17_19.png
# Background added: lon_10.2493842_lat_53.6299917_Ellerbrook_18_18.png
# Background added: lon_10.2493842_lat_53.6299917_Ellerbrook_18_5.png
# Background added: lon_10.2493842_lat_53.6299917_Ellerbrook_18_6.png
# Background added: lon_10.2493842_lat_53.6299917_Ellerbrook_1_19.png
# Background added: lon_10.2493842_lat_53.6299917_Ellerbrook_1_2.png
# Background added: lon_10.2493842_lat_53.6299917_Ellerbrook_3_17.png
# Background added: lon_10.2493842_lat_53.6299917_Ellerbrook_4_12.png
# Parking added: lon_10.2493842_lat_53.6299917_Ellerbrook_5_6.png
# Parking added: lon_10.2493842_lat_53.6299917_Ellerbrook_5_7.png
# Parking added: lon_10.2493842_lat_53.6299917_Ellerbrook_6_5.png
# Parking added: lon_10.2493842_lat_53.6299917_Ellerbrook_6_6.png
# Parking added: lon_10.2493842_lat_53.6299917_Ellerbrook_6_7.png
# Parking added: lon_10.2493842_lat_53.6299917_Ellerbrook_7_4.png
# Parking added: lon_10.2493842_lat_53.6299917_Ellerbrook_7_5.png
# Parking added: lon_10.2493842_lat_53.6299917_Ellerbrook_7_6.png
# Parking added: lon_10.2493842_lat_53.6299917_Ellerbrook_7_7.png
# Background added: lon_10.2493842_lat_53.6299917_Ellerbrook_8_19.png
# Parking added: lon_10.2493842_lat_53.6299917_Ellerbrook_8_4.png
# Parking added: lon_10.2493842_lat_53.6299917_Ellerbrook_8_5.png
# Parking added: lon_10.2493842_lat_53.6299917_Ellerbrook_8_6.png
# Background added: lon_10.2493842_lat_53.6299917_Ellerbrook_9_12.png
# Parking added: lon_10.2493842_lat_53.6299917_Ellerbrook_9_4.png
# Parking added: lon_10.2493842_lat_53.6299917_Ellerbrook_9_5.png
# Parking added: lon_10.2493842_lat_53.6299917_Ellerbrook_9_6.png
# Background added: lon_10.2594398_lat_53.6359541_Ohlendieck_0_4.png
# Background added: lon_10.2594398_lat_53.6359541_Ohlendieck_11_13.png
# Background added: lon_10.2594398_lat_53.6359541_Ohlendieck_12_19.png
# Background added: lon_10.2594398_lat_53.6359541_Ohlendieck_12_5.png
# Background added: lon_10.2594398_lat_53.6359541_Ohlendieck_13_0.png
# Background added: lon_10.2594398_lat_53.6359541_Ohlendieck_13_10.png
# Background added: lon_10.2594398_lat_53.6359541_Ohlendieck_13_16.png
# Background added: lon_10.2594398_lat_53.6359541_Ohlendieck_15_3.png
# Background added: lon_10.2594398_lat_53.6359541_Ohlendieck_17_10.png
# Background added: lon_10.2594398_lat_53.6359541_Ohlendieck_17_17.png
# Background added: lon_10.2594398_lat_53.6359541_Ohlendieck_17_6.png
# Background added: lon_10.2594398_lat_53.6359541_Ohlendieck_18_14.png
# Background added: lon_10.2594398_lat_53.6359541_Ohlendieck_19_19.png
# Background added: lon_10.2594398_lat_53.6359541_Ohlendieck_1_16.png
# Background added: lon_10.2594398_lat_53.6359541_Ohlendieck_2_12.png
# Background added: lon_10.2594398_lat_53.6359541_Ohlendieck_2_2.png
# Background added: lon_10.2594398_lat_53.6359541_Ohlendieck_5_2.png
# Background added: lon_10.2594398_lat_53.6359541_Ohlendieck_6_0.png
# Background added: lon_10.2594398_lat_53.6359541_Ohlendieck_6_10.png
# Background added: lon_10.2594398_lat_53.6359541_Ohlendieck_6_16.png
# ...
# Background added: lon_9.9398139_lat_53.9224456_Sielsbrook_10_8.png
# Background added: lon_9.9398139_lat_53.9224456_Sielsbrook_11_9.png
# Background added: lon_9.9398139_lat_53.9224456_Sielsbrook_12_11.png
# Background added: lon_9.9398139_lat_53.9224456_Sielsbrook_12_5.png
# Background added: lon_9.9398139_lat_53.9224456_Sielsbrook_12_8.png
# Background added: lon_9.9398139_lat_53.9224456_Sielsbrook_13_5.png
# Background added: lon_9.9398139_lat_53.9224456_Sielsbrook_13_6.png
# Background added: lon_9.9398139_lat_53.9224456_Sielsbrook_14_1.png
# Background added: lon_9.9398139_lat_53.9224456_Sielsbrook_14_10.png
# Background added: lon_9.9398139_lat_53.9224456_Sielsbrook_15_13.png
# Background added: lon_9.9398139_lat_53.9224456_Sielsbrook_15_15.png
# Background added: lon_9.9398139_lat_53.9224456_Sielsbrook_15_5.png
# Background added: lon_9.9398139_lat_53.9224456_Sielsbrook_16_2.png
# Background added: lon_9.9398139_lat_53.9224456_Sielsbrook_16_4.png
# Background added: lon_9.9398139_lat_53.9224456_Sielsbrook_17_8.png
# Background added: lon_9.9398139_lat_53.9224456_Sielsbrook_18_11.png
# Background added: lon_9.9398139_lat_53.9224456_Sielsbrook_18_4.png
# Background added: lon_9.9398139_lat_53.9224456_Sielsbrook_18_8.png
# Background added: lon_9.9398139_lat_53.9224456_Sielsbrook_1_1.png
# Background added: lon_9.9398139_lat_53.9224456_Sielsbrook_1_2.png
# Parking added: lon_9.9398139_lat_53.9224456_Sielsbrook_1_9.png
# Parking added: lon_9.9398139_lat_53.9224456_Sielsbrook_2_10.png
# Background added: lon_9.9398139_lat_53.9224456_Sielsbrook_2_14.png
# Parking added: lon_9.9398139_lat_53.9224456_Sielsbrook_2_8.png
# Parking added: lon_9.9398139_lat_53.9224456_Sielsbrook_2_9.png
# Parking added: lon_9.9398139_lat_53.9224456_Sielsbrook_3_10.png
# Background added: lon_9.9398139_lat_53.9224456_Sielsbrook_3_13.png
# Parking added: lon_9.9398139_lat_53.9224456_Sielsbrook_3_7.png
# Parking added: lon_9.9398139_lat_53.9224456_Sielsbrook_3_8.png
# Parking added: lon_9.9398139_lat_53.9224456_Sielsbrook_3_9.png
# Parking added: lon_9.9398139_lat_53.9224456_Sielsbrook_4_10.png
# Parking added: lon_9.9398139_lat_53.9224456_Sielsbrook_4_7.png
# Parking added: lon_9.9398139_lat_53.9224456_Sielsbrook_4_8.png
# Parking added: lon_9.9398139_lat_53.9224456_Sielsbrook_5_10.png
# Background added: lon_9.9398139_lat_53.9224456_Sielsbrook_5_17.png
# Parking added: lon_9.9398139_lat_53.9224456_Sielsbrook_5_7.png
# Parking added: lon_9.9398139_lat_53.9224456_Sielsbrook_5_8.png
# Background added: lon_9.9398139_lat_53.9224456_Sielsbrook_6_1.png
# Parking added: lon_9.9398139_lat_53.9224456_Sielsbrook_6_10.png
# Background added: lon_9.9398139_lat_53.9224456_Sielsbrook_6_17.png
# Background added: lon_9.9398139_lat_53.9224456_Sielsbrook_6_19.png
# Background added: lon_9.9398139_lat_53.9224456_Sielsbrook_6_2.png
# Parking added: lon_9.9398139_lat_53.9224456_Sielsbrook_6_7.png
# Parking added: lon_9.9398139_lat_53.9224456_Sielsbrook_6_9.png
# Parking added: lon_9.9398139_lat_53.9224456_Sielsbrook_7_10.png
# Background added: lon_9.9398139_lat_53.9224456_Sielsbrook_7_13.png
# Parking added: lon_9.9398139_lat_53.9224456_Sielsbrook_7_6.png
# Parking added: lon_9.9398139_lat_53.9224456_Sielsbrook_7_7.png
# Parking added: lon_9.9398139_lat_53.9224456_Sielsbrook_7_9.png
# Parking added: lon_9.9398139_lat_53.9224456_Sielsbrook_8_10.png
# Parking added: lon_9.9398139_lat_53.9224456_Sielsbrook_8_6.png
# Parking added: lon_9.9398139_lat_53.9224456_Sielsbrook_8_7.png
# Parking added: lon_9.9398139_lat_53.9224456_Sielsbrook_8_8.png
# Parking added: lon_9.9398139_lat_53.9224456_Sielsbrook_8_9.png
# Background added: lon_9.9398139_lat_53.9224456_Sielsbrook_9_17.png
# Parking added: lon_9.9398139_lat_53.9224456_Sielsbrook_9_6.png
# Parking added: lon_9.9398139_lat_53.9224456_Sielsbrook_9_7.png
# Parking added: lon_9.9398139_lat_53.9224456_Sielsbrook_9_8.png
# Parking added: lon_9.9398139_lat_53.9224456_Sielsbrook_9_9.png
# Background added: lon_9.9423746_lat_51.7161249_Schlochau-Ost_0_19.png
# Parking added: lon_9.9423746_lat_51.7161249_Schlochau-Ost_10_10.png
# Parking added: lon_9.9423746_lat_51.7161249_Schlochau-Ost_10_8.png
# Parking added: lon_9.9423746_lat_51.7161249_Schlochau-Ost_10_9.png
# Background added: lon_9.9423746_lat_51.7161249_Schlochau-Ost_11_0.png
# Background added: lon_9.9423746_lat_51.7161249_Schlochau-Ost_11_1.png
# Parking added: lon_9.9423746_lat_51.7161249_Schlochau-Ost_11_8.png
# Parking added: lon_9.9423746_lat_51.7161249_Schlochau-Ost_11_9.png
# Parking added: lon_9.9423746_lat_51.7161249_Schlochau-Ost_12_7.png
# Parking added: lon_9.9423746_lat_51.7161249_Schlochau-Ost_12_8.png
# Parking added: lon_9.9423746_lat_51.7161249_Schlochau-Ost_12_9.png
# Parking added: lon_9.9423746_lat_51.7161249_Schlochau-Ost_13_10.png
# Parking added: lon_9.9423746_lat_51.7161249_Schlochau-Ost_13_7.png
# Parking added: lon_9.9423746_lat_51.7161249_Schlochau-Ost_13_8.png
# Parking added: lon_9.9423746_lat_51.7161249_Schlochau-Ost_13_9.png
# Background added: lon_9.9423746_lat_51.7161249_Schlochau-Ost_14_4.png
# Parking added: lon_9.9423746_lat_51.7161249_Schlochau-Ost_14_6.png
# Parking added: lon_9.9423746_lat_51.7161249_Schlochau-Ost_14_7.png
# Parking added: lon_9.9423746_lat_51.7161249_Schlochau-Ost_14_8.png
# Parking added: lon_9.9423746_lat_51.7161249_Schlochau-Ost_14_9.png
# Parking added: lon_9.9423746_lat_51.7161249_Schlochau-Ost_15_6.png
# Parking added: lon_9.9423746_lat_51.7161249_Schlochau-Ost_15_7.png
# Parking added: lon_9.9423746_lat_51.7161249_Schlochau-Ost_15_8.png
# Parking added: lon_9.9423746_lat_51.7161249_Schlochau-Ost_15_9.png
# Background added: lon_9.9423746_lat_51.7161249_Schlochau-Ost_16_15.png
# Background added: lon_9.9423746_lat_51.7161249_Schlochau-Ost_16_18.png
# Parking added: lon_9.9423746_lat_51.7161249_Schlochau-Ost_16_6.png
# Parking added: lon_9.9423746_lat_51.7161249_Schlochau-Ost_16_7.png
# Parking added: lon_9.9423746_lat_51.7161249_Schlochau-Ost_16_8.png
# Background added: lon_9.9423746_lat_51.7161249_Schlochau-Ost_17_6.png
# Background added: lon_9.9423746_lat_51.7161249_Schlochau-Ost_18_13.png
# Background added: lon_9.9423746_lat_51.7161249_Schlochau-Ost_18_3.png
# Background added: lon_9.9423746_lat_51.7161249_Schlochau-Ost_19_6.png
# Background added: lon_9.9423746_lat_51.7161249_Schlochau-Ost_3_11.png
# Background added: lon_9.9423746_lat_51.7161249_Schlochau-Ost_5_12.png
# Background added: lon_9.9423746_lat_51.7161249_Schlochau-Ost_5_14.png
# Background added: lon_9.9423746_lat_51.7161249_Schlochau-Ost_6_10.png
# Background added: lon_9.9423746_lat_51.7161249_Schlochau-Ost_6_3.png
# Background added: lon_9.9423746_lat_51.7161249_Schlochau-Ost_6_9.png
# Parking added: lon_9.9423746_lat_51.7161249_Schlochau-Ost_7_10.png
# Background added: lon_9.9423746_lat_51.7161249_Schlochau-Ost_7_17.png
# Background added: lon_9.9423746_lat_51.7161249_Schlochau-Ost_7_18.png
# Background added: lon_9.9423746_lat_51.7161249_Schlochau-Ost_7_19.png
# Background added: lon_9.9423746_lat_51.7161249_Schlochau-Ost_7_7.png
# Parking added: lon_9.9423746_lat_51.7161249_Schlochau-Ost_8_10.png
# Parking added: lon_9.9423746_lat_51.7161249_Schlochau-Ost_8_11.png
# Background added: lon_9.9423746_lat_51.7161249_Schlochau-Ost_8_18.png
# Background added: lon_9.9423746_lat_51.7161249_Schlochau-Ost_8_8.png
# Parking added: lon_9.9423746_lat_51.7161249_Schlochau-Ost_8_9.png
# Parking added: lon_9.9423746_lat_51.7161249_Schlochau-Ost_9_10.png
# Background added: lon_9.9423746_lat_51.7161249_Schlochau-Ost_9_7.png
# Parking added: lon_9.9423746_lat_51.7161249_Schlochau-Ost_9_9.png
# Background added: lon_9.946725_lat_53.9405503_Bimöhlen_0_14.png
# Parking added: lon_9.946725_lat_53.9405503_Bimöhlen_10_10.png
# Parking added: lon_9.946725_lat_53.9405503_Bimöhlen_10_11.png
# Parking added: lon_9.946725_lat_53.9405503_Bimöhlen_10_12.png
# Parking added: lon_9.946725_lat_53.9405503_Bimöhlen_10_9.png
# Parking added: lon_9.946725_lat_53.9405503_Bimöhlen_11_10.png
# Parking added: lon_9.946725_lat_53.9405503_Bimöhlen_11_11.png
# Background added: lon_9.946725_lat_53.9405503_Bimöhlen_11_17.png
# Background added: lon_9.946725_lat_53.9405503_Bimöhlen_11_18.png
# Background added: lon_9.946725_lat_53.9405503_Bimöhlen_11_4.png
# Parking added: lon_9.946725_lat_53.9405503_Bimöhlen_12_11.png
# Background added: lon_9.946725_lat_53.9405503_Bimöhlen_13_14.png
# Background added: lon_9.946725_lat_53.9405503_Bimöhlen_15_16.png
# Background added: lon_9.946725_lat_53.9405503_Bimöhlen_16_3.png
# Background added: lon_9.946725_lat_53.9405503_Bimöhlen_16_4.png
# Background added: lon_9.946725_lat_53.9405503_Bimöhlen_17_5.png
# Background added: lon_9.946725_lat_53.9405503_Bimöhlen_17_6.png
# Background added: lon_9.946725_lat_53.9405503_Bimöhlen_19_1.png
# Background added: lon_9.946725_lat_53.9405503_Bimöhlen_19_16.png
# Background added: lon_9.946725_lat_53.9405503_Bimöhlen_1_15.png
# Background added: lon_9.946725_lat_53.9405503_Bimöhlen_1_16.png
# Background added: lon_9.946725_lat_53.9405503_Bimöhlen_1_6.png
# Background added: lon_9.946725_lat_53.9405503_Bimöhlen_2_14.png
# Background added: lon_9.946725_lat_53.9405503_Bimöhlen_3_13.png
# Background added: lon_9.946725_lat_53.9405503_Bimöhlen_3_17.png
# Parking added: lon_9.946725_lat_53.9405503_Bimöhlen_5_10.png
# Parking added: lon_9.946725_lat_53.9405503_Bimöhlen_5_11.png
# Parking added: lon_9.946725_lat_53.9405503_Bimöhlen_5_12.png
# Parking added: lon_9.946725_lat_53.9405503_Bimöhlen_6_10.png
# Parking added: lon_9.946725_lat_53.9405503_Bimöhlen_6_11.png
# Parking added: lon_9.946725_lat_53.9405503_Bimöhlen_6_12.png
# Parking added: lon_9.946725_lat_53.9405503_Bimöhlen_6_9.png
# Parking added: lon_9.946725_lat_53.9405503_Bimöhlen_7_10.png
# Parking added: lon_9.946725_lat_53.9405503_Bimöhlen_7_11.png
# Parking added: lon_9.946725_lat_53.9405503_Bimöhlen_7_12.png
# Background added: lon_9.946725_lat_53.9405503_Bimöhlen_7_18.png
# Background added: lon_9.946725_lat_53.9405503_Bimöhlen_7_7.png
# Parking added: lon_9.946725_lat_53.9405503_Bimöhlen_7_9.png
# Parking added: lon_9.946725_lat_53.9405503_Bimöhlen_8_10.png
# Parking added: lon_9.946725_lat_53.9405503_Bimöhlen_8_11.png
# Parking added: lon_9.946725_lat_53.9405503_Bimöhlen_8_12.png
# Background added: lon_9.946725_lat_53.9405503_Bimöhlen_8_7.png
# Parking added: lon_9.946725_lat_53.9405503_Bimöhlen_8_9.png
# Parking added: lon_9.946725_lat_53.9405503_Bimöhlen_9_10.png
# Parking added: lon_9.946725_lat_53.9405503_Bimöhlen_9_11.png
# Parking added: lon_9.946725_lat_53.9405503_Bimöhlen_9_12.png
# Parking added: lon_9.946725_lat_53.9405503_Bimöhlen_9_9.png
# Background added: lon_9.9534437_lat_53.3780392_Sunderblick_0_12.png
# Background added: lon_9.9534437_lat_53.3780392_Sunderblick_0_3.png
# Parking added: lon_9.9534437_lat_53.3780392_Sunderblick_11_10.png
# Parking added: lon_9.9534437_lat_53.3780392_Sunderblick_11_11.png
# Parking added: lon_9.9534437_lat_53.3780392_Sunderblick_11_12.png
# Parking added: lon_9.9534437_lat_53.3780392_Sunderblick_11_13.png
# Parking added: lon_9.9534437_lat_53.3780392_Sunderblick_12_10.png
# Parking added: lon_9.9534437_lat_53.3780392_Sunderblick_12_11.png
# Parking added: lon_9.9534437_lat_53.3780392_Sunderblick_12_12.png
# Parking added: lon_9.9534437_lat_53.3780392_Sunderblick_12_13.png
# Parking added: lon_9.9534437_lat_53.3780392_Sunderblick_12_14.png
# Parking added: lon_9.9534437_lat_53.3780392_Sunderblick_12_15.png
# Parking added: lon_9.9534437_lat_53.3780392_Sunderblick_13_10.png
# Parking added: lon_9.9534437_lat_53.3780392_Sunderblick_13_11.png
# Parking added: lon_9.9534437_lat_53.3780392_Sunderblick_13_12.png
# Parking added: lon_9.9534437_lat_53.3780392_Sunderblick_13_13.png
# Parking added: lon_9.9534437_lat_53.3780392_Sunderblick_13_14.png
# Parking added: lon_9.9534437_lat_53.3780392_Sunderblick_13_15.png
# Background added: lon_9.9534437_lat_53.3780392_Sunderblick_13_18.png
# Background added: lon_9.9534437_lat_53.3780392_Sunderblick_13_2.png
# Background added: lon_9.9534437_lat_53.3780392_Sunderblick_14_14.png
# Background added: lon_9.9534437_lat_53.3780392_Sunderblick_14_3.png
# Background added: lon_9.9534437_lat_53.3780392_Sunderblick_16_9.png
# Background added: lon_9.9534437_lat_53.3780392_Sunderblick_17_7.png
# Background added: lon_9.9534437_lat_53.3780392_Sunderblick_18_1.png
# Background added: lon_9.9534437_lat_53.3780392_Sunderblick_18_15.png
# Background added: lon_9.9534437_lat_53.3780392_Sunderblick_18_2.png
# Background added: lon_9.9534437_lat_53.3780392_Sunderblick_18_3.png
# Background added: lon_9.9534437_lat_53.3780392_Sunderblick_19_14.png
# Background added: lon_9.9534437_lat_53.3780392_Sunderblick_19_2.png
# Background added: lon_9.9534437_lat_53.3780392_Sunderblick_19_7.png
# Background added: lon_9.9534437_lat_53.3780392_Sunderblick_1_13.png
# Background added: lon_9.9534437_lat_53.3780392_Sunderblick_1_14.png
# Background added: lon_9.9534437_lat_53.3780392_Sunderblick_1_6.png
# Background added: lon_9.9534437_lat_53.3780392_Sunderblick_2_10.png
# Background added: lon_9.9534437_lat_53.3780392_Sunderblick_2_11.png
# Background added: lon_9.9534437_lat_53.3780392_Sunderblick_3_1.png
# Background added: lon_9.9534437_lat_53.3780392_Sunderblick_3_15.png
# Background added: lon_9.9534437_lat_53.3780392_Sunderblick_3_9.png
# Background added: lon_9.9534437_lat_53.3780392_Sunderblick_4_19.png
# Background added: lon_9.9534437_lat_53.3780392_Sunderblick_6_18.png
# Background added: lon_9.9534437_lat_53.3780392_Sunderblick_8_0.png
# Background added: lon_9.9534437_lat_53.3780392_Sunderblick_8_12.png
# Background added: lon_9.9534437_lat_53.3780392_Sunderblick_8_2.png
# Background added: lon_9.9534437_lat_53.3780392_Sunderblick_8_4.png
# Background added: lon_9.9577331_lat_53.3781014_Hittfeld_0_18.png
# Background added: lon_9.9577331_lat_53.3781014_Hittfeld_10_15.png
# Background added: lon_9.9577331_lat_53.3781014_Hittfeld_10_17.png
# Parking added: lon_9.9577331_lat_53.3781014_Hittfeld_10_4.png
# Parking added: lon_9.9577331_lat_53.3781014_Hittfeld_10_5.png
# Parking added: lon_9.9577331_lat_53.3781014_Hittfeld_10_6.png
# Parking added: lon_9.9577331_lat_53.3781014_Hittfeld_10_7.png
# Parking added: lon_9.9577331_lat_53.3781014_Hittfeld_10_8.png
# Parking added: lon_9.9577331_lat_53.3781014_Hittfeld_10_9.png
# Background added: lon_9.9577331_lat_53.3781014_Hittfeld_11_2.png
# Parking added: lon_9.9577331_lat_53.3781014_Hittfeld_11_7.png
# Parking added: lon_9.9577331_lat_53.3781014_Hittfeld_11_8.png
# Parking added: lon_9.9577331_lat_53.3781014_Hittfeld_11_9.png
# Background added: lon_9.9577331_lat_53.3781014_Hittfeld_13_0.png
# Background added: lon_9.9577331_lat_53.3781014_Hittfeld_13_6.png
# Background added: lon_9.9577331_lat_53.3781014_Hittfeld_13_7.png
# Background added: lon_9.9577331_lat_53.3781014_Hittfeld_13_9.png
# Background added: lon_9.9577331_lat_53.3781014_Hittfeld_14_4.png
# Background added: lon_9.9577331_lat_53.3781014_Hittfeld_15_0.png
# Background added: lon_9.9577331_lat_53.3781014_Hittfeld_15_2.png
# Background added: lon_9.9577331_lat_53.3781014_Hittfeld_16_0.png
# Background added: lon_9.9577331_lat_53.3781014_Hittfeld_16_17.png
# Background added: lon_9.9577331_lat_53.3781014_Hittfeld_18_1.png
# Background added: lon_9.9577331_lat_53.3781014_Hittfeld_19_1.png
# Background added: lon_9.9577331_lat_53.3781014_Hittfeld_19_7.png
# Background added: lon_9.9577331_lat_53.3781014_Hittfeld_1_13.png
# Background added: lon_9.9577331_lat_53.3781014_Hittfeld_2_8.png
# Background added: lon_9.9577331_lat_53.3781014_Hittfeld_3_17.png
# Background added: lon_9.9577331_lat_53.3781014_Hittfeld_5_1.png
# Background added: lon_9.9577331_lat_53.3781014_Hittfeld_7_16.png
# Background added: lon_9.9577331_lat_53.3781014_Hittfeld_8_10.png
# Background added: lon_9.9577331_lat_53.3781014_Hittfeld_9_0.png
# Parking added: lon_9.9577331_lat_53.3781014_Hittfeld_9_10.png
# Background added: lon_9.9577331_lat_53.3781014_Hittfeld_9_12.png
# Background added: lon_9.9577331_lat_53.3781014_Hittfeld_9_4.png
# Parking added: lon_9.9577331_lat_53.3781014_Hittfeld_9_7.png
# Parking added: lon_9.9577331_lat_53.3781014_Hittfeld_9_8.png
# Parking added: lon_9.9577331_lat_53.3781014_Hittfeld_9_9.png
# Finished copying at 2024-04-23 16:04:49 in 29.28 seconds.
# Total evaluated: 75828
# Total background discarded: 66672
# Total copied: 9156
# thereof parking: 4768
# thereof background: 4388

# %% [markdown]
# Main experiment: From the 4,516 evaluated images, 2,907 were discarded as pure background images. The final dataset contains 1,609 images, of which 842 include parking spaces as well as 767 pure background images.
#
# Tiling experiment 256: From the 18,663 evaluated images, 14,994 were discarded as pure background images. The final dataset contains 3,669 images, of which 1,933 include parking spaces as well as 1,736 pure background images.
#
# Tiling experiment 128: From the 75,828 evaluated images, 66,672 were discarded as pure background images. The final dataset contains 9,156 images, of which 4,768 include parking spaces as well as 4,388 pure background images.

# %% [markdown]
# # Create train/val folder

# %%
def split_and_copy_data(base_input_path, test_size=0.2, random_seed=42):
    """
    Splits data into training and validation sets ensuring no image is split across sets,
    and stratifies groups by the number of tiles containing parking, with a special category for more than 10 parking tiles.
    """
    # Define directories
    images_dir = os.path.join(base_input_path, "images")
    masks_dir = os.path.join(base_input_path, "masks")
    train_image_dir = os.path.join(base_input_path, "train", "images")
    train_mask_dir = os.path.join(base_input_path, "train", "masks")
    val_image_dir = os.path.join(base_input_path, "val", "images")
    val_mask_dir = os.path.join(base_input_path, "val", "masks")

    # Create directories
    os.makedirs(train_image_dir, exist_ok=True)
    os.makedirs(train_mask_dir, exist_ok=True)
    os.makedirs(val_image_dir, exist_ok=True)
    os.makedirs(val_mask_dir, exist_ok=True)

    # Get and sort filenames
    image_files = [f for f in os.listdir(images_dir) if f.endswith('.png')]
    mask_files = [f for f in os.listdir(masks_dir) if f.endswith('.png')]
    image_files.sort()
    mask_files.sort()

    # Group by source image
    groups = {}
    for file_name in image_files:
        group_key = '_'.join(file_name.split('_')[:5]) 
        if group_key not in groups:
            groups[group_key] = []
        groups[group_key].append(file_name)

    # Calculate number of tiles containing parking in each group
    parking_counts = []
    for group in groups:
        parking_tiles_count = 0
        for file_name in groups[group]:
            mask_path = os.path.join(masks_dir, file_name.replace("images", "masks"))
            mask = Image.open(mask_path)
            mask_array = np.array(mask)
            if np.any(mask_array == 100) or np.any(mask_array == 200) or np.any(mask_array == 250): 
                parking_tiles_count += 1

    # Split data using stratification by number of parking tiles
    try:
        groups_train, groups_val = train_test_split(list(groups.keys()), test_size=test_size, random_state=random_seed, stratify=parking_counts)
    except ValueError as e:
        print("Error with stratification:", e)
        groups_train, groups_val = train_test_split(list(groups.keys()), test_size=test_size, random_state=random_seed)

    # Copy function
    def copy_grouped_files(group_keys, src_dir, dest_dir):
        for key in group_keys:
            for file_name in groups[key]:
                src_file_path = os.path.join(src_dir, file_name)
                dest_file_path = os.path.join(dest_dir, file_name)
                shutil.copy(src_file_path, dest_file_path)

    # Copy files to respective directories
    copy_grouped_files(groups_train, images_dir, train_image_dir)
    copy_grouped_files(groups_train, masks_dir, train_mask_dir)
    copy_grouped_files(groups_val, images_dir, val_image_dir)
    copy_grouped_files(groups_val, masks_dir, val_mask_dir)

    print(f"Data successfully split and copied.\nTraining images: {len(groups_train)}, Validation images: {len(groups_val)}")

# %%
# Create training and validation folders
base_input_path = "02_mask_creation_and_split/train_validate_images_masks_reduced_128"
split_and_copy_data(base_input_path, test_size=0.2, random_seed=42)
# Out:
# Error with stratification: Found array with 0 sample(s) (shape=(0,)) while a minimum of 1 is required.
# Data successfully split and copied.
# Training images: 177, Validation images: 45

# %%
def count_image_intensities(folder_dir):
    """
    Count car, truck and pure background masks in folder.
    """
    count_all_zero = 0
    count_include_100 = 0
    count_include_200 = 0
    count_include_250 = 0
    count_include_100_200_250 = 0

    # Loop through all image files in the folder
    for filename in os.listdir(folder_dir):
        if filename.lower().endswith(".png"):
            img_path = os.path.join(folder_dir, filename)
            img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)

            # Check if the entire image is black
            if np.all(img == 0):
                count_all_zero += 1

            # Check if the image includes pixel intensities of 100
            if np.any(img == 100):
                count_include_100 += 1

            # Check if the image includes pixel intensities of 200
            if np.any(img == 200):
                count_include_200 += 1

            # Check if the image includes pixel intensities of 250
            if np.any(img == 250):
                count_include_250 += 1

            # Check if the image includes pixel intensities of 100 or 200
            if np.any(img == 100) or np.any(img == 200) or np.any(img == 250):
                count_include_100_200_250 += 1

    total_count = count_all_zero + count_include_100_200_250

    return total_count, count_all_zero, count_include_100, count_include_200, count_include_250, count_include_100_200_250

# %%
# Count the instances of car and truck parking as well as background in the train/val folder
train_dir = "02_mask_creation_and_split/train_validate_images_masks_reduced_128/train/masks"
val_dir = "02_mask_creation_and_split/train_validate_images_masks_reduced_128/val/masks"

total_count, count_all_zero, count_include_100, count_include_200, count_include_250, count_include_100_200_250 = count_image_intensities(train_dir)

share_parking = round(count_include_100_200_250/total_count, 2)
share_background = round(count_all_zero/total_count, 2)
share_car = round(count_include_100/count_include_100_200_250, 2)
share_truck = round(count_include_200/count_include_100_200_250, 2)
share_quick = round(count_include_250/count_include_100_200_250, 2)

print("Training set:")
print(f"Total count: {total_count}")
print(f"Background images: {count_all_zero}")
print(f"Images including car parking: {count_include_100}")
print(f"Images including truck parking: {count_include_200}")
print(f"Images including quick parking: {count_include_250}")
print(f"Images including car, truck or quick parking: {count_include_100_200_250}")
print(f"Share of parking tiles of total tiles: {share_parking}")
print(f"Share of background tiles of total tiles: {share_background}")
print(f"Share of car parking tiles of parking tiles: {share_car}")
print(f"Share of truck parking tiles of parking tiles: {share_truck}")
print(f"Share of quick parking tiles of parking tiles: {share_quick}")

total_count, count_all_zero, count_include_100, count_include_200, count_include_250, count_include_100_200_250 = count_image_intensities(val_dir)

share_parking = round(count_include_100_200_250/total_count, 2)
share_background = round(count_all_zero/total_count, 2)
share_car = round(count_include_100/count_include_100_200_250, 2)
share_truck = round(count_include_200/count_include_100_200_250, 2)
share_quick = round(count_include_250/count_include_100_200_250, 2)

print("Validation set:")
print(f"Total count: {total_count}")
print(f"Background images: {count_all_zero}")
print(f"Images including car parking: {count_include_100}")
print(f"Images including truck parking: {count_include_200}")
print(f"Images including quick parking: {count_include_250}")
print(f"Images including car, truck or quick parking: {count_include_100_200_250}")
print(f"Share of parking tiles of total tiles: {share_parking}")
print(f"Share of background tiles of total tiles: {share_background}")
print(f"Share of car parking tiles of parking tiles: {share_car}")
print(f"Share of truck parking tiles of parking tiles: {share_truck}")
print(f"Share of quick parking tiles of parking tiles: {share_quick}")
# Out:
# Training set:
# Total count: 7264
# Background images: 3460
# Images including car parking: 1425
# Images including truck parking: 2238
# Images including quick parking: 1076
# Images including car, truck or quick parking: 3804
# Share of parking tiles of total tiles: 0.52
# Share of background tiles of total tiles: 0.48
# Share of car parking tiles of parking tiles: 0.37
# Share of truck parking tiles of parking tiles: 0.59
# Share of quick parking tiles of parking tiles: 0.28
# Validation set:
# Total count: 1890
# Background images: 926
# Images including car parking: 395
# Images including truck parking: 529
# Images including quick parking: 237
# Images including car, truck or quick parking: 964
# Share of parking tiles of total tiles: 0.51
# Share of background tiles of total tiles: 0.49
# Share of car parking tiles of parking tiles: 0.41
# Share of truck parking tiles of parking tiles: 0.55
# Share of quick parking tiles of parking tiles: 0.25

# %% [markdown]
# For 512x512:
#
# The training set includes 1,282 tiles, of which 404 include car parking, 445 include truck parking, 261 include quick parking and 712 include car, truck or quick parking. 617 images are pure background images.
#
# The validation set includes 327 images, of which 110 include car parking, 119 include truck parking, 84 include quick parking and 184 include car, truck or quick parking. 150 images are pure background images.

# %% [markdown]
# ## Create split visualization

# %%
def count_image_intensities_with_combinations(folder_dir):
    """
    Count combinations of car, truck, and quick parking masks in folder,
    including total number of tiles.
    """
    combinations = Counter()
    total_tiles = 0

    # Loop through all image files in the folder
    for filename in os.listdir(folder_dir):
        if filename.lower().endswith('.png'):
            total_tiles += 1
            img_path = os.path.join(folder_dir, filename)
            img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)

            # Check combination
            combination = []
            if np.all(img == 0):
                combination.append("Pure Background")
            if np.any(img == 100):
                combination.append("Car")
            if np.any(img == 200):
                combination.append("Truck")
            if np.any(img == 250):
                combination.append("Pull-Off")

            if combination:
                combinations[tuple(combination)] += 1

    return combinations, total_tiles

# %%
# Define directory paths
train_dir = "02_mask_creation_and_split/train_validate_images_masks_reduced/train/masks"
val_dir = "02_mask_creation_and_split/train_validate_images_masks_reduced/val/masks"

# Collect data
train_combinations, train_total = count_image_intensities_with_combinations(train_dir)
val_combinations, val_total = count_image_intensities_with_combinations(val_dir)

# Merge data for plotting
all_keys = set(train_combinations.keys()).union(val_combinations.keys())
sorted_keys = sorted(all_keys, key=lambda k: train_combinations.get(k, 0) + val_combinations.get(k, 0), reverse=True)

# Prepare labels and counts for plotting
labels = ['Total'] + [" + ".join(k) for k in sorted_keys]

train_counts = [train_total] + [train_combinations.get(k, 0) for k in sorted_keys]
val_counts = [val_total] + [val_combinations.get(k, 0) for k in sorted_keys]

# %%
# Show labels
labels
# Out:
# ['Total',
#  'Pure Background',
#  'Truck',
#  'Car',
#  'Pull-Off',
#  'Truck + Pull-Off',
#  'Car + Truck',
#  'Car + Pull-Off',
#  'Car + Truck + Pull-Off']

# %%
x = np.arange(len(labels))  # the label locations

fig, ax = plt.subplots()
rects1 = ax.bar(x, train_counts, label='Training Set')
rects2 = ax.bar(x, val_counts, bottom=train_counts, label='Validation Set')

# Add some text for labels, title, and custom x-axis tick labels, etc.
ax.set_ylabel('Number of Tiles')
ax.set_xticks(x)
ax.set_xticklabels(labels, rotation=45, ha='right')
ax.legend()

fig.tight_layout()

plt.show()

# %%
totals = [t + v for t, v in zip(train_counts, val_counts)]  # Total counts for each category

# Normalize counts to percentage
train_percents = [t / total * 100 if total != 0 else 0 for t, total in zip(train_counts, totals)]
val_percents = [v / total * 100 if total != 0 else 0 for v, total in zip(val_counts, totals)]

x = np.arange(len(labels))

fig, ax = plt.subplots()
rects1 = ax.bar(x, train_percents, label="Training Set")
rects2 = ax.bar(x, val_percents, bottom=train_percents, label='Validation Set')

# Add labels with percentages on the bars
def add_labels(rects):
    for rect in rects:
        height = rect.get_height()
        if height > 5:
            ax.annotate(f"{height:.1f}%",
                        xy=(rect.get_x() + rect.get_width() / 2, rect.get_y() + height/2),
                        xytext=(0, 0),
                        textcoords="offset points",
                        ha="center", va="center",
                        color="white", fontsize=9)

add_labels(rects1)
add_labels(rects2)

ax.set_ylabel("Percentage of Tiles")
ax.set_xticks(x)
ax.set_xticklabels(labels, rotation=45, ha="right")

fig.tight_layout()
plt.show()
