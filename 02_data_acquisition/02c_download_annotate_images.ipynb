# %% [markdown]
# # Libraries and Google Drive

# %%
import pandas as pd
import numpy as np
import geopandas as gpd

from owslib.wms import WebMapService
import matplotlib.pyplot as plt

from PIL import Image
from IPython.display import display
from IPython.display import Image as displayImage

import io
from io import BytesIO
import time
import random
import os

import rasterio
from rasterio.transform import from_bounds
from rasterio.plot import show
from rasterio.crs import CRS
import rasterio.features
from rasterio.features import geometry_mask

import shapely
from shapely.geometry import Polygon, LineString

from pyproj import Geod
from pyproj import Transformer
from geopy.distance import distance

import math

import ast

# %%
# Mount Drive
#from google.colab import drive
#drive.mount("/content/drive")

# %%
# Set wd
os.chdir('/Users/benediktkorbach/Documents/GitHub/remote-sensing-of-parking-areas')

print("Working directory:", os.getcwd())
# Out:
# Working directory: /Users/benediktkorbach/Documents/GitHub/remote-sensing-of-parking-areas

# %% [markdown]
# # Import csv of correctly/wrongly labelled service stations and extract associated polygons

# %%
# Load correctly_labelled_service_stations csv and transform to list
correctly_labelled_service_stations_path = "02_data_acquisition/verified_parking_data/service_stations/correctly_labelled_service_stations.csv"
wrongly_labelled_service_stations_path = "02_data_acquisition/verified_parking_data/service_stations/wrongly_labelled_service_stations.csv"

# Read the CSV file into a pandas DataFrame
correctly_labelled_service_stations = pd.read_csv(correctly_labelled_service_stations_path)
wrongly_labelled_service_stations = pd.read_csv(wrongly_labelled_service_stations_path)

# Transform df to list
correctly_labelled_service_stations_list = []
for row in correctly_labelled_service_stations.values.tolist():
    correctly_labelled_service_stations_list.extend(row)

wrongly_labelled_service_stations_list = []
for row in wrongly_labelled_service_stations.values.tolist():
    wrongly_labelled_service_stations_list.extend(row)

# Print first 5 items of correctly_labelled_service_stations_list
print(correctly_labelled_service_stations[:5])
print("\n")
print("Number of correctly labelled service stations:", len(correctly_labelled_service_stations_list))
# Out:
#                          id_rest
# 0   lon_8.6630029_lat_50.2542348
# 1  lon_11.3531491_lat_50.9378362
# 2   lon_10.2712414_lat_53.331074
# 3   lon_9.6300119_lat_53.8303266
# 4   lon_9.6297338_lat_53.8301666
#
#
# Number of correctly labelled service stations: 296

# %%
# Load the GeoJSON files containing service station polygons and truck/car/quick parking polygons together with service station IDs

corrected_parking = gpd.read_file("02_data_acquisition/verified_parking_data/parking/corrected_parking.geojson") # polygons of car, truck and quick parking space
rest_stations = gpd.read_file("02_data_acquisition/parking_data/rest_stations.geojson") # polygons and ids of rest stations

# %%
rest_stations.shape
# Out:
# (506, 5)

# %%
# Create geopandas geodataframes that only contain polygons of correctly/wrongly labelled service stations

print("Shape of corrected_parking before dropping irrelevant rows:", corrected_parking.shape)
print("Shape of rest_stations before dropping irrelevant rows:", rest_stations.shape)

# Drop all rows not corresponding to correctly labelled service stations
parking_at_correct= corrected_parking[corrected_parking["id_rest"].isin(correctly_labelled_service_stations_list)]
correctly_labelled_service_stations = rest_stations[rest_stations["id"].isin(correctly_labelled_service_stations_list)]

# Drop all rows corresponding to correctly labelled service stations
parking_at_wrong = corrected_parking[corrected_parking["id_rest"].isin(wrongly_labelled_service_stations_list)]
wrongly_labelled_service_stations = rest_stations[rest_stations["id"].isin(wrongly_labelled_service_stations_list)]

print("Shape of parking_at_correct:", parking_at_correct.shape)
print("Shape of correctly_labelled_service_stations:", correctly_labelled_service_stations.shape)

print("Shape of parking_at_wrong:", parking_at_wrong.shape)
print("Shape of wrongly_labelled_service_stations:", wrongly_labelled_service_stations.shape)
# Out:
# Shape of corrected_parking before dropping irrelevant rows: (1606, 6)
# Shape of rest_stations before dropping irrelevant rows: (506, 5)
# Shape of parking_at_correct: (1304, 6)
# Shape of correctly_labelled_service_stations: (296, 5)
# Shape of parking_at_wrong: (299, 6)
# Shape of wrongly_labelled_service_stations: (208, 5)

# %% [markdown]
# ## Clean up dataframes

# %%
# Drop irrelevant columns, reorder columns, reset index of parking_at_correct

parking_at_correct = parking_at_correct.drop(["id_car", "name"], axis = 1)
parking_at_correct = parking_at_correct.rename(columns={"@id": "id_OSM_parking"})
parking_at_correct = parking_at_correct.reindex(columns=["id_rest", "id_OSM_parking", "type", "geometry"])
parking_at_correct = parking_at_correct.reset_index(drop = True)

parking_at_correct.head()
# Out:
#                          id_rest     id_OSM_parking type  \
# 0   lon_10.2712414_lat_53.331074  relation/13277623  car
# 1   lon_7.5846163_lat_53.2588511       way/33526884  car
# 2   lon_7.2005154_lat_52.2816225       way/38125314  car
# 3   lon_10.7306355_lat_50.559048       way/48905621  car
# 4  lon_10.7298729_lat_50.5605634       way/48925325  car
#
#                                             geometry
# 0  MULTIPOLYGON (((10.26848 53.33228, 10.26872 53...
# 1  POLYGON ((7.58527 53.25883, 7.58618 53.25869, ...
# 2  POLYGON ((7.19685 52.28128, 7.19692 52.28127, ...
# 3  POLYGON ((10.73083 50.55915, 10.73087 50.55881...
# 4  POLYGON ((10.72986 50.56033, 10.72980 50.56026...

# %%
# Drop irrelevant columns, reorder columns, reset index of correctly_labelled_service_stations

correctly_labelled_service_stations = correctly_labelled_service_stations.rename(columns={"id": "id_rest", "@id": "id_OSM_rest"})
correctly_labelled_service_stations = correctly_labelled_service_stations.drop("highway", axis = 1)
correctly_labelled_service_stations = correctly_labelled_service_stations.reset_index(drop = True)

correctly_labelled_service_stations.head()
# Out:
#                          id_rest   id_OSM_rest          name  \
# 0   lon_8.6630029_lat_50.2542348  way/22568867   Schäferborn
# 1  lon_11.3531491_lat_50.9378362  way/27549694  Habichtsfang
# 2   lon_10.2712414_lat_53.331074  way/29376062        Roddau
# 3   lon_9.6300119_lat_53.8303266  way/31128689     Steinburg
# 4   lon_9.6297338_lat_53.8301666  way/31128716     Steinburg
#
#                                             geometry
# 0  POLYGON ((8.66300 50.25423, 8.66302 50.25237, ...
# 1  POLYGON ((11.35315 50.93784, 11.35315 50.93783...
# 2  POLYGON ((10.27124 53.33107, 10.27096 53.33121...
# 3  POLYGON ((9.63001 53.83033, 9.63273 53.82905, ...
# 4  POLYGON ((9.62973 53.83017, 9.62965 53.83010, ...

# %%
# Drop irrelevant columns, reorder columns, reset index of parking_at_wrong

parking_at_wrong = parking_at_wrong.drop(["id_car", "name"], axis = 1)
parking_at_wrong = parking_at_wrong.rename(columns={"@id": "id_OSM_parking"})
parking_at_wrong = parking_at_wrong.reindex(columns=["id_rest", "id_OSM_parking", "type", "geometry"])
parking_at_wrong = parking_at_wrong.reset_index(drop = True)

parking_at_wrong.head()
# Out:
#                          id_rest     id_OSM_parking   type  \
# 0  lon_10.2703215_lat_53.3301407  relation/13277622    car
# 1   lon_12.140788_lat_52.2431929  relation/15482166  truck
# 2   lon_12.149456_lat_52.2449316  relation/15482306    car
# 3    lon_9.323161_lat_54.0686721       way/31129920    car
# 4  lon_11.2481831_lat_52.1991827       way/42750034    car
#
#                                             geometry
# 0  MULTIPOLYGON (((10.26903 53.33039, 10.26926 53...
# 1  MULTIPOLYGON (((12.14216 52.24271, 12.14213 52...
# 2  MULTIPOLYGON (((12.14713 52.24497, 12.14717 52...
# 3  POLYGON ((9.32127 54.06898, 9.32314 54.06861, ...
# 4  POLYGON ((11.24512 52.19985, 11.24526 52.19971...

# %%
# Drop irrelevant columns, reorder columns, reset index of wrongly_labelled_service_stations

wrongly_labelled_service_stations = wrongly_labelled_service_stations.rename(columns={"id": "id_rest", "@id": "id_OSM_rest"})
wrongly_labelled_service_stations = wrongly_labelled_service_stations.drop("highway", axis = 1)
wrongly_labelled_service_stations = wrongly_labelled_service_stations.reset_index(drop = True)

wrongly_labelled_service_stations.head()
# Out:
#                          id_rest       id_OSM_rest                   name  \
# 0  lon_11.2442867_lat_51.3248863  relation/3947321     Hohe Schrecke West
# 1  lon_13.5458137_lat_52.7129474  relation/4672225            Probstheide
# 2   lon_13.549042_lat_52.7092396  relation/4672228       Ladeburger Heide
# 3   lon_8.6624068_lat_50.2544468      way/22568868              Spießwald
# 4   lon_8.6184146_lat_49.7896285      way/28329065  Rastplatz Rolandshöhe
#
#                                             geometry
# 0  MULTIPOLYGON (((11.24429 51.32489, 11.24430 51...
# 1  POLYGON ((13.54581 52.71295, 13.54556 52.71258...
# 2  POLYGON ((13.54904 52.70924, 13.54912 52.70919...
# 3  POLYGON ((8.66241 50.25445, 8.66205 50.25369, ...
# 4  POLYGON ((8.61841 49.78963, 8.61857 49.79067, ...

# %% [markdown]
# ## Download dataframes

# %%
# Check shapes of dataframes

print("Shape of parking_at_correct:", parking_at_correct.shape)
print("Shape of correctly_labelled_service_stations:", correctly_labelled_service_stations.shape)
print("Shape of parking_at_wrong:", parking_at_wrong.shape)
print("Shape of wrongly_labelled_service_stations:", wrongly_labelled_service_stations.shape)
# Out:
# Shape of parking_at_correct: (1304, 4)
# Shape of correctly_labelled_service_stations: (296, 4)
# Shape of parking_at_wrong: (299, 4)
# Shape of wrongly_labelled_service_stations: (208, 4)

# %%
# Download geopandas geodataframes as GeoJSONs

# Specify the path where you want to save the GeoJSON file
output_path_parking_at_correct = "02_data_acquisition/verified_parking_data/parking/parking_at_correct.geojson"
output_path_correctly_labelled_service_stations = "02_data_acquisition/verified_parking_data/service_stations/correctly_labelled_service_stations.geojson"
output_path_parking_at_wrong = "02_data_acquisition/verified_parking_data/parking/parking_at_wrong.geojson"
output_path_wrongly_labelled_service_stations = "02_data_acquisition/verified_parking_data/service_stations/wrongly_labelled_service_stations.geojson"

# Export the GeoPandas DataFrame to GeoJSON
parking_at_correct.to_file(output_path_parking_at_correct, driver='GeoJSON')
correctly_labelled_service_stations.to_file(output_path_correctly_labelled_service_stations, driver='GeoJSON')
parking_at_wrong.to_file(output_path_parking_at_wrong, driver='GeoJSON')
wrongly_labelled_service_stations.to_file(output_path_wrongly_labelled_service_stations, driver='GeoJSON')

# %% [markdown]
# # Load GeoJSONs and define bounding boxes for download

# %%
# Load the GeoJSON files of correctly labelled service stations and parking areas
parking_at_correct = gpd.read_file("02_data_acquisition/verified_parking_data/parking/parking_at_correct.geojson") # polygons of parkings areas at correctly labelled service stations
correctly_labelled_service_stations = gpd.read_file("02_data_acquisition/verified_parking_data/service_stations/correctly_labelled_service_stations.geojson") # polygons of verified rest stops

# Load the GeoJSON files of wrongly labelled service stations
parking_at_wrong = gpd.read_file("02_data_acquisition/verified_parking_data/parking/parking_at_wrong.geojson") # polygons of parkings areas at wrongly labelled service stations

# %%
parking_at_correct
# Out:
#                             id_rest     id_OSM_parking   type  \
# 0      lon_10.2712414_lat_53.331074  relation/13277623    car
# 1      lon_7.5846163_lat_53.2588511       way/33526884    car
# 2      lon_7.2005154_lat_52.2816225       way/38125314    car
# 3      lon_10.7306355_lat_50.559048       way/48905621    car
# 4     lon_10.7298729_lat_50.5605634       way/48925325    car
# ...                             ...                ...    ...
# 1299  lon_11.0467665_lat_51.4688222     way/1194289084  truck
# 1300  lon_11.0467665_lat_51.4688222     way/1194289085  truck
# 1301  lon_11.0467665_lat_51.4688222     way/1194289086  truck
# 1302  lon_11.0467665_lat_51.4688222     way/1194289087  quick
# 1303  lon_11.0467665_lat_51.4688222     way/1194289095  quick
#
#                                                geometry
# 0     MULTIPOLYGON (((10.26848 53.33228, 10.26872 53...
# 1     POLYGON ((7.58527 53.25883, 7.58618 53.25869, ...
# 2     POLYGON ((7.19685 52.28128, 7.19692 52.28127, ...
# 3     POLYGON ((10.73083 50.55915, 10.73087 50.55881...
# 4     POLYGON ((10.72986 50.56033, 10.72980 50.56026...
# ...                                                 ...
# 1299  POLYGON ((11.04380 51.46788, 11.04414 51.46784...
# 1300  POLYGON ((11.04439 51.46815, 11.04445 51.46815...
# 1301  POLYGON ((11.04503 51.46846, 11.04506 51.46846...
# 1302  POLYGON ((11.04375 51.46758, 11.04399 51.46763...
# 1303  POLYGON ((11.04365 51.46793, 11.04365 51.46788...
#
# [1304 rows x 4 columns]

# %%
correctly_labelled_service_stations
# Out:
#                            id_rest     id_OSM_rest                      name  \
# 0     lon_8.6630029_lat_50.2542348    way/22568867               Schäferborn
# 1    lon_11.3531491_lat_50.9378362    way/27549694              Habichtsfang
# 2     lon_10.2712414_lat_53.331074    way/29376062                    Roddau
# 3     lon_9.6300119_lat_53.8303266    way/31128689                 Steinburg
# 4     lon_9.6297338_lat_53.8301666    way/31128716                 Steinburg
# ..                             ...             ...                       ...
# 291  lon_12.7580653_lat_52.8778128   way/915630046               Am Rhinluch
# 292   lon_7.2005154_lat_52.2816225   way/988014767         Gut Friedrichstal
# 293   lon_8.5597202_lat_49.5969765   way/992004892                  Wildbahn
# 294   lon_10.7306355_lat_50.559048  way/1171916133                Adlersberg
# 295   lon_9.7695159_lat_52.5102873  way/1192709800  Rastplatz Bissendorf Süd
#
#                                               geometry
# 0    POLYGON ((8.66300 50.25423, 8.66302 50.25237, ...
# 1    POLYGON ((11.35315 50.93784, 11.35315 50.93783...
# 2    POLYGON ((10.27124 53.33107, 10.27096 53.33121...
# 3    POLYGON ((9.63001 53.83033, 9.63273 53.82905, ...
# 4    POLYGON ((9.62973 53.83017, 9.62965 53.83010, ...
# ..                                                 ...
# 291  POLYGON ((12.75807 52.87781, 12.75786 52.87778...
# 292  POLYGON ((7.20052 52.28162, 7.20053 52.28167, ...
# 293  POLYGON ((8.55972 49.59698, 8.55958 49.59693, ...
# 294  POLYGON ((10.73064 50.55905, 10.73067 50.55851...
# 295  POLYGON ((9.76952 52.51029, 9.77003 52.51132, ...
#
# [296 rows x 4 columns]

# %%
wrongly_labelled_service_stations
# Out:
#                            id_rest       id_OSM_rest  \
# 0    lon_11.2442867_lat_51.3248863  relation/3947321
# 1    lon_13.5458137_lat_52.7129474  relation/4672225
# 2     lon_13.549042_lat_52.7092396  relation/4672228
# 3     lon_8.6624068_lat_50.2544468      way/22568868
# 4     lon_8.6184146_lat_49.7896285      way/28329065
# ..                             ...               ...
# 203   lon_7.2459984_lat_52.3914582    way/1024211059
# 204   lon_7.2465958_lat_52.3950579    way/1024211060
# 205   lon_8.5358385_lat_49.5561227    way/1075944398
# 206    lon_8.4350744_lat_50.607106    way/1104993376
# 207   lon_8.6089092_lat_49.5422193    way/1172007491
#
#                                name  \
# 0                Hohe Schrecke West
# 1                       Probstheide
# 2                  Ladeburger Heide
# 3                         Spießwald
# 4             Rastplatz Rolandshöhe
# ..                              ...
# 203      Rastplatz Bergler Feld Ost
# 204     Rastplatz Bergler Feld West
# 205                      Rennschlag
# 206  Park und Rastplatz Am Behlkopf
# 207                            None
#
#                                               geometry
# 0    MULTIPOLYGON (((11.24429 51.32489, 11.24430 51...
# 1    POLYGON ((13.54581 52.71295, 13.54556 52.71258...
# 2    POLYGON ((13.54904 52.70924, 13.54912 52.70919...
# 3    POLYGON ((8.66241 50.25445, 8.66205 50.25369, ...
# 4    POLYGON ((8.61841 49.78963, 8.61857 49.79067, ...
# ..                                                 ...
# 203  POLYGON ((7.24600 52.39146, 7.24561 52.38924, ...
# 204  POLYGON ((7.24660 52.39506, 7.24656 52.39511, ...
# 205  POLYGON ((8.53584 49.55612, 8.53523 49.55625, ...
# 206  POLYGON ((8.43507 50.60711, 8.43507 50.60706, ...
# 207  POLYGON ((8.60891 49.54222, 8.60955 49.54229, ...
#
# [208 rows x 4 columns]

# %% [markdown]
# ## Determine download bounding boxes

# %% [markdown]
# ### Define function

# %%
def create_image_bounding_box(polygon, bbox_size_m = 500):
    """
    Create an output bounding box that fully covers the input bounding box and is of size bbox_size_m x bbox_size_m.

    Parameters:
    polygon (shapely Polygon): input polygon
    bbox_size_m (int): size of the output bounding box

    Returns:
    The output bounding box as [left, bottom, right, top]
    """

    minx, miny, maxx, maxy = polygon.bounds

    # Calculate the centre of the input bounding box
    centre_x = (miny + maxy) / 2
    centre_y = (minx + maxx) / 2

    distance_from_centre = bbox_size_m / 2

    # Calculate the coordinates distance_from_centre meters north, south, east, and west of the center
    north = distance(meters=distance_from_centre).destination((centre_x, centre_y), bearing=0).latitude
    south = distance(meters=distance_from_centre).destination((centre_x, centre_y), bearing=180).latitude
    east = distance(meters=distance_from_centre).destination((centre_x, centre_y), bearing=90).longitude
    west = distance(meters=distance_from_centre).destination((centre_x, centre_y), bearing=270).longitude

    # Calculate the maximum allowable shift in each direction to keep the input bbox within the output bbox
    max_shift_north = north - maxy
    max_shift_south = miny - south
    max_shift_east = east - maxx
    max_shift_west = minx - west

    # Randomly shift the center within the allowable range
    shift_x = random.uniform(-min(max_shift_west, distance_from_centre), min(max_shift_east, distance_from_centre))
    shift_y = random.uniform(-min(max_shift_south, distance_from_centre), min(max_shift_north, distance_from_centre))

    # Calculate the final output bounding box
    output_bbox = [
        west + shift_x,  # left
        south + shift_y, # bottom
        east + shift_x,  # right
        north + shift_y  # top
    ]

    return output_bbox

# %%
def determine_bbox_max_span_m(bbox):
    """
    Determine the size of a bounding box in meters.

    Parameters:
    bbox (list): bounding box as [left, bottom, right, top]
    """

    minx, miny, maxx, maxy = bbox

    x_line = shapely.LineString([(minx, miny), (maxx, miny)])
    y_line = shapely.LineString([(minx, miny), (minx, maxy)])

    geod = Geod(ellps="WGS84")

    length_x = math.ceil(geod.geometry_length(x_line))
    length_y = math.ceil(geod.geometry_length(y_line))

    print(f"The bounding box has a width of: {length_x}m and a height of: {length_y}m")

# %% [markdown]
# ### Test function

# %%
# Extract random rest stop polygon

random_index = random.randint(0, 266)
print("Random index:", random_index)

# Extract polygon
test_polygon = correctly_labelled_service_stations.iloc[random_index]["geometry"]
print(test_polygon)
# Out:
# Random index: 242
# POLYGON ((8.0316758 52.415733, 8.0315558 52.415725, 8.032054 52.4121665, 8.0321693 52.4121753, 8.032627 52.4122906, 8.0330226 52.4127078, 8.033087 52.4129957, 8.0328295 52.4145074, 8.032328 52.4155979, 8.0318828 52.4158139, 8.0316758 52.415733))

# %%
# Create bounding box
covering_test_bbox = create_image_bounding_box(test_polygon)
covering_test_bbox
# Out:
# [8.029274592923368, 52.41153767053867, 8.036622921856104, 52.416031034526846]

# %%
# Check bounding box size in meter
determine_bbox_max_span_m(covering_test_bbox)
# Out:
# The bounding box has a width of: 501m and a height of: 500m

# %% [markdown]
# A bounding box of around 500mx500m ensures the pixel resolution of at least 0.2m/pixel when downloading 2560x2560 pixel images.

# %% [markdown]
# ### Calculate bbox for every rest stop

# %%
# Set random seed
random.seed(103)

# Create image bounding boxes for every rest station
correctly_labelled_service_stations["bbox"] = correctly_labelled_service_stations['geometry'].apply(create_image_bounding_box)
wrongly_labelled_service_stations["bbox"] = wrongly_labelled_service_stations['geometry'].apply(create_image_bounding_box)

# %%
# Change order of columns to comply with geopandas convention

correctly_labelled_service_stations = correctly_labelled_service_stations[["id_rest", "id_OSM_rest", "name", "bbox", "geometry"]]
wrongly_labelled_service_stations = wrongly_labelled_service_stations[["id_rest", "id_OSM_rest", "name", "bbox", "geometry"]]

# %%
correctly_labelled_service_stations
# Out:
#                            id_rest     id_OSM_rest                      name  \
# 0     lon_8.6630029_lat_50.2542348    way/22568867               Schäferborn
# 1    lon_11.3531491_lat_50.9378362    way/27549694              Habichtsfang
# 2     lon_10.2712414_lat_53.331074    way/29376062                    Roddau
# 3     lon_9.6300119_lat_53.8303266    way/31128689                 Steinburg
# 4     lon_9.6297338_lat_53.8301666    way/31128716                 Steinburg
# ..                             ...             ...                       ...
# 291  lon_12.7580653_lat_52.8778128   way/915630046               Am Rhinluch
# 292   lon_7.2005154_lat_52.2816225   way/988014767         Gut Friedrichstal
# 293   lon_8.5597202_lat_49.5969765   way/992004892                  Wildbahn
# 294   lon_10.7306355_lat_50.559048  way/1171916133                Adlersberg
# 295   lon_9.7695159_lat_52.5102873  way/1192709800  Rastplatz Bissendorf Süd
#
#                                                   bbox  \
# 0    [8.662897964530508, 50.24947031826926, 8.66990...
# 1    [11.352126356256656, 50.93673132065365, 11.359...
# 2    [10.264345359109937, 53.328233742563924, 10.27...
# 3    [9.629200346595411, 53.82616873812249, 9.63679...
# 4    [9.628319773449437, 53.82730601524238, 9.63591...
# ..                                                 ...
# 291  [12.754311642753441, 52.87373430027324, 12.761...
# 292  [7.196198912998569, 52.27916482977726, 7.20352...
# 293  [8.554638173536537, 49.59453943341597, 8.56155...
# 294  [10.724665021750997, 50.55768307908295, 10.731...
# 295  [9.76628898503676, 52.5095042232054, 9.7736534...
#
#                                               geometry
# 0    POLYGON ((8.66300 50.25423, 8.66302 50.25237, ...
# 1    POLYGON ((11.35315 50.93784, 11.35315 50.93783...
# 2    POLYGON ((10.27124 53.33107, 10.27096 53.33121...
# 3    POLYGON ((9.63001 53.83033, 9.63273 53.82905, ...
# 4    POLYGON ((9.62973 53.83017, 9.62965 53.83010, ...
# ..                                                 ...
# 291  POLYGON ((12.75807 52.87781, 12.75786 52.87778...
# 292  POLYGON ((7.20052 52.28162, 7.20053 52.28167, ...
# 293  POLYGON ((8.55972 49.59698, 8.55958 49.59693, ...
# 294  POLYGON ((10.73064 50.55905, 10.73067 50.55851...
# 295  POLYGON ((9.76952 52.51029, 9.77003 52.51132, ...
#
# [296 rows x 5 columns]

# %%
wrongly_labelled_service_stations
# Out:
#                            id_rest       id_OSM_rest  \
# 0    lon_11.2442867_lat_51.3248863  relation/3947321
# 1    lon_13.5458137_lat_52.7129474  relation/4672225
# 2     lon_13.549042_lat_52.7092396  relation/4672228
# 3     lon_8.6624068_lat_50.2544468      way/22568868
# 4     lon_8.6184146_lat_49.7896285      way/28329065
# ..                             ...               ...
# 203   lon_7.2459984_lat_52.3914582    way/1024211059
# 204   lon_7.2465958_lat_52.3950579    way/1024211060
# 205   lon_8.5358385_lat_49.5561227    way/1075944398
# 206    lon_8.4350744_lat_50.607106    way/1104993376
# 207   lon_8.6089092_lat_49.5422193    way/1172007491
#
#                                name  \
# 0                Hohe Schrecke West
# 1                       Probstheide
# 2                  Ladeburger Heide
# 3                         Spießwald
# 4             Rastplatz Rolandshöhe
# ..                              ...
# 203      Rastplatz Bergler Feld Ost
# 204     Rastplatz Bergler Feld West
# 205                      Rennschlag
# 206  Park und Rastplatz Am Behlkopf
# 207                            None
#
#                                                   bbox  \
# 0    [11.241064915797857, 51.32243637400286, 11.248...
# 1    [13.540777948956048, 52.71013054268637, 13.548...
# 2    [13.5452955790032, 52.70705615941434, 13.55269...
# 3    [8.660065778552887, 50.25160742899144, 8.66707...
# 4    [8.616622212048906, 49.788430865137876, 8.6235...
# ..                                                 ...
# 203  [7.24460460097266, 52.38743780607369, 7.251949...
# 204  [7.243070829595409, 52.39210190678455, 7.25041...
# 205  [8.52982204213126, 49.55406843116357, 8.536732...
# 206  [8.431103744122044, 50.60606866341377, 8.43816...
# 207  [8.606961328053691, 49.53880495000331, 8.61386...
#
#                                               geometry
# 0    MULTIPOLYGON (((11.24429 51.32489, 11.24430 51...
# 1    POLYGON ((13.54581 52.71295, 13.54556 52.71258...
# 2    POLYGON ((13.54904 52.70924, 13.54912 52.70919...
# 3    POLYGON ((8.66241 50.25445, 8.66205 50.25369, ...
# 4    POLYGON ((8.61841 49.78963, 8.61857 49.79067, ...
# ..                                                 ...
# 203  POLYGON ((7.24600 52.39146, 7.24561 52.38924, ...
# 204  POLYGON ((7.24660 52.39506, 7.24656 52.39511, ...
# 205  POLYGON ((8.53584 49.55612, 8.53523 49.55625, ...
# 206  POLYGON ((8.43507 50.60711, 8.43507 50.60706, ...
# 207  POLYGON ((8.60891 49.54222, 8.60955 49.54229, ...
#
# [208 rows x 5 columns]

# %%
# Delete geometry column from correctly_labelled_service_stations
correctly_labelled_service_stations_bbox = correctly_labelled_service_stations.drop("geometry", axis = 1)

# Delete geometry column from wrongly_labelled_service_stations
wrongly_labelled_service_stations_bbox = wrongly_labelled_service_stations.drop("geometry", axis = 1)

# Download correctly_labelled_service_stations as csv
output_path_rest_stations_ver_bbox = "02_data_acquisition/verified_parking_data/bounding_boxes/correctly_labelled_service_stations_bbox.csv"
correctly_labelled_service_stations_bbox.to_csv(output_path_rest_stations_ver_bbox, index = False)

# Download wrongly_labelled_service_stations as csv
output_path_rest_stations_wrong_bbox = "02_data_acquisition/verified_parking_data/bounding_boxes/wrongly_labelled_service_stations_bbox.csv"
wrongly_labelled_service_stations_bbox.to_csv(output_path_rest_stations_wrong_bbox, index = False)

# %%
correctly_labelled_service_stations_bbox
# Out:
#                            id_rest     id_OSM_rest                      name  \
# 0     lon_8.6630029_lat_50.2542348    way/22568867               Schäferborn
# 1    lon_11.3531491_lat_50.9378362    way/27549694              Habichtsfang
# 2     lon_10.2712414_lat_53.331074    way/29376062                    Roddau
# 3     lon_9.6300119_lat_53.8303266    way/31128689                 Steinburg
# 4     lon_9.6297338_lat_53.8301666    way/31128716                 Steinburg
# ..                             ...             ...                       ...
# 291  lon_12.7580653_lat_52.8778128   way/915630046               Am Rhinluch
# 292   lon_7.2005154_lat_52.2816225   way/988014767         Gut Friedrichstal
# 293   lon_8.5597202_lat_49.5969765   way/992004892                  Wildbahn
# 294   lon_10.7306355_lat_50.559048  way/1171916133                Adlersberg
# 295   lon_9.7695159_lat_52.5102873  way/1192709800  Rastplatz Bissendorf Süd
#
#                                                   bbox
# 0    [8.662897964530508, 50.24947031826926, 8.66990...
# 1    [11.352126356256656, 50.93673132065365, 11.359...
# 2    [10.264345359109937, 53.328233742563924, 10.27...
# 3    [9.629200346595411, 53.82616873812249, 9.63679...
# 4    [9.628319773449437, 53.82730601524238, 9.63591...
# ..                                                 ...
# 291  [12.754311642753441, 52.87373430027324, 12.761...
# 292  [7.196198912998569, 52.27916482977726, 7.20352...
# 293  [8.554638173536537, 49.59453943341597, 8.56155...
# 294  [10.724665021750997, 50.55768307908295, 10.731...
# 295  [9.76628898503676, 52.5095042232054, 9.7736534...
#
# [296 rows x 4 columns]

# %%
wrongly_labelled_service_stations_bbox
# Out:
#                            id_rest       id_OSM_rest  \
# 0    lon_11.2442867_lat_51.3248863  relation/3947321
# 1    lon_13.5458137_lat_52.7129474  relation/4672225
# 2     lon_13.549042_lat_52.7092396  relation/4672228
# 3     lon_8.6624068_lat_50.2544468      way/22568868
# 4     lon_8.6184146_lat_49.7896285      way/28329065
# ..                             ...               ...
# 203   lon_7.2459984_lat_52.3914582    way/1024211059
# 204   lon_7.2465958_lat_52.3950579    way/1024211060
# 205   lon_8.5358385_lat_49.5561227    way/1075944398
# 206    lon_8.4350744_lat_50.607106    way/1104993376
# 207   lon_8.6089092_lat_49.5422193    way/1172007491
#
#                                name  \
# 0                Hohe Schrecke West
# 1                       Probstheide
# 2                  Ladeburger Heide
# 3                         Spießwald
# 4             Rastplatz Rolandshöhe
# ..                              ...
# 203      Rastplatz Bergler Feld Ost
# 204     Rastplatz Bergler Feld West
# 205                      Rennschlag
# 206  Park und Rastplatz Am Behlkopf
# 207                            None
#
#                                                   bbox
# 0    [11.241064915797857, 51.32243637400286, 11.248...
# 1    [13.540777948956048, 52.71013054268637, 13.548...
# 2    [13.5452955790032, 52.70705615941434, 13.55269...
# 3    [8.660065778552887, 50.25160742899144, 8.66707...
# 4    [8.616622212048906, 49.788430865137876, 8.6235...
# ..                                                 ...
# 203  [7.24460460097266, 52.38743780607369, 7.251949...
# 204  [7.243070829595409, 52.39210190678455, 7.25041...
# 205  [8.52982204213126, 49.55406843116357, 8.536732...
# 206  [8.431103744122044, 50.60606866341377, 8.43816...
# 207  [8.606961328053691, 49.53880495000331, 8.61386...
#
# [208 rows x 4 columns]

# %% [markdown]
# # Set up tile services

# %% [markdown]
# ## WMS and layer information

# %% [markdown]
# This code was partly taken from: [OWSLib 0.29.3 documentation -> Examples -> Interact with a WMS](https://owslib.readthedocs.io/en/stable/notebooks/wms.html)

# %%
def get_wms_information(wms_url):
    """
    Output all necessary WMS information for the WMS service provided.

    Parameters:
    wms_url: The GetCapabilities url of the WMS service

    Returns:
    A dictionary with version, url, title, abstract, provider_name, layer_names, operations, operations_urls, format_options
    """

    wms = WebMapService(wms_url, version="1.3.0")

    version = wms.identification.version
    title = wms.identification.title
    abstract = wms.identification.abstract
    provider_name = wms.provider.name
    layer_names = list(wms.contents)
    operations = [op.name for op in wms.operations]
    operations_urls = wms.getOperationByName("GetMap").methods
    format_options = wms.getOperationByName("GetMap").formatOptions

    wms_information = {"version": version,
                       "url": wms_url,
                       "title": title,
                       "abstract": abstract,
                       "provider_name": provider_name,
                       "layer_names": layer_names,
                       "operations": operations,
                       "operations_urls": operations_urls,
                       "format_options": format_options
                       }

    return wms_information

def get_layer_information(wms_url, layer_name):
    """
    Retrieve information about extent and crs_options of selected layer.

    Paramters:
    wms_url: The GetCapabilities url of the WMS service
    layer_name: The name of the selected layer

    Returns:
    A dictionary with layer_name, extent, crs_options.
    """

    wms = WebMapService(wms_url, version="1.3.0")

    extent = wms.contents[layer_name].boundingBoxWGS84
    crs_options = wms[layer_name].crsOptions

    layer_information = {"layer_name": layer_name,
                         "extent": extent,
                         "crs_options": crs_options
                         }

    return layer_information

# %%
# Define WMS service and layer to be tested

test_wms_url = "https://www.geobasisdaten.niedersachsen.de/doorman/noauth/wms_ni_dop?Request=GetCapabilities&Service=WMS"
test_layer = "WMS_NI_DOP"

# %%
# Return all relevant WMS service information
get_wms_information(test_wms_url)
# Out:
# {'version': '1.3.0',
#  'url': 'https://www.geobasisdaten.niedersachsen.de/doorman/noauth/wms_ni_dop?Request=GetCapabilities&Service=WMS',
#  'title': 'WMS NI DOP',
#  'abstract': 'Digitale Orthophotos Niedersachsen, Bodenauflösung 20 cm (DOP20)',
#  'provider_name': 'Landesamt für Geoinformation und Landesvermessung Niedersachsen (LGLN) - Landesbetrieb Landesvermessung und Geobasisinformation',
#  'layer_names': ['WMS_NI_DOP', 'dop20'],
#  'operations': ['GetCapabilities', 'GetMap', 'GetFeatureInfo'],
#  'operations_urls': [{'type': 'Get',
#    'url': 'https://www.geobasisdaten.niedersachsen.de/doorman/noauth/wms_ni_dop?'},
#   {'type': 'Post',
#    'url': 'https://www.geobasisdaten.niedersachsen.de/doorman/noauth/wms_ni_dop?'}],
#  'format_options': ['image/png',
#   'image/jpeg',
#   'image/png; mode=8bit',
#   'image/vnd.jpeg-png',
#   'image/vnd.jpeg-png8',
#   'application/x-pdf',
#   'image/svg+xml',
#   'image/tiff',
#   'application/vnd.google-earth.kml+xml',
#   'application/vnd.google-earth.kmz',
#   'application/vnd.mapbox-vector-tile',
#   'application/x-protobuf',
#   'application/json']}

# %%
# Return all relevant layer information
get_layer_information(test_wms_url, test_layer)
# Out:
# {'layer_name': 'WMS_NI_DOP',
#  'extent': (6.505772, 51.153098, 11.754046, 54.148101),
#  'crs_options': ['EPSG:4647',
#   'EPSG:3857',
#   'EPSG:3035',
#   'EPSG:4258',
#   'EPSG:31469',
#   'EPSG:3034',
#   'EPSG:32632',
#   'EPSG:31466',
#   'EPSG:25833',
#   'EPSG:31467',
#   'EPSG:4326',
#   'EPSG:31468',
#   'EPSG:3044',
#   'EPSG:25832',
#   'EPSG:3045',
#   'EPSG:32633']}

# %% [markdown]
# ## Return image from WMS bbox

# %%
# Define WMS service and layer for each German state

wms_urls = {
        'WMS_NI_DOP': 'https://www.geobasisdaten.niedersachsen.de/doorman/noauth/wms_ni_dop?Request=GetCapabilities&Service=WMS', # Lower Saxony
        'bebb_dop20c': 'https://isk.geobasis-bb.de/mapproxy/dop20c/service/wms?Request=GetCapabilities&Service=WMS', # Brandenburg & Berlin
        'th_dop': 'https://www.geoproxy.geoportal-th.de/geoproxy/services/DOP?REQUEST=GetCapabilities&version=1.1.1&service=WMS', # Thuringia
        'lsa_lvermgeo_dop20_2': 'https://www.geodatenportal.sachsen-anhalt.de/wss/service/ST_LVermGeo_DOP_WMS_OpenData/guest?', # Saxony-Anhalt
        'he_dop_rgb': 'https://gds-srv.hessen.de/cgi-bin/lika-services/ogc-free-images.ows?', # Hessia
        'sh_dop20_rgb': 'https://dienste.gdi-sh.de/WMS_SH_DOP20col_OpenGBD?Service=wms&version=1.3.0&request=getCapabilities', # Schleswig-Holstein
    }

# %% [markdown]
# *   sh_dop20_rgb has an overly large, inaccurate extent. For this reason, this layer is tested last

# %%
# Print WMS and layer information for all selected Länder layers
counter = 1

for layer, url in wms_urls.items():
    print(f"wms_{counter}", get_wms_information(url))
    print(f"layer_{counter}", get_layer_information(url, layer))
    print("\n")
    counter += 1
# Out:
# wms_1 {'version': '1.3.0', 'url': 'https://www.geobasisdaten.niedersachsen.de/doorman/noauth/wms_ni_dop?Request=GetCapabilities&Service=WMS', 'title': 'WMS NI DOP', 'abstract': 'Digitale Orthophotos Niedersachsen, Bodenauflösung 20 cm (DOP20)', 'provider_name': 'Landesamt für Geoinformation und Landesvermessung Niedersachsen (LGLN) - Landesbetrieb Landesvermessung und Geobasisinformation', 'layer_names': ['WMS_NI_DOP', 'dop20'], 'operations': ['GetCapabilities', 'GetMap', 'GetFeatureInfo'], 'operations_urls': [{'type': 'Get', 'url': 'https://www.geobasisdaten.niedersachsen.de/doorman/noauth/wms_ni_dop?'}, {'type': 'Post', 'url': 'https://www.geobasisdaten.niedersachsen.de/doorman/noauth/wms_ni_dop?'}], 'format_options': ['image/png', 'image/jpeg', 'image/png; mode=8bit', 'image/vnd.jpeg-png', 'image/vnd.jpeg-png8', 'application/x-pdf', 'image/svg+xml', 'image/tiff', 'application/vnd.google-earth.kml+xml', 'application/vnd.google-earth.kmz', 'application/vnd.mapbox-vector-tile', 'application/x-protobuf', 'application/json']}
# layer_1 {'layer_name': 'WMS_NI_DOP', 'extent': (6.505772, 51.153098, 11.754046, 54.148101), 'crs_options': ['EPSG:4647', 'EPSG:3857', 'EPSG:3035', 'EPSG:4258', 'EPSG:31469', 'EPSG:3034', 'EPSG:32632', 'EPSG:31466', 'EPSG:25833', 'EPSG:31467', 'EPSG:4326', 'EPSG:31468', 'EPSG:3044', 'EPSG:25832', 'EPSG:3045', 'EPSG:32633']}
#
#
# wms_2 {'version': '1.3.0', 'url': 'https://isk.geobasis-bb.de/mapproxy/dop20c/service/wms?Request=GetCapabilities&Service=WMS', 'title': 'WMS BB-BE DOP20c Cache', 'abstract': 'Dieser Web Map Service ist ein gekachelter Kartendienst zur schnelleren Anzeige, welcher als Datengrundlage die digitalen farbigen Orthophotos (Luftbilder) mit der Bodenauflösung von 20cm vom Gebiet Brandenburg mit Berlin hat.', 'provider_name': 'Landesvermessung und Geobasisinformation Brandenburg', 'layer_names': ['bebb_dop20c'], 'operations': ['GetCapabilities', 'GetMap', 'GetFeatureInfo'], 'operations_urls': [{'type': 'Get', 'url': 'https://isk.geobasis-bb.de/mapproxy/dop20c/service/wms?'}], 'format_options': ['image/png', 'image/jpeg', 'image/gif']}
# layer_2 {'layer_name': 'bebb_dop20c', 'extent': (11.152768795679583, 51.2635170116316, 15.009068839315324, 53.61004915755329), 'crs_options': ['CRS:84', 'EPSG:3857', 'EPSG:3035', 'EPSG:900913', 'EPSG:4258', 'EPSG:3034', 'EPSG:5650', 'EPSG:25833', 'EPSG:4839', 'EPSG:4326', 'EPSG:25832', 'EPSG:3045']}
#
#
# wms_3 {'version': '1.3.0', 'url': 'https://www.geoproxy.geoportal-th.de/geoproxy/services/DOP?REQUEST=GetCapabilities&version=1.1.1&service=WMS', 'title': 'WMS TH DOP', 'abstract': 'Geoproxy Thüringen WMS für Digitale Orthophotos. Der Web Map Service stellt flächendeckend DOP in den Ausprägungen farbig (RBG), panchromatisch/Graustufen (PAN) und Color-Infrarot (CIR) in den Bodenauflösungen 20cm und 200cm bereit. Für kachelbezogene Informationen, die derzeit nicht über das GeoMIS.Thüringen aufgerufen werden können, wird ein zusätzlicher Layer mit Metainformationen bereitgestellt, der z.B. Daten zur Aktualität des ausgewählten Orthophotos enthält.', 'provider_name': 'Thüringer Ministerium für Infrastruktur und Landwirtschaft', 'layer_names': ['th_dop200cir', 'th_dop200pan', 'th_dop200rgb', 'th_dop20cir', 'th_dop20pan', 'th_dop', 'th_dop_info'], 'operations': ['GetCapabilities', 'GetMap', 'GetFeatureInfo', 'GetLegendGraphic'], 'operations_urls': [{'type': 'Get', 'url': 'https://www.geoproxy.geoportal-th.de/geoproxy/services/DOP?'}], 'format_options': ['image/jpeg', 'image/png', 'image/png; mode=8bit', 'image/png; subtype=8bit', 'image/tiff', 'image/gif']}
# layer_3 {'layer_name': 'th_dop', 'extent': (9.70043908, 50.13516795, 12.75958006, 51.7188448), 'crs_options': ['EPSG:3035', 'EPSG:3040', 'EPSG:4258', 'EPSG:3034', 'EPSG:3041', 'EPSG:31468', 'EPSG:3046', 'EPSG:3038', 'EPSG:3045', 'EPSG:3857', 'EPSG:4326', 'EPSG:3043', 'EPSG:25832', 'EPSG:3042', 'EPSG:3039', 'EPSG:25833', 'EPSG:31467', 'EPSG:3044', 'EPSG:3047']}
#
#
# wms_4 {'version': '1.3.0', 'url': 'https://www.geodatenportal.sachsen-anhalt.de/wss/service/ST_LVermGeo_DOP_WMS_OpenData/guest?', 'title': 'WMS Geobasisdaten MapApps', 'abstract': None, 'provider_name': 'Landesamt fuer Vermessung und Geoinformation Sachsen-Anhalt', 'layer_names': ['lsa_lvermgeo_dop20_2', 'lsa_lvermgeo_dop100_unbesch'], 'operations': ['GetCapabilities', 'GetMap', 'GetFeatureInfo', 'GetLegendGraphic'], 'operations_urls': [{'type': 'Get', 'url': 'https://www.geodatenportal.sachsen-anhalt.de/wss/service/ST_LVermGeo_DOP_WMS_OpenData/guest?'}, {'type': 'Post', 'url': 'https://www.geodatenportal.sachsen-anhalt.de/wss/service/ST_LVermGeo_DOP_WMS_OpenData/guest?'}], 'format_options': ['image/jpeg', 'image/png', 'image/gif', 'image/svg+xml']}
# layer_4 {'layer_name': 'lsa_lvermgeo_dop20_2', 'extent': (10.5092, 50.8927, 13.3233, 53.0769), 'crs_options': ['EPSG:4647', 'EPSG:2166', 'EPSG:2399', 'EPSG:3857', 'EPSG:2168', 'EPSG:31469', 'EPSG:2398', 'EPSG:25833', 'EPSG:31468', 'EPSG:31467', 'EPSG:4326', 'EPSG:2397', 'EPSG:25832', 'EPSG:2167']}
#
#
# wms_5 {'version': '1.3.0', 'url': 'https://gds-srv.hessen.de/cgi-bin/lika-services/ogc-free-images.ows?', 'title': 'WMS HE DOP', 'abstract': 'Geobasisdaten © Hessische Verwaltung für Bodenmanagement und Geoinformation: Digitale Orthophotos', 'provider_name': 'Hessisches Landesamt für Bodenmanagement und Geoinformation', 'layer_names': ['wms_he_dop', 'he_dop20_rgb', 'el_dop320_rgb', 'el_dop5000_rgb', 'he_dop_rgb', 'el_alk_tk', 'he_dop_alk_t', 'he_dop_rgb_info', 'he_dop20_cir', 'el_dop320_cir', 'he_dop_cir', 'he_dop_cir_info'], 'operations': ['GetCapabilities', 'GetMap', 'GetFeatureInfo', 'DescribeLayer', 'GetLegendGraphic', 'GetStyles'], 'operations_urls': [{'type': 'Get', 'url': 'https://www.gds-srv.hessen.de/cgi-bin/lika-services/ogc-free-images.ows?language=ger&'}, {'type': 'Post', 'url': 'https://www.gds-srv.hessen.de/cgi-bin/lika-services/ogc-free-images.ows?language=ger&'}], 'format_options': ['image/jpeg', 'image/png', 'image/png; mode=8bit', 'image/vnd.jpeg-png', 'image/vnd.jpeg-png8', 'image/tiff', 'application/json']}
# layer_5 {'layer_name': 'he_dop_rgb', 'extent': (7.41867, 49.25, 10.5, 51.7596), 'crs_options': ['EPSG:3040', 'EPSG:4258', 'EPSG:3041', 'EPSG:31468', 'EPSG:3046', 'EPSG:3038', 'EPSG:3045', 'EPSG:3857', 'EPSG:31466', 'EPSG:4326', 'EPSG:3043', 'EPSG:25832', 'EPSG:3042', 'EPSG:3039', 'EPSG:900913', 'EPSG:31469', 'EPSG:25833', 'EPSG:31467', 'EPSG:3044', 'EPSG:3047']}
#
#
# wms_6 {'version': '1.3.0', 'url': 'https://dienste.gdi-sh.de/WMS_SH_DOP20col_OpenGBD?Service=wms&version=1.3.0&request=getCapabilities', 'title': 'WMS SH DOP20', 'abstract': 'Dieser Web Map Service transportiert die abgeleiteten Rasterbilder der Digitalen Orthophotos DOP20 entsprechend dem Produkt- und Qualitätsstandard für Digitale Orthophotos (www.adv-online.de). Die Ausgangsdaten liegen in folgender Ausprägung vor: rgb - Es handelt sich um eine Darstellung als 3-Kanal-Echtfarbbild (Rot – Grün – Blau).', 'provider_name': 'Landesamt für Vermessung und Geoinformation Schleswig-Holstein', 'layer_names': ['sh_dop20_rgb'], 'operations': ['GetCapabilities', 'GetMap', 'GetFeatureInfo', 'GetLegendGraphic'], 'operations_urls': [{'type': 'Get', 'url': 'https://dienste.gdi-sh.de//WMS_SH_DOP20col_OpenGBD?'}], 'format_options': ['image/png', 'image/gif', 'image/jpeg']}
# layer_6 {'layer_name': 'sh_dop20_rgb', 'extent': (0.105946742406, 45.237542736, 20.4488912945, 56.8478734515), 'crs_options': ['EPSG:4647', 'EPSG:3857', 'EPSG:4258', 'EPSG:25833', 'EPSG:4326', 'EPSG:25832']}

# %% [markdown]
# **Findings:**
#
# *   All layers have the option to select the EPSG:4326 coordinate system, a coordinate system on the WGS84 reference ellipsoid
# *   WGS84 is also used as the standard coordinates system used by GSP and also OSM
# *   Only Niedersachsen, Thüringen and Hessen can export in Tiff format

# %%
def retrieve_layer_extents(wms_urls):
        """
        Retrieve layer extents of the WMS urls.

        Parameters:
        wms_urls (dict): dictionary of layer names and WMS GetCapability URLs

        Returns:
        A dictionary of the extents of the WMS layers.
        """
        wms_layer_extents = {}

        for layer_name, url in wms_urls.items():
            bounding_box = get_layer_information(url, layer_name)["extent"]
            wms_layer_extents[layer_name] = bounding_box

        return wms_layer_extents

# %%
# Extract layer extents
layer_extents = retrieve_layer_extents(wms_urls)
print(layer_extents)
# Out:
# {'WMS_NI_DOP': (6.505772, 51.153098, 11.754046, 54.148101), 'bebb_dop20c': (11.152768795679583, 51.2635170116316, 15.009068839315324, 53.61004915755329), 'th_dop': (9.70043908, 50.13516795, 12.75958006, 51.7188448), 'lsa_lvermgeo_dop20_2': (10.5092, 50.8927, 13.3233, 53.0769), 'he_dop_rgb': (7.41867, 49.25, 10.5, 51.7596), 'sh_dop20_rgb': (0.105946742406, 45.237542736, 20.4488912945, 56.8478734515)}

# %%
def create_png_from_bbox(bbox, wms_urls, layer_extents, size = 2560):
    """
    Create square png map from a bounding box sourced from WMS services.

    Parameters:
    bbox (tuple): (left, bottom, right, top)
    wms_urls (dict): dictionary containing layer_names as keys and urls as values
    layer_extents (dict): dictionary containing layer_names as keys and layer extent tuples as values
    size (int): determines the size of the output png in pixels

    Returns:
    A square png image of the map.
    """


    def bbox_intersects(bbox1, bbox2):
        """
        Check if two bounding boxes intersect.

        Parameters:
        bbox1, bbox2 (tuple): tuple of bbox corners (left, bottom, right, top)

        Returns:
        True if bboxes intersect, False otherwise
        """
        return not (bbox1[2] < bbox2[0] or bbox1[0] > bbox2[2] or
                    bbox1[3] < bbox2[1] or bbox1[1] > bbox2[3])


    def is_blank_image(image):
        """
        Check whether an image is blank or not.

        Parameters:
        image (image object): image of WMS service

        Returns:
        True if image is blank, False otherwise.
        """
        try:
            # Open the image from the image object
            image = Image.open(io.BytesIO(image.read()))

            # Convert the image to a numpy array
            image_array = np.array(image)

            # Depending on the image mode, check whether image is completely white or black
            if image.mode == 'RGB':
                # Check if the image is completely white or black
                is_white = np.all(image_array == [255, 255, 255], axis=(-1)).all()
                is_black = np.all(image_array == [0, 0, 0], axis=(-1)).all()
            elif image.mode == 'RGBA':
                # Check if the image is completely white or black
                is_white = np.all(image_array[:, :, :3] == [255, 255, 255], axis=(-1)).all()
                is_black = np.all(image_array[:, :, :3] == [0, 0, 0], axis=(-1)).all()
            else:
                # Raise error for other image mode
                raise ValueError("Unsupported image mode.")

            return is_white or is_black

        except Exception as e:
            print(f"An error occurred: {e}")
            return False


    def determine_layer_for_bbox(bbox, wms_urls, layer_extents):
        """
        Determine which layer to use based for the provided bounding box.

        Parameters:
        bbox (tuple): bounding box (left, bottom, right, top)
        wms_urls (dict): dictionary containing layer_names as keys and urls as values
        layer_extents: dictionary of layer names and their extent bounding boxes

        Returns:
        Layer name or None if no intersection
        """
        # Check WMSs one after the other until image is returned
        for layer, extent in layer_extents.items():
            wms = WebMapService(wms_urls[layer])
            response = wms.getmap(layers=[layer],
                              srs='EPSG:4326',
                              bbox=bbox,
                              size=(2, 2),
                              format='image/png')
            # First, check if bounding box intersects
            if not bbox_intersects(bbox, extent):
                print(f"{layer} does not contain bounding box.")
            # Second, check whether image is blank
            elif is_blank_image(response):
                print(f"{layer} returns blank image.")
            # Return image
            else:
                print(f"{layer} returns image.")

                return layer
        return None

    # Determine the layer that intersects the bounding box
    chosen_layer = determine_layer_for_bbox(bbox, wms_urls, layer_extents)

    if chosen_layer == None:
        raise ValueError("No layer intersects with the provided bounding box.")
    else:
        # Correctly create a WebMapService object from chosen layer
        wms = WebMapService(wms_urls[chosen_layer])
        response = wms.getmap(layers=[chosen_layer],
                              srs='EPSG:4326',
                              bbox=bbox,
                              size=(size, size),
                              format='image/png')
    # Return the image
    return response

# %%
def pixel_dimensions(image):
    """
    Return pixel dimensions of an image.

    Parameters:
    image (PIL Image object)

    Returns:
    A tuple of width and height dimensions of the input image.
    """

    image_data = BytesIO(image.read())
    image_loaded = Image.open(image_data)

    # Get image dimensions (Width x Height)
    width, height = image_loaded.size

    return (width, height)

# %% [markdown]
# # Download images

# %% [markdown]
# ## Define downloading functions

# %%
def download_as_png(image, filepath):
    """
    Download an image as a PNG file.

    Parameters:
    image (PIL Image object)
    filepath (str): path to save the image
    """
    # Assuming img_new is your image response object
    image_data = BytesIO(image.read())

    # Write the image data to a file
    with open(filepath, 'wb') as file:
        file.write(image_data.getvalue())

# %%
def download_tif_from_png(png_path, tif_path, bbox):
    """
    Convert a PNG image to a GeoTIFF file.

    Parameters:
    png_path (str): path to the PNG image
    tif_path (str): path to save the GeoTIFF file
    bbox (list): bounding box as [left, bottom, right, top]
    """
    # Load the PNG image as a Rasterio dataset
    png = rasterio.open(png_path)

    # Read the data from the dataset into a NumPy array
    image_array = png.read()

    # Define transformation from bounding box
    left, bottom, right, top = bbox
    transform = from_bounds(left, bottom, right, top, png.width, png.height)

    # Update metadata
    meta = {
        'driver': 'GTiff',
        'dtype': png.dtypes[0],
        'nodata': None,
        'width': png.width,
        'height': png.height,
        'count': png.count,
        'crs': CRS.from_epsg(4326),  # WGS84
        'transform': transform
    }

    # Write the array to a new TIFF file
    with rasterio.open(tif_path, 'w', **meta) as dst:
        dst.write(image_array)

# %%
def delete_file(file_path):
    """
    Delete a file.

    Parameters:
    file_path (str): path to the file to be deleted
    """
    # Check if the file exists
    if os.path.exists(file_path):
        os.remove(file_path)
    else:
        print(f"File '{file_path}' does not exist.")

# %% [markdown]
# ## Test Download

# %%
# Define test index
test_index = 4

test_bbox = correctly_labelled_service_stations.iloc[test_index].loc["bbox"]
test_id_rest = correctly_labelled_service_stations.iloc[test_index].loc["id_rest"]
test_name = correctly_labelled_service_stations.iloc[test_index].loc["name"]

print("Test bounding box:", test_bbox)
print("Test id box:", test_id_rest)
print("Test service station:", test_name)

# %%
# Create map for test service station
response = create_png_from_bbox(test_bbox, wms_urls, layer_extents, size = 2560)

# %%
# Display service station
displayImage(response.read())

# %%
# Print type and pixel dimensions
print(type(response))
print("Image pixel dimensions", pixel_dimensions(response))

# %%
# Download image as PNG
file_path_png = f"02_data_acquisition/test_image_download/{test_id_rest}_{test_name}.png"
download_as_png(response, file_path_png)

# %%
# Download image as tif from png
file_path_tif = f"02_data_acquisition/test_image_download/{test_id_rest}_{test_name}.tif"
download_tif_from_png(file_path_png, file_path_tif, test_bbox)

# %%
# Delete PNG function

def delete_file(file_path):
    # Check if the file exists
    if os.path.exists(file_path):
        os.remove(file_path)
        print(f"File '{file_path}' has been deleted.")
    else:
        print(f"File '{file_path}' does not exist.")

# %%
# Delete Png
file_path_png = file_path_png
delete_file(file_path_png)

# %% [markdown]
# ## Mass-Download correctly laballed service stations as tifs

# %%
def mass_download_tif(geodataframe, wms_urls, layer_extents, size = 2560):
    """
    Download a large number of GeoTIFF images from WMS services

    Parameters:
    geodataframe (GeoDataFrame): GeoDataFrame containing the bounding boxes
    wms_urls (dict): dictionary containing layer_names as keys and urls as values
    layer_extents: dictionary of layer names and their extent bounding boxes
    size (int): determines the size of the output png in pixels
    """

    for index, row in geodataframe.iterrows():
        bbox = row["bbox"]
        id_rest = row["id_rest"]
        name = row["name"]

        print(f"Downloading image {index}: {name} ({id_rest})\n")

        # Create map
        response = create_png_from_bbox(bbox, wms_urls, layer_extents, size)

        # Define base directory
        base_dir = "02_data_acquisition/tif_download_correctly_labelled_service_stations"
        
        # Ensure the directory exists
        os.makedirs(base_dir, exist_ok=True)

        # Save map as png
        file_path_png = f"02_data_acquisition/tif_download_correctly_labelled_service_stations/{id_rest}_{name}.png"
        download_as_png(response, file_path_png)

        # Safe tif from png
        file_path_tif = f"02_data_acquisition/tif_download_correctly_labelled_service_stations/{id_rest}_{name}.tif"
        download_tif_from_png(file_path_png, file_path_tif, bbox)

        # Delete png
        delete_file(file_path_png)

        print(f"\nDownload completed for image {index}: {name} ({id_rest})")
        print("----------------------------------------------------------------------------------------- \n")

# %%
mass_download_tif(correctly_labelled_service_stations_bbox, wms_urls, layer_extents, size = 2560)
# Out:
# Downloading image 0: Schäferborn (lon_8.6630029_lat_50.2542348)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
# /opt/homebrew/lib/python3.11/site-packages/rasterio/__init__.py:304: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# Download completed for image 0: Schäferborn (lon_8.6630029_lat_50.2542348)
# -----------------------------------------------------------------------------------------
#
# Downloading image 1: Habichtsfang (lon_11.3531491_lat_50.9378362)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop returns image.
#
# Download completed for image 1: Habichtsfang (lon_11.3531491_lat_50.9378362)
# -----------------------------------------------------------------------------------------
#
# Downloading image 2: Roddau (lon_10.2712414_lat_53.331074)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 2: Roddau (lon_10.2712414_lat_53.331074)
# -----------------------------------------------------------------------------------------
#
# Downloading image 3: Steinburg (lon_9.6300119_lat_53.8303266)
#
# WMS_NI_DOP returns blank image.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb does not contain bounding box.
# sh_dop20_rgb returns image.
#
# Download completed for image 3: Steinburg (lon_9.6300119_lat_53.8303266)
# -----------------------------------------------------------------------------------------
#
# Downloading image 4: Steinburg (lon_9.6297338_lat_53.8301666)
#
# WMS_NI_DOP returns blank image.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb does not contain bounding box.
# sh_dop20_rgb returns image.
#
# Download completed for image 4: Steinburg (lon_9.6297338_lat_53.8301666)
# -----------------------------------------------------------------------------------------
#
# Downloading image 5: Dithmarscher Geest (lon_9.2506723_lat_54.1383328)
#
# WMS_NI_DOP returns blank image.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb does not contain bounding box.
# sh_dop20_rgb returns image.
#
# Download completed for image 5: Dithmarscher Geest (lon_9.2506723_lat_54.1383328)
# -----------------------------------------------------------------------------------------
#
# Downloading image 6: Dornheimer Rieth (lon_11.0102562_lat_50.8353109)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop returns image.
#
# Download completed for image 6: Dornheimer Rieth (lon_11.0102562_lat_50.8353109)
# -----------------------------------------------------------------------------------------
#
# Downloading image 7: Kabelsketal (lon_12.1106921_lat_51.4564157)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns blank image.
# th_dop returns blank image.
# lsa_lvermgeo_dop20_2 returns image.
#
# Download completed for image 7: Kabelsketal (lon_12.1106921_lat_51.4564157)
# -----------------------------------------------------------------------------------------
#
# Downloading image 8: Kabelsketal (lon_12.1076965_lat_51.4562754)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns blank image.
# th_dop returns blank image.
# lsa_lvermgeo_dop20_2 returns image.
#
# Download completed for image 8: Kabelsketal (lon_12.1076965_lat_51.4562754)
# -----------------------------------------------------------------------------------------
#
# Downloading image 9: Luhewiesen (lon_10.1688328_lat_53.3457924)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 9: Luhewiesen (lon_10.1688328_lat_53.3457924)
# -----------------------------------------------------------------------------------------
#
# Downloading image 10: Pörstental (lon_12.0315302_lat_51.2103528)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop returns blank image.
# lsa_lvermgeo_dop20_2 returns image.
#
# Download completed for image 10: Pörstental (lon_12.0315302_lat_51.2103528)
# -----------------------------------------------------------------------------------------
#
# Downloading image 11: Adlersberg (lon_10.7298729_lat_50.5605634)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop returns image.
#
# Download completed for image 11: Adlersberg (lon_10.7298729_lat_50.5605634)
# -----------------------------------------------------------------------------------------
#
# Downloading image 12: Stauferburg-Ost (lon_8.7976979_lat_50.4392699)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 12: Stauferburg-Ost (lon_8.7976979_lat_50.4392699)
# -----------------------------------------------------------------------------------------
#
# Downloading image 13: Stauferburg-West (lon_8.7960067_lat_50.4414072)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 13: Stauferburg-West (lon_8.7960067_lat_50.4414072)
# -----------------------------------------------------------------------------------------
#
# Downloading image 14: Auf der Pfingstweide West (lon_9.0037966_lat_50.1997276)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 14: Auf der Pfingstweide West (lon_9.0037966_lat_50.1997276)
# -----------------------------------------------------------------------------------------
#
# Downloading image 15: Auf der Pfingstweide Ost (lon_9.006114_lat_50.1972118)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 15: Auf der Pfingstweide Ost (lon_9.006114_lat_50.1972118)
# -----------------------------------------------------------------------------------------
#
# Downloading image 16: Hohe Berg (lon_8.9264579_lat_50.3435768)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 16: Hohe Berg (lon_8.9264579_lat_50.3435768)
# -----------------------------------------------------------------------------------------
#
# Downloading image 17: Auf der Nachtweide Ost (lon_8.9282225_lat_50.3458508)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 17: Auf der Nachtweide Ost (lon_8.9282225_lat_50.3458508)
# -----------------------------------------------------------------------------------------
#
# Downloading image 18: Grevelau (lon_10.16857_lat_53.3461669)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 18: Grevelau (lon_10.16857_lat_53.3461669)
# -----------------------------------------------------------------------------------------
#
# Downloading image 19: Hainich (lon_10.444298_lat_50.9932399)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop returns image.
#
# Download completed for image 19: Hainich (lon_10.444298_lat_50.9932399)
# -----------------------------------------------------------------------------------------
#
# Downloading image 20: Hainich (lon_10.4367549_lat_50.9933128)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop returns image.
#
# Download completed for image 20: Hainich (lon_10.4367549_lat_50.9933128)
# -----------------------------------------------------------------------------------------
#
# Downloading image 21: Dätgen (lon_9.9309273_lat_54.1889457)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb does not contain bounding box.
# sh_dop20_rgb returns image.
#
# Download completed for image 21: Dätgen (lon_9.9309273_lat_54.1889457)
# -----------------------------------------------------------------------------------------
#
# Downloading image 22: Schaapskaben (lon_10.0774066_lat_53.2322212)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 22: Schaapskaben (lon_10.0774066_lat_53.2322212)
# -----------------------------------------------------------------------------------------
#
# Downloading image 23: Rumohr (lon_10.0214344_lat_54.2446698)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb does not contain bounding box.
# sh_dop20_rgb returns image.
#
# Download completed for image 23: Rumohr (lon_10.0214344_lat_54.2446698)
# -----------------------------------------------------------------------------------------
#
# Downloading image 24: Johannispfad (lon_8.4094366_lat_50.0433047)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 24: Johannispfad (lon_8.4094366_lat_50.0433047)
# -----------------------------------------------------------------------------------------
#
# Downloading image 25: Oberbach (lon_8.409903_lat_50.0435443)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 25: Oberbach (lon_8.409903_lat_50.0435443)
# -----------------------------------------------------------------------------------------
#
# Downloading image 26: Rosselquelle (lon_12.484777_lat_51.9700491)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns blank image.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 returns image.
#
# Download completed for image 26: Rosselquelle (lon_12.484777_lat_51.9700491)
# -----------------------------------------------------------------------------------------
#
# Downloading image 27: Hagen (lon_12.6318286_lat_52.0445002)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns image.
#
# Download completed for image 27: Hagen (lon_12.6318286_lat_52.0445002)
# -----------------------------------------------------------------------------------------
#
# Downloading image 28: Godshorn (lon_9.6950885_lat_52.4313338)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 28: Godshorn (lon_9.6950885_lat_52.4313338)
# -----------------------------------------------------------------------------------------
#
# Downloading image 29: Tramm (lon_10.6158177_lat_53.5536922)
#
# WMS_NI_DOP returns blank image.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb does not contain bounding box.
# sh_dop20_rgb returns image.
#
# Download completed for image 29: Tramm (lon_10.6158177_lat_53.5536922)
# -----------------------------------------------------------------------------------------
#
# Downloading image 30: Roseburg (lon_10.6284325_lat_53.5509146)
#
# WMS_NI_DOP returns blank image.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb does not contain bounding box.
# sh_dop20_rgb returns image.
#
# Download completed for image 30: Roseburg (lon_10.6284325_lat_53.5509146)
# -----------------------------------------------------------------------------------------
#
# Downloading image 31: Jalm (lon_9.43935_lat_54.6368415)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb does not contain bounding box.
# sh_dop20_rgb returns image.
#
# Download completed for image 31: Jalm (lon_9.43935_lat_54.6368415)
# -----------------------------------------------------------------------------------------
#
# Downloading image 32: Hasenmoor (lon_9.9118833_lat_54.3141951)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb does not contain bounding box.
# sh_dop20_rgb returns image.
#
# Download completed for image 32: Hasenmoor (lon_9.9118833_lat_54.3141951)
# -----------------------------------------------------------------------------------------
#
# Downloading image 33: Neu-Nordsee (lon_9.9181171_lat_54.315654)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb does not contain bounding box.
# sh_dop20_rgb returns image.
#
# Download completed for image 33: Neu-Nordsee (lon_9.9181171_lat_54.315654)
# -----------------------------------------------------------------------------------------
#
# Downloading image 34: Ruhlander Heide (lon_13.8513592_lat_51.4570059)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns image.
#
# Download completed for image 34: Ruhlander Heide (lon_13.8513592_lat_51.4570059)
# -----------------------------------------------------------------------------------------
#
# Downloading image 35: Elsteraue (lon_13.8516172_lat_51.4581664)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns image.
#
# Download completed for image 35: Elsteraue (lon_13.8516172_lat_51.4581664)
# -----------------------------------------------------------------------------------------
#
# Downloading image 36: Rodaborn (lon_11.8748503_lat_50.7596459)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop returns image.
#
# Download completed for image 36: Rodaborn (lon_11.8748503_lat_50.7596459)
# -----------------------------------------------------------------------------------------
#
# Downloading image 37: Dubje (lon_14.125127_lat_51.7568185)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns image.
#
# Download completed for image 37: Dubje (lon_14.125127_lat_51.7568185)
# -----------------------------------------------------------------------------------------
#
# Downloading image 38: Kuhberg (lon_11.8452583_lat_50.957723)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop returns image.
#
# Download completed for image 38: Kuhberg (lon_11.8452583_lat_50.957723)
# -----------------------------------------------------------------------------------------
#
# Downloading image 39: Kuhberg (lon_11.8511459_lat_50.9610243)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop returns image.
#
# Download completed for image 39: Kuhberg (lon_11.8511459_lat_50.9610243)
# -----------------------------------------------------------------------------------------
#
# Downloading image 40: Mosigkauer Heide (lon_12.2160563_lat_51.7230405)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns blank image.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 returns image.
#
# Download completed for image 40: Mosigkauer Heide (lon_12.2160563_lat_51.7230405)
# -----------------------------------------------------------------------------------------
#
# Downloading image 41: Leinetal (lon_10.1793156_lat_51.408897)
#
# WMS_NI_DOP returns blank image.
# bebb_dop20c does not contain bounding box.
# th_dop returns image.
#
# Download completed for image 41: Leinetal (lon_10.1793156_lat_51.408897)
# -----------------------------------------------------------------------------------------
#
# Downloading image 42: None (lon_10.6222227_lat_51.4346456)
#
# WMS_NI_DOP returns blank image.
# bebb_dop20c does not contain bounding box.
# th_dop returns image.
#
# Download completed for image 42: None (lon_10.6222227_lat_51.4346456)
# -----------------------------------------------------------------------------------------
#
# Downloading image 43: Rastplatz Kesselberg-Nord (lon_10.7814825_lat_51.4714133)
#
# WMS_NI_DOP returns blank image.
# bebb_dop20c does not contain bounding box.
# th_dop returns image.
#
# Download completed for image 43: Rastplatz Kesselberg-Nord (lon_10.7814825_lat_51.4714133)
# -----------------------------------------------------------------------------------------
#
# Downloading image 44: Goldene Aue (lon_11.042875_lat_51.4666501)
#
# WMS_NI_DOP returns blank image.
# bebb_dop20c does not contain bounding box.
# th_dop returns blank image.
# lsa_lvermgeo_dop20_2 returns image.
#
# Download completed for image 44: Goldene Aue (lon_11.042875_lat_51.4666501)
# -----------------------------------------------------------------------------------------
#
# Downloading image 45: Goldene Aue (lon_11.0467665_lat_51.4688222)
#
# WMS_NI_DOP returns blank image.
# bebb_dop20c does not contain bounding box.
# th_dop returns blank image.
# lsa_lvermgeo_dop20_2 returns image.
#
# Download completed for image 45: Goldene Aue (lon_11.0467665_lat_51.4688222)
# -----------------------------------------------------------------------------------------
#
# Downloading image 46: Helmetal (lon_11.2298121_lat_51.4520557)
#
# WMS_NI_DOP returns blank image.
# bebb_dop20c returns blank image.
# th_dop returns blank image.
# lsa_lvermgeo_dop20_2 returns image.
#
# Download completed for image 46: Helmetal (lon_11.2298121_lat_51.4520557)
# -----------------------------------------------------------------------------------------
#
# Downloading image 47: Helmetal (lon_11.225695_lat_51.4521931)
#
# WMS_NI_DOP returns blank image.
# bebb_dop20c returns blank image.
# th_dop returns blank image.
# lsa_lvermgeo_dop20_2 returns image.
#
# Download completed for image 47: Helmetal (lon_11.225695_lat_51.4521931)
# -----------------------------------------------------------------------------------------
#
# Downloading image 48: Querfurter Platte Nord (lon_11.721026_lat_51.4012188)
#
# WMS_NI_DOP returns blank image.
# bebb_dop20c returns blank image.
# th_dop returns blank image.
# lsa_lvermgeo_dop20_2 returns image.
#
# Download completed for image 48: Querfurter Platte Nord (lon_11.721026_lat_51.4012188)
# -----------------------------------------------------------------------------------------
#
# Downloading image 49: Saaletal (lon_11.997727_lat_51.2571166)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop returns blank image.
# lsa_lvermgeo_dop20_2 returns image.
#
# Download completed for image 49: Saaletal (lon_11.997727_lat_51.2571166)
# -----------------------------------------------------------------------------------------
#
# Downloading image 50: Hackelberg (lon_9.7800847_lat_51.3955138)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 50: Hackelberg (lon_9.7800847_lat_51.3955138)
# -----------------------------------------------------------------------------------------
#
# Downloading image 51: Baunsberg (lon_9.4159061_lat_51.2721518)
#
# WMS_NI_DOP returns blank image.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 51: Baunsberg (lon_9.4159061_lat_51.2721518)
# -----------------------------------------------------------------------------------------
#
# Downloading image 52: Waldkater (lon_11.0524687_lat_52.2204778)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 52: Waldkater (lon_11.0524687_lat_52.2204778)
# -----------------------------------------------------------------------------------------
#
# Downloading image 53: Hundsberg (lon_9.2953023_lat_51.3111859)
#
# WMS_NI_DOP returns blank image.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 53: Hundsberg (lon_9.2953023_lat_51.3111859)
# -----------------------------------------------------------------------------------------
#
# Downloading image 54: Rohrberg (lon_9.2831674_lat_51.3432322)
#
# WMS_NI_DOP returns blank image.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 54: Rohrberg (lon_9.2831674_lat_51.3432322)
# -----------------------------------------------------------------------------------------
#
# Downloading image 55: Unter den Buchen (lon_9.1405642_lat_51.4446215)
#
# WMS_NI_DOP returns blank image.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 55: Unter den Buchen (lon_9.1405642_lat_51.4446215)
# -----------------------------------------------------------------------------------------
#
# Downloading image 56: Staufenberg (lon_9.6038325_lat_51.3476078)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 56: Staufenberg (lon_9.6038325_lat_51.3476078)
# -----------------------------------------------------------------------------------------
#
# Downloading image 57: Schwalenberg-Ost (lon_10.1268892_lat_51.8569148)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 57: Schwalenberg-Ost (lon_10.1268892_lat_51.8569148)
# -----------------------------------------------------------------------------------------
#
# Downloading image 58: Schwalenberg-West (lon_10.1230601_lat_51.8561527)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 58: Schwalenberg-West (lon_10.1230601_lat_51.8561527)
# -----------------------------------------------------------------------------------------
#
# Downloading image 59: Ostseeblick (lon_10.9814416_lat_54.3623714)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb does not contain bounding box.
# sh_dop20_rgb returns image.
#
# Download completed for image 59: Ostseeblick (lon_10.9814416_lat_54.3623714)
# -----------------------------------------------------------------------------------------
#
# Downloading image 60: Ostseeblick (lon_10.9810513_lat_54.3627005)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb does not contain bounding box.
# sh_dop20_rgb returns image.
#
# Download completed for image 60: Ostseeblick (lon_10.9810513_lat_54.3627005)
# -----------------------------------------------------------------------------------------
#
# Downloading image 61: Kersdorfer See (lon_14.2175841_lat_52.3368637)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns image.
#
# Download completed for image 61: Kersdorfer See (lon_14.2175841_lat_52.3368637)
# -----------------------------------------------------------------------------------------
#
# Downloading image 62: Berliner Urstromtal (lon_14.222133_lat_52.3378744)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns image.
#
# Download completed for image 62: Berliner Urstromtal (lon_14.222133_lat_52.3378744)
# -----------------------------------------------------------------------------------------
#
# Downloading image 63: Geiseltal (lon_11.922428_lat_51.3459818)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns blank image.
# th_dop returns blank image.
# lsa_lvermgeo_dop20_2 returns image.
#
# Download completed for image 63: Geiseltal (lon_11.922428_lat_51.3459818)
# -----------------------------------------------------------------------------------------
#
# Downloading image 64: Geiseltal (lon_11.9228882_lat_51.346147)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns blank image.
# th_dop returns blank image.
# lsa_lvermgeo_dop20_2 returns image.
#
# Download completed for image 64: Geiseltal (lon_11.9228882_lat_51.346147)
# -----------------------------------------------------------------------------------------
#
# Downloading image 65: Rodaborn (lon_11.8732122_lat_50.759018)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop returns image.
#
# Download completed for image 65: Rodaborn (lon_11.8732122_lat_50.759018)
# -----------------------------------------------------------------------------------------
#
# Downloading image 66: Glindbusch (lon_9.2988549_lat_53.2031954)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 66: Glindbusch (lon_9.2988549_lat_53.2031954)
# -----------------------------------------------------------------------------------------
#
# Downloading image 67: Glindbusch (lon_9.2955316_lat_53.2000997)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 67: Glindbusch (lon_9.2955316_lat_53.2000997)
# -----------------------------------------------------------------------------------------
#
# Downloading image 68: Hatzte (lon_9.4285484_lat_53.2538351)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 68: Hatzte (lon_9.4285484_lat_53.2538351)
# -----------------------------------------------------------------------------------------
#
# Downloading image 69: Stellheide (lon_9.653454_lat_53.342582)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 69: Stellheide (lon_9.653454_lat_53.342582)
# -----------------------------------------------------------------------------------------
#
# Downloading image 70: Stellheide (lon_9.6697291_lat_53.3475987)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 70: Stellheide (lon_9.6697291_lat_53.3475987)
# -----------------------------------------------------------------------------------------
#
# Downloading image 71: Täubcheshöhle (lon_8.6078461_lat_49.9067102)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 71: Täubcheshöhle (lon_8.6078461_lat_49.9067102)
# -----------------------------------------------------------------------------------------
#
# Downloading image 72: Brühlgraben (lon_8.6071636_lat_49.9067628)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 72: Brühlgraben (lon_8.6071636_lat_49.9067628)
# -----------------------------------------------------------------------------------------
#
# Downloading image 73: Springhorst (lon_9.8233956_lat_52.5072277)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 73: Springhorst (lon_9.8233956_lat_52.5072277)
# -----------------------------------------------------------------------------------------
#
# Downloading image 74: None (lon_9.1016757_lat_53.0145562)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 74: None (lon_9.1016757_lat_53.0145562)
# -----------------------------------------------------------------------------------------
#
# Downloading image 75: Hamwiede Süd (lon_9.4541541_lat_52.8865005)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 75: Hamwiede Süd (lon_9.4541541_lat_52.8865005)
# -----------------------------------------------------------------------------------------
#
# Downloading image 76: Hamwiede Nord (lon_9.4711124_lat_52.8827146)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 76: Hamwiede Nord (lon_9.4711124_lat_52.8827146)
# -----------------------------------------------------------------------------------------
#
# Downloading image 77: Krelinger Heide (lon_9.6499469_lat_52.7971201)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 77: Krelinger Heide (lon_9.6499469_lat_52.7971201)
# -----------------------------------------------------------------------------------------
#
# Downloading image 78: Up´n Bummelskampe (lon_9.7749645_lat_52.577053)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 78: Up´n Bummelskampe (lon_9.7749645_lat_52.577053)
# -----------------------------------------------------------------------------------------
#
# Downloading image 79: Osterriehe (lon_9.7769111_lat_52.5742903)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 79: Osterriehe (lon_9.7769111_lat_52.5742903)
# -----------------------------------------------------------------------------------------
#
# Downloading image 80: Dorfmark (lon_9.7910429_lat_52.9061454)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 80: Dorfmark (lon_9.7910429_lat_52.9061454)
# -----------------------------------------------------------------------------------------
#
# Downloading image 81: Wolfsgrund Ost (lon_9.679135_lat_52.8070774)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 81: Wolfsgrund Ost (lon_9.679135_lat_52.8070774)
# -----------------------------------------------------------------------------------------
#
# Downloading image 82: Wolfsgrund West (lon_9.6807029_lat_52.8134767)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 82: Wolfsgrund West (lon_9.6807029_lat_52.8134767)
# -----------------------------------------------------------------------------------------
#
# Downloading image 83: Steinbach (lon_9.7597687_lat_52.8860299)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 83: Steinbach (lon_9.7597687_lat_52.8860299)
# -----------------------------------------------------------------------------------------
#
# Downloading image 84: Sunderblick (lon_9.9534437_lat_53.3780392)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 84: Sunderblick (lon_9.9534437_lat_53.3780392)
# -----------------------------------------------------------------------------------------
#
# Downloading image 85: Hittfeld (lon_9.9577331_lat_53.3781014)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 85: Hittfeld (lon_9.9577331_lat_53.3781014)
# -----------------------------------------------------------------------------------------
#
# Downloading image 86: Rosengarten (lon_9.8798749_lat_53.3889549)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 86: Rosengarten (lon_9.8798749_lat_53.3889549)
# -----------------------------------------------------------------------------------------
#
# Downloading image 87: Wilmersdorfer Forst (lon_13.8520632_lat_53.0925266)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns image.
#
# Download completed for image 87: Wilmersdorfer Forst (lon_13.8520632_lat_53.0925266)
# -----------------------------------------------------------------------------------------
#
# Downloading image 88: Rheiderland (lon_7.3726926_lat_53.2222086)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 88: Rheiderland (lon_7.3726926_lat_53.2222086)
# -----------------------------------------------------------------------------------------
#
# Downloading image 89: Rheiderland (lon_7.3693221_lat_53.2220034)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 89: Rheiderland (lon_7.3693221_lat_53.2220034)
# -----------------------------------------------------------------------------------------
#
# Downloading image 90: Pörstental (lon_12.0320348_lat_51.2100148)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop returns blank image.
# lsa_lvermgeo_dop20_2 returns image.
#
# Download completed for image 90: Pörstental (lon_12.0320348_lat_51.2100148)
# -----------------------------------------------------------------------------------------
#
# Downloading image 91: Herzogsberge (lon_10.6333468_lat_52.2512109)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 91: Herzogsberge (lon_10.6333468_lat_52.2512109)
# -----------------------------------------------------------------------------------------
#
# Downloading image 92: Herzogsberge (lon_10.6320454_lat_52.2513501)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 92: Herzogsberge (lon_10.6320454_lat_52.2513501)
# -----------------------------------------------------------------------------------------
#
# Downloading image 93: Hasselhöhe (lon_10.0413714_lat_53.3330705)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 93: Hasselhöhe (lon_10.0413714_lat_53.3330705)
# -----------------------------------------------------------------------------------------
#
# Downloading image 94: Seevetal (lon_10.0385684_lat_53.3493845)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 94: Seevetal (lon_10.0385684_lat_53.3493845)
# -----------------------------------------------------------------------------------------
#
# Downloading image 95: Hummelskopf (lon_9.6802586_lat_50.6048477)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 95: Hummelskopf (lon_9.6802586_lat_50.6048477)
# -----------------------------------------------------------------------------------------
#
# Downloading image 96: Lohmühle (lon_9.7447582_lat_50.4360417)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop returns blank image.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 96: Lohmühle (lon_9.7447582_lat_50.4360417)
# -----------------------------------------------------------------------------------------
#
# Downloading image 97: Markwald (lon_9.4723046_lat_51.1759244)
#
# WMS_NI_DOP returns blank image.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 97: Markwald (lon_9.4723046_lat_51.1759244)
# -----------------------------------------------------------------------------------------
#
# Downloading image 98: Quillerwald (lon_9.474156_lat_51.1815402)
#
# WMS_NI_DOP returns blank image.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 98: Quillerwald (lon_9.474156_lat_51.1815402)
# -----------------------------------------------------------------------------------------
#
# Downloading image 99: Riederberg (lon_9.7216043_lat_50.461791)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop returns blank image.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 99: Riederberg (lon_9.7216043_lat_50.461791)
# -----------------------------------------------------------------------------------------
#
# Downloading image 100: Rotkopf (lon_9.6778656_lat_50.6230423)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 100: Rotkopf (lon_9.6778656_lat_50.6230423)
# -----------------------------------------------------------------------------------------
#
# Downloading image 101: Steinhauk (lon_9.7123388_lat_50.4733475)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop returns blank image.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 101: Steinhauk (lon_9.7123388_lat_50.4733475)
# -----------------------------------------------------------------------------------------
#
# Downloading image 102: Thüringer Becken West (lon_11.1650168_lat_51.1280879)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop returns image.
#
# Download completed for image 102: Thüringer Becken West (lon_11.1650168_lat_51.1280879)
# -----------------------------------------------------------------------------------------
#
# Downloading image 103: Thüringer Becken Ost (lon_11.165322_lat_51.1277215)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop returns image.
#
# Download completed for image 103: Thüringer Becken Ost (lon_11.165322_lat_51.1277215)
# -----------------------------------------------------------------------------------------
#
# Downloading image 104: Erfurter Becken - Ost (lon_10.9544554_lat_50.9407623)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop returns image.
#
# Download completed for image 104: Erfurter Becken - Ost (lon_10.9544554_lat_50.9407623)
# -----------------------------------------------------------------------------------------
#
# Downloading image 105: Thüringer Tor (lon_10.4537487_lat_50.4697772)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop returns image.
#
# Download completed for image 105: Thüringer Tor (lon_10.4537487_lat_50.4697772)
# -----------------------------------------------------------------------------------------
#
# Downloading image 106: Thüringer Tor (lon_10.4530068_lat_50.4711034)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop returns image.
#
# Download completed for image 106: Thüringer Tor (lon_10.4530068_lat_50.4711034)
# -----------------------------------------------------------------------------------------
#
# Downloading image 107: Ziegenberg (lon_10.5152409_lat_52.0369274)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 107: Ziegenberg (lon_10.5152409_lat_52.0369274)
# -----------------------------------------------------------------------------------------
#
# Downloading image 108: Werla (lon_10.5080423_lat_52.0491815)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 108: Werla (lon_10.5080423_lat_52.0491815)
# -----------------------------------------------------------------------------------------
#
# Downloading image 109: Jalmer Moor (lon_9.4422125_lat_54.6154292)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb does not contain bounding box.
# sh_dop20_rgb returns image.
#
# Download completed for image 109: Jalmer Moor (lon_9.4422125_lat_54.6154292)
# -----------------------------------------------------------------------------------------
#
# Downloading image 110: Auf dem Karkfeld (lon_10.6690769_lat_53.8037285)
#
# WMS_NI_DOP returns blank image.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb does not contain bounding box.
# sh_dop20_rgb returns image.
#
# Download completed for image 110: Auf dem Karkfeld (lon_10.6690769_lat_53.8037285)
# -----------------------------------------------------------------------------------------
#
# Downloading image 111: Auf dem Karkfeld (lon_10.675298_lat_53.8007703)
#
# WMS_NI_DOP returns blank image.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb does not contain bounding box.
# sh_dop20_rgb returns image.
#
# Download completed for image 111: Auf dem Karkfeld (lon_10.675298_lat_53.8007703)
# -----------------------------------------------------------------------------------------
#
# Downloading image 112: Erfurter Becken - West (lon_10.9549595_lat_50.9380515)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop returns image.
#
# Download completed for image 112: Erfurter Becken - West (lon_10.9549595_lat_50.9380515)
# -----------------------------------------------------------------------------------------
#
# Downloading image 113: Bremer Schweiz (lon_8.6561041_lat_53.2118683)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 113: Bremer Schweiz (lon_8.6561041_lat_53.2118683)
# -----------------------------------------------------------------------------------------
#
# Downloading image 114: Habichthorst (lon_8.6583088_lat_53.2111443)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 114: Habichthorst (lon_8.6583088_lat_53.2111443)
# -----------------------------------------------------------------------------------------
#
# Downloading image 115: Altwarmbüchener Moor (lon_9.8969787_lat_52.4106715)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 115: Altwarmbüchener Moor (lon_9.8969787_lat_52.4106715)
# -----------------------------------------------------------------------------------------
#
# Downloading image 116: Ohe Ost (lon_9.7695186_lat_54.2841989)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb does not contain bounding box.
# sh_dop20_rgb returns image.
#
# Download completed for image 116: Ohe Ost (lon_9.7695186_lat_54.2841989)
# -----------------------------------------------------------------------------------------
#
# Downloading image 117: Habichtsfang (lon_11.3570959_lat_50.9374444)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop returns image.
#
# Download completed for image 117: Habichtsfang (lon_11.3570959_lat_50.9374444)
# -----------------------------------------------------------------------------------------
#
# Downloading image 118: Willroder Forst (lon_11.0708191_lat_50.9099067)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop returns image.
#
# Download completed for image 118: Willroder Forst (lon_11.0708191_lat_50.9099067)
# -----------------------------------------------------------------------------------------
#
# Downloading image 119: Willroder Forst (lon_11.070887_lat_50.9105953)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop returns image.
#
# Download completed for image 119: Willroder Forst (lon_11.070887_lat_50.9105953)
# -----------------------------------------------------------------------------------------
#
# Downloading image 120: Drei Gleichen (lon_10.8080134_lat_50.8782277)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop returns image.
#
# Download completed for image 120: Drei Gleichen (lon_10.8080134_lat_50.8782277)
# -----------------------------------------------------------------------------------------
#
# Downloading image 121: Burgberg (lon_10.1726923_lat_51.0086765)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop returns blank image.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 121: Burgberg (lon_10.1726923_lat_51.0086765)
# -----------------------------------------------------------------------------------------
#
# Downloading image 122: Seulingswald (lon_9.8774063_lat_50.9046737)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop returns blank image.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 122: Seulingswald (lon_9.8774063_lat_50.9046737)
# -----------------------------------------------------------------------------------------
#
# Downloading image 123: Bruchwiese (lon_9.0527584_lat_52.2180625)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 123: Bruchwiese (lon_9.0527584_lat_52.2180625)
# -----------------------------------------------------------------------------------------
#
# Downloading image 124: Bad Nenndorf (lon_9.423032_lat_52.3476048)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 124: Bad Nenndorf (lon_9.423032_lat_52.3476048)
# -----------------------------------------------------------------------------------------
#
# Downloading image 125: Bückethaler Knick (lon_9.4208246_lat_52.3458992)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 125: Bückethaler Knick (lon_9.4208246_lat_52.3458992)
# -----------------------------------------------------------------------------------------
#
# Downloading image 126: Bornhorster Wiesen Ost (lon_8.2630337_lat_53.1820056)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 126: Bornhorster Wiesen Ost (lon_8.2630337_lat_53.1820056)
# -----------------------------------------------------------------------------------------
#
# Downloading image 127: Bornhorster Wiesen West (lon_8.2596852_lat_53.1852074)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 127: Bornhorster Wiesen West (lon_8.2596852_lat_53.1852074)
# -----------------------------------------------------------------------------------------
#
# Downloading image 128: Dornheimer Rieth (lon_11.0100226_lat_50.8366037)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop returns image.
#
# Download completed for image 128: Dornheimer Rieth (lon_11.0100226_lat_50.8366037)
# -----------------------------------------------------------------------------------------
#
# Downloading image 129: Dolmar (lon_10.5316238_lat_50.5995636)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop returns image.
#
# Download completed for image 129: Dolmar (lon_10.5316238_lat_50.5995636)
# -----------------------------------------------------------------------------------------
#
# Downloading image 130: Dreihöhenberg (lon_11.6915015_lat_51.9435264)
#
# WMS_NI_DOP returns blank image.
# bebb_dop20c returns blank image.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 returns image.
#
# Download completed for image 130: Dreihöhenberg (lon_11.6915015_lat_51.9435264)
# -----------------------------------------------------------------------------------------
#
# Downloading image 131: Saaleaue (lon_11.7205665_lat_51.7087958)
#
# WMS_NI_DOP returns blank image.
# bebb_dop20c returns blank image.
# th_dop returns blank image.
# lsa_lvermgeo_dop20_2 returns image.
#
# Download completed for image 131: Saaleaue (lon_11.7205665_lat_51.7087958)
# -----------------------------------------------------------------------------------------
#
# Downloading image 132: Saaleaue (lon_11.7174498_lat_51.7113852)
#
# WMS_NI_DOP returns blank image.
# bebb_dop20c returns blank image.
# th_dop returns blank image.
# lsa_lvermgeo_dop20_2 returns image.
#
# Download completed for image 132: Saaleaue (lon_11.7174498_lat_51.7113852)
# -----------------------------------------------------------------------------------------
#
# Downloading image 133: Petersberg (lon_12.0055212_lat_51.5564663)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns blank image.
# th_dop returns blank image.
# lsa_lvermgeo_dop20_2 returns image.
#
# Download completed for image 133: Petersberg (lon_12.0055212_lat_51.5564663)
# -----------------------------------------------------------------------------------------
#
# Downloading image 134: Petersberg (lon_12.0026469_lat_51.5585101)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns blank image.
# th_dop returns blank image.
# lsa_lvermgeo_dop20_2 returns image.
#
# Download completed for image 134: Petersberg (lon_12.0026469_lat_51.5585101)
# -----------------------------------------------------------------------------------------
#
# Downloading image 135: Leineholz (lon_9.9061758_lat_51.6070521)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 135: Leineholz (lon_9.9061758_lat_51.6070521)
# -----------------------------------------------------------------------------------------
#
# Downloading image 136: Leineholz (lon_9.9052624_lat_51.601567)
#
# ...
#
# Downloading image 192: Rastplatz Finkenwald (lon_8.9660829_lat_50.6403329)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 192: Rastplatz Finkenwald (lon_8.9660829_lat_50.6403329)
# -----------------------------------------------------------------------------------------
#
# Downloading image 193: Rastplatz Heg-Berg (lon_8.967664_lat_50.6400352)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 193: Rastplatz Heg-Berg (lon_8.967664_lat_50.6400352)
# -----------------------------------------------------------------------------------------
#
# Downloading image 194: Krachgarten (lon_9.1042696_lat_50.7142736)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 194: Krachgarten (lon_9.1042696_lat_50.7142736)
# -----------------------------------------------------------------------------------------
#
# Downloading image 195: Eifa (lon_9.3510531_lat_50.7567778)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 195: Eifa (lon_9.3510531_lat_50.7567778)
# -----------------------------------------------------------------------------------------
#
# Downloading image 196: Limes-Ost (lon_8.7562282_lat_50.5199458)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 196: Limes-Ost (lon_8.7562282_lat_50.5199458)
# -----------------------------------------------------------------------------------------
#
# Downloading image 197: Limes-West (lon_8.7576588_lat_50.5220146)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 197: Limes-West (lon_8.7576588_lat_50.5220146)
# -----------------------------------------------------------------------------------------
#
# Downloading image 198: Rastplatz Barnholz (lon_9.499416_lat_50.801026)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 198: Rastplatz Barnholz (lon_9.499416_lat_50.801026)
# -----------------------------------------------------------------------------------------
#
# Downloading image 199: Raststätte Rimberg (lon_9.4729545_lat_50.7936044)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 199: Raststätte Rimberg (lon_9.4729545_lat_50.7936044)
# -----------------------------------------------------------------------------------------
#
# Downloading image 200: Am Sonnenborn (lon_9.3965197_lat_51.1916109)
#
# WMS_NI_DOP returns blank image.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 200: Am Sonnenborn (lon_9.3965197_lat_51.1916109)
# -----------------------------------------------------------------------------------------
#
# Downloading image 201: Bärenberg (lon_9.2789301_lat_51.3543365)
#
# WMS_NI_DOP returns blank image.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 201: Bärenberg (lon_9.2789301_lat_51.3543365)
# -----------------------------------------------------------------------------------------
#
# Downloading image 202: Scharfenstein (lon_9.3955169_lat_51.1918568)
#
# WMS_NI_DOP returns blank image.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 202: Scharfenstein (lon_9.3955169_lat_51.1918568)
# -----------------------------------------------------------------------------------------
#
# Downloading image 203: Rathsburgseen Nord (lon_13.9559485_lat_53.2109455)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns image.
#
# Download completed for image 203: Rathsburgseen Nord (lon_13.9559485_lat_53.2109455)
# -----------------------------------------------------------------------------------------
#
# Downloading image 204: None (lon_12.9854246_lat_52.6306623)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns image.
#
# Download completed for image 204: None (lon_12.9854246_lat_52.6306623)
# -----------------------------------------------------------------------------------------
#
# Downloading image 205: Rossower Heide (lon_12.5905719_lat_53.0085503)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns image.
#
# Download completed for image 205: Rossower Heide (lon_12.5905719_lat_53.0085503)
# -----------------------------------------------------------------------------------------
#
# Downloading image 206: None (lon_12.6092758_lat_52.9913176)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns image.
#
# Download completed for image 206: None (lon_12.6092758_lat_52.9913176)
# -----------------------------------------------------------------------------------------
#
# Downloading image 207: Blesenberg (lon_12.274776_lat_53.1981473)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns image.
#
# Download completed for image 207: Blesenberg (lon_12.274776_lat_53.1981473)
# -----------------------------------------------------------------------------------------
#
# Downloading image 208: Parkplatz Kiebitzberg (lon_12.276264_lat_53.1954521)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns image.
#
# Download completed for image 208: Parkplatz Kiebitzberg (lon_12.276264_lat_53.1954521)
# -----------------------------------------------------------------------------------------
#
# Downloading image 209: None (lon_12.0740424_lat_53.2849259)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns image.
#
# Download completed for image 209: None (lon_12.0740424_lat_53.2849259)
# -----------------------------------------------------------------------------------------
#
# Downloading image 210: None (lon_12.0732519_lat_53.2843058)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns image.
#
# Download completed for image 210: None (lon_12.0732519_lat_53.2843058)
# -----------------------------------------------------------------------------------------
#
# Downloading image 211: None (lon_13.9017286_lat_51.6960837)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns image.
#
# Download completed for image 211: None (lon_13.9017286_lat_51.6960837)
# -----------------------------------------------------------------------------------------
#
# Downloading image 212: Lebbiner Heide (lon_13.9503161_lat_52.3112817)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns image.
#
# Download completed for image 212: Lebbiner Heide (lon_13.9503161_lat_52.3112817)
# -----------------------------------------------------------------------------------------
#
# Downloading image 213: Briesenluch (lon_13.9496292_lat_52.3118174)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns image.
#
# Download completed for image 213: Briesenluch (lon_13.9496292_lat_52.3118174)
# -----------------------------------------------------------------------------------------
#
# Downloading image 214: Dreihöhenberg (lon_11.6940307_lat_51.9416459)
#
# WMS_NI_DOP returns blank image.
# bebb_dop20c returns blank image.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 returns image.
#
# Download completed for image 214: Dreihöhenberg (lon_11.6940307_lat_51.9416459)
# -----------------------------------------------------------------------------------------
#
# Downloading image 215: Suckower Forst (lon_13.8491933_lat_53.0912185)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns image.
#
# Download completed for image 215: Suckower Forst (lon_13.8491933_lat_53.0912185)
# -----------------------------------------------------------------------------------------
#
# Downloading image 216: Ravensmühle (lon_13.7762186_lat_53.5200667)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns image.
#
# Download completed for image 216: Ravensmühle (lon_13.7762186_lat_53.5200667)
# -----------------------------------------------------------------------------------------
#
# Downloading image 217: Rabenstein (lon_12.6186218_lat_52.0343636)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns image.
#
# Download completed for image 217: Rabenstein (lon_12.6186218_lat_52.0343636)
# -----------------------------------------------------------------------------------------
#
# Downloading image 218: Bönningstedt (lon_9.9397588_lat_53.6702339)
#
# WMS_NI_DOP returns blank image.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb does not contain bounding box.
# sh_dop20_rgb returns image.
#
# Download completed for image 218: Bönningstedt (lon_9.9397588_lat_53.6702339)
# -----------------------------------------------------------------------------------------
#
# Downloading image 219: Nortmoor (lon_7.5752644_lat_53.2596141)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 219: Nortmoor (lon_7.5752644_lat_53.2596141)
# -----------------------------------------------------------------------------------------
#
# Downloading image 220: Saaletal (lon_11.9979819_lat_51.2573447)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop returns blank image.
# lsa_lvermgeo_dop20_2 returns image.
#
# Download completed for image 220: Saaletal (lon_11.9979819_lat_51.2573447)
# -----------------------------------------------------------------------------------------
#
# Downloading image 221: Fuchsrain (lon_9.5327857_lat_50.9448923)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 221: Fuchsrain (lon_9.5327857_lat_50.9448923)
# -----------------------------------------------------------------------------------------
#
# Downloading image 222: Silbersee (lon_8.6698347_lat_50.6184956)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 222: Silbersee (lon_8.6698347_lat_50.6184956)
# -----------------------------------------------------------------------------------------
#
# Downloading image 223: Essehof Nord (lon_10.6559369_lat_52.3098001)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 223: Essehof Nord (lon_10.6559369_lat_52.3098001)
# -----------------------------------------------------------------------------------------
#
# Downloading image 224: Rastplatz Belten - Wótpócywanišćo Běłośin (lon_13.9981944_lat_51.8273183)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns image.
#
# Download completed for image 224: Rastplatz Belten - Wótpócywanišćo Běłośin (lon_13.9981944_lat_51.8273183)
# -----------------------------------------------------------------------------------------
#
# Downloading image 225: Rastplatz Leipe - Wótpócywanišćo Lipje (lon_13.9980682_lat_51.8277903)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns image.
#
# Download completed for image 225: Rastplatz Leipe - Wótpócywanišćo Lipje (lon_13.9980682_lat_51.8277903)
# -----------------------------------------------------------------------------------------
#
# Downloading image 226: Wendgräben (lon_12.5174451_lat_52.3423742)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns image.
#
# Download completed for image 226: Wendgräben (lon_12.5174451_lat_52.3423742)
# -----------------------------------------------------------------------------------------
#
# Downloading image 227: Borker Heide (lon_12.8828997_lat_52.2006051)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns image.
#
# Download completed for image 227: Borker Heide (lon_12.8828997_lat_52.2006051)
# -----------------------------------------------------------------------------------------
#
# Downloading image 228: Zauche (lon_12.8828606_lat_52.1997595)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns image.
#
# Download completed for image 228: Zauche (lon_12.8828606_lat_52.1997595)
# -----------------------------------------------------------------------------------------
#
# Downloading image 229: Kliekener Aue (lon_12.3708436_lat_51.8676138)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns blank image.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 returns image.
#
# Download completed for image 229: Kliekener Aue (lon_12.3708436_lat_51.8676138)
# -----------------------------------------------------------------------------------------
#
# Downloading image 230: Mosigkauer Heide (lon_12.2151522_lat_51.7240882)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns blank image.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 returns image.
#
# Download completed for image 230: Mosigkauer Heide (lon_12.2151522_lat_51.7240882)
# -----------------------------------------------------------------------------------------
#
# Downloading image 231: Kapellenberg (lon_12.2052029_lat_51.4908324)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns blank image.
# th_dop returns blank image.
# lsa_lvermgeo_dop20_2 returns image.
#
# Download completed for image 231: Kapellenberg (lon_12.2052029_lat_51.4908324)
# -----------------------------------------------------------------------------------------
#
# Downloading image 232: Kapellenberg (lon_12.2060105_lat_51.4912736)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns blank image.
# th_dop returns blank image.
# lsa_lvermgeo_dop20_2 returns blank image.
# he_dop_rgb does not contain bounding box.
# sh_dop20_rgb returns blank image.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[166], line 1
# ----> 1 mass_download_tif(correctly_labelled_service_stations_bbox, wms_urls, layer_extents, size = 2560)
#
# Cell In[165], line 20, in mass_download_tif(geodataframe, wms_urls, layer_extents, size)
#      17 print(f"Downloading image {index}: {name} ({id_rest})\n")
#      19 # Create map
# ---> 20 response = create_png_from_bbox(bbox, wms_urls, layer_extents, size)
#      22 # Define base directory
#      23 base_dir = "02_data_acquisition/tif_download"
#
# Cell In[160], line 104, in create_png_from_bbox(bbox, wms_urls, layer_extents, size)
#     101 chosen_layer = determine_layer_for_bbox(bbox, wms_urls, layer_extents)
#     103 if chosen_layer == None:
# --> 104     raise ValueError("No layer intersects with the provided bounding box.")
#     105 else:
#     106     # Correctly create a WebMapService object from chosen layer
#     107     wms = WebMapService(wms_urls[chosen_layer])
#
# ValueError: No layer intersects with the provided bounding box.

# %% [markdown]
# Kapellenberg (lon_12.2060105_lat_51.4912736)(index 232) did not return an image, as it is located at the border of WMS services. Restarted download from index 233:

# %%
correctly_labelled_service_stations_bbox_rest = correctly_labelled_service_stations_bbox[233:]

# %%
mass_download_tif(correctly_labelled_service_stations_bbox_rest, wms_urls, layer_extents, size = 2560)
# Out:
# Downloading image 260: Depenauer Moor (lon_10.2127333_lat_54.1387697)
#
# WMS_NI_DOP returns blank image.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb does not contain bounding box.
# sh_dop20_rgb returns image.
# /opt/homebrew/lib/python3.11/site-packages/rasterio/__init__.py:304: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# Download completed for image 260: Depenauer Moor (lon_10.2127333_lat_54.1387697)
# -----------------------------------------------------------------------------------------
#
# Downloading image 261: None (lon_8.601339_lat_53.0351727)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 261: None (lon_8.601339_lat_53.0351727)
# -----------------------------------------------------------------------------------------
#
# Downloading image 262: Rastplatz Hemmelsberg (lon_8.3213798_lat_53.0763179)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 262: Rastplatz Hemmelsberg (lon_8.3213798_lat_53.0763179)
# -----------------------------------------------------------------------------------------
#
# Downloading image 263: None (lon_8.3918309_lat_53.0580378)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 263: None (lon_8.3918309_lat_53.0580378)
# -----------------------------------------------------------------------------------------
#
# Downloading image 264: Rastplatz Frohnkreuz (lon_9.4436964_lat_50.7901379)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 264: Rastplatz Frohnkreuz (lon_9.4436964_lat_50.7901379)
# -----------------------------------------------------------------------------------------
#
# Downloading image 265: Abelbeck-Kuhbusch (lon_9.9017252_lat_52.9620913)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 265: Abelbeck-Kuhbusch (lon_9.9017252_lat_52.9620913)
# -----------------------------------------------------------------------------------------
#
# Downloading image 266: Rastplatz Hirschkopf (lon_8.2878722_lat_50.7097059)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 266: Rastplatz Hirschkopf (lon_8.2878722_lat_50.7097059)
# -----------------------------------------------------------------------------------------
#
# Downloading image 267: Weinberg (lon_9.4544286_lat_50.3278031)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 267: Weinberg (lon_9.4544286_lat_50.3278031)
# -----------------------------------------------------------------------------------------
#
# Downloading image 268: Pfahlgraben (lon_8.6953849_lat_50.4835355)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 268: Pfahlgraben (lon_8.6953849_lat_50.4835355)
# -----------------------------------------------------------------------------------------
#
# Downloading image 269: Dankern (lon_7.1699082_lat_52.7895152)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 269: Dankern (lon_7.1699082_lat_52.7895152)
# -----------------------------------------------------------------------------------------
#
# Downloading image 270: Rastplatz Volkersbach (lon_8.3511087_lat_50.6250118)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 270: Rastplatz Volkersbach (lon_8.3511087_lat_50.6250118)
# -----------------------------------------------------------------------------------------
#
# Downloading image 271: Auf dem Bon (lon_8.2313263_lat_50.7463103)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 271: Auf dem Bon (lon_8.2313263_lat_50.7463103)
# -----------------------------------------------------------------------------------------
#
# Downloading image 272: Schlierberg (lon_8.2341062_lat_50.7448722)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 272: Schlierberg (lon_8.2341062_lat_50.7448722)
# -----------------------------------------------------------------------------------------
#
# Downloading image 273: Tümmelsberg (lon_11.9466188_lat_50.8889659)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop returns image.
#
# Download completed for image 273: Tümmelsberg (lon_11.9466188_lat_50.8889659)
# -----------------------------------------------------------------------------------------
#
# Downloading image 274: Delmetal Nord (lon_8.5524082_lat_52.9532189)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 274: Delmetal Nord (lon_8.5524082_lat_52.9532189)
# -----------------------------------------------------------------------------------------
#
# Downloading image 275: Bentheimer Wald (lon_7.0388979_lat_52.3124962)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 275: Bentheimer Wald (lon_7.0388979_lat_52.3124962)
# -----------------------------------------------------------------------------------------
#
# Downloading image 276: De Poppe (lon_7.0475122_lat_52.3150498)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 276: De Poppe (lon_7.0475122_lat_52.3150498)
# -----------------------------------------------------------------------------------------
#
# Downloading image 277: Tümmelsberg (lon_11.9467773_lat_50.8894919)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop returns image.
#
# Download completed for image 277: Tümmelsberg (lon_11.9467773_lat_50.8894919)
# -----------------------------------------------------------------------------------------
#
# Downloading image 278: Am Stern (lon_13.1525352_lat_52.3854871)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns image.
#
# Download completed for image 278: Am Stern (lon_13.1525352_lat_52.3854871)
# -----------------------------------------------------------------------------------------
#
# Downloading image 279: Parforceheide (lon_13.1523908_lat_52.3828016)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns image.
#
# Download completed for image 279: Parforceheide (lon_13.1523908_lat_52.3828016)
# -----------------------------------------------------------------------------------------
#
# Downloading image 280: Rodablick (lon_11.7099428_lat_50.8741147)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop returns image.
#
# Download completed for image 280: Rodablick (lon_11.7099428_lat_50.8741147)
# -----------------------------------------------------------------------------------------
#
# Downloading image 281: Rastplatz Scheidskopf (lon_8.1811559_lat_50.7558251)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 281: Rastplatz Scheidskopf (lon_8.1811559_lat_50.7558251)
# -----------------------------------------------------------------------------------------
#
# Downloading image 282: Handewitter Forst (lon_9.3607539_lat_54.7605641)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb does not contain bounding box.
# sh_dop20_rgb returns image.
#
# Download completed for image 282: Handewitter Forst (lon_9.3607539_lat_54.7605641)
# -----------------------------------------------------------------------------------------
#
# Downloading image 283: Delmetal Süd (lon_8.5326591_lat_52.9474104)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 283: Delmetal Süd (lon_8.5326591_lat_52.9474104)
# -----------------------------------------------------------------------------------------
#
# Downloading image 284: Ziethener Luch (lon_13.0690147_lat_52.7049792)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns image.
#
# Download completed for image 284: Ziethener Luch (lon_13.0690147_lat_52.7049792)
# -----------------------------------------------------------------------------------------
#
# Downloading image 285: Krämer Forst (lon_13.0680682_lat_52.7042058)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns image.
#
# Download completed for image 285: Krämer Forst (lon_13.0680682_lat_52.7042058)
# -----------------------------------------------------------------------------------------
#
# Downloading image 286: Engelmannsbäke Süd (lon_8.2751069_lat_52.8833357)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 286: Engelmannsbäke Süd (lon_8.2751069_lat_52.8833357)
# -----------------------------------------------------------------------------------------
#
# Downloading image 287: Olle Rheen Ost (lon_7.2412833_lat_53.0872526)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 287: Olle Rheen Ost (lon_7.2412833_lat_53.0872526)
# -----------------------------------------------------------------------------------------
#
# Downloading image 288: Olle Rheen West (lon_7.2401552_lat_53.0870132)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 288: Olle Rheen West (lon_7.2401552_lat_53.0870132)
# -----------------------------------------------------------------------------------------
#
# Downloading image 289: None (lon_12.9224257_lat_52.4200411)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns image.
#
# Download completed for image 289: None (lon_12.9224257_lat_52.4200411)
# -----------------------------------------------------------------------------------------
#
# Downloading image 290: Ruppiner See (lon_12.7592133_lat_52.8776048)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns image.
#
# Download completed for image 290: Ruppiner See (lon_12.7592133_lat_52.8776048)
# -----------------------------------------------------------------------------------------
#
# Downloading image 291: Am Rhinluch (lon_12.7580653_lat_52.8778128)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns image.
#
# Download completed for image 291: Am Rhinluch (lon_12.7580653_lat_52.8778128)
# -----------------------------------------------------------------------------------------
#
# Downloading image 292: Gut Friedrichstal (lon_7.2005154_lat_52.2816225)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 292: Gut Friedrichstal (lon_7.2005154_lat_52.2816225)
# -----------------------------------------------------------------------------------------
#
# Downloading image 293: Wildbahn (lon_8.5597202_lat_49.5969765)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 293: Wildbahn (lon_8.5597202_lat_49.5969765)
# -----------------------------------------------------------------------------------------
#
# Downloading image 294: Adlersberg (lon_10.7306355_lat_50.559048)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop returns image.
#
# Download completed for image 294: Adlersberg (lon_10.7306355_lat_50.559048)
# -----------------------------------------------------------------------------------------
#
# Downloading image 295: Rastplatz Bissendorf Süd (lon_9.7695159_lat_52.5102873)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 295: Rastplatz Bissendorf Süd (lon_9.7695159_lat_52.5102873)
# -----------------------------------------------------------------------------------------

# %% [markdown]
# ## Mass-Download correctly laballed service stations as tifs

# %%
def mass_download_tif(geodataframe, wms_urls, layer_extents, size = 2560):
    """
    Download a large number of GeoTIFF images from WMS services

    Parameters:
    geodataframe (GeoDataFrame): GeoDataFrame containing the bounding boxes
    wms_urls (dict): dictionary containing layer_names as keys and urls as values
    layer_extents: dictionary of layer names and their extent bounding boxes
    size (int): determines the size of the output png in pixels
    """

    for index, row in geodataframe.iterrows():
        bbox = row["bbox"]
        id_rest = row["id_rest"]
        name = row["name"]

        print(f"Downloading image {index}: {name} ({id_rest})\n")

        # Create map
        response = create_png_from_bbox(bbox, wms_urls, layer_extents, size)

        # Define base directory
        base_dir = "02_data_acquisition/tif_download_wrongly_labelled_service_stations"
        
        # Ensure the directory exists
        os.makedirs(base_dir, exist_ok=True)

        # Save map as png
        file_path_png = f"02_data_acquisition/tif_download_wrongly_labelled_service_stations/{id_rest}_{name}.png"
        download_as_png(response, file_path_png)

        # Safe tif from png
        file_path_tif = f"02_data_acquisition/tif_download_wrongly_labelled_service_stations/{id_rest}_{name}.tif"
        download_tif_from_png(file_path_png, file_path_tif, bbox)

        # Delete png
        delete_file(file_path_png)

        print(f"\nDownload completed for image {index}: {name} ({id_rest})")
        print("----------------------------------------------------------------------------------------- \n")

# %%
mass_download_tif(wrongly_labelled_service_stations_bbox, wms_urls, layer_extents, size = 2560)
# Out:
# Downloading image 0: Hohe Schrecke West (lon_11.2442867_lat_51.3248863)
#
# WMS_NI_DOP returns blank image.
# bebb_dop20c returns blank image.
# th_dop returns image.
# /opt/homebrew/lib/python3.11/site-packages/rasterio/__init__.py:304: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# Download completed for image 0: Hohe Schrecke West (lon_11.2442867_lat_51.3248863)
# -----------------------------------------------------------------------------------------
#
# Downloading image 1: Probstheide (lon_13.5458137_lat_52.7129474)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns image.
#
# Download completed for image 1: Probstheide (lon_13.5458137_lat_52.7129474)
# -----------------------------------------------------------------------------------------
#
# Downloading image 2: Ladeburger Heide (lon_13.549042_lat_52.7092396)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns image.
#
# Download completed for image 2: Ladeburger Heide (lon_13.549042_lat_52.7092396)
# -----------------------------------------------------------------------------------------
#
# Downloading image 3: Spießwald (lon_8.6624068_lat_50.2544468)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 3: Spießwald (lon_8.6624068_lat_50.2544468)
# -----------------------------------------------------------------------------------------
#
# Downloading image 4: Rastplatz Rolandshöhe (lon_8.6184146_lat_49.7896285)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 4: Rastplatz Rolandshöhe (lon_8.6184146_lat_49.7896285)
# -----------------------------------------------------------------------------------------
#
# Downloading image 5: Vahrenheide (lon_9.7581375_lat_52.4268193)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 5: Vahrenheide (lon_9.7581375_lat_52.4268193)
# -----------------------------------------------------------------------------------------
#
# Downloading image 6: Stadtwald (lon_8.633307_lat_50.0540941)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 6: Stadtwald (lon_8.633307_lat_50.0540941)
# -----------------------------------------------------------------------------------------
#
# Downloading image 7: Busschewald (lon_10.2703215_lat_53.3301407)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 7: Busschewald (lon_10.2703215_lat_53.3301407)
# -----------------------------------------------------------------------------------------
#
# Downloading image 8: An der Alpe Ost (lon_9.930895_lat_52.2392839)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 8: An der Alpe Ost (lon_9.930895_lat_52.2392839)
# -----------------------------------------------------------------------------------------
#
# Downloading image 9: An der Alpe West (lon_9.9290741_lat_52.2397704)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 9: An der Alpe West (lon_9.9290741_lat_52.2397704)
# -----------------------------------------------------------------------------------------
#
# Downloading image 10: Brockenblick (lon_10.6579729_lat_51.9212477)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 10: Brockenblick (lon_10.6579729_lat_51.9212477)
# -----------------------------------------------------------------------------------------
#
# Downloading image 11: Eichower Fließ (lon_14.1236975_lat_51.7547827)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns image.
#
# Download completed for image 11: Eichower Fließ (lon_14.1236975_lat_51.7547827)
# -----------------------------------------------------------------------------------------
#
# Downloading image 12: Leinetal (lon_10.1741282_lat_51.4096944)
#
# WMS_NI_DOP returns blank image.
# bebb_dop20c does not contain bounding box.
# th_dop returns image.
#
# Download completed for image 12: Leinetal (lon_10.1741282_lat_51.4096944)
# -----------------------------------------------------------------------------------------
#
# Downloading image 13: None (lon_10.6238862_lat_51.4340877)
#
# WMS_NI_DOP returns blank image.
# bebb_dop20c does not contain bounding box.
# th_dop returns image.
#
# Download completed for image 13: None (lon_10.6238862_lat_51.4340877)
# -----------------------------------------------------------------------------------------
#
# Downloading image 14: Rastplatz Kesselberg-Süd (lon_10.7778756_lat_51.4723257)
#
# WMS_NI_DOP returns blank image.
# bebb_dop20c does not contain bounding box.
# th_dop returns image.
#
# Download completed for image 14: Rastplatz Kesselberg-Süd (lon_10.7778756_lat_51.4723257)
# -----------------------------------------------------------------------------------------
#
# Downloading image 15: Querfurter Platte Süd (lon_11.7243104_lat_51.3999369)
#
# WMS_NI_DOP returns blank image.
# bebb_dop20c returns blank image.
# th_dop returns blank image.
# lsa_lvermgeo_dop20_2 returns image.
#
# Download completed for image 15: Querfurter Platte Süd (lon_11.7243104_lat_51.3999369)
# -----------------------------------------------------------------------------------------
#
# Downloading image 16: Fuchsaue Nord (lon_12.2147233_lat_51.2415014)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop returns blank image.
# lsa_lvermgeo_dop20_2 returns blank image.
# he_dop_rgb does not contain bounding box.
# sh_dop20_rgb returns blank image.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[227], line 1
# ----> 1 mass_download_tif(wrongly_labelled_service_stations_bbox, wms_urls, layer_extents, size = 2560)
#
# Cell In[226], line 20, in mass_download_tif(geodataframe, wms_urls, layer_extents, size)
#      17 print(f"Downloading image {index}: {name} ({id_rest})\n")
#      19 # Create map
# ---> 20 response = create_png_from_bbox(bbox, wms_urls, layer_extents, size)
#      22 # Define base directory
#      23 base_dir = "02_data_acquisition/tif_download_wrongly_labelled_service_stations"
#
# Cell In[160], line 104, in create_png_from_bbox(bbox, wms_urls, layer_extents, size)
#     101 chosen_layer = determine_layer_for_bbox(bbox, wms_urls, layer_extents)
#     103 if chosen_layer == None:
# --> 104     raise ValueError("No layer intersects with the provided bounding box.")
#     105 else:
#     106     # Correctly create a WebMapService object from chosen layer
#     107     wms = WebMapService(wms_urls[chosen_layer])
#
# ValueError: No layer intersects with the provided bounding box.

# %% [markdown]
# Fuchsaue Nord (lon_12.2147233_lat_51.2415014) does not return an image.

# %%
wrongly_labelled_service_stations_bbox_rest = wrongly_labelled_service_stations_bbox[17:]

# %%
mass_download_tif(wrongly_labelled_service_stations_bbox_rest, wms_urls, layer_extents, size = 2560)
# Out:
# Downloading image 17: Humboldtblick (lon_9.6690837_lat_51.3960842)
#
# WMS_NI_DOP returns image.
# /opt/homebrew/lib/python3.11/site-packages/rasterio/__init__.py:304: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# Download completed for image 17: Humboldtblick (lon_9.6690837_lat_51.3960842)
# -----------------------------------------------------------------------------------------
#
# Downloading image 18: Herkulesblick (lon_9.5648832_lat_51.3206232)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 18: Herkulesblick (lon_9.5648832_lat_51.3206232)
# -----------------------------------------------------------------------------------------
#
# Downloading image 19: Hedemünden (lon_9.7765986_lat_51.39495)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 19: Hedemünden (lon_9.7765986_lat_51.39495)
# -----------------------------------------------------------------------------------------
#
# Downloading image 20: Brasselberg (lon_9.4159049_lat_51.2726438)
#
# WMS_NI_DOP returns blank image.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 20: Brasselberg (lon_9.4159049_lat_51.2726438)
# -----------------------------------------------------------------------------------------
#
# Downloading image 21: Firnsbachtal (lon_9.3682659_lat_51.2848607)
#
# WMS_NI_DOP returns blank image.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 21: Firnsbachtal (lon_9.3682659_lat_51.2848607)
# -----------------------------------------------------------------------------------------
#
# Downloading image 22: Hirzstein (lon_9.3696302_lat_51.2844243)
#
# WMS_NI_DOP returns blank image.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 22: Hirzstein (lon_9.3696302_lat_51.2844243)
# -----------------------------------------------------------------------------------------
#
# Downloading image 23: Roterain (lon_9.2941255_lat_51.3122625)
#
# WMS_NI_DOP returns blank image.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 23: Roterain (lon_9.2941255_lat_51.3122625)
# -----------------------------------------------------------------------------------------
#
# Downloading image 24: Schoren (lon_9.1600031_lat_51.4173784)
#
# WMS_NI_DOP returns blank image.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 24: Schoren (lon_9.1600031_lat_51.4173784)
# -----------------------------------------------------------------------------------------
#
# Downloading image 25: Am roten Ufer (lon_9.1613741_lat_51.4145048)
#
# WMS_NI_DOP returns blank image.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 25: Am roten Ufer (lon_9.1613741_lat_51.4145048)
# -----------------------------------------------------------------------------------------
#
# Downloading image 26: None (lon_7.2187753_lat_52.2848132)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 26: None (lon_7.2187753_lat_52.2848132)
# -----------------------------------------------------------------------------------------
#
# Downloading image 27: Am Quast (lon_9.0331918_lat_51.4840659)
#
# WMS_NI_DOP returns blank image.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 27: Am Quast (lon_9.0331918_lat_51.4840659)
# -----------------------------------------------------------------------------------------
#
# Downloading image 28: None (lon_14.6664657_lat_51.6935159)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns image.
#
# Download completed for image 28: None (lon_14.6664657_lat_51.6935159)
# -----------------------------------------------------------------------------------------
#
# Downloading image 29: Hatzte (lon_9.4270122_lat_53.2544235)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 29: Hatzte (lon_9.4270122_lat_53.2544235)
# -----------------------------------------------------------------------------------------
#
# Downloading image 30: Seckbruch (lon_9.8243386_lat_52.5040831)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 30: Seckbruch (lon_9.8243386_lat_52.5040831)
# -----------------------------------------------------------------------------------------
#
# Downloading image 31: Südhorn (lon_9.7141782_lat_52.6403023)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 31: Südhorn (lon_9.7141782_lat_52.6403023)
# -----------------------------------------------------------------------------------------
#
# Downloading image 32: Rosengarten (lon_9.8725742_lat_53.3827185)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 32: Rosengarten (lon_9.8725742_lat_53.3827185)
# -----------------------------------------------------------------------------------------
#
# Downloading image 33: Klockow-Ost (lon_13.9939049_lat_53.3959562)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns image.
#
# Download completed for image 33: Klockow-Ost (lon_13.9939049_lat_53.3959562)
# -----------------------------------------------------------------------------------------
#
# Downloading image 34: Klockow-West (lon_13.9923448_lat_53.3923443)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns image.
#
# Download completed for image 34: Klockow-West (lon_13.9923448_lat_53.3923443)
# -----------------------------------------------------------------------------------------
#
# Downloading image 35: Dolmar (lon_10.5352437_lat_50.6005787)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop returns image.
#
# Download completed for image 35: Dolmar (lon_10.5352437_lat_50.6005787)
# -----------------------------------------------------------------------------------------
#
# Downloading image 36: Fuchsberg (lon_9.6811216_lat_50.6510697)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 36: Fuchsberg (lon_9.6811216_lat_50.6510697)
# -----------------------------------------------------------------------------------------
#
# Downloading image 37: Steinborntal (lon_9.7320035_lat_50.4520141)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop returns blank image.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 37: Steinborntal (lon_9.7320035_lat_50.4520141)
# -----------------------------------------------------------------------------------------
#
# Downloading image 38: Brockenblick (lon_10.6630829_lat_51.917356)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 38: Brockenblick (lon_10.6630829_lat_51.917356)
# -----------------------------------------------------------------------------------------
#
# Downloading image 39: Regensteinblick (lon_10.8884541_lat_51.839659)
#
# WMS_NI_DOP returns blank image.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 returns image.
#
# Download completed for image 39: Regensteinblick (lon_10.8884541_lat_51.839659)
# -----------------------------------------------------------------------------------------
#
# Downloading image 40: Ravensmühle (lon_13.7777207_lat_53.5210372)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns image.
#
# Download completed for image 40: Ravensmühle (lon_13.7777207_lat_53.5210372)
# -----------------------------------------------------------------------------------------
#
# Downloading image 41: Röhrse Nord (lon_10.1665917_lat_52.3598134)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 41: Röhrse Nord (lon_10.1665917_lat_52.3598134)
# -----------------------------------------------------------------------------------------
#
# Downloading image 42: Mahndorfer Marsch (lon_8.9424542_lat_53.0280869)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 42: Mahndorfer Marsch (lon_8.9424542_lat_53.0280869)
# -----------------------------------------------------------------------------------------
#
# Downloading image 43: Harmonie (lon_8.6074934_lat_53.3413264)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 43: Harmonie (lon_8.6074934_lat_53.3413264)
# -----------------------------------------------------------------------------------------
#
# Downloading image 44: Binnermoor (lon_8.5844001_lat_53.3595834)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 44: Binnermoor (lon_8.5844001_lat_53.3595834)
# -----------------------------------------------------------------------------------------
#
# Downloading image 45: Bütteler Holz Ost (lon_8.6579523_lat_53.6066306)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 45: Bütteler Holz Ost (lon_8.6579523_lat_53.6066306)
# -----------------------------------------------------------------------------------------
#
# Downloading image 46: Bütteler Holz West (lon_8.6591991_lat_53.6100326)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 46: Bütteler Holz West (lon_8.6591991_lat_53.6100326)
# -----------------------------------------------------------------------------------------
#
# Downloading image 47: Nesse (lon_8.6167533_lat_53.47697)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 47: Nesse (lon_8.6167533_lat_53.47697)
# -----------------------------------------------------------------------------------------
#
# Downloading image 48: Nesse (lon_8.615916_lat_53.4773133)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 48: Nesse (lon_8.615916_lat_53.4773133)
# -----------------------------------------------------------------------------------------
#
# Downloading image 49: Midlum (lon_8.6612579_lat_53.727224)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 49: Midlum (lon_8.6612579_lat_53.727224)
# -----------------------------------------------------------------------------------------
#
# Downloading image 50: Krempel (lon_8.6635734_lat_53.709556)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 50: Krempel (lon_8.6635734_lat_53.709556)
# -----------------------------------------------------------------------------------------
#
# Downloading image 51: Thünen (lon_9.0222248_lat_53.0518133)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 51: Thünen (lon_9.0222248_lat_53.0518133)
# -----------------------------------------------------------------------------------------
#
# Downloading image 52: Rodablick (lon_11.6645768_lat_50.8773612)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop returns image.
#
# Download completed for image 52: Rodablick (lon_11.6645768_lat_50.8773612)
# -----------------------------------------------------------------------------------------
#
# Downloading image 53: None (lon_9.9597557_lat_50.9450357)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop returns image.
#
# Download completed for image 53: None (lon_9.9597557_lat_50.9450357)
# -----------------------------------------------------------------------------------------
#
# Downloading image 54: Nadelöhr (lon_9.8798686_lat_50.9064497)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop returns blank image.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 54: Nadelöhr (lon_9.8798686_lat_50.9064497)
# -----------------------------------------------------------------------------------------
#
# Downloading image 55: Papenbrink (lon_9.0552368_lat_52.2187953)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 55: Papenbrink (lon_9.0552368_lat_52.2187953)
# -----------------------------------------------------------------------------------------
#
# Downloading image 56: Bernser Kirchweg (lon_9.16598_lat_52.2161316)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 56: Bernser Kirchweg (lon_9.16598_lat_52.2161316)
# -----------------------------------------------------------------------------------------
#
# Downloading image 57: Schafstrift (lon_9.3134158_lat_52.2616336)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 57: Schafstrift (lon_9.3134158_lat_52.2616336)
# -----------------------------------------------------------------------------------------
#
# Downloading image 58: Varrelheide (lon_9.8246715_lat_52.4258443)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 58: Varrelheide (lon_9.8246715_lat_52.4258443)
# -----------------------------------------------------------------------------------------
#
# Downloading image 59: Alter Postweg (lon_11.6762787_lat_51.8279886)
#
# WMS_NI_DOP returns blank image.
# bebb_dop20c returns blank image.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 returns image.
#
# Download completed for image 59: Alter Postweg (lon_11.6762787_lat_51.8279886)
# -----------------------------------------------------------------------------------------
#
# Downloading image 60: Alter Postweg (lon_11.6751194_lat_51.8288226)
#
# WMS_NI_DOP returns blank image.
# bebb_dop20c returns blank image.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 returns image.
#
# Download completed for image 60: Alter Postweg (lon_11.6751194_lat_51.8288226)
# -----------------------------------------------------------------------------------------
#
# Downloading image 61: Schlochau-West (lon_9.9402235_lat_51.7140776)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 61: Schlochau-West (lon_9.9402235_lat_51.7140776)
# -----------------------------------------------------------------------------------------
#
# Downloading image 62: None (lon_10.4688724_lat_51.4093481)
#
# WMS_NI_DOP returns blank image.
# bebb_dop20c does not contain bounding box.
# th_dop returns image.
#
# Download completed for image 62: None (lon_10.4688724_lat_51.4093481)
# -----------------------------------------------------------------------------------------
#
# Downloading image 63: None (lon_8.73536_lat_50.0770423)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 63: None (lon_8.73536_lat_50.0770423)
# -----------------------------------------------------------------------------------------
#
# Downloading image 64: None (lon_8.736501_lat_50.0785698)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 64: None (lon_8.736501_lat_50.0785698)
# -----------------------------------------------------------------------------------------
#
# Downloading image 65: Teutoburger Wald Ost (lon_8.1571296_lat_52.1690264)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 65: Teutoburger Wald Ost (lon_8.1571296_lat_52.1690264)
# -----------------------------------------------------------------------------------------
#
# Downloading image 66: Teutoburger Wald West (lon_8.1555659_lat_52.1705103)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 66: Teutoburger Wald West (lon_8.1555659_lat_52.1705103)
# -----------------------------------------------------------------------------------------
#
# Downloading image 67: Ihlegrund (lon_11.9661867_lat_52.2348893)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns blank image.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 returns image.
#
# Download completed for image 67: Ihlegrund (lon_11.9661867_lat_52.2348893)
# -----------------------------------------------------------------------------------------
#
# Downloading image 68: Wüstenforst (lon_12.140788_lat_52.2431929)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns blank image.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 returns image.
#
# Download completed for image 68: Wüstenforst (lon_12.140788_lat_52.2431929)
# -----------------------------------------------------------------------------------------
#
# Downloading image 69: Bispinger Tor (lon_9.9675853_lat_53.0856623)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 69: Bispinger Tor (lon_9.9675853_lat_53.0856623)
# -----------------------------------------------------------------------------------------
#
# Downloading image 70: Wilseder Berg (lon_9.9478762_lat_53.0352366)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 70: Wilseder Berg (lon_9.9478762_lat_53.0352366)
# -----------------------------------------------------------------------------------------
#
# Downloading image 71: Rumohr (lon_10.0237836_lat_54.2450733)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb does not contain bounding box.
# sh_dop20_rgb returns image.
#
# Download completed for image 71: Rumohr (lon_10.0237836_lat_54.2450733)
# -----------------------------------------------------------------------------------------
#
# Downloading image 72: PWC Hohe Schrecke West (lon_11.2429922_lat_51.3232808)
#
# WMS_NI_DOP returns blank image.
# bebb_dop20c returns blank image.
# th_dop returns image.
#
# Download completed for image 72: PWC Hohe Schrecke West (lon_11.2429922_lat_51.3232808)
# -----------------------------------------------------------------------------------------
#
# Downloading image 73: None (lon_12.9659112_lat_52.5330037)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns image.
#
# Download completed for image 73: None (lon_12.9659112_lat_52.5330037)
# -----------------------------------------------------------------------------------------
#
# Downloading image 74: Gartherfeld (lon_8.2197171_lat_52.8413999)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 74: Gartherfeld (lon_8.2197171_lat_52.8413999)
# -----------------------------------------------------------------------------------------
#
# Downloading image 75: Drantumer Mühle (lon_8.2151783_lat_52.8283254)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 75: Drantumer Mühle (lon_8.2151783_lat_52.8283254)
# -----------------------------------------------------------------------------------------
#
# Downloading image 76: None (lon_8.5063482_lat_52.9364036)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 76: None (lon_8.5063482_lat_52.9364036)
# -----------------------------------------------------------------------------------------
#
# Downloading image 77: None (lon_8.3817045_lat_52.9120153)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 77: None (lon_8.3817045_lat_52.9120153)
# -----------------------------------------------------------------------------------------
#
# Downloading image 78: Rastplatz Kiekut-Nord (lon_8.6688465_lat_52.9984663)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 78: Rastplatz Kiekut-Nord (lon_8.6688465_lat_52.9984663)
# -----------------------------------------------------------------------------------------
#
# Downloading image 79: Wildeshausen (lon_8.3620815_lat_52.907909)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 79: Wildeshausen (lon_8.3620815_lat_52.907909)
# -----------------------------------------------------------------------------------------
#
# Downloading image 80: Oldenburg (lon_8.5996573_lat_52.9660452)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 80: Oldenburg (lon_8.5996573_lat_52.9660452)
# -----------------------------------------------------------------------------------------
#
# Downloading image 81: Groß Ippener (lon_8.5946304_lat_52.9638508)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 81: Groß Ippener (lon_8.5946304_lat_52.9638508)
# -----------------------------------------------------------------------------------------
#
# Downloading image 82: Brockdorf (lon_8.1481291_lat_52.6359183)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 82: Brockdorf (lon_8.1481291_lat_52.6359183)
# -----------------------------------------------------------------------------------------
#
# Downloading image 83: Rastplatz Fuchsbuckel (lon_8.6191945_lat_49.6223186)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 83: Rastplatz Fuchsbuckel (lon_8.6191945_lat_49.6223186)
# -----------------------------------------------------------------------------------------
#
# Downloading image 84: Rastplatz Nachtweide (lon_8.5925199_lat_49.7314605)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 84: Rastplatz Nachtweide (lon_8.5925199_lat_49.7314605)
# -----------------------------------------------------------------------------------------
#
# Downloading image 85: Rastplatz Erlensee (lon_8.602833_lat_49.7668168)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 85: Rastplatz Erlensee (lon_8.602833_lat_49.7668168)
# -----------------------------------------------------------------------------------------
#
# Downloading image 86: Bornbruch (Ost) (lon_8.6036028_lat_49.9748114)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 86: Bornbruch (Ost) (lon_8.6036028_lat_49.9748114)
# -----------------------------------------------------------------------------------------
#
# Downloading image 87: Bornbruch (West) (lon_8.6029015_lat_49.975111)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 87: Bornbruch (West) (lon_8.6029015_lat_49.975111)
# -----------------------------------------------------------------------------------------
#
# Downloading image 88: Steingrund (lon_8.5969375_lat_50.0002998)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 88: Steingrund (lon_8.5969375_lat_50.0002998)
# -----------------------------------------------------------------------------------------
#
# Downloading image 89: Rehbrook Ost (lon_10.3245839_lat_53.7345734)
#
# WMS_NI_DOP returns blank image.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb does not contain bounding box.
# sh_dop20_rgb returns image.
#
# Download completed for image 89: Rehbrook Ost (lon_10.3245839_lat_53.7345734)
# -----------------------------------------------------------------------------------------
#
# Downloading image 90: Melmshöhe (lon_10.455208_lat_53.8050009)
#
# WMS_NI_DOP returns blank image.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb does not contain bounding box.
# sh_dop20_rgb returns image.
#
# Download completed for image 90: Melmshöhe (lon_10.455208_lat_53.8050009)
# -----------------------------------------------------------------------------------------
#
# Downloading image 91: None (lon_11.8481003_lat_50.875064)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop returns image.
#
# Download completed for image 91: None (lon_11.8481003_lat_50.875064)
# -----------------------------------------------------------------------------------------
#
# Downloading image 92: Bloh (lon_8.1332443_lat_53.1614875)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 92: Bloh (lon_8.1332443_lat_53.1614875)
# -----------------------------------------------------------------------------------------
#
# Downloading image 93: Bloh (lon_8.1221134_lat_53.1667353)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 93: Bloh (lon_8.1221134_lat_53.1667353)
# -----------------------------------------------------------------------------------------
#
# Downloading image 94: Wüstenforst (lon_12.149456_lat_52.2449316)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns blank image.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 returns image.
#
# Download completed for image 94: Wüstenforst (lon_12.149456_lat_52.2449316)
# -----------------------------------------------------------------------------------------
#
# Downloading image 95: Krähenberge (lon_11.7524542_lat_52.2277066)
#
# WMS_NI_DOP returns blank image.
# bebb_dop20c returns blank image.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 returns image.
#
# Download completed for image 95: Krähenberge (lon_11.7524542_lat_52.2277066)
# -----------------------------------------------------------------------------------------
#
# Downloading image 96: Krähenberge (lon_11.7559379_lat_52.2272876)
#
# WMS_NI_DOP returns blank image.
# bebb_dop20c returns blank image.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 returns image.
#
# Download completed for image 96: Krähenberge (lon_11.7559379_lat_52.2272876)
# -----------------------------------------------------------------------------------------
#
# Downloading image 97: Jühnsdorfer Heide (lon_13.3713665_lat_52.3078778)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns image.
#
# Download completed for image 97: Jühnsdorfer Heide (lon_13.3713665_lat_52.3078778)
# -----------------------------------------------------------------------------------------
#
# Downloading image 98: Ihlegrund (lon_11.9876903_lat_52.2359165)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns blank image.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 returns image.
#
# Download completed for image 98: Ihlegrund (lon_11.9876903_lat_52.2359165)
# -----------------------------------------------------------------------------------------
#
# Downloading image 99: Beckhauser Büsche (lon_8.1468263_lat_53.2976569)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 99: Beckhauser Büsche (lon_8.1468263_lat_53.2976569)
# -----------------------------------------------------------------------------------------
#
# Downloading image 100: Beckhauser Büsche (lon_8.1467217_lat_53.2944936)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 100: Beckhauser Büsche (lon_8.1467217_lat_53.2944936)
# -----------------------------------------------------------------------------------------
#
# Downloading image 101: Schieferberg (lon_13.1937997_lat_52.3010565)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns image.
#
# Download completed for image 101: Schieferberg (lon_13.1937997_lat_52.3010565)
# -----------------------------------------------------------------------------------------
#
# Downloading image 102: Schwielowsee (lon_12.8531966_lat_52.3198213)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns image.
#
# Download completed for image 102: Schwielowsee (lon_12.8531966_lat_52.3198213)
# -----------------------------------------------------------------------------------------
#
# Downloading image 103: Dorngrund Nord (lon_12.1425003_lat_53.2643763)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns image.
#
# Download completed for image 103: Dorngrund Nord (lon_12.1425003_lat_53.2643763)
# -----------------------------------------------------------------------------------------
#
# Downloading image 104: Dorngrund Süd (lon_12.1423532_lat_53.263714)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns image.
#
# Download completed for image 104: Dorngrund Süd (lon_12.1423532_lat_53.263714)
# -----------------------------------------------------------------------------------------
#
# Downloading image 105: Thünen (lon_9.0123215_lat_53.0517663)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 105: Thünen (lon_9.0123215_lat_53.0517663)
# -----------------------------------------------------------------------------------------
#
# Downloading image 106: Hahnenkoppel (lon_10.3048543_lat_53.568087)
#
# WMS_NI_DOP returns blank image.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb does not contain bounding box.
# sh_dop20_rgb returns image.
#
# Download completed for image 106: Hahnenkoppel (lon_10.3048543_lat_53.568087)
# -----------------------------------------------------------------------------------------
#
# Downloading image 107: Hahnenkoppel (lon_10.3003947_lat_53.5683535)
#
# WMS_NI_DOP returns blank image.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb does not contain bounding box.
# sh_dop20_rgb returns image.
#
# Download completed for image 107: Hahnenkoppel (lon_10.3003947_lat_53.5683535)
# -----------------------------------------------------------------------------------------
#
# Downloading image 108: Geißhecke (lon_9.6953904_lat_50.5889326)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 108: Geißhecke (lon_9.6953904_lat_50.5889326)
# -----------------------------------------------------------------------------------------
#
# Downloading image 109: Rastplatz Rauschenberg (lon_9.7165998_lat_50.5758475)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop returns blank image.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 109: Rastplatz Rauschenberg (lon_9.7165998_lat_50.5758475)
# -----------------------------------------------------------------------------------------
#
# Downloading image 110: Rastplatz Richtgraben (lon_9.6008842_lat_50.7612535)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 110: Rastplatz Richtgraben (lon_9.6008842_lat_50.7612535)
# -----------------------------------------------------------------------------------------
#
# Downloading image 111: Rastplatz Strampen (lon_9.5552964_lat_50.7839373)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 111: Rastplatz Strampen (lon_9.5552964_lat_50.7839373)
# -----------------------------------------------------------------------------------------
#
# Downloading image 112: Caputh (lon_12.8608997_lat_52.3180343)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns image.
#
# Download completed for image 112: Caputh (lon_12.8608997_lat_52.3180343)
# -----------------------------------------------------------------------------------------
#
# Downloading image 113: Kranichberge (lon_13.7976643_lat_52.4383976)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns image.
#
# Download completed for image 113: Kranichberge (lon_13.7976643_lat_52.4383976)
# -----------------------------------------------------------------------------------------
#
# Downloading image 114: Lankensee (lon_13.704978_lat_52.3214486)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns image.
#
# Download completed for image 114: Lankensee (lon_13.704978_lat_52.3214486)
# -----------------------------------------------------------------------------------------
#
# Downloading image 115: Uckleysee (lon_13.7073795_lat_52.3234317)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns image.
#
# Download completed for image 115: Uckleysee (lon_13.7073795_lat_52.3234317)
# -----------------------------------------------------------------------------------------
#
# Downloading image 116: Siethener Elsbruch (lon_13.1860148_lat_52.2996676)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns image.
#
# Download completed for image 116: Siethener Elsbruch (lon_13.1860148_lat_52.2996676)
# -----------------------------------------------------------------------------------------
#
# Downloading image 117: Parkplatz Schönwalde (lon_13.394675_lat_52.6763168)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns image.
#
# Download completed for image 117: Parkplatz Schönwalde (lon_13.394675_lat_52.6763168)
# -----------------------------------------------------------------------------------------
#
# Downloading image 118: None (lon_13.3912216_lat_52.6771222)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns image.
#
# Download completed for image 118: None (lon_13.3912216_lat_52.6771222)
# -----------------------------------------------------------------------------------------
#
# Downloading image 119: Am Rhinluch (lon_12.8219803_lat_52.7663465)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns image.
#
# Download completed for image 119: Am Rhinluch (lon_12.8219803_lat_52.7663465)
# -----------------------------------------------------------------------------------------
#
# Downloading image 120: None (lon_12.5509414_lat_53.0440047)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns image.
#
# Download completed for image 120: None (lon_12.5509414_lat_53.0440047)
# -----------------------------------------------------------------------------------------
#
# Downloading image 121: None (lon_12.5518272_lat_53.042607)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns image.
#
# Download completed for image 121: None (lon_12.5518272_lat_53.042607)
# -----------------------------------------------------------------------------------------
#
# Downloading image 122: Lichtenauer See - Lichtnojski jazor (lon_13.8920938_lat_51.814936)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns image.
#
# Download completed for image 122: Lichtenauer See - Lichtnojski jazor (lon_13.8920938_lat_51.814936)
# -----------------------------------------------------------------------------------------
#
# Downloading image 123: None (lon_13.8992016_lat_51.7010657)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns image.
#
# Download completed for image 123: None (lon_13.8992016_lat_51.7010657)
# -----------------------------------------------------------------------------------------
#
# Downloading image 124: Lorkberg Süd (lon_11.2477836_lat_52.1980946)
#
# WMS_NI_DOP returns blank image.
# bebb_dop20c returns blank image.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 returns image.
#
# Download completed for image 124: Lorkberg Süd (lon_11.2477836_lat_52.1980946)
# -----------------------------------------------------------------------------------------
#
# Downloading image 125: Lorkberg Nord (lon_11.2481831_lat_52.1991827)
#
# WMS_NI_DOP returns blank image.
# bebb_dop20c returns blank image.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 returns image.
#
# Download completed for image 125: Lorkberg Nord (lon_11.2481831_lat_52.1991827)
# -----------------------------------------------------------------------------------------
#
# Downloading image 126: Uhry (lon_10.8447017_lat_52.3053945)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 126: Uhry (lon_10.8447017_lat_52.3053945)
# -----------------------------------------------------------------------------------------
#
# Downloading image 127: Essehof Süd (lon_10.7014522_lat_52.3068605)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 127: Essehof Süd (lon_10.7014522_lat_52.3068605)
# -----------------------------------------------------------------------------------------
#
# Downloading image 128: Gleiberger Land (lon_8.6692184_lat_50.618922)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 128: Gleiberger Land (lon_8.6692184_lat_50.618922)
# -----------------------------------------------------------------------------------------
#
# Downloading image 129: Ahlhorn (lon_8.165554_lat_52.9134371)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 129: Ahlhorn (lon_8.165554_lat_52.9134371)
# -----------------------------------------------------------------------------------------
#
# Downloading image 130: Ahlhorn (lon_8.1656279_lat_52.9117566)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 130: Ahlhorn (lon_8.1656279_lat_52.9117566)
# -----------------------------------------------------------------------------------------
#
# Downloading image 131: Hasselburger Mühle (lon_10.8562049_lat_54.1557257)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb does not contain bounding box.
# sh_dop20_rgb returns image.
#
# Download completed for image 131: Hasselburger Mühle (lon_10.8562049_lat_54.1557257)
# -----------------------------------------------------------------------------------------
#
# Downloading image 132: Fladderlohhausen (lon_8.1094233_lat_52.5785402)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 132: Fladderlohhausen (lon_8.1094233_lat_52.5785402)
# -----------------------------------------------------------------------------------------
#
# Downloading image 133: Holdorf (lon_8.110306_lat_52.5754054)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 133: Holdorf (lon_8.110306_lat_52.5754054)
# -----------------------------------------------------------------------------------------
#
# Downloading image 134: Neuenkirchen (lon_8.0944079_lat_52.511622)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 134: Neuenkirchen (lon_8.0944079_lat_52.511622)
# -----------------------------------------------------------------------------------------
#
# Downloading image 135: Clemens-August-Dorf (lon_8.0932141_lat_52.5099163)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 135: Clemens-August-Dorf (lon_8.0932141_lat_52.5099163)
# -----------------------------------------------------------------------------------------
#
# Downloading image 136: Zur alten Römerstraße (lon_8.310856_lat_50.0263363)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 136: Zur alten Römerstraße (lon_8.310856_lat_50.0263363)
# -----------------------------------------------------------------------------------------
#
# Downloading image 137: Waldseite Süd (lon_7.1091394_lat_52.3359631)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 137: Waldseite Süd (lon_7.1091394_lat_52.3359631)
# -----------------------------------------------------------------------------------------
#
# Downloading image 138: Theißtal (lon_8.2912876_lat_50.1706652)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 138: Theißtal (lon_8.2912876_lat_50.1706652)
# -----------------------------------------------------------------------------------------
#
# Downloading image 139: Theißtal (lon_8.2958812_lat_50.1651148)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 139: Theißtal (lon_8.2958812_lat_50.1651148)
# -----------------------------------------------------------------------------------------
#
# Downloading image 140: Mainhausen (lon_8.9921725_lat_50.0032275)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 140: Mainhausen (lon_8.9921725_lat_50.0032275)
# -----------------------------------------------------------------------------------------
#
# Downloading image 141: Mainhausen (lon_8.990713_lat_50.0031845)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 141: Mainhausen (lon_8.990713_lat_50.0031845)
# -----------------------------------------------------------------------------------------
#
# Downloading image 142: Altholzkrug (lon_9.3762358_lat_54.7490204)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb does not contain bounding box.
# sh_dop20_rgb returns image.
#
# Download completed for image 142: Altholzkrug (lon_9.3762358_lat_54.7490204)
# -----------------------------------------------------------------------------------------
#
# Downloading image 143: Jägerturm Ost (lon_10.1924796_lat_52.0579861)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 143: Jägerturm Ost (lon_10.1924796_lat_52.0579861)
# -----------------------------------------------------------------------------------------
#
# Downloading image 144: Jägerturm West (lon_10.1921974_lat_52.0597398)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 144: Jägerturm West (lon_10.1921974_lat_52.0597398)
# -----------------------------------------------------------------------------------------
#
# Downloading image 145: Bebenseer Moor (lon_10.2941836_lat_53.8901124)
#
# WMS_NI_DOP returns blank image.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb does not contain bounding box.
# sh_dop20_rgb returns image.
#
# Download completed for image 145: Bebenseer Moor (lon_10.2941836_lat_53.8901124)
# -----------------------------------------------------------------------------------------
#
# Downloading image 146: Schwisseler Kamp (lon_10.2940174_lat_53.8904229)
#
# WMS_NI_DOP returns blank image.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb does not contain bounding box.
# sh_dop20_rgb returns image.
#
# Download completed for image 146: Schwisseler Kamp (lon_10.2940174_lat_53.8904229)
# -----------------------------------------------------------------------------------------
#
# Downloading image 147: Kaaksburg (lon_9.4784635_lat_54.0053378)
#
# WMS_NI_DOP returns blank image.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb does not contain bounding box.
# sh_dop20_rgb returns image.
#
# Download completed for image 147: Kaaksburg (lon_9.4784635_lat_54.0053378)
# -----------------------------------------------------------------------------------------
#
# Downloading image 148: Kaaksburg (lon_9.4792901_lat_54.0062045)
#
# WMS_NI_DOP returns blank image.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb does not contain bounding box.
# sh_dop20_rgb returns image.
#
# Download completed for image 148: Kaaksburg (lon_9.4792901_lat_54.0062045)
# -----------------------------------------------------------------------------------------
#
# Downloading image 149: Kinzigtal (lon_9.2098035_lat_50.1951851)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 149: Kinzigtal (lon_9.2098035_lat_50.1951851)
# -----------------------------------------------------------------------------------------
#
# Downloading image 150: Lemper Berg (lon_8.4125929_lat_50.6132695)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 150: Lemper Berg (lon_8.4125929_lat_50.6132695)
# -----------------------------------------------------------------------------------------
#
# Downloading image 151: Hasenwinkel (lon_11.4856603_lat_51.7805949)
#
# WMS_NI_DOP returns blank image.
# bebb_dop20c returns blank image.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 returns image.
#
# Download completed for image 151: Hasenwinkel (lon_11.4856603_lat_51.7805949)
# -----------------------------------------------------------------------------------------
#
# Downloading image 152: Hasenwinkel (lon_11.4857212_lat_51.7803271)
#
# WMS_NI_DOP returns blank image.
# bebb_dop20c returns blank image.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 returns image.
#
# Download completed for image 152: Hasenwinkel (lon_11.4857212_lat_51.7803271)
# -----------------------------------------------------------------------------------------
#
# Downloading image 153: Regensteinblick (lon_10.8830203_lat_51.8398105)
#
# WMS_NI_DOP returns blank image.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 returns image.
#
# Download completed for image 153: Regensteinblick (lon_10.8830203_lat_51.8398105)
# -----------------------------------------------------------------------------------------
#
# Downloading image 154: Sülzegrund (lon_11.5855061_lat_52.0606307)
#
# WMS_NI_DOP returns blank image.
# bebb_dop20c returns blank image.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 returns image.
#
# Download completed for image 154: Sülzegrund (lon_11.5855061_lat_52.0606307)
# -----------------------------------------------------------------------------------------
#
# Downloading image 155: Sülzegrund (lon_11.5846515_lat_52.0604543)
#
# WMS_NI_DOP returns blank image.
# bebb_dop20c returns blank image.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 returns image.
#
# Download completed for image 155: Sülzegrund (lon_11.5846515_lat_52.0604543)
# -----------------------------------------------------------------------------------------
#
# Downloading image 156: None (lon_8.1131885_lat_53.389612)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 156: None (lon_8.1131885_lat_53.389612)
# -----------------------------------------------------------------------------------------
#
# Downloading image 157: None (lon_10.0897595_lat_51.8052249)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 157: None (lon_10.0897595_lat_51.8052249)
# ...
# -----------------------------------------------------------------------------------------
#
# Downloading image 164: Hohe Wart (lon_8.4872997_lat_50.0061725)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 164: Hohe Wart (lon_8.4872997_lat_50.0061725)
# -----------------------------------------------------------------------------------------
#
# Downloading image 165: Timmerloh (lon_9.9496082_lat_53.0490828)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 165: Timmerloh (lon_9.9496082_lat_53.0490828)
# -----------------------------------------------------------------------------------------
#
# Downloading image 166: Auegrund (lon_10.0219933_lat_53.1474029)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 166: Auegrund (lon_10.0219933_lat_53.1474029)
# -----------------------------------------------------------------------------------------
#
# Downloading image 167: Utspann (lon_10.0880844_lat_53.254075)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 167: Utspann (lon_10.0880844_lat_53.254075)
# -----------------------------------------------------------------------------------------
#
# Downloading image 168: Eichberg (lon_10.0771629_lat_53.2925598)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 168: Eichberg (lon_10.0771629_lat_53.2925598)
# -----------------------------------------------------------------------------------------
#
# Downloading image 169: Vorm Naturschutzpark (lon_9.9969879_lat_53.1357379)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 169: Vorm Naturschutzpark (lon_9.9969879_lat_53.1357379)
# -----------------------------------------------------------------------------------------
#
# Downloading image 170: Südhorn (lon_9.7140608_lat_52.6397167)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 170: Südhorn (lon_9.7140608_lat_52.6397167)
# -----------------------------------------------------------------------------------------
#
# Downloading image 171: Walchum-Ost (lon_7.2544308_lat_52.9241632)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 171: Walchum-Ost (lon_7.2544308_lat_52.9241632)
# -----------------------------------------------------------------------------------------
#
# Downloading image 172: Rastplatz Hebel (lon_7.1723831_lat_52.7953751)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 172: Rastplatz Hebel (lon_7.1723831_lat_52.7953751)
# -----------------------------------------------------------------------------------------
#
# Downloading image 173: Ellund (lon_9.3286652_lat_54.8045491)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb does not contain bounding box.
# sh_dop20_rgb returns image.
#
# Download completed for image 173: Ellund (lon_9.3286652_lat_54.8045491)
# -----------------------------------------------------------------------------------------
#
# Downloading image 174: Rastplatz Bissendorf Nord (lon_9.7581285_lat_52.5049195)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 174: Rastplatz Bissendorf Nord (lon_9.7581285_lat_52.5049195)
# -----------------------------------------------------------------------------------------
#
# Downloading image 175: Rastplatz Hohenrain (lon_8.324182_lat_50.6472087)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 175: Rastplatz Hohenrain (lon_8.324182_lat_50.6472087)
# -----------------------------------------------------------------------------------------
#
# Downloading image 176: Rastplatz Ebersbach (lon_8.324524_lat_50.6450633)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 176: Rastplatz Ebersbach (lon_8.324524_lat_50.6450633)
# -----------------------------------------------------------------------------------------
#
# Downloading image 177: Büttelborn Nord (lon_8.5415272_lat_49.8947103)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 177: Büttelborn Nord (lon_8.5415272_lat_49.8947103)
# -----------------------------------------------------------------------------------------
#
# Downloading image 178: Rottkamp-Nord (lon_8.2028282_lat_52.2243557)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 178: Rottkamp-Nord (lon_8.2028282_lat_52.2243557)
# -----------------------------------------------------------------------------------------
#
# Downloading image 179: Rottkamp Süd (lon_8.1997168_lat_52.2249111)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 179: Rottkamp Süd (lon_8.1997168_lat_52.2249111)
# -----------------------------------------------------------------------------------------
#
# Downloading image 180: Pfaffenpfad (lon_8.6168768_lat_50.5273434)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 180: Pfaffenpfad (lon_8.6168768_lat_50.5273434)
# -----------------------------------------------------------------------------------------
#
# Downloading image 181: Kalkberge (lon_13.7994366_lat_52.4570641)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns image.
#
# Download completed for image 181: Kalkberge (lon_13.7994366_lat_52.4570641)
# -----------------------------------------------------------------------------------------
#
# Downloading image 182: Parkplatz Scheidweg (lon_8.6024977_lat_49.6962206)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 182: Parkplatz Scheidweg (lon_8.6024977_lat_49.6962206)
# -----------------------------------------------------------------------------------------
#
# Downloading image 183: Heseper Moor Ost (lon_7.1913537_lat_52.6347607)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 183: Heseper Moor Ost (lon_7.1913537_lat_52.6347607)
# -----------------------------------------------------------------------------------------
#
# Downloading image 184: Heseper Moor West (lon_7.1908361_lat_52.6363967)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 184: Heseper Moor West (lon_7.1908361_lat_52.6363967)
# -----------------------------------------------------------------------------------------
#
# Downloading image 185: None (lon_13.5622182_lat_52.3790797)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns image.
#
# Download completed for image 185: None (lon_13.5622182_lat_52.3790797)
# -----------------------------------------------------------------------------------------
#
# Downloading image 186: None (lon_13.5617962_lat_52.376454)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns image.
#
# Download completed for image 186: None (lon_13.5617962_lat_52.376454)
# -----------------------------------------------------------------------------------------
#
# Downloading image 187: Rastplatz Kalteiche (lon_8.1506512_lat_50.7729109)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 187: Rastplatz Kalteiche (lon_8.1506512_lat_50.7729109)
# -----------------------------------------------------------------------------------------
#
# Downloading image 188: Rastplatz Am Wildenstein (lon_8.1514665_lat_50.7732654)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 188: Rastplatz Am Wildenstein (lon_8.1514665_lat_50.7732654)
# -----------------------------------------------------------------------------------------
#
# Downloading image 189: Rastplatz Gaulskopf (lon_8.2810761_lat_50.7241346)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 189: Rastplatz Gaulskopf (lon_8.2810761_lat_50.7241346)
# -----------------------------------------------------------------------------------------
#
# Downloading image 190: Rastplatz Burger Hain (lon_8.2881044_lat_50.7075757)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 190: Rastplatz Burger Hain (lon_8.2881044_lat_50.7075757)
# -----------------------------------------------------------------------------------------
#
# Downloading image 191: Rastplatz Am Rehberg (lon_8.2885542_lat_50.6684857)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 191: Rastplatz Am Rehberg (lon_8.2885542_lat_50.6684857)
# -----------------------------------------------------------------------------------------
#
# Downloading image 192: Varrelheide (lon_9.8191407_lat_52.4272417)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 192: Varrelheide (lon_9.8191407_lat_52.4272417)
# -----------------------------------------------------------------------------------------
#
# Downloading image 193: Am Borbelholz (lon_8.1719914_lat_50.7599376)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 193: Am Borbelholz (lon_8.1719914_lat_50.7599376)
# -----------------------------------------------------------------------------------------
#
# Downloading image 194: Walchum West (lon_7.2526746_lat_52.9419091)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 194: Walchum West (lon_7.2526746_lat_52.9419091)
# -----------------------------------------------------------------------------------------
#
# Downloading image 195: Kappgraben Nord (lon_13.5128574_lat_52.6185225)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns image.
#
# Download completed for image 195: Kappgraben Nord (lon_13.5128574_lat_52.6185225)
# -----------------------------------------------------------------------------------------
#
# Downloading image 196: Kappgraben Süd (lon_13.5093849_lat_52.6184258)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c returns image.
#
# Download completed for image 196: Kappgraben Süd (lon_13.5093849_lat_52.6184258)
# -----------------------------------------------------------------------------------------
#
# Downloading image 197: None (lon_8.6293369_lat_49.6096602)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 197: None (lon_8.6293369_lat_49.6096602)
# -----------------------------------------------------------------------------------------
#
# Downloading image 198: None (lon_9.3211064_lat_54.0687246)
#
# WMS_NI_DOP returns blank image.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb does not contain bounding box.
# sh_dop20_rgb returns image.
#
# Download completed for image 198: None (lon_9.3211064_lat_54.0687246)
# -----------------------------------------------------------------------------------------
#
# Downloading image 199: Nord-Ostsee-Kanal (lon_9.323161_lat_54.0686721)
#
# WMS_NI_DOP returns blank image.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb does not contain bounding box.
# sh_dop20_rgb returns image.
#
# Download completed for image 199: Nord-Ostsee-Kanal (lon_9.323161_lat_54.0686721)
# -----------------------------------------------------------------------------------------
#
# Downloading image 200: Rastplatz Hemmelsberg (lon_8.3300319_lat_53.0714671)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 200: Rastplatz Hemmelsberg (lon_8.3300319_lat_53.0714671)
# -----------------------------------------------------------------------------------------
#
# Downloading image 201: Jägersburger Wald (lon_8.5494019_lat_49.6964652)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 201: Jägersburger Wald (lon_8.5494019_lat_49.6964652)
# -----------------------------------------------------------------------------------------
#
# Downloading image 202: Forsthaus (lon_8.5503184_lat_49.6951599)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 202: Forsthaus (lon_8.5503184_lat_49.6951599)
# -----------------------------------------------------------------------------------------
#
# Downloading image 203: Rastplatz Bergler Feld Ost (lon_7.2459984_lat_52.3914582)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 203: Rastplatz Bergler Feld Ost (lon_7.2459984_lat_52.3914582)
# -----------------------------------------------------------------------------------------
#
# Downloading image 204: Rastplatz Bergler Feld West (lon_7.2465958_lat_52.3950579)
#
# WMS_NI_DOP returns image.
#
# Download completed for image 204: Rastplatz Bergler Feld West (lon_7.2465958_lat_52.3950579)
# -----------------------------------------------------------------------------------------
#
# Downloading image 205: Rennschlag (lon_8.5358385_lat_49.5561227)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 205: Rennschlag (lon_8.5358385_lat_49.5561227)
# -----------------------------------------------------------------------------------------
#
# Downloading image 206: Park und Rastplatz Am Behlkopf (lon_8.4350744_lat_50.607106)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 206: Park und Rastplatz Am Behlkopf (lon_8.4350744_lat_50.607106)
# -----------------------------------------------------------------------------------------
#
# Downloading image 207: None (lon_8.6089092_lat_49.5422193)
#
# WMS_NI_DOP does not contain bounding box.
# bebb_dop20c does not contain bounding box.
# th_dop does not contain bounding box.
# lsa_lvermgeo_dop20_2 does not contain bounding box.
# he_dop_rgb returns image.
#
# Download completed for image 207: None (lon_8.6089092_lat_49.5422193)
# -----------------------------------------------------------------------------------------

# %% [markdown]
# Fuchsaue Nord (lon_12.2147233_lat_51.2415014) did not return an image.
#
# - lon_8.6579523_lat_53.6066306_Bütteler Holz Ost
# - lon_8.6591991_lat_53.6100326_Bütteler Holz West
# - lon_8.9424542_lat_53.0280869_Mahndorfer Marsch
# - lon_9.5648832_lat_51.3206232_Herkulesblick
# - lon_10.6579729_lat_51.9212477_Brockenblick
# - lon_10.6630829_lat_51.917356_Brockenblick
#
# returned faulty images. Large swathes of the images at WMS borders.
#
# Hence, they were deleted from the folder, resulting in 201 images.

# %% [markdown]
# # Delete service station from gpd with missing image

# %% [markdown]
# ## Correctly labelled service stations

# %% [markdown]
# Kapellenberg (lon_12.2060105_lat_51.4912736)has returned no image, as this service station is located at the borders of WMS services.

# %%
# Load the GeoJSON files of correctly rest stops
parking_at_correct = gpd.read_file("02_data_acquisition/verified_parking_data/parking/parking_at_correct.geojson") # polygons of parkings areas at correctly labelled service stations
correctly_labelled_service_stations = gpd.read_file("02_data_acquisition/verified_parking_data/service_stations/correctly_labelled_service_stations.geojson") # polygons of correctly labelled service stations

# Load bbox csv
correctly_labelled_service_stations_bbox = pd.read_csv("02_data_acquisition/verified_parking_data/bounding_boxes/correctly_labelled_service_stations_bbox.csv")

# %%
# Check shapes of dataframes

print("Shape of parking_at_correct before dropping:", parking_at_correct.shape)
print("Shape of correctly_labelled_service_stations before dropping:", correctly_labelled_service_stations.shape)
print("Shape of correctly_labelled_service_stations_bbox before dropping:", correctly_labelled_service_stations_bbox.shape, "\n")

# Drop rows referring to Kapellenberg (lon_12.2060105_lat_51.4912736) by id_rest
correctly_labelled_service_stations = correctly_labelled_service_stations[~correctly_labelled_service_stations["id_rest"].isin(["lon_12.2060105_lat_51.4912736"])]
correctly_labelled_service_stations_bbox = correctly_labelled_service_stations_bbox[~correctly_labelled_service_stations_bbox["id_rest"].isin(["lon_12.2060105_lat_51.4912736"])]
parking_at_correct = parking_at_correct[~parking_at_correct["id_rest"].isin(["lon_12.2060105_lat_51.4912736"])]

print("Shape of parking_at_correct after dropping:", parking_at_correct.shape)
print("Shape of correctly_labelled_service_stations after dropping:", correctly_labelled_service_stations.shape)
print("Shape of correctly_labelled_service_stations_bbox after dropping:", correctly_labelled_service_stations_bbox.shape)
# Out:
# Shape of parking_at_correct before dropping: (1304, 4)
# Shape of correctly_labelled_service_stations before dropping: (296, 4)
# Shape of correctly_labelled_service_stations_bbox before dropping: (296, 4)
#
# Shape of parking_at_correct after dropping: (1300, 4)
# Shape of correctly_labelled_service_stations after dropping: (295, 4)
# Shape of correctly_labelled_service_stations_bbox after dropping: (295, 4)

# %%
correctly_labelled_service_stations_bbox
# Out:
#                            id_rest     id_OSM_rest                      name  \
# 0     lon_8.6630029_lat_50.2542348    way/22568867               Schäferborn
# 1    lon_11.3531491_lat_50.9378362    way/27549694              Habichtsfang
# 2     lon_10.2712414_lat_53.331074    way/29376062                    Roddau
# 3     lon_9.6300119_lat_53.8303266    way/31128689                 Steinburg
# 4     lon_9.6297338_lat_53.8301666    way/31128716                 Steinburg
# ..                             ...             ...                       ...
# 291  lon_12.7580653_lat_52.8778128   way/915630046               Am Rhinluch
# 292   lon_7.2005154_lat_52.2816225   way/988014767         Gut Friedrichstal
# 293   lon_8.5597202_lat_49.5969765   way/992004892                  Wildbahn
# 294   lon_10.7306355_lat_50.559048  way/1171916133                Adlersberg
# 295   lon_9.7695159_lat_52.5102873  way/1192709800  Rastplatz Bissendorf Süd
#
#                                                   bbox
# 0    [8.662897964530508, 50.24947031826926, 8.66990...
# 1    [11.352126356256656, 50.93673132065365, 11.359...
# 2    [10.264345359109937, 53.328233742563924, 10.27...
# 3    [9.629200346595411, 53.82616873812249, 9.63679...
# 4    [9.628319773449437, 53.82730601524238, 9.63591...
# ..                                                 ...
# 291  [12.754311642753441, 52.87373430027324, 12.761...
# 292  [7.196198912998569, 52.27916482977726, 7.20352...
# 293  [8.554638173536537, 49.59453943341597, 8.56155...
# 294  [10.724665021750997, 50.55768307908295, 10.731...
# 295  [9.76628898503676, 52.5095042232054, 9.7736534...
#
# [295 rows x 4 columns]

# %%
# Download parking_at_correct, correctly_labelled_service_stations as GeoJSN and correctly_labelled_service_stations_bbox as csv

# Specify the path where you want to save the GeoJSON file
output_path_correctly_labelled_service_stations = "02_data_acquisition/verified_parking_data/service_stations/correctly_labelled_service_stations_post_download.geojson"
output_path_parking_at_correct = "02_data_acquisition/verified_parking_data/parking/parking_at_correct_post_download.geojson"
output_path_correctly_labelled_service_stations_bbox = "02_data_acquisition/verified_parking_data/bounding_boxes/correctly_labelled_service_stations_bbox_post_download.csv"

# Export rest_stations_ver_final and parking_areas_ver_final as GeoJSON
correctly_labelled_service_stations.to_file(output_path_correctly_labelled_service_stations, driver='GeoJSON')
parking_at_correct.to_file(output_path_parking_at_correct, driver='GeoJSON')

# Export rest_stations_ver_bbox_final to CSV
correctly_labelled_service_stations_bbox.to_csv(output_path_correctly_labelled_service_stations_bbox, index = False)

# %% [markdown]
# ## Wrongly labelled service stations

# %%
# Load the GeoJSON files of wrongly labelled rest stops
parking_at_wrong = gpd.read_file("02_data_acquisition/verified_parking_data/parking/parking_at_wrong.geojson") # polygons of parkings areas at wrongly labelled service stations
wrongly_labelled_service_stations = gpd.read_file("02_data_acquisition/verified_parking_data/service_stations/wrongly_labelled_service_stations.geojson") # polygons of wrongly labelled service stations

# Load bbox csv
wrongly_labelled_service_stations_bbox = pd.read_csv("02_data_acquisition/verified_parking_data/bounding_boxes/wrongly_labelled_service_stations_bbox.csv")

# %% [markdown]
# Drop
#
# - Fuchsaue Nord (lon_12.2147233_lat_51.2415014)
# - Bütteler Holz Ost (lon_8.6579523_lat_53.6066306)
# - Bütteler Holz West (lon_8.6591991_lat_53.6100326)
# - Mahndorfer Marsch (lon_8.9424542_lat_53.0280869)
# - Herkulesblick(lon_9.5648832_lat_51.3206232)
# - Brockenblick (lon_10.6579729_lat_51.9212477)
# - Brockenblick (lon_10.6630829_lat_51.917356)

# %%
# Check shapes of dataframes

print("Shape of parking_at_wrong before dropping:", parking_at_wrong.shape)
print("Shape of wrongly_labelled_service_stations before dropping:", wrongly_labelled_service_stations.shape)
print("Shape of wrongly_labelled_service_stations_bbox before dropping:", wrongly_labelled_service_stations_bbox.shape, "\n")

# Drop rows of services stations with faulty images by id_rest
wrongly_labelled_service_stations = wrongly_labelled_service_stations[~wrongly_labelled_service_stations["id_rest"].isin(["lon_12.2147233_lat_51.2415014", "lon_8.6579523_lat_53.6066306", "lon_8.6591991_lat_53.6100326", "lon_8.9424542_lat_53.0280869", "lon_9.5648832_lat_51.3206232", "lon_10.6579729_lat_51.9212477", "lon_10.6630829_lat_51.917356"])]
wrongly_labelled_service_stations_bbox = wrongly_labelled_service_stations_bbox[~wrongly_labelled_service_stations_bbox["id_rest"].isin(["lon_12.2147233_lat_51.2415014", "lon_8.6579523_lat_53.6066306", "lon_8.6591991_lat_53.6100326", "lon_8.9424542_lat_53.0280869", "lon_9.5648832_lat_51.3206232", "lon_10.6579729_lat_51.9212477", "lon_10.6630829_lat_51.917356"])]
parking_at_wrong = parking_at_wrong[~parking_at_wrong["id_rest"].isin(["lon_12.2147233_lat_51.2415014", "lon_8.6579523_lat_53.6066306", "lon_8.6591991_lat_53.6100326", "lon_8.9424542_lat_53.0280869", "lon_9.5648832_lat_51.3206232", "lon_10.6579729_lat_51.9212477", "lon_10.6630829_lat_51.917356"])]

print("Shape of parking_at_wrong after dropping:", parking_at_wrong.shape)
print("Shape of wrongly_labelled_service_stations after dropping:", wrongly_labelled_service_stations.shape)
print("Shape of wrongly_labelled_service_stations_bbox after dropping:", wrongly_labelled_service_stations_bbox.shape)
# Out:
# Shape of parking_at_wrong before dropping: (299, 4)
# Shape of wrongly_labelled_service_stations before dropping: (208, 4)
# Shape of wrongly_labelled_service_stations_bbox before dropping: (208, 4)
#
# Shape of parking_at_wrong after dropping: (281, 4)
# Shape of wrongly_labelled_service_stations after dropping: (201, 4)
# Shape of wrongly_labelled_service_stations_bbox after dropping: (201, 4)

# %%
# Download parking_at_wrong, wrongly_labelled_service_stations as GeoJSN and wrongly_labelled_service_stations_bbox as csv

# Specify the path where you want to save the GeoJSON file
output_path_wrongly_labelled_service_stations = "02_data_acquisition/verified_parking_data/service_stations/wrongly_labelled_service_stations_post_download.geojson"
output_path_parking_at_wrong = "02_data_acquisition/verified_parking_data/parking/parking_at_wrong_post_download.geojson"
output_path_wrongly_labelled_service_stations_bbox = "02_data_acquisition/verified_parking_data/bounding_boxes/wrongly_labelled_service_stations_bbox_post_download.csv"

# Export rest_stations_ver_final and parking_areas_ver_final as GeoJSON
wrongly_labelled_service_stations.to_file(output_path_wrongly_labelled_service_stations, driver='GeoJSON')
parking_at_wrong.to_file(output_path_parking_at_wrong, driver='GeoJSON')

# Export rest_stations_ver_bbox_final to CSV
wrongly_labelled_service_stations_bbox.to_csv(output_path_wrongly_labelled_service_stations_bbox, index = False)
