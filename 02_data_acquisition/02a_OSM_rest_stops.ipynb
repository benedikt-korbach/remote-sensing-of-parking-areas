# %% [markdown]
# Description:
#
# Input:
# This file takes as input geojson OSM dataframes containing the polygons of:
#
# - service stations
# - car parking areas close to service stations
# - truck parking areas close to service stations
#
# The dataframes are transformed by deleting non-polygon rows.
#
# The car and truck parking dataframes are merged into one, containing all parking areas at service stations: all_parking
#
# Output:
# - all_parking (1606, 6): geojson dataframe containing all parking (car and truck) polygons at service stations and service station ids
# - rest_stations (506, 5): geojson dataframe containing all service stations polygons
#
# Of the 506 service stations with polygons, 467 contain annotated parking spaces.

# %% [markdown]
# # Libraries and Google Drive

# %%
import geopandas as gpd
import pandas as pd
from shapely.geometry import Polygon, MultiPolygon

import os

# %%
# Mount Drive
#from google.colab import drive
#drive.mount("/content/drive")

# %%
# Set wd
os.chdir('/Users/benediktkorbach/Documents/GitHub/remote-sensing-of-parking-areas')

print("Working directory:", os.getcwd())
# Out:
# Working directory: /Users/benediktkorbach/Documents/GitHub/remote-sensing-of-parking-areas

# %% [markdown]
# # Import OSM data and combine into one dataframe

# %%
# Load the OSM GeoJSON files containing rest station area polygons and car/ truck parking area polygons
rest_stations = gpd.read_file("02_data_acquisition/OSM_exports/OSM_service_stops.geojson")
car_parkings = gpd.read_file("02_data_acquisition/OSM_exports/OSM_car_parking_service_stops.geojson")
truck_parkings = gpd.read_file("02_data_acquisition/OSM_exports/OSM_truck_parking_service_stops.geojson")

# %% [markdown]
# ## Inspect and Transform JSONs

# %%
# Set the option to display all columns
pd.set_option("display.max_columns", None)

# %%
# Print shapes of geopandas Dataframe
print("Shape rest_stations:", rest_stations.shape)
print("Shape car_stations:", car_parkings.shape)
print("Shape truck_parkings:", truck_parkings.shape)
# Out:
# Shape rest_stations: (510, 65)
# Shape car_stations: (2299, 112)
# Shape truck_parkings: (1043, 104)

# %%
# Functions used to transform dataframes

def keep_polygon_rows(gdf):
    """
    Filter out rows that contain polygons or multipolygons.

    Parameters:
    gdf (geopandas geodataframe): geodataframe containing geometry column

    Returns:
    A geodataframe consisting of rows with polygons/ multipolygons.
    """

    # Define a function to check the geometry type
    def is_polygon(geometry):
        return isinstance(geometry, (Polygon, MultiPolygon))

    # Apply the function to the 'geometry' column and filter the df
    gdf_filtered = gdf[gdf["geometry"].apply(is_polygon)]

    return gdf_filtered


def create_id(row):
    """
    Create unique identifier for each rest stop.

    Parameters:
    row: row of a geopandas geodataframe

    Returns:
    String containing id.
    """
    coord = None  # Initialize coord with a default value
    try:
        if row["geometry"].geom_type == "Polygon":
            coord = row["geometry"].exterior.coords[0]
        elif row["geometry"].geom_type == "MultiPolygon":
            coord = list(row["geometry"].geoms)[0].exterior.coords[0] # inspect first polygon in multipolygon

        lon = round(coord[0], 8)
        lat = round(coord[1], 8)
        id = f"lon_{lon}_lat_{lat}"

        return id

    except Exception as e:
        print(f"Error occurred: {e}")

        return None

# %% [markdown]
# ### Inspect and transform rest_stations

# %%
type(rest_stations)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
rest_stations.head()
# Out:
#                  id               @id access aeroway alt_name alt_name:de  \
# 0  relation/3947321  relation/3947321    yes    None     None        None
# 1  relation/4672225  relation/4672225   None    None     None        None
# 2  relation/4672228  relation/4672228   None    None     None        None
# 3      way/22568867      way/22568867   None    None     None        None
# 4      way/22568868      way/22568868   None    None     None        None
#
#   alt_name:nl  amenity  area atmotorway   bin capacity capacity:abnormal_load  \
# 0        None  parking   yes       None  None     None                   None
# 1        None     None  None       None  None     None                   None
# 2        None     None  None       None  None     None                   None
# 3        None     None  None       None  None     None                   None
# 4        None     None  None       None  None     None                   None
#
#   capacity:bus capacity:car capacity:caravan capacity:disabled capacity:hgv  \
# 0         None         None             None              None         None
# 1         None         None             None              None         None
# 2         None         None             None              None         None
# 3         None         None             None              None         None
# 4         None         None             None              None         None
#
#   capacity:long changing_table check_date check_date:toilets:wheelchair  \
# 0          None           None       None                          None
# 1          None           None       None                          None
# 2          None           None       None                          None
# 3          None           None       None                          None
# 4          None           None       None                          None
#
#   description direction drinking_water   fee fixme hazmat:water         hgv  \
# 0        None      None           None    no  None         None  designated
# 1        None      None           None  None  None         None        None
# 2        None      None           None  None  None         None        None
# 3        None      None           None  None  None         None        None
# 4        None      None           None  None  None         None        None
#
#      highway landuse   lit mapillary motorcar                name name:alt  \
# 0  rest_area    None  None      None     None  Hohe Schrecke West     None
# 1  rest_area    None  None      None     None         Probstheide     None
# 2  rest_area    None  None      None     None    Ladeburger Heide     None
# 3  rest_area    None  None      None     None         Schäferborn     None
# 4  rest_area    None  None      None     None           Spießwald     None
#
#   name:de name:dsb name:etymology:wikidata noise_barrier  note note:de  \
# 0    None     None                    None          None  None    None
# 1    None     None                    None          None  None    None
# 2    None     None                    None          None  None    None
# 3    None     None                    None          None  None    None
# 4    None     None                    None          None  None    None
#
#   old_name opening_date opening_hours operator operator:wikidata park_ride  \
# 0     None         None          None     None              None      None
# 1     None         None          None     None              None      None
# 2     None         None          None     None              None      None
# 3     None         None          None     None              None      None
# 4     None         None          None     None              None      None
#
#    parking picnic_table preserved shower source start_date supervised  \
# 0  surface         None      None   None   None       None       None
# 1     None         None      None   None   None       None       None
# 2     None         None      None   None   None       None       None
# 3     None         None      None   None   None       None       None
# 4     None         None      None   None   None       None       None
#
#          surface survey:date toilets toilets:fee toilets:wheelchair  \
# 0  paving_stones        None    None        None               None
# 1           None        None     yes        None               None
# 2           None        None     yes        None               None
# 3           None        None     yes        None               None
# 4           None        None     yes        None               None
#
#            type wheelchair wikidata wikipedia  \
# 0  multipolygon       None     None      None
# 1  multipolygon        yes     None      None
# 2  multipolygon        yes     None      None
# 3          None       None     None      None
# 4          None        yes     None      None
#
#                                             geometry
# 0  MULTIPOLYGON (((11.24429 51.32489, 11.24430 51...
# 1  POLYGON ((13.54581 52.71295, 13.54556 52.71258...
# 2  POLYGON ((13.54904 52.70924, 13.54912 52.70919...
# 3  POLYGON ((8.66300 50.25423, 8.66302 50.25237, ...
# 4  POLYGON ((8.66241 50.25445, 8.66205 50.25369, ...

# %%
# Transform rest_stations to only contain relevant columns

# Drop non-polygon rows
rest_stations = keep_polygon_rows(rest_stations)
print("Shape rest_stations:", rest_stations.shape)

# Keep necessary columns
keep_columns = ["id", "@id", "highway", "name", "geometry"]
rest_stations = rest_stations[keep_columns]
# Out:
# Shape rest_stations: (506, 65)

# %%
rest_stations.head()
# Out:
#                  id               @id    highway                name  \
# 0  relation/3947321  relation/3947321  rest_area  Hohe Schrecke West
# 1  relation/4672225  relation/4672225  rest_area         Probstheide
# 2  relation/4672228  relation/4672228  rest_area    Ladeburger Heide
# 3      way/22568867      way/22568867  rest_area         Schäferborn
# 4      way/22568868      way/22568868  rest_area           Spießwald
#
#                                             geometry
# 0  MULTIPOLYGON (((11.24429 51.32489, 11.24430 51...
# 1  POLYGON ((13.54581 52.71295, 13.54556 52.71258...
# 2  POLYGON ((13.54904 52.70924, 13.54912 52.70919...
# 3  POLYGON ((8.66300 50.25423, 8.66302 50.25237, ...
# 4  POLYGON ((8.66241 50.25445, 8.66205 50.25369, ...

# %%
rest_stations['id'] = rest_stations.apply(create_id, axis=1)

# %%
rest_stations.head()
# Out:
#                               id               @id    highway  \
# 0  lon_11.2442867_lat_51.3248863  relation/3947321  rest_area
# 1  lon_13.5458137_lat_52.7129474  relation/4672225  rest_area
# 2   lon_13.549042_lat_52.7092396  relation/4672228  rest_area
# 3   lon_8.6630029_lat_50.2542348      way/22568867  rest_area
# 4   lon_8.6624068_lat_50.2544468      way/22568868  rest_area
#
#                  name                                           geometry
# 0  Hohe Schrecke West  MULTIPOLYGON (((11.24429 51.32489, 11.24430 51...
# 1         Probstheide  POLYGON ((13.54581 52.71295, 13.54556 52.71258...
# 2    Ladeburger Heide  POLYGON ((13.54904 52.70924, 13.54912 52.70919...
# 3         Schäferborn  POLYGON ((8.66300 50.25423, 8.66302 50.25237, ...
# 4           Spießwald  POLYGON ((8.66241 50.25445, 8.66205 50.25369, ...

# %%
rest_stations_geoms = rest_stations[["id", "geometry"]]

# %%
rest_stations_geoms.head()
# Out:
#                               id  \
# 0  lon_11.2442867_lat_51.3248863
# 1  lon_13.5458137_lat_52.7129474
# 2   lon_13.549042_lat_52.7092396
# 3   lon_8.6630029_lat_50.2542348
# 4   lon_8.6624068_lat_50.2544468
#
#                                             geometry
# 0  MULTIPOLYGON (((11.24429 51.32489, 11.24430 51...
# 1  POLYGON ((13.54581 52.71295, 13.54556 52.71258...
# 2  POLYGON ((13.54904 52.70924, 13.54912 52.70919...
# 3  POLYGON ((8.66300 50.25423, 8.66302 50.25237, ...
# 4  POLYGON ((8.66241 50.25445, 8.66205 50.25369, ...

# %% [markdown]
# ### Inspect and transform truck_parkings

# %%
type(truck_parkings)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
truck_parkings.head()
# Out:
#                   id                @id TMC:cid_58:tabcd_1:Class  \
# 0   relation/3947321   relation/3947321                     None
# 1  relation/11487370  relation/11487370                     None
# 2  relation/12993807  relation/12993807                     None
# 3  relation/13277585  relation/13277585                     None
# 4  relation/13277586  relation/13277586                     None
#
#   TMC:cid_58:tabcd_1:Direction TMC:cid_58:tabcd_1:LCLversion  \
# 0                         None                          None
# 1                         None                          None
# 2                         None                          None
# 3                         None                          None
# 4                         None                          None
#
#   TMC:cid_58:tabcd_1:LocationCode TMC:cid_58:tabcd_1:NextLocationCode  \
# 0                            None                                None
# 1                            None                                None
# 2                            None                                None
# 3                            None                                None
# 4                            None                                None
#
#   TMC:cid_58:tabcd_1:PrevLocationCode abnormal_load access addr:city  \
# 0                                None          None    yes      None
# 1                                None          None   None      None
# 2                                None          None   None      None
# 3                                None          None    yes      None
# 4                                None          None    yes      None
#
#   addr:country addr:housenumber addr:postcode addr:street  amenity  \
# 0         None             None          None        None  parking
# 1         None             None          None        None  parking
# 2         None             None          None        None  parking
# 3         None             None          None        None  parking
# 4         None             None          None        None  parking
#
#   amenity:truck_stop  area atmotorway bdouble bureau_de_change   bus capacity  \
# 0               None   yes       None    None             None  None     None
# 1               None  None       None    None             None  None     None
# 2               None  None       None    None             None  None     None
# 3               None  None       None    None             None  None       56
# 4               None  None       None    None             None  None       56
#
#   capacity:abnormal_load capacity:bus capacity:car capacity:caravan  \
# 0                   None         None         None             None
# 1                   None         None         None             None
# 2                   None         None         None             None
# 3                   None         None         None             None
# 4                   None         None         None             None
#
#   capacity:disabled capacity:hgv capacity:long capacity:motorcar  \
# 0              None         None          None              None
# 1              None         None          None              None
# 2              None         None          None              None
# 3              None         None          None              None
# 4              None         None          None              None
#
#   capacity:parent capacity:restaurant capacity:shower capacity:truck  \
# 0            None                None            None           None
# 1            None                None            None           None
# 2            None                None            None           None
# 3            None                None            None           None
# 4            None                None            None           None
#
#   capacity:truck_diesel_pumps capacity:washers capacity:women   car caravan  \
# 0                        None             None           None  None    None
# 1                        None             None           None  None    None
# 2                        None             None           None  None    None
# 3                        None             None           None  None    None
# 4                        None             None           None  None    None
#
#   check_date:fee coach contact:email contact:fax contact:phone  \
# 0           None  None          None        None          None
# 1           None  None          None        None          None
# 2           None  None          None        None          None
# 3           None  None          None        None          None
# 4           None  None          None        None          None
#
#   contact:website copier covered description description:en fast_food   fax  \
# 0            None   None    None        None           None      None  None
# 1            None   None    None        None           None      None  None
# 2            None   None    None        None           None      None  None
# 3            None   None    None        None           None      None  None
# 4            None   None    None        None           None      None  None
#
#     fee goods         hgv    highway internet_access   lit maxheight maxstay  \
# 0    no  None  designated  rest_area            None  None      None    None
# 1  None  None  designated       None            None  None      None    None
# 2    no  None  designated       None            None  None      None    None
# 3    no  None  designated       None            None  None      None    None
# 4    no  None  designated       None            None  None      None    None
#
#   motor_vehicle motorcar motorcycle motorhome                name name:de  \
# 0          None     None       None      None  Hohe Schrecke West    None
# 1          None     None       None      None                None    None
# 2          None     None       None      None                None    None
# 3          None       no       None      None                None    None
# 4          None       no       None      None                None    None
#
#    note opening_hours operator orientation park_ride  parking  \
# 0  None          None     None        None      None  surface
# 1  None          None     None        None      None     None
# 2  None          None     None        None      None  surface
# 3  None          None     None        None      None  surface
# 4  None          None     None        None      None  surface
#
#   parking:condition:vehicles parking:orientation parking_space  \
# 0                       None                None          None
# 1                       None                None          None
# 2                       None                None          None
# 3                       None                None          None
# 4                       None                None          None
#
#   payment:american_express payment:bancomat payment:diners_club payment:dkv  \
# 0                     None             None                None        None
# 1                     None             None                None        None
# 2                     None             None                None        None
# 3                     None             None                None        None
# 4                     None             None                None        None
#
#   payment:ec payment:esso_card payment:euroshell payment:mastercard  \
# 0       None              None              None               None
# 1       None              None              None               None
# 2       None              None              None               None
# 3       None              None              None               None
# 4       None              None              None               None
#
#   payment:uta payment:visa playground   psv restaurant  shop smoothness  \
# 0        None         None       None  None       None  None       None
# 1        None         None       None  None       None  None       None
# 2        None         None       None  None       None  None       None
# 3        None         None       None    no       None  None       None
# 4        None         None       None    no       None  None       None
#
#   source supervised        surface @relations toilets toilets:wheelchair  \
# 0   None       None  paving_stones       None    None               None
# 1   None       None           None       None    None               None
# 2   None       None           None       None    None               None
# 3   None       None  paving_stones       None    None               None
# 4   None       None  paving_stones       None    None               None
#
#   tourist_bus trailer truck_repair    tv          type vehicle wheelchair  \
# 0        None    None         None  None  multipolygon    None       None
# 1        None    None         None  None  multipolygon    None       None
# 2        None    None         None  None  multipolygon    None        yes
# 3        None    None         None  None  multipolygon    None       None
# 4        None    None         None  None  multipolygon    None       None
#
#                                             geometry
# 0  MULTIPOLYGON (((11.24429 51.32489, 11.24430 51...
# 1  POLYGON ((9.51885 51.26893, 9.51880 51.26888, ...
# 2  MULTIPOLYGON (((9.54446 54.47736, 9.54388 54.4...
# 3  MULTIPOLYGON (((11.42584 51.43480, 11.42585 51...
# 4  MULTIPOLYGON (((11.42634 51.43379, 11.42626 51...

# %%
# Transform truck_parkings to only contain relevant columns

# Delete non-polygon rows
truck_parkings = keep_polygon_rows(truck_parkings)

# Keep necessary columns
keep_columns = ["id", "@id", "hgv", "name", "geometry"]
truck_parkings = truck_parkings[keep_columns]
print("Shape truck_parkings:", truck_parkings.shape)
# Out:
# Shape truck_parkings: (1028, 5)

# %%
truck_parkings.head()
# Out:
#                   id                @id         hgv                name  \
# 0   relation/3947321   relation/3947321  designated  Hohe Schrecke West
# 1  relation/11487370  relation/11487370  designated                None
# 2  relation/12993807  relation/12993807  designated                None
# 3  relation/13277585  relation/13277585  designated                None
# 4  relation/13277586  relation/13277586  designated                None
#
#                                             geometry
# 0  MULTIPOLYGON (((11.24429 51.32489, 11.24430 51...
# 1  POLYGON ((9.51885 51.26893, 9.51880 51.26888, ...
# 2  MULTIPOLYGON (((9.54446 54.47736, 9.54388 54.4...
# 3  MULTIPOLYGON (((11.42584 51.43480, 11.42585 51...
# 4  MULTIPOLYGON (((11.42634 51.43379, 11.42626 51...

# %% [markdown]
# ### Inspect and transform car_parkings

# %%
type(car_parkings)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
car_parkings.head()
# Out:
#                   id                @id     access access:description  \
# 0  relation/11487080  relation/11487080       None               None
# 1  relation/11489034  relation/11489034    private               None
# 2  relation/11489035  relation/11489035       None               None
# 3  relation/11489084  relation/11489084  customers               None
# 4  relation/13277584  relation/13277584        yes               None
#
#   access:disabled access:hgv addr:city addr:country addr:housenumber  \
# 0            None       None      None         None             None
# 1            None       None      None         None             None
# 2            None       None      None         None             None
# 3            None       None      None         None             None
# 4            None       None      None         None             None
#
#   addr:postcode addr:street addr:suburb  amenity  area atmotorway barrier  \
# 0          None        None        None  parking  None       None    None
# 1          None        None        None  parking  None       None    None
# 2          None        None        None  parking  None       None    None
# 3          None        None        None  parking  None       None    None
# 4          None        None        None  parking  None       None    None
#
#   building   bus capacity capacity:abnormal_load capacity:bus capacity:car  \
# 0     None  None     None                   None         None         None
# 1     None  None     None                   None         None         None
# 2     None  None     None                   None         None         None
# 3     None  None     None                   None         None         None
# 4     None  None       75                   None         None         None
#
#   capacity:caravan capacity:charging capacity:disabled capacity:hgv  \
# 0             None              None              None         None
# 1             None              None              None         None
# 2             None              None              None         None
# 3             None              None              None         None
# 4             None              None              None         None
#
#   capacity:hgv:abnormal_load capacity:motorcar capacity:motorcar_trailer  \
# 0                       None              None                      None
# 1                       None              None                      None
# 2                       None              None                      None
# 3                       None              None                      None
# 4                       None              None                      None
#
#   capacity:parent capacity:restaurant capacity:shower capacity:smoker_free  \
# 0            None                None            None                 None
# 1            None                None            None                 None
# 2            None                None            None                 None
# 3            None                None            None                 None
# 4            None                None            None                 None
#
#   capacity:toilets capacity:tourist_bus capacity:truck  \
# 0             None                 None           None
# 1             None                 None           None
# 2             None                 None           None
# 3             None                 None           None
# 4             None                 None           None
#
#   capacity:truck_diesel_pumps capacity:washers capacity:women   car caravan  \
# 0                        None             None           None  None    None
# 1                        None             None           None  None    None
# 2                        None             None           None  None    None
# 3                        None             None           None  None    None
# 4                        None             None           None  None    None
#
#   caravans check_date check_date:fee coach contact:fax contact:phone copier  \
# 0     None       None           None  None        None          None   None
# 1     None       None           None  None        None          None   None
# 2     None       None           None  None        None          None   None
# 3     None       None           None  None        None          None   None
# 4     None       None           None  None        None          None   None
#
#   description disabled disabled_spaces   ele fast_food   fee fixme goods  \
# 0        None     None            None  None      None  None  None  None
# 1        None     None            None  None      None  None  None  None
# 2        None     None            None  None      None  None  None  None
# 3        None     None            None  None      None  None  None  None
# 4        None     None            None  None      None    no  None  None
#
#     hgv hgv:conditional highway internet_access landuse layer   lit maxheight  \
# 0  None            None    None            None    None  None  None      None
# 1  None            None    None            None    None  None  None      None
# 2  None            None    None            None    None  None  None      None
# 3  None            None    None            None    None  None  None      None
# 4    no            None    None            None    None  None   yes      None
#
#   maxstay motor_vehicle    motorcar motorcar:conditional motorcycle  \
# 0    None          None        None                 None       None
# 1    None          None        None                 None       None
# 2    None          None        None                 None       None
# 3    None          None        None                 None       None
# 4    None          None  designated                 None       None
#
#   motorcycle:conditional motorhome  name name:alt name:ru  note opening_hours  \
# 0                   None      None  None     None    None  None          None
# 1                   None      None  None     None    None  None          None
# 2                   None      None  None     None    None  None          None
# 3                   None      None  None     None    None  None          None
# 4                   None      None  None     None    None  None          None
#
#   operator operator:type orientation park_ride      parking  \
# 0     None          None        None      None  street_side
# 1     None          None        None      None      surface
# 2     None          None        None      None         None
# 3     None          None        None      None      surface
# 4     None          None        None      None      surface
#
#   parking:condition:vehicles parking:hgv parking:orientation parking_space  \
# 0                       None        None                None          None
# 1                       None        None                None          None
# 2                       None        None                None          None
# 3                       None        None                None          None
# 4                       None        None                None          None
#
#   payment:dkv payment:ec payment:mastercard payment:uta payment:visa   psv  \
# 0        None       None               None        None         None  None
# 1        None       None               None        None         None  None
# 2        None       None               None        None         None  None
# 3        None       None               None        None         None  None
# 4        None       None               None        None         None    no
#
#   restaurant  shop smoothness source supervised        surface @relations  \
# 0       None  None       None   None       None           None       None
# 1       None  None       None   None       None           None       None
# 2       None  None       None   None       None           None       None
# 3       None  None       None   None       None           None       None
# 4       None  None       None   None       None  paving_stones       None
#
#   survey:date toilets toilets:wheelchair tourism tourist_bus traffic_sign  \
# 0        None    None               None    None        None         None
# 1        None    None               None    None        None         None
# 2        None    None               None    None        None         None
# 3        None    None               None    None        None         None
# 4        None    None               None    None        None         None
#
#   trailer truck    tv          type vehicle wheelchair wheelchair:description  \
# 0    None  None  None  multipolygon    None       None                   None
# 1    None  None  None  multipolygon    None       None                   None
# 2    None  None  None  multipolygon    None       None                   None
# 3    None  None  None  multipolygon    None       None                   None
# 4    None  None  None  multipolygon    None       None                   None
#
#                                             geometry
# 0  POLYGON ((9.52106 51.26784, 9.52101 51.26783, ...
# 1  POLYGON ((9.52541 51.26901, 9.52542 51.26898, ...
# 2  POLYGON ((9.52566 51.27037, 9.52586 51.26995, ...
# 3  POLYGON ((9.52691 51.27054, 9.52698 51.27045, ...
# 4  MULTIPOLYGON (((11.42781 51.43533, 11.42764 51...

# %%
# Transform car_parkings to only contain relevant columns

# Delete non-polygon rows
car_parkings = keep_polygon_rows(car_parkings)

# Keep necessary columns
keep_columns = ["id", "@id", "name", "geometry"]
car_parkings = car_parkings[keep_columns]
print("Shape car_parkings:", car_parkings.shape)
# Out:
# Shape car_parkings: (2194, 4)

# %%
car_parkings.head()
# Out:
#                   id                @id  name  \
# 0  relation/11487080  relation/11487080  None
# 1  relation/11489034  relation/11489034  None
# 2  relation/11489035  relation/11489035  None
# 3  relation/11489084  relation/11489084  None
# 4  relation/13277584  relation/13277584  None
#
#                                             geometry
# 0  POLYGON ((9.52106 51.26784, 9.52101 51.26783, ...
# 1  POLYGON ((9.52541 51.26901, 9.52542 51.26898, ...
# 2  POLYGON ((9.52566 51.27037, 9.52586 51.26995, ...
# 3  POLYGON ((9.52691 51.27054, 9.52698 51.27045, ...
# 4  MULTIPOLYGON (((11.42781 51.43533, 11.42764 51...

# %% [markdown]
# ## Merge DataFrames

# %%
# Print shapes of geopandas Dataframe after removing rows not containing polygons
print("Shape rest_stations:", rest_stations.shape)
print("Shape car_stations:", car_parkings.shape)
print("Shape truck_parkings:", truck_parkings.shape)
# Out:
# Shape rest_stations: (506, 5)
# Shape car_stations: (2194, 4)
# Shape truck_parkings: (1028, 5)

# %%
# Combine GeoDataFrames into one

# Perform spatial join - parking areas to rest stations
car_parkings_joined = gpd.sjoin(car_parkings, rest_stations_geoms, how="left", predicate='intersects', lsuffix = "car", rsuffix = "rest")
truck_parkings_joined = gpd.sjoin(truck_parkings, rest_stations_geoms, how="left", predicate='intersects', lsuffix = "truck", rsuffix = "rest")

# %%
car_parkings_joined.head()
# Out:
#               id_car                @id  name  \
# 0  relation/11487080  relation/11487080  None
# 1  relation/11489034  relation/11489034  None
# 2  relation/11489035  relation/11489035  None
# 3  relation/11489084  relation/11489084  None
# 4  relation/13277584  relation/13277584  None
#
#                                             geometry  index_rest id_rest
# 0  POLYGON ((9.52106 51.26784, 9.52101 51.26783, ...         NaN     NaN
# 1  POLYGON ((9.52541 51.26901, 9.52542 51.26898, ...         NaN     NaN
# 2  POLYGON ((9.52566 51.27037, 9.52586 51.26995, ...         NaN     NaN
# 3  POLYGON ((9.52691 51.27054, 9.52698 51.27045, ...         NaN     NaN
# 4  MULTIPOLYGON (((11.42781 51.43533, 11.42764 51...         NaN     NaN

# %%
car_parkings_joined.shape
# Out:
# (2194, 6)

# %%
# Filter out rows that do not correspond to a rest/ service stop

car_parkings_joined = car_parkings_joined[car_parkings_joined["id_rest"].notnull()]
car_parkings_joined = car_parkings_joined.drop("index_rest", axis=1)

# %%
car_parkings_joined.head()
# Out:
#                id_car                @id               name  \
# 6   relation/13277622  relation/13277622               None
# 7   relation/13277623  relation/13277623               None
# 8   relation/15482166  relation/15482166               None
# 9   relation/15482306  relation/15482306               None
# 23       way/31129920       way/31129920  Nord-Ostsee-Kanal
#
#                                              geometry  \
# 6   MULTIPOLYGON (((10.26903 53.33039, 10.26926 53...
# 7   MULTIPOLYGON (((10.26848 53.33228, 10.26872 53...
# 8   MULTIPOLYGON (((12.14216 52.24271, 12.14213 52...
# 9   MULTIPOLYGON (((12.14713 52.24497, 12.14717 52...
# 23  POLYGON ((9.32127 54.06898, 9.32314 54.06861, ...
#
#                           id_rest
# 6   lon_10.2703215_lat_53.3301407
# 7    lon_10.2712414_lat_53.331074
# 8    lon_12.140788_lat_52.2431929
# 9    lon_12.149456_lat_52.2449316
# 23    lon_9.323161_lat_54.0686721

# %%
car_parkings_joined.shape
# Out:
# (999, 5)

# %%
truck_parkings_joined.head()
# Out:
#             id_truck                @id         hgv                name  \
# 0   relation/3947321   relation/3947321  designated  Hohe Schrecke West
# 0   relation/3947321   relation/3947321  designated  Hohe Schrecke West
# 1  relation/11487370  relation/11487370  designated                None
# 2  relation/12993807  relation/12993807  designated                None
# 3  relation/13277585  relation/13277585  designated                None
#
#                                             geometry  index_rest  \
# 0  MULTIPOLYGON (((11.24429 51.32489, 11.24430 51...       227.0
# 0  MULTIPOLYGON (((11.24429 51.32489, 11.24430 51...         0.0
# 1  POLYGON ((9.51885 51.26893, 9.51880 51.26888, ...         NaN
# 2  MULTIPOLYGON (((9.54446 54.47736, 9.54388 54.4...         NaN
# 3  MULTIPOLYGON (((11.42584 51.43480, 11.42585 51...         NaN
#
#                          id_rest
# 0  lon_11.2429922_lat_51.3232808
# 0  lon_11.2442867_lat_51.3248863
# 1                            NaN
# 2                            NaN
# 3                            NaN

# %%
truck_parkings_joined.shape
# Out:
# (1030, 7)

# %%
truck_parkings_joined = truck_parkings_joined[truck_parkings_joined["id_rest"].notnull()]
truck_parkings_joined = truck_parkings_joined.drop("index_rest", axis=1)

# %%
truck_parkings_joined.head()
# Out:
#            id_truck               @id         hgv                name  \
# 0  relation/3947321  relation/3947321  designated  Hohe Schrecke West
# 0  relation/3947321  relation/3947321  designated  Hohe Schrecke West
# 5       way/4701435       way/4701435  designated                None
# 8      way/24301057      way/24301057  designated                None
# 9      way/24301220      way/24301220  designated           Kalkberge
#
#                                             geometry  \
# 0  MULTIPOLYGON (((11.24429 51.32489, 11.24430 51...
# 0  MULTIPOLYGON (((11.24429 51.32489, 11.24430 51...
# 5  POLYGON ((9.54079 50.93981, 9.54063 50.94007, ...
# 8  POLYGON ((13.79667 52.43752, 13.79614 52.43743...
# 9  POLYGON ((13.79893 52.45696, 13.79870 52.45678...
#
#                          id_rest
# 0  lon_11.2429922_lat_51.3232808
# 0  lon_11.2442867_lat_51.3248863
# 5   lon_9.5406188_lat_50.9403942
# 8  lon_13.7976643_lat_52.4383976
# 9  lon_13.7994366_lat_52.4570641

# %%
truck_parkings_joined.shape
# Out:
# (607, 6)

# %%
car_parkings_joined['type'] = 'car'
truck_parkings_joined['type'] = 'truck'

# Combine data
all_parkings = gpd.GeoDataFrame(pd.concat([car_parkings_joined, truck_parkings_joined], ignore_index=True))

# %%
all_parkings = all_parkings.drop(["id_truck", "hgv"], axis=1)

# %%
all_parkings.head()
# Out:
#               id_car                @id               name  \
# 0  relation/13277622  relation/13277622               None
# 1  relation/13277623  relation/13277623               None
# 2  relation/15482166  relation/15482166               None
# 3  relation/15482306  relation/15482306               None
# 4       way/31129920       way/31129920  Nord-Ostsee-Kanal
#
#                                             geometry  \
# 0  MULTIPOLYGON (((10.26903 53.33039, 10.26926 53...
# 1  MULTIPOLYGON (((10.26848 53.33228, 10.26872 53...
# 2  MULTIPOLYGON (((12.14216 52.24271, 12.14213 52...
# 3  MULTIPOLYGON (((12.14713 52.24497, 12.14717 52...
# 4  POLYGON ((9.32127 54.06898, 9.32314 54.06861, ...
#
#                          id_rest type
# 0  lon_10.2703215_lat_53.3301407  car
# 1   lon_10.2712414_lat_53.331074  car
# 2   lon_12.140788_lat_52.2431929  car
# 3   lon_12.149456_lat_52.2449316  car
# 4    lon_9.323161_lat_54.0686721  car

# %%
unique_entries_count = all_parkings['id_rest'].nunique()

print("Number of unique rest_stops:", unique_entries_count)
# Out:
# Number of unique rest_stops: 467

# %%
# Print shapes of geopandas Dataframe after merging
print("Shape rest_stations:", rest_stations.shape)
print("Shape all_parkings:", all_parkings.shape)
# Out:
# Shape rest_stations: (506, 5)
# Shape all_parkings: (1606, 6)

# %% [markdown]
# ## Inspect all_parkings

# %%
unique_rest_stops = all_parkings['id_rest'].unique()
print("Unique rest stops:", len(unique_rest_stops))
# Out:
# Unique rest stops: 467

# %%
# Create dictionary that indicates the number of car/truck polygons per rest stops

rest_stop_dic = {}

for index, row in all_parkings.iterrows():
    id_rest = row["id_rest"]
    car_count = 0
    truck_count = 0

    if id_rest in rest_stop_dic:
        car_count = rest_stop_dic[id_rest].get("car", 0)
        truck_count = rest_stop_dic[id_rest].get("truck", 0)

    if row["type"] == "car":
        car_count += 1
    elif row["type"] == "truck":
        truck_count += 1

    rest_stop_dic[id_rest] = {"car": car_count, "truck": truck_count}

# %%
rest_stop_dic
# Out:
# {'lon_10.2703215_lat_53.3301407': {'car': 1, 'truck': 0},
#  'lon_10.2712414_lat_53.331074': {'car': 1, 'truck': 1},
#  'lon_12.140788_lat_52.2431929': {'car': 1, 'truck': 0},
#  'lon_12.149456_lat_52.2449316': {'car': 1, 'truck': 0},
#  'lon_9.323161_lat_54.0686721': {'car': 1, 'truck': 0},
#  'lon_7.5846163_lat_53.2588511': {'car': 2, 'truck': 1},
#  'lon_7.2005154_lat_52.2816225': {'car': 1, 'truck': 1},
#  'lon_11.2481831_lat_52.1991827': {'car': 1, 'truck': 1},
#  'lon_11.2477836_lat_52.1980946': {'car': 1, 'truck': 0},
#  'lon_10.7306355_lat_50.559048': {'car': 1, 'truck': 1},
#  'lon_10.7298729_lat_50.5605634': {'car': 1, 'truck': 1},
#  'lon_13.9503161_lat_52.3112817': {'car': 1, 'truck': 1},
#  'lon_13.9496292_lat_52.3118174': {'car': 1, 'truck': 1},
#  'lon_10.444298_lat_50.9932399': {'car': 5, 'truck': 1},
#  'lon_10.4367549_lat_50.9933128': {'car': 5, 'truck': 1},
#  'lon_11.6645768_lat_50.8773612': {'car': 3, 'truck': 0},
#  'lon_10.4530068_lat_50.4711034': {'car': 1, 'truck': 2},
#  'lon_10.1665917_lat_52.3598134': {'car': 2, 'truck': 2},
#  'lon_9.1106685_lat_50.7152858': {'car': 1, 'truck': 1},
#  'lon_9.4159049_lat_51.2726438': {'car': 1, 'truck': 0},
#  'lon_9.4159061_lat_51.2721518': {'car': 1, 'truck': 0},
#  'lon_7.2187753_lat_52.2848132': {'car': 7, 'truck': 0},
#  'lon_13.7777207_lat_53.5210372': {'car': 1, 'truck': 2},
#  'lon_13.7762186_lat_53.5200667': {'car': 1, 'truck': 2},
#  'lon_9.3211064_lat_54.0687246': {'car': 1, 'truck': 0},
#  'lon_14.2175841_lat_52.3368637': {'car': 9, 'truck': 1},
#  'lon_14.222133_lat_52.3378744': {'car': 8, 'truck': 1},
#  'lon_11.857285_lat_51.4667145': {'car': 1, 'truck': 1},
#  'lon_11.8562646_lat_51.4660138': {'car': 1, 'truck': 1},
#  'lon_7.3693221_lat_53.2220034': {'car': 2, 'truck': 2},
#  'lon_9.1042696_lat_50.7142736': {'car': 1, 'truck': 1},
#  'lon_8.2341062_lat_50.7448722': {'car': 0, 'truck': 1},
#  'lon_11.5846515_lat_52.0604543': {'car': 0, 'truck': 1},
#  'lon_11.5855061_lat_52.0606307': {'car': 0, 'truck': 1},
#  'lon_10.9814416_lat_54.3623714': {'car': 0, 'truck': 1},
#  'lon_8.3620815_lat_52.907909': {'car': 0, 'truck': 1},
#  'lon_8.5063482_lat_52.9364036': {'car': 0, 'truck': 1},
#  'lon_8.5064074_lat_52.9359003': {'car': 0, 'truck': 1},
#  'lon_8.5946304_lat_52.9638508': {'car': 0, 'truck': 1},
#  'lon_8.656512_lat_52.9922486': {'car': 0, 'truck': 1},
#  'lon_8.2151783_lat_52.8283254': {'car': 0, 'truck': 1},
#  'lon_8.2197171_lat_52.8413999': {'car': 0, 'truck': 1},
#  'lon_8.110306_lat_52.5754054': {'car': 0, 'truck': 1},
#  'lon_12.9854246_lat_52.6306623': {'car': 0, 'truck': 1},
#  'lon_12.9657887_lat_52.5227729': {'car': 0, 'truck': 1},
#  'lon_13.8992016_lat_51.7010657': {'car': 0, 'truck': 1},
#  'lon_13.9939049_lat_53.3959562': {'car': 0, 'truck': 2},
#  'lon_13.9923448_lat_53.3923443': {'car': 0, 'truck': 1},
#  'lon_10.3245839_lat_53.7345734': {'car': 0, 'truck': 1},
#  'lon_10.2941836_lat_53.8901124': {'car': 0, 'truck': 1},
#  'lon_10.2940174_lat_53.8904229': {'car': 0, 'truck': 1},
#  'lon_12.0740424_lat_53.2849259': {'car': 0, 'truck': 1},
#  'lon_12.0732519_lat_53.2843058': {'car': 0, 'truck': 1},
#  'lon_10.3003947_lat_53.5683535': {'car': 0, 'truck': 1},
#  'lon_8.5981794_lat_53.034872': {'car': 0, 'truck': 1},
#  'lon_8.165554_lat_52.9134371': {'car': 0, 'truck': 1},
#  'lon_8.1656279_lat_52.9117566': {'car': 0, 'truck': 1},
#  'lon_9.7581285_lat_52.5049195': {'car': 0, 'truck': 1},
#  'lon_8.0697116_lat_53.2090872': {'car': 0, 'truck': 1}}

# %%
# Length of reststop dictionary
len(rest_stop_dic)
# Out:
# 467

# %% [markdown]
# ## Save geoJSONs

# %%
# Specify the path where you want to save the GeoJSON file
output_file_all_parkings = "/content/drive/MyDrive/Master Thesis/01 Data Acquisition/OSM GeoJSON/all_parkings.geojson"
output_file_rest_stations = "/content/drive/MyDrive/Master Thesis/01 Data Acquisition/OSM GeoJSON/rest_stations.geojson"
output_file_car_parkings = "/content/drive/MyDrive/Master Thesis/01 Data Acquisition/OSM GeoJSON/car_parkings.geojson"
output_file_truck_parkings = "/content/drive/MyDrive/Master Thesis/01 Data Acquisition/OSM GeoJSON/truck_parkings.geojson"

# Export the GeoPandas DataFrame to GeoJSON
#all_parkings.to_file(output_file_all_parkings, driver='GeoJSON')
#rest_stations.to_file(output_file_rest_stations, driver='GeoJSON')
#car_parkings_joined.to_file(output_file_car_parkings, driver='GeoJSON')
#truck_parkings_joined.to_file(output_file_truck_parkings, driver='GeoJSON')
