# %% [markdown]
# <a href="https://colab.research.google.com/github/benedikt-korbach/remote-sensing-of-parking-areas/blob/main/4a_image%20segmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import packages, mount drive, set wd

# %%
 # %pip install segmentation_models
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 2.6 MB/s eta 0:00:00
# ...

# %%
import os
os.environ['SM_FRAMEWORK'] = "tf.keras"
from segmentation_models import Unet
from segmentation_models.metrics import IOUScore
from segmentation_models.losses import CategoricalFocalLoss
import segmentation_models as sm
import tensorflow as tf
import numpy as np
import cv2
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.utils import to_categorical
from segmentation_models import Unet
from segmentation_models.utils import set_trainable
import matplotlib.pyplot as plt
import numpy as np
import datetime
import random
import shutil
import albumentations as A
import keras
# Out:
# Segmentation Models: using `tf.keras` framework.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Set wd
#os.chdir("/Users/benediktkorbach/Documents/GitHub/remote-sensing-of-parking-areas")
os.chdir("/content/drive/MyDrive/Master Thesis")

print("Working directory:", os.getcwd())
# Out:
# Working directory: /content/drive/MyDrive/Master Thesis

# %% [markdown]
# # Car parking, truck parking, background

# %% [markdown]
# ## Define Dataloader

# %%
# Helper function to adjust class values based on mask intensities
def adjust_mask(mask, class_values):
    # Create a blank array with zeros where the background is
    adjusted_mask = np.zeros((*mask.shape, len(class_values) + 1), dtype=np.float32) # +1 for background # asterix unpacks shape tuple
    # For each class, set the corresponding slice of the adjusted mask
    for i, value in enumerate(class_values):
        adjusted_mask[:, :, i] = (mask == value) # Sets slice to 1 if mask has class value
    # Last channel for background
    adjusted_mask[:, :, -1] = (mask == 0) # background pixels
    return adjusted_mask

class Dataset(keras.utils.Sequence):
    """Read images, apply augmentation and preprocessing transformations.

    Args:
        images_dir (str): Path to images folder.
        masks_dir (str): Path to segmentation masks folder.
        class_values (list): Pixel values to extract from the segmentation mask.
        augmentation (callable): Data transformation pipeline (e.g., flip, scale).
        preprocessing (callable): Data preprocessing (e.g., normalization, shape manipulation).
    """

    def __init__(self, images_dir, masks_dir, class_values=[100, 200, 255], augmentation=None, preprocessing=None):
        self.ids = [os.path.splitext(file)[0] for file in os.listdir(images_dir) if not file.startswith('.')] # list of base file names
        self.images_fps = [os.path.join(images_dir, id_ + ".png") for id_ in self.ids]
        self.masks_fps = [os.path.join(masks_dir, id_ + ".png") for id_ in self.ids]
        self.class_values = class_values
        self.augmentation = augmentation
        self.preprocessing = preprocessing

    def __getitem__(self, i): # enables indexing of instances
        # read data
        image = cv2.imread(self.images_fps[i])
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        mask = cv2.imread(self.masks_fps[i], cv2.IMREAD_GRAYSCALE)

        # Adjust the mask based on class values
        mask = adjust_mask(mask, self.class_values)

        # Apply augmentations
        if self.augmentation:
            augmented = self.augmentation(image=image, mask=mask)
            image, mask = augmented["image"], augmented["mask"]

        # Apply preprocessing
        if self.preprocessing:
            preprocessed = self.preprocessing(image=image, mask=mask)
            image, mask = preprocessed["image"], preprocessed["mask"]

        return image, mask

    def __len__(self): # enables len()
        return len(self.ids)

class Dataloader(keras.utils.Sequence):
    """Load data from dataset and form batches.

    Args:
        dataset: Instance of Dataset class for image loading and preprocessing.
        batch_size: Integer number of images in batch.
        shuffle: Boolean, if `True` shuffle image indexes each epoch.
    """

    def __init__(self, dataset, batch_size=1, shuffle=False):
        self.dataset = dataset
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.indexes = np.arange(len(dataset))

        self.on_epoch_end()

    def __getitem__(self, i):
        # Collect batch data
        start = i * self.batch_size
        stop = (i + 1) * self.batch_size
        batch = [self.dataset[j] for j in range(start, stop)]

        # Transpose list of lists
        batch_images, batch_masks = zip(*batch)
        return np.stack(batch_images, axis=0), np.stack(batch_masks, axis=0) # returns single arrays for images and masks

    def __len__(self):
        """Denotes the number of batches per epoch"""
        return len(self.indexes) // self.batch_size

    def on_epoch_end(self):
        """Callback function to shuffle indexes each epoch"""
        if self.shuffle:
            np.random.shuffle(self.indexes)

# %%
# define augmentations
def get_training_augmentation():
    train_transform = [

        A.HorizontalFlip(p=0.5),
        A.VerticalFlip(p=0.5),
        A.RandomRotate90(p=0.5)
    ]
    return A.Compose(train_transform)

def get_preprocessing(preprocessing_fn):
    """Construct preprocessing transform

    Args:
        preprocessing_fn (callbale): data normalization function
            (can be specific for each pretrained neural network)
    Return:
        transform: albumentations.Compose

    """

    _transform = [
        A.Lambda(image=preprocessing_fn),
    ]
    return A.Compose(_transform)

# %% [markdown]
# ## Load training and validation set

# %%
train_dataset = Dataset(
    images_dir="03 Model Training/train_validate_images_masks_reduced/train/images",
    masks_dir="03 Model Training/train_validate_images_masks_reduced/train/masks",
    class_values=[100, 200, 250],
    augmentation=None,
    preprocessing=None
)

train_dataloader = Dataloader(dataset=train_dataset, batch_size=16, shuffle=True)

val_dataset = Dataset(
    images_dir="03 Model Training/train_validate_images_masks_reduced/val/images",
    masks_dir="03 Model Training/train_validate_images_masks_reduced/val/masks",
    class_values=[100, 200, 250],
    augmentation=None,
    preprocessing=None
)

val_dataloader = Dataloader(dataset=val_dataset, batch_size=1, shuffle=False)

# %% [markdown]
# ## Inspect batches, images and masks

# %%
print("Number of batches: ", len(train_dataloader))
print("Elements within first batch", len(train_dataloader[0])) # image, mask

first_batch_images, _ = train_dataloader[0]
first_image = first_batch_images[0]
image_shape = first_image.shape
print("Image shape:", image_shape)

_, first_batch_masks = train_dataloader[0]
first_mask = first_batch_masks[0]
mask_shape = first_mask.shape
print("Mask shape:", mask_shape)
# Out:
# Number of batches:  80
# Elements within first batch 2
# Image shape: (512, 512, 3)
# Mask shape: (512, 512, 4)

# %%
def visualize_image_with_mask_edges(data_loader):

    # Define colors for each category in BGR format
    colors = {
        "car_parking": (0, 0, 255), # cars in red
        "truck_parking": (255, 0, 0), # trucks in blue
        "quick_parking": (0, 255, 0) # quick in green
    }

    # Randomly select a batch index
    batch_index = np.random.randint(len(data_loader))

    # Get the batch
    images, masks = data_loader[batch_index]

    # Randomly select an image index
    image_index = np.random.randint(images.shape[0])

    # Get the random image and its mask
    image = images[image_index]
    mask = masks[image_index]

    # Convert image to BGR for cv2
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

    # Create a copy of the image to draw on
    image_to_draw = image.copy()

    # Iterate over each channel in the mask, excluding the background
    for channel, (label, color) in enumerate(colors.items()):
        # Extract the current channel mask
        current_mask = mask[:, :, channel]

        # Find contours from the binary mask
        contours, _ = cv2.findContours(current_mask.astype(np.uint8), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

        # Draw contours on the image
        cv2.drawContours(image_to_draw, contours, -1, color, 2)  # Thickness set to 2

    # Plot the original image and the image with mask edges
    fig, axes = plt.subplots(1, 2, figsize=(12, 6))
    axes[0].imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))  # Convert to RGB for displaying
    axes[0].set_title('Original Image')
    axes[1].imshow(cv2.cvtColor(image_to_draw, cv2.COLOR_BGR2RGB))  # Convert to RGB for displaying
    axes[1].set_title('Image with Mask Edges')

    # Remove axis numbers for a cleaner look
    axes[0].axis('off')
    axes[1].axis('off')

    plt.show()

# %%
visualize_image_with_mask_edges(train_dataloader)

# %%
def visualize_random_image_with_masks(data_loader):
    # Randomly select a batch index
    batch_index = np.random.randint(len(data_loader))

    # Get the batch
    images, masks = data_loader[batch_index]

    # Randomly select an image index
    image_index = np.random.randint(images.shape[0])

    # Get the random image and its masks
    image = images[image_index]
    mask = masks[image_index]

    # Plot the image and masks
    fig, axes = plt.subplots(1, 1 + mask.shape[-1], figsize=(15, 5))
    axes[0].imshow(image)
    axes[0].set_title(f"Image {image_index}, batch {batch_index}")

    axes[1].imshow(mask[..., 0], cmap="gray")
    axes[1].set_title(f"Car Mask")
    axes[2].imshow(mask[..., 1], cmap="gray")
    axes[2].set_title(f"Truck Mask")
    axes[3].imshow(mask[..., 2], cmap="gray")
    axes[3].set_title(f"Quick Mask")
    axes[4].imshow(mask[..., 3], cmap="gray")
    axes[4].set_title(f"Background Mask")

    plt.show()

# %%
visualize_random_image_with_masks(train_dataloader)

# %% [markdown]
# If the image only shows background, imshow will show it as black as all white pixels are normalized to zero.

# %% [markdown]
# # Model Training

# %% [markdown]
# ## UNet hyperparameter tuning

# %%
# Define a function to create and train the model
def train_model(backbone, batch_size, encoder_freeze, epochs=50):

    # Define directories
    NAME = f"03 Model Training/models/unet_{backbone}_bs{batch_size}_lr0.0001_e{epochs}_ef{str(encoder_freeze)}"
    print(NAME)
    HISTORY_DIR = "03 Model Training/models_training_history"
    LR = 0.0001
    os.makedirs(NAME, exist_ok=True)
    os.makedirs(HISTORY_DIR, exist_ok=True)

    preprocess_input = sm.get_preprocessing(backbone)

    # Set up model, optimizer, evaluation metrics and compile the model
    model = Unet(backbone, classes=4, activation="softmax", encoder_weights="imagenet", encoder_freeze=encoder_freeze)
    optim = keras.optimizers.Adam(LR)
    metrics = [sm.metrics.IOUScore(threshold=0.5, class_indexes=[0, 1], per_image=True), sm.metrics.FScore(threshold=0.5, class_indexes=[0, 1], per_image=True)]
    model.compile(optimizer=optim, loss=sm.losses.dice_loss, metrics=metrics)

    # Define training and validation set
    train_dataset = Dataset(
        images_dir="03 Model Training/train_validate_images_masks_reduced/train/images",
        masks_dir="03 Model Training/train_validate_images_masks_reduced/train/masks",
        class_values=[100, 200, 250],
        augmentation=get_training_augmentation(),
        preprocessing=get_preprocessing(preprocess_input),
    )

    val_dataset = Dataset(
        images_dir="03 Model Training/train_validate_images_masks_reduced/val/images",
        masks_dir="03 Model Training/train_validate_images_masks_reduced/val/masks",
        class_values=[100, 200, 250],
        augmentation=None,
        preprocessing=get_preprocessing(preprocess_input),
    )

    train_dataloader = Dataloader(train_dataset, batch_size=batch_size, shuffle=True)
    val_dataloader = Dataloader(val_dataset, batch_size=1, shuffle=False)

    # Callbacks
    callbacks = [
        keras.callbacks.ModelCheckpoint(os.path.join(NAME, "best_model.h5"), monitor="val_loss", verbose=1, save_best_only=True, mode="min"),
        keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.1, patience=5)
    ]

    # Fit model
    history = model.fit(
        train_dataloader,
        epochs=epochs,
        verbose=1,
        callbacks=callbacks,
        validation_data=val_dataloader
    )

    # Plot and save training history
    plt.figure(figsize=(30, 5))
    plt.subplot(121)
    plt.plot(history.history["iou_score"])
    plt.plot(history.history["val_iou_score"])
    plt.title("Intersection over Union score")
    plt.ylabel("iou_score")
    plt.xlabel("Epoch")
    plt.legend(["Train", "Validation"], loc="upper left")

    plt.subplot(122)
    plt.plot(history.history["loss"])
    plt.plot(history.history["val_loss"])
    plt.title("Dice loss")
    plt.ylabel("dice_loss")
    plt.xlabel("Epoch")
    plt.legend(["Train", "Validation"], loc="upper left")
    plt.savefig(os.path.join(HISTORY_DIR, f"history_unet_{backbone}_bs{batch_size}_lr0.0001_e{epochs}_ef{str(encoder_freeze)}.png"), bbox_inches='tight')
    plt.close()

# %%
# Define possible hyperparameters
backbones = ["resnet101", "vgg16"]
batch_sizes = [4, 8]
encoder_freezes = [True, False]

# %%
# Loop over all combinations of hyperparameters
for backbone in backbones:
    for batch_size in batch_sizes:
        for encoder_freeze in encoder_freezes:
            start_time = datetime.datetime.now()
            print(f"Training model with Backbone: {backbone}, Batch Size: {batch_size}, Encoder Freeze: {encoder_freeze}")
            print(f"Start Time: {start_time.strftime('%Y-%m-%d %H:%M:%S')}")

            train_model(backbone, batch_size, encoder_freeze)

            end_time = datetime.datetime.now()
            print(f"End Time: {end_time.strftime('%Y-%m-%d %H:%M:%S')}")
            print(f"Training Duration: {end_time - start_time}")
# Out:
# Training model with Backbone: resnet101, Batch Size: 4, Encoder Freeze: True
# Start Time: 2024-04-14 08:28:30
# 03 Model Training/models/unet_resnet101_bs4_lr0.0001_e50_efTrue
# ...
# 171164896/171164896 [==============================] - 0s 0us/step
# Epoch 1/50
# 320/320 [==============================] - ETA: 0s - loss: 0.7353 - iou_score: 0.2301 - f1-score: 0.2604
# Epoch 1: val_loss improved from inf to 0.72407, saving model to 03 Model Training/models/unet_resnet101_bs4_lr0.0001_e50_efTrue/best_model.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# ...

# %% [markdown]
# ## FPN hyperparameter tuning

# %%
# Define a function to create and train the model
def train_model(backbone, batch_size, encoder_freeze, epochs=50):

    # Define directories
    NAME = f"03 Model Training/models/fpn_{backbone}_bs{batch_size}_lr0.0001_e{epochs}_ef{str(encoder_freeze)}"
    print(NAME)
    HISTORY_DIR = "03 Model Training/models_training_history"
    LR = 0.0001
    os.makedirs(NAME, exist_ok=True)
    os.makedirs(HISTORY_DIR, exist_ok=True)

    preprocess_input = sm.get_preprocessing(backbone)

    # Set up model, optimizer, evaluation metrics and compile the model
    model = sm.FPN(backbone, classes=4, activation="softmax", encoder_weights="imagenet", encoder_freeze=encoder_freeze)
    optim = keras.optimizers.Adam(LR)
    metrics = [sm.metrics.IOUScore(threshold=0.5, class_indexes=[0, 1], per_image=True), sm.metrics.FScore(threshold=0.5, class_indexes=[0, 1], per_image=True)]
    model.compile(optimizer=optim, loss=sm.losses.dice_loss, metrics=metrics)

    # Define training and validation set
    train_dataset = Dataset(
        images_dir="03 Model Training/train_validate_images_masks_reduced/train/images",
        masks_dir="03 Model Training/train_validate_images_masks_reduced/train/masks",
        class_values=[100, 200, 250],
        augmentation=get_training_augmentation(),
        preprocessing=get_preprocessing(preprocess_input),
    )

    val_dataset = Dataset(
        images_dir="03 Model Training/train_validate_images_masks_reduced/val/images",
        masks_dir="03 Model Training/train_validate_images_masks_reduced/val/masks",
        class_values=[100, 200, 250],
        augmentation=None,
        preprocessing=get_preprocessing(preprocess_input),
    )

    train_dataloader = Dataloader(train_dataset, batch_size=batch_size, shuffle=True)
    val_dataloader = Dataloader(val_dataset, batch_size=1, shuffle=False)

    # Callbacks
    callbacks = [
        keras.callbacks.ModelCheckpoint(os.path.join(NAME, "best_model.h5"), monitor="val_loss", verbose=1, save_best_only=True, mode="min"),
        keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.1, patience=5)
    ]

    # Fit model
    history = model.fit(
        train_dataloader,
        epochs=epochs,
        verbose=1,
        callbacks=callbacks,
        validation_data=val_dataloader
    )

    # Plot and save training history
    plt.figure(figsize=(30, 5))
    plt.subplot(121)
    plt.plot(history.history["iou_score"])
    plt.plot(history.history["val_iou_score"])
    plt.title("Intersection over Union")
    plt.ylabel("iou_score")
    plt.xlabel("Epoch")
    plt.legend(["Train", "Validation"], loc="upper left")

    plt.subplot(122)
    plt.plot(history.history["loss"])
    plt.plot(history.history["val_loss"])
    plt.title("Dice Loss")
    plt.ylabel("dice_loss")
    plt.xlabel("Epoch")
    plt.legend(["Train", "Validation"], loc="upper left")
    plt.savefig(os.path.join(HISTORY_DIR, f"history_fpn_{backbone}_bs{batch_size}_lr0.0001_e{epochs}_ef{str(encoder_freeze)}.png"), bbox_inches='tight')
    plt.close()

# %%
# Define possible hyperparameters
backbones = ["resnet101", "vgg"]
batch_sizes = [8]
encoder_freezes = [False]

# %%
# Loop over all combinations of hyperparameters
for backbone in backbones:
    for batch_size in batch_sizes:
        for encoder_freeze in encoder_freezes:
            start_time = datetime.datetime.now()
            print(f"Training model with Backbone: {backbone}, Batch Size: {batch_size}, Encoder Freeze: {encoder_freeze}")
            print(f"Start Time: {start_time.strftime('%Y-%m-%d %H:%M:%S')}")

            train_model(backbone, batch_size, encoder_freeze)

            end_time = datetime.datetime.now()
            print(f"End Time: {end_time.strftime('%Y-%m-%d %H:%M:%S')}")
            print(f"Training Duration: {end_time - start_time}")
# Out:
# Training model with Backbone: resnet101, Batch Size: 8, Encoder Freeze: False
# Start Time: 2024-04-15 08:48:21
# 03 Model Training/models/fpn_resnet101_bs8_lr0.0001_e50_efFalse
# Epoch 1/50
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-14-80f430aaf479> in <cell line: 2>()
#       7             print(f"Start Time: {start_time.strftime('%Y-%m-%d %H:%M:%S')}")
#       8
# ----> 9             train_model(backbone, batch_size, encoder_freeze)
#      10
#      11             end_time = datetime.datetime.now()
#
# <ipython-input-11-50e4e60fed5f> in train_model(backbone, batch_size, encoder_freeze, epochs)
#      40     ]
#      41
# ---> 42     history = model.fit(
#      43         train_dataloader,
#      44         epochs=epochs,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
# ...

# %% [markdown]
# ## Linknet hyperparameter tuning

# %%
# Define a function to create and train the model
def train_model(backbone, batch_size, encoder_freeze, epochs=50):

    # Define directories
    NAME = f"03 Model Training/models/linknet_{backbone}_bs{batch_size}_lr0.0001_e{epochs}_ef{str(encoder_freeze)}"
    print(NAME)
    HISTORY_DIR = "03 Model Training/models_training_history"
    LR = 0.0001
    os.makedirs(NAME, exist_ok=True)
    os.makedirs(HISTORY_DIR, exist_ok=True)

    preprocess_input = sm.get_preprocessing(backbone)

    # Set up model, optimizer, evaluation metrics and compile the model
    model = sm.Linknet(backbone, classes=4, activation="softmax", encoder_weights="imagenet", encoder_freeze=encoder_freeze)
    optim = keras.optimizers.Adam(LR)
    metrics = [sm.metrics.IOUScore(threshold=0.5, class_indexes=[0, 1], per_image=True), sm.metrics.FScore(threshold=0.5, class_indexes=[0, 1], per_image=True)]
    model.compile(optimizer=optim, loss=sm.losses.dice_loss, metrics=metrics)

    # Define training and validation set
    train_dataset = Dataset(
        images_dir="03 Model Training/train_validate_images_masks_reduced/train/images",
        masks_dir="03 Model Training/train_validate_images_masks_reduced/train/masks",
        class_values=[100, 200, 250],
        augmentation=get_training_augmentation(),
        preprocessing=get_preprocessing(preprocess_input),
    )

    val_dataset = Dataset(
        images_dir="03 Model Training/train_validate_images_masks_reduced/val/images",
        masks_dir="03 Model Training/train_validate_images_masks_reduced/val/masks",
        class_values=[100, 200, 250],
        augmentation=None,
        preprocessing=get_preprocessing(preprocess_input),
    )

    train_dataloader = Dataloader(train_dataset, batch_size=batch_size, shuffle=True)
    val_dataloader = Dataloader(val_dataset, batch_size=batch_size, shuffle=False)

    # Callbacks
    callbacks = [
        keras.callbacks.ModelCheckpoint(os.path.join(NAME, "best_model.h5"), monitor="val_iou_score", verbose=1, save_best_only=True, mode="max"),
        keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.1, patience=5)
    ]

    # Fit model
    history = model.fit(
        train_dataloader,
        epochs=epochs,
        verbose=1,
        callbacks=callbacks,
        validation_data=val_dataloader
    )

    # Plot and save training history
    plt.figure(figsize=(30, 5))
    plt.subplot(121)
    plt.plot(history.history["iou_score"])
    plt.plot(history.history["val_iou_score"])
    plt.title("Intersection over Union")
    plt.ylabel("iou_score")
    plt.xlabel("Epoch")
    plt.legend(["Train", "Validation"], loc="upper left")

    plt.subplot(122)
    plt.plot(history.history["loss"])
    plt.plot(history.history["val_loss"])
    plt.title("Dice Loss")
    plt.ylabel("dice_loss")
    plt.xlabel("Epoch")
    plt.legend(["Train", "Validation"], loc="upper left")
    plt.savefig(os.path.join(HISTORY_DIR, f"history_linknet_{backbone}_bs{batch_size}_lr0.0001_e{epochs}_ef{str(encoder_freeze)}.png"), bbox_inches='tight')
    plt.close()

# %%
# Define possible hyperparameters
backbones = ["resnet101", "vgg16"]
batch_sizes = [4, 8]
encoder_freezes = [True, False]

# %%
# Loop over all combinations of hyperparameters
for backbone in backbones:
    for batch_size in batch_sizes:
        for encoder_freeze in encoder_freezes:
            start_time = datetime.datetime.now()
            print(f"Training model with Backbone: {backbone}, Batch Size: {batch_size}, Encoder Freeze: {encoder_freeze}")
            print(f"Start Time: {start_time.strftime('%Y-%m-%d %H:%M:%S')}")

            train_model(backbone, batch_size, encoder_freeze)

            end_time = datetime.datetime.now()
            print(f"End Time: {end_time.strftime('%Y-%m-%d %H:%M:%S')}")
            print(f"Training Duration: {end_time - start_time}")
# Out:
# Training model with Backbone: resnet101, Batch Size: 4, Encoder Freeze: True
# Start Time: 2024-04-11 22:58:42
# 03 Model Training/models/linknet_resnet101_bs4_lr0.0001_e50_efTrue
# Epoch 1/50
# 320/320 [==============================] - ETA: 0s - loss: 0.7334 - iou_score: 0.1935 - f1-score: 0.2212
# Epoch 1: val_iou_score improved from -inf to 0.45135, saving model to 03 Model Training/models/linknet_resnet101_bs4_lr0.0001_e50_efTrue/best_model.h5
# 320/320 [==============================] - 94s 182ms/step - loss: 0.7334 - iou_score: 0.1935 - f1-score: 0.2212 - val_loss: 0.6613 - val_iou_score: 0.4513 - val_f1-score: 0.4902 - lr: 1.0000e-04
# Epoch 2/50
# 320/320 [==============================] - ETA: 0s - loss: 0.6308 - iou_score: 0.3690 - f1-score: 0.4041
# Epoch 2: val_iou_score improved from 0.45135 to 0.47293, saving model to 03 Model Training/models/linknet_resnet101_bs4_lr0.0001_e50_efTrue/best_model.h5
# ...

# %% [markdown]
# # Model evaluation

# %% [markdown]
# ## Model evaluation on validation set

# %%
# Define the hyperparameter combinations
model_types = ["unet", "fpn", "linknet"]
backbones = ["resnet101", "vgg16"]
batch_sizes = [4, 8,]
encoder_freezes = [True, False]

# Custom objects for loading models
custom_objects = {
    "iou_score": sm.metrics.IOUScore(threshold=0.5, class_indexes=[0,1], per_image=True), # change class indeces to calculate IoU for cars (0), trucks (1), or both (0,1)
    "f1-score": sm.metrics.FScore(threshold=0.5, class_indexes=[0,1], per_image=True), # change class indeces to calculate f1 for cars (0), trucks (1), or both (0,1)
    "dice_loss": sm.losses.dice_loss
}

# Function to evaluate the model
def evaluate_model(model, dataloader):
    results = model.evaluate(dataloader, verbose=1)
    return results

# Store model performance for sorting
model_performance = []

# Loop over all combinations of model types and hyperparameters
for model_type in model_types:
    for backbone in backbones:
        for batch_size in batch_sizes:
            for encoder_freeze in encoder_freezes:
                model_dir = f"03 Model Training/models/{model_type}_{backbone}_bs{batch_size}_lr0.0001_e50_ef{str(encoder_freeze)}"
                model_path = os.path.join(model_dir, "best_model.h5")

                if os.path.exists(model_path):
                    print(f"Evaluating model {model_path}")
                    loaded_model = tf.keras.models.load_model(model_path, custom_objects=custom_objects)

                    # Load validation dataset
                    val_dataset = Dataset(
                        images_dir="03 Model Training/train_validate_images_masks_reduced/val/images",
                        masks_dir="03 Model Training/train_validate_images_masks_reduced/val/masks",
                        class_values=[100, 200, 250],
                        augmentation=None,  # No augmentation for evaluation
                        preprocessing=get_preprocessing(sm.get_preprocessing(backbone))
                    )
                    val_dataloader = Dataloader(val_dataset, batch_size=1, shuffle=False)

                    # Evaluate the model
                    evaluation_results = evaluate_model(loaded_model, val_dataloader)
                    model_performance.append((model_path, evaluation_results[1]))
                    print(f"Results for {model_type} with {backbone}, Batch Size: {batch_size}, Encoder Freeze: {encoder_freeze}: {evaluation_results}")
                else:
                    print(f"Model file not found: {model_path}")

# Sort models by IoU score from highest to lowest
model_performance.sort(key=lambda x: x[1], reverse=True)

# Print sorted results
for model, iou_score in model_performance:
    print(f"Model {model} has IoU score: {iou_score}")
# Out:
# Evaluating model 03 Model Training/models/unet_resnet101_bs4_lr0.0001_e50_efTrue/best_model.h5
# 327/327 [==============================] - 166s 500ms/step - loss: 0.6295 - iou_score: 0.7087 - f1-score: 0.7474
# Results for unet with resnet101, Batch Size: 4, Encoder Freeze: True: [0.6294876933097839, 0.7086676955223083, 0.7474195957183838]
# Evaluating model 03 Model Training/models/unet_resnet101_bs4_lr0.0001_e50_efFalse/best_model.h5
# 327/327 [==============================] - 12s 30ms/step - loss: 0.6099 - iou_score: 0.7980 - f1-score: 0.8339
# Results for unet with resnet101, Batch Size: 4, Encoder Freeze: False: [0.6098713278770447, 0.798020601272583, 0.8339118361473083]
# Evaluating model 03 Model Training/models/unet_resnet101_bs8_lr0.0001_e50_efTrue/best_model.h5
# 327/327 [==============================] - 12s 29ms/step - loss: 0.6248 - iou_score: 0.7217 - f1-score: 0.7599
# ...

# %% [markdown]
# Overall:
#
# *   Model 03 Model Training/models/linknet_resnet101_bs8_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.8193722367286682
# *   Model 03 Model Training/models/unet_resnet101_bs8_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.809856653213501
# *   Model 03 Model Training/models/fpn_resnet101_bs4_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.8012911677360535
# *   Model 03 Model Training/models/linknet_resnet101_bs4_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.7995907664299011
# *   Model 03 Model Training/models/unet_resnet101_bs4_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.798020601272583
# *   Model 03 Model Training/models/fpn_vgg16_bs4_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.7896596193313599
# *   Model 03 Model Training/models/unet_vgg16_bs8_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.7392765879631042
# *   Model 03 Model Training/models/linknet_resnet101_bs4_lr0.0001_e50_efTrue/best_model.h5 has IoU score: 0.7337772250175476
# *   Model 03 Model Training/models/unet_resnet101_bs8_lr0.0001_e50_efTrue/best_model.h5 has IoU score: 0.7217395305633545
# *   Model 03 Model Training/models/linknet_resnet101_bs8_lr0.0001_e50_efTrue/best_model.h5 has IoU score: 0.7141426801681519
# *   Model 03 Model Training/models/unet_resnet101_bs4_lr0.0001_e50_efTrue/best_model.h5 has IoU score: 0.7086676955223083
# *   Model 03 Model Training/models/fpn_resnet101_bs8_lr0.0001_e50_efTrue/best_model.h5 has IoU score: 0.6982511878013611
# *   Model 03 Model Training/models/fpn_resnet101_bs4_lr0.0001_e50_efTrue/best_model.h5 has IoU score: 0.6978514790534973
# *   Model 03 Model Training/models/fpn_vgg16_bs4_lr0.0001_e50_efTrue/best_model.h5 has IoU score: 0.6615665555000305
# *   Model 03 Model Training/models/fpn_vgg16_bs8_lr0.0001_e50_efTrue/best_model.h5 has IoU score: 0.6480434536933899
# *   Model 03 Model Training/models/unet_vgg16_bs4_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.6446937918663025
# *   Model 03 Model Training/models/unet_vgg16_bs4_lr0.0001_e50_efTrue/best_model.h5 has IoU score: 0.6436582803726196
# *   Model 03 Model Training/models/linknet_vgg16_bs4_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.6355123519897461
# *   Model 03 Model Training/models/unet_vgg16_bs8_lr0.0001_e50_efTrue/best_model.h5 has IoU score: 0.633143424987793
# *   Model 03 Model Training/models/linknet_vgg16_bs8_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.5799106955528259
# *   Model 03 Model Training/models/linknet_vgg16_bs8_lr0.0001_e50_efTrue/best_model.h5 has IoU score: 0.3662072420120239
# *   Model 03 Model Training/models/linknet_vgg16_bs4_lr0.0001_e50_efTrue/best_model.h5 has IoU score: 0.3089069426059723
# *   Model 03 Model Training/models/fpn_vgg16_bs8_lr0.0001_e50_efFalse/best_model.h5 stopped training and could not be evaluated
# *   Model 03 Model Training/models/fpn_vgg16_bs8_lr0.0001_e50_efFalse/best_model.h5 stopped training and could not be evaluated
#
#
# Car:
#
# *   Model 03 Model Training/models/linknet_resnet101_bs8_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.7656872868537903
# *   Model 03 Model Training/models/unet_resnet101_bs4_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.763706624507904
# *   Model 03 Model Training/models/linknet_resnet101_bs4_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.761753261089325
# *   Model 03 Model Training/models/unet_resnet101_bs8_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.7593119144439697
# *   Model 03 Model Training/models/fpn_resnet101_bs4_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.7523444890975952
# *   Model 03 Model Training/models/fpn_vgg16_bs4_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.7369402647018433
# *   Model 03 Model Training/models/unet_vgg16_bs8_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.716785728931427
# *   Model 03 Model Training/models/linknet_resnet101_bs4_lr0.0001_e50_efTrue/best_model.h5 has IoU score: 0.7025055885314941
# *   Model 03 Model Training/models/fpn_resnet101_bs4_lr0.0001_e50_efTrue/best_model.h5 has IoU score: 0.6846007108688354
# *   Model 03 Model Training/models/unet_resnet101_bs8_lr0.0001_e50_efTrue/best_model.h5 has IoU score: 0.6842025518417358
# *   Model 03 Model Training/models/linknet_vgg16_bs4_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.6836614608764648
# *   Model 03 Model Training/models/unet_resnet101_bs4_lr0.0001_e50_efTrue/best_model.h5 has IoU score: 0.6801961064338684
# *   Model 03 Model Training/models/linknet_resnet101_bs8_lr0.0001_e50_efTrue/best_model.h5 has IoU score: 0.6799314618110657
# *   Model 03 Model Training/models/unet_vgg16_bs4_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.6484952569007874
# *   Model 03 Model Training/models/fpn_resnet101_bs8_lr0.0001_e50_efTrue/best_model.h5 has IoU score: 0.6390809416770935
# *   Model 03 Model Training/models/fpn_vgg16_bs4_lr0.0001_e50_efTrue/best_model.h5 has IoU score: 0.6194937825202942
# *   Model 03 Model Training/models/fpn_vgg16_bs8_lr0.0001_e50_efTrue/best_model.h5 has IoU score: 0.6100039482116699
# *   Model 03 Model Training/models/linknet_vgg16_bs8_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.5954875946044922
# *   Model 03 Model Training/models/linknet_vgg16_bs8_lr0.0001_e50_efTrue/best_model.h5 has IoU score: 0.5810407996177673
# *   Model 03 Model Training/models/unet_vgg16_bs4_lr0.0001_e50_efTrue/best_model.h5 has IoU score: 0.5696407556533813
# *   Model 03 Model Training/models/unet_vgg16_bs8_lr0.0001_e50_efTrue/best_model.h5 has IoU score: 0.5260281562805176
# *   Model 03 Model Training/models/linknet_vgg16_bs4_lr0.0001_e50_efTrue/best_model.h5 has IoU score: 0.3559165894985199
#
# Truck:
#
# *   Model 03 Model Training/models/linknet_resnet101_bs8_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.8730567693710327
# *   Model 03 Model Training/models/unet_resnet101_bs8_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.8604017496109009
# *   Model 03 Model Training/models/fpn_resnet101_bs4_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.8502379059791565
# *   Model 03 Model Training/models/fpn_vgg16_bs4_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.8423789739608765
# *   Model 03 Model Training/models/linknet_resnet101_bs4_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.8374282121658325
# *   Model 03 Model Training/models/unet_resnet101_bs4_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.8323343992233276
# *   Model 03 Model Training/models/linknet_resnet101_bs4_lr0.0001_e50_efTrue/best_model.h5 has IoU score: 0.7650488018989563
# *   Model 03 Model Training/models/unet_vgg16_bs8_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.7617675065994263
# *   Model 03 Model Training/models/unet_resnet101_bs8_lr0.0001_e50_efTrue/best_model.h5 has IoU score: 0.7592764496803284
# *   Model 03 Model Training/models/fpn_resnet101_bs8_lr0.0001_e50_efTrue/best_model.h5 has IoU score: 0.7574213147163391
# *   Model 03 Model Training/models/linknet_resnet101_bs8_lr0.0001_e50_efTrue/best_model.h5 has IoU score: 0.7483541965484619
# *   Model 03 Model Training/models/unet_vgg16_bs8_lr0.0001_e50_efTrue/best_model.h5 has IoU score: 0.7402584552764893
# *   Model 03 Model Training/models/unet_resnet101_bs4_lr0.0001_e50_efTrue/best_model.h5 has IoU score: 0.7371395230293274
# *   Model 03 Model Training/models/unet_vgg16_bs4_lr0.0001_e50_efTrue/best_model.h5 has IoU score: 0.7176753282546997
# *   Model 03 Model Training/models/fpn_resnet101_bs4_lr0.0001_e50_efTrue/best_model.h5 has IoU score: 0.7111018896102905
# *   Model 03 Model Training/models/fpn_vgg16_bs4_lr0.0001_e50_efTrue/best_model.h5 has IoU score: 0.7036393880844116
# *   Model 03 Model Training/models/fpn_vgg16_bs8_lr0.0001_e50_efTrue/best_model.h5 has IoU score: 0.6860827207565308
# *   Model 03 Model Training/models/unet_vgg16_bs4_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.6408922672271729
# *   Model 03 Model Training/models/linknet_vgg16_bs4_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.587363064289093
# *   Model 03 Model Training/models/linknet_vgg16_bs8_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.564333975315094
# *   Model 03 Model Training/models/linknet_vgg16_bs4_lr0.0001_e50_efTrue/best_model.h5 has IoU score: 0.26189717650413513
# *   Model 03 Model Training/models/linknet_vgg16_bs8_lr0.0001_e50_efTrue/best_model.h5 has IoU score: 0.1513737142086029

# %% [markdown]
# ## Best model evaluation on test set

# %%
# Define the hyperparameter combinations
model_types = ["unet"]
backbones = ["resnet101"]
batch_sizes = [16]
encoder_freezes = [False]

# Custom objects for loading models
custom_objects = {
    "iou_score": sm.metrics.IOUScore(threshold=0.5, class_indexes=[0,1], per_image=True), # change class indeces to calculate IoU for cars (0), trucks (1), or both (0,1)
    "f1-score": sm.metrics.FScore(threshold=0.5, class_indexes=[0,1], per_image=True), # change class indeces to calculate IoU for cars (0), trucks (1), or both (0,1)
    "dice_loss": sm.losses.dice_loss
}

# Function to evaluate the model
def evaluate_model(model, dataloader):
    results = model.evaluate(dataloader, verbose=1)
    return results

# Store model performance for sorting
model_performance = []

# Loop over all combinations of model types and hyperparameters
for model_type in model_types:
    for backbone in backbones:
        for batch_size in batch_sizes:
            for encoder_freeze in encoder_freezes:
                model_dir = f"03 Model Training/models_256/{model_type}_{backbone}_bs{batch_size}_lr0.0001_e50_ef{str(encoder_freeze)}"
                model_path = os.path.join(model_dir, "best_model.h5")

                if os.path.exists(model_path):
                    print(f"Evaluating model {model_path}")
                    loaded_model = tf.keras.models.load_model(model_path, custom_objects=custom_objects)

                    # Load test dataset
                    test_dataset = Dataset(
                        images_dir="03 Model Training/test_images_masks/images_png",
                        masks_dir="03 Model Training/test_images_masks/masks",
                        class_values=[100, 200, 250],
                        augmentation=None,  # Usually, we don't apply augmentation to validation data
                        preprocessing=get_preprocessing(sm.get_preprocessing(backbone)),
                    )
                    test_dataloader = Dataloader(test_dataset, batch_size=1, shuffle=False)

                    # Evaluate the model
                    evaluation_results = evaluate_model(loaded_model, test_dataloader)
                    model_performance.append((model_path, evaluation_results[1]))  # Assuming IoU is the second metric
                    print(f"Results for {model_type} with {backbone}, Batch Size: {batch_size}, Encoder Freeze: {encoder_freeze}: {evaluation_results}")
                else:
                    print(f"Model file not found: {model_path}")

# Sort models by IoU score from highest to lowest
model_performance.sort(key=lambda x: x[1], reverse=True)

# Print sorted results
for model, iou_score in model_performance:
    print(f"Model {model} has IoU score: {iou_score}")
# Out:
# Evaluating model 03 Model Training/models_256/unet_resnet101_bs16_lr0.0001_e50_efFalse/best_model.h5
# 23/23 [==============================] - 46s 2s/step - loss: 0.2774 - iou_score: 0.6990 - f1-score: 0.8135
# Results for unet with resnet101, Batch Size: 16, Encoder Freeze: False: [0.2773723304271698, 0.6990471482276917, 0.813496470451355]
# Model 03 Model Training/models_256/unet_resnet101_bs16_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.6990471482276917

# %% [markdown]
# Overall:
#
# Model 03 Model Training/models/linknet_resnet101_bs8_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.7010171413421631
#
# Car:
#
# Model 03 Model Training/models/linknet_resnet101_bs8_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.59691321849823
#
# Truck:
#
# Model 03 Model Training/models/linknet_resnet101_bs8_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.8051210641860962

# %% [markdown]
# ## Inspect best model prediction on test set

# %% [markdown]
# ### Convert test cases to png

# %%
def tiff_to_png(tiff_dir, png_dir):
    """
    Converts all TIFF images in a directory to PNG format and saves them
    in another directory.

    Args:
        tiff_dir (str): The directory containing the TIFF files.
        png_dir (str): The directory where the PNG files will be saved.
    """
    if not os.path.exists(png_dir):
        os.makedirs(png_dir)

    for filename in os.listdir(tiff_dir):
        if filename.endswith('.tif') or filename.endswith('.tiff'):
            # Read the TIFF image
            tiff_path = os.path.join(tiff_dir, filename)
            image = Image.open(tiff_path)

            # Convert the TIFF image to PNG format
            png_path = os.path.join(png_dir, os.path.splitext(filename)[0] + '.png')
            image.save(png_path, 'PNG')

# %%
# Define the directories
tiff_images_dir = "03 Model Training/test_images_masks/images"
png_images_dir = "03 Model Training/test_images_masks/images_png"

# Convert all TIFF images to PNG format
tiff_to_png(tiff_images_dir, png_images_dir)

# %% [markdown]
# ### Inspect predictions

# %%
custom_objects = {
    "iou_score": sm.metrics.IOUScore(threshold=0.5, class_indexes=[0,1], per_image=True),
    "f1-score": sm.metrics.FScore(threshold=0.5, class_indexes=[0,1], per_image=True),
    "dice_loss": sm.losses.dice_loss
}

loaded_model = tf.keras.models.load_model(
    "03 Model Training/models/linknet_resnet101_bs8_lr0.0001_e50_efFalse/best_model.h5",
    custom_objects=custom_objects
)

BACKBONE = "resnet101"
preprocess_input = sm.get_preprocessing(BACKBONE)

# %%
def predict_and_visualize_with_mask_edges(model, dataloader, batch_num=0, image_num=0, output_path=None, attribution_text_gt=None, attribution_text_pred=None):
    colors = {
        'car_parking': (0, 0, 255),  # cars in blue
        'truck_parking': (255, 0, 0),  # trucks in red
        'quick_parking': (0, 255, 0),  # quick parking in green
    }

    # Fetch the specified batch
    if batch_num >= len(dataloader):
        print(f"Batch number {batch_num} is out of range. The dataloader has {len(dataloader)} batches.")
        return

    batch = dataloader[batch_num]
    images = batch[0]
    true_masks = batch[1]

    if image_num >= images.shape[0]:
        print(f"Image number {image_num} is out of range. The batch has {images.shape[0]} images.")
        return

    # Select the specified image and its true mask
    display_image = images[image_num]
    display_true_mask = np.argmax(true_masks[image_num], axis=-1) if true_masks.ndim == 4 else true_masks[image_num]

    # Prepare the original image for display
    display_image_bgr = cv2.cvtColor(display_image, cv2.COLOR_RGB2BGR)

    # Predict mask for the selected image
    pred_mask = model.predict(np.expand_dims(display_image, axis=0))
    display_pred_mask = np.argmax(pred_mask[0], axis=-1) if pred_mask.ndim == 4 else pred_mask[0]

    # Draw contours for the true mask on a copy of the image
    true_mask_contoured = display_image_bgr.copy()
    for channel, color in enumerate(colors.values()):
        true_mask = display_true_mask == channel
        contours, _ = cv2.findContours(true_mask.astype(np.uint8), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        cv2.drawContours(true_mask_contoured, contours, -1, color, 2)

    # Draw contours for the predicted mask on a copy of the image
    pred_mask_contoured = display_image_bgr.copy()
    for channel, color in enumerate(colors.values()):
        pred_mask = display_pred_mask == channel
        contours, _ = cv2.findContours(pred_mask.astype(np.uint8), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        cv2.drawContours(pred_mask_contoured, contours, -1, color, 2)

    # Plot the images
    plt.figure(figsize=(18, 6))

    ax1 = plt.subplot(1, 3, 2)
    plt.imshow(cv2.cvtColor(true_mask_contoured, cv2.COLOR_BGR2RGB))
    plt.title('Ground Truth')
    plt.axis('off')
    if attribution_text_gt is not None:
        ax1.text(x=1, y=0, s=attribution_text_gt, horizontalalignment='right', verticalalignment='bottom',
                 transform=ax1.transAxes, color="white", fontsize=7, bbox=dict(facecolor='black', alpha=0.5, edgecolor='none', boxstyle='round,pad=0.1'))

    ax2 = plt.subplot(1, 3, 3)
    plt.imshow(cv2.cvtColor(pred_mask_contoured, cv2.COLOR_BGR2RGB))
    plt.title('Prediction')
    plt.axis('off')
    if attribution_text_pred is not None:
        ax2.text(x=1, y=0, s=attribution_text_pred, horizontalalignment='right', verticalalignment='bottom',
                 transform=ax2.transAxes, color="white", fontsize=7, bbox=dict(facecolor='black', alpha=0.5, edgecolor='none', boxstyle='round,pad=0.1'))

    # Save the figure if an output path is provided
    if output_path is not None:
        plt.savefig(output_path, bbox_inches="tight", pad_inches=0, dpi=100)

    plt.show()

# %%
# Load test dataset

test_dataset = Dataset(
    images_dir="03 Model Training/test_images_masks/images_png",
    masks_dir="03 Model Training/test_images_masks/masks",
    class_values=[100, 200, 250],
    augmentation=None,  # Usually, we don't apply augmentation to validation data
    preprocessing=get_preprocessing(preprocess_input),
)

test_dataloader = Dataloader(test_dataset, batch_size=1, shuffle=False)

# %%
# Inspect test data set batches and dimensions

print("Number of batches: ", len(test_dataloader))
print("Elements within first batch:", len(test_dataloader[0])) # image, mask

first_batch_images, _ = test_dataloader[0]
first_image = first_batch_images[0]
image_shape = first_image.shape
print("Image shape:", image_shape)

_, first_batch_masks = test_dataloader[0]
first_mask = first_batch_masks[0]
mask_shape = first_image.shape
print("Mask shape:", mask_shape)
# Out:
# Number of batches:  23
# Elements within first batch: 2
# Image shape: (2560, 2560, 3)
# Mask shape: (2560, 2560, 3)

# %% [markdown]
# "03 Model Training/figures"

# %%
predict_and_visualize_with_mask_edges(loaded_model, test_dataloader, batch_num=18, image_num=0, output_path="03 Model Training/figures/lon_12.3708436_lat_51.8676138_Kliekener Aue.png", attribution_text_gt="Imagery © LVermGeo LSA, Annotation © OpenStreetMap", attribution_text_pred="Imagery © LVermGeo LSA")
# Out:
# 1/1 [==============================] - 0s 43ms/step

# %% [markdown]
# Selected images for download:
#
# - 3: lon_10.9544554_lat_50.9407623_Erfurter Becken - Ost: Thuringia
# - 7: lon_10.1726923_lat_51.0086765_Burgberg: Hessia
# - lon_9.6807029_lat_52.8134767_Wolfsgrund West: Lower Saxony

# %% [markdown]
# # Understand mIoU calculation

# %%
custom_objects = {
    "iou_score": sm.metrics.IOUScore(threshold=None, class_indexes=[0,1]),
    "f1-score": sm.metrics.FScore(threshold=None, class_indexes=[0,1]),
    "dice_loss": sm.losses.dice_loss
}

loaded_model = tf.keras.models.load_model(
    "03 Model Training/models/unet_resnet101_bs8_lr0.0001_e50_efFalse/best_model.h5",
    custom_objects=custom_objects
)

BACKBONE = "resnet101"
preprocess_input = sm.get_preprocessing(BACKBONE)

# %%
test_dataset_iou = Dataset(
    images_dir="03 Model Training/iou_val/images",
    masks_dir="03 Model Training/iou_val/masks",
    class_values=[100, 200, 250],
    augmentation=None,  # Usually, we don't apply augmentation to validation data
    preprocessing=get_preprocessing(preprocess_input),
)

test_dataloader_iou = Dataloader(test_dataset_iou, batch_size=1, shuffle=False)

# %%
def evaluate_model(model, dataloader):

    # Evaluate the loaded_model on the test dataset
    results = model.evaluate(dataloader, verbose=1)

    return results  # This includes the loss as the first element and the metrics afterwards

# %%
evaluate_model(loaded_model, test_dataloader_iou)
# Out:
# 1/1 [==============================] - 2s 2s/step - loss: 0.3823 - iou_score: 0.6244 - f1-score: 0.7494
# [0.38225144147872925, 0.6244316101074219, 0.7493605613708496]

# %%
def predict_TP_FP_FN(model, dataloader, batch_num=0, image_num=0, output_path=None, attribution_text=None):
    colors = {
        'car_parking': (0, 0, 255),  # cars in red
        'truck_parking': (255, 0, 0),  # trucks in blue
        'quick_parking': (0, 255, 0),
        'background': (100, 100, 100)
    }

    # Fetch the specified batch
    if batch_num >= len(dataloader):
        print(f"Batch number {batch_num} is out of range. The dataloader has {len(dataloader)} batches.")
        return

    batch = dataloader[batch_num]
    images = batch[0]
    true_masks = batch[1]

    if image_num >= images.shape[0]:
        print(f"Image number {image_num} is out of range. The batch has {images.shape[0]} images.")
        return

    # Select the specified image and its true mask
    display_image = images[image_num]
    display_true_mask = np.argmax(true_masks[image_num], axis=-1) if true_masks.ndim == 4 else true_masks[image_num]

    # Predict mask for the selected image
    pred_mask = model.predict(np.expand_dims(display_image, axis=0))
    display_pred_mask = np.argmax(pred_mask[0], axis=-1) if pred_mask.ndim == 4 else pred_mask[0]

    # Calculate and Print Per-Class Metrics
    for channel, label in enumerate(colors):
        TP = np.sum((display_pred_mask == channel) & (display_true_mask == channel))
        FP = np.sum((display_pred_mask == channel) & (display_true_mask != channel))
        FN = np.sum((display_pred_mask != channel) & (display_true_mask == channel))
        print(f"{label}: TP={TP}, FP={FP}, FN={FN}")

# %%
predict_TP_FP_FN(loaded_model, test_dataloader_iou, batch_num=0, image_num=0)
# Out:
# 1/1 [==============================] - 0s 35ms/step
# car_parking: TP=6609, FP=10642, FN=242
# truck_parking: TP=19218, FP=2248, FN=1366
# quick_parking: TP=0, FP=0, FN=0
# background: TP=221819, FP=1608, FN=12890

# %%
def print_image_prediction(image_index):
    if image_index < 0 or image_index >= len(test_dataset_iou):
        print("Invalid image index. Please select an index between 0 and", len(test_dataset_iou) - 1)
        return

    image = test_dataset_iou[image_index][0]
    image_processed = preprocess_input(image)
    image_batch = np.expand_dims(image_processed, axis=0)
    prediction = loaded_model.predict(image_batch)

    print("Shape of the predicted output:", prediction[0].shape)
    print("Predicted Class Probabilities for Each Pixel:")
    print(prediction[0][0][0])  # Outputs the prediction array for the entire image

# %%
print_image_prediction(0)
# Out:
# 1/1 [==============================] - 0s 30ms/step
# Shape of the predicted output: (512, 512, 4)
# Predicted Class Probabilities for Each Pixel:
# [0.00258139 0.8609032  0.01833622 0.11817925]

# %% [markdown]
# # Experiment 2: Tile Sizes

# %%
train_dataset = Dataset(
    images_dir="03 Model Training/train_validate_images_masks_reduced_256_upload/train/images",
    masks_dir="03 Model Training/train_validate_images_masks_reduced_256_upload/train/masks",
    class_values=[100, 200, 250],
    augmentation=None,
    preprocessing=None
)

train_dataloader = Dataloader(dataset=train_dataset, batch_size=1, shuffle=True)

val_dataset = Dataset(
    images_dir="03 Model Training/train_validate_images_masks_reduced_256_upload/val/images",
    masks_dir="03 Model Training/train_validate_images_masks_reduced_256_upload/val/masks",
    class_values=[100, 200, 250],
    augmentation=None,
    preprocessing=None
)

val_dataloader = Dataloader(dataset=val_dataset, batch_size=1, shuffle=False)

# %%
print("Number of batches: ", len(train_dataloader))
print("Elements within first batch", len(train_dataloader[0])) # image, mask

first_batch_images, _ = train_dataloader[0]
first_image = first_batch_images[0]
image_shape = first_image.shape
print("Image shape:", image_shape)

_, first_batch_masks = train_dataloader[0]
first_mask = first_batch_masks[0]
mask_shape = first_mask.shape
print("Mask shape:", mask_shape)
# Out:
# Number of batches:  2877
# Elements within first batch 2
# Image shape: (256, 256, 3)
# Mask shape: (256, 256, 4)

# %% [markdown]
# ## Unet Hyperparameter tuning

# %%
# Define a function to create and train the model
def train_model(backbone, batch_size, encoder_freeze, epochs=50):

    # Define directories
    NAME = f"03 Model Training/models_256/unet_{backbone}_bs{batch_size}_lr0.0001_e{epochs}_ef{str(encoder_freeze)}"
    print(NAME)
    HISTORY_DIR = "03 Model Training/models_training_history_256"
    LR = 0.0001
    os.makedirs(NAME, exist_ok=True)
    os.makedirs(HISTORY_DIR, exist_ok=True)

    preprocess_input = sm.get_preprocessing(backbone)

    # Set up model, optimizer, evaluation metrics and compile the model
    model = Unet(backbone, classes=4, activation="softmax", encoder_weights="imagenet", encoder_freeze=encoder_freeze)
    optim = keras.optimizers.Adam(LR)
    metrics = [sm.metrics.IOUScore(threshold=0.5, class_indexes=[0, 1], per_image=True), sm.metrics.FScore(threshold=0.5, class_indexes=[0, 1], per_image=True)]
    model.compile(optimizer=optim, loss=sm.losses.dice_loss, metrics=metrics)

    # Define training and validation set
    train_dataset = Dataset(
        images_dir="03 Model Training/train_validate_images_masks_reduced_256_upload/train/images",
        masks_dir="03 Model Training/train_validate_images_masks_reduced_256_upload/train/masks",
        class_values=[100, 200, 250],
        augmentation=get_training_augmentation(),
        preprocessing=get_preprocessing(preprocess_input),
    )

    val_dataset = Dataset(
        images_dir="03 Model Training/train_validate_images_masks_reduced_256_upload/val/images",
        masks_dir="03 Model Training/train_validate_images_masks_reduced_256_upload/val/masks",
        class_values=[100, 200, 250],
        augmentation=None,
        preprocessing=get_preprocessing(preprocess_input),
    )

    train_dataloader = Dataloader(train_dataset, batch_size=batch_size, shuffle=True)
    val_dataloader = Dataloader(val_dataset, batch_size=1, shuffle=False)

    # Callbacks
    callbacks = [
        keras.callbacks.ModelCheckpoint(os.path.join(NAME, "best_model.h5"), monitor="val_loss", verbose=1, save_best_only=True, mode="min"),
        keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.1, patience=5)
    ]

    # Fit model
    history = model.fit(
        train_dataloader,
        epochs=epochs,
        verbose=1,
        callbacks=callbacks,
        validation_data=val_dataloader
    )

    # Plot and save training history
    plt.figure(figsize=(30, 5))
    plt.subplot(121)
    plt.plot(history.history["iou_score"])
    plt.plot(history.history["val_iou_score"])
    plt.title("Intersection over Union score")
    plt.ylabel("iou_score")
    plt.xlabel("Epoch")
    plt.legend(["Train", "Validation"], loc="upper left")

    plt.subplot(122)
    plt.plot(history.history["loss"])
    plt.plot(history.history["val_loss"])
    plt.title("Dice loss")
    plt.ylabel("dice_loss")
    plt.xlabel("Epoch")
    plt.legend(["Train", "Validation"], loc="upper left")
    plt.savefig(os.path.join(HISTORY_DIR, f"history_unet_{backbone}_bs{batch_size}_lr0.0001_e{epochs}_ef{str(encoder_freeze)}.png"), bbox_inches='tight')
    plt.close()

# %%
# Define possible hyperparameters
backbones = ["resnet101"]
batch_sizes = [4, 8, 16, 32, 64]
encoder_freezes = [False]

# %%
# Loop over all combinations of hyperparameters
for backbone in backbones:
    for batch_size in batch_sizes:
        for encoder_freeze in encoder_freezes:
            start_time = datetime.datetime.now()
            print(f"Training model with Backbone: {backbone}, Batch Size: {batch_size}, Encoder Freeze: {encoder_freeze}")
            print(f"Start Time: {start_time.strftime('%Y-%m-%d %H:%M:%S')}")

            train_model(backbone, batch_size, encoder_freeze)

            end_time = datetime.datetime.now()
            print(f"End Time: {end_time.strftime('%Y-%m-%d %H:%M:%S')}")
            print(f"Training Duration: {end_time - start_time}")
# Out:
# Training model with Backbone: resnet101, Batch Size: 4, Encoder Freeze: False
# Start Time: 2024-04-22 15:10:19
# 03 Model Training/models_256/unet_resnet101_bs4_lr0.0001_e50_efFalse
# Epoch 1/50
# 719/719 [==============================] - ETA: 0s - loss: 0.7029 - iou_score: 0.4131 - f1-score: 0.4390
# Epoch 1: val_loss improved from inf to 0.76710, saving model to 03 Model Training/models_256/unet_resnet101_bs4_lr0.0001_e50_efFalse/best_model.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 719/719 [==============================] - 2400s 3s/step - loss: 0.7029 - iou_score: 0.4131 - f1-score: 0.4390 - val_loss: 0.7671 - val_iou_score: 0.5812 - val_f1-score: 0.5994 - lr: 1.0000e-04
# Epoch 2/50
# ...

# %% [markdown]
# ## LinkNet hyperparameter tuning

# %%
# Define a function to create and train the model
def train_model(backbone, batch_size, encoder_freeze, epochs=50):

    # Define directories
    NAME = f"03 Model Training/models_256/linknet_{backbone}_bs{batch_size}_lr0.0001_e{epochs}_ef{str(encoder_freeze)}"
    print(NAME)
    HISTORY_DIR = "03 Model Training/models_training_history_256"
    LR = 0.0001
    os.makedirs(NAME, exist_ok=True)
    os.makedirs(HISTORY_DIR, exist_ok=True)

    preprocess_input = sm.get_preprocessing(backbone)

    # Set up model, optimizer, evaluation metrics and compile the model
    model = sm.Linknet(backbone, classes=4, activation="softmax", encoder_weights="imagenet", encoder_freeze=encoder_freeze)
    optim = keras.optimizers.Adam(LR)
    metrics = [sm.metrics.IOUScore(threshold=0.5, class_indexes=[0, 1], per_image=True), sm.metrics.FScore(threshold=0.5, class_indexes=[0, 1], per_image=True)]
    model.compile(optimizer=optim, loss=sm.losses.dice_loss, metrics=metrics)

    # Define training and validation set
    train_dataset = Dataset(
        images_dir="03 Model Training/train_validate_images_masks_reduced_256_upload/train/images",
        masks_dir="03 Model Training/train_validate_images_masks_reduced_256_upload/train/masks",
        class_values=[100, 200, 250],
        augmentation=get_training_augmentation(),
        preprocessing=get_preprocessing(preprocess_input),
    )

    val_dataset = Dataset(
        images_dir="03 Model Training/train_validate_images_masks_reduced_256_upload/val/images",
        masks_dir="03 Model Training/train_validate_images_masks_reduced_256_upload/val/masks",
        class_values=[100, 200, 250],
        augmentation=None,
        preprocessing=get_preprocessing(preprocess_input),
    )

    train_dataloader = Dataloader(train_dataset, batch_size=batch_size, shuffle=True)
    val_dataloader = Dataloader(val_dataset, batch_size=1, shuffle=False)

    # Callbacks
    callbacks = [
        keras.callbacks.ModelCheckpoint(os.path.join(NAME, "best_model.h5"), monitor="val_loss", verbose=1, save_best_only=True, mode="min"),
        keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.1, patience=5)
    ]

    # Fit model
    history = model.fit(
        train_dataloader,
        epochs=epochs,
        verbose=1,
        callbacks=callbacks,
        validation_data=val_dataloader
    )

    # Plot and save training history
    plt.figure(figsize=(30, 5))
    plt.subplot(121)
    plt.plot(history.history["iou_score"])
    plt.plot(history.history["val_iou_score"])
    plt.title("Intersection over Union score")
    plt.ylabel("iou_score")
    plt.xlabel("Epoch")
    plt.legend(["Train", "Validation"], loc="upper left")

    plt.subplot(122)
    plt.plot(history.history["loss"])
    plt.plot(history.history["val_loss"])
    plt.title("Dice loss")
    plt.ylabel("dice_loss")
    plt.xlabel("Epoch")
    plt.legend(["Train", "Validation"], loc="upper left")
    plt.savefig(os.path.join(HISTORY_DIR, f"history_linknet_{backbone}_bs{batch_size}_lr0.0001_e{epochs}_ef{str(encoder_freeze)}.png"), bbox_inches='tight')
    plt.close()

# %%
# Define possible hyperparameters
backbones = ["resnet101"]
batch_sizes = [4, 8, 16, 32]
encoder_freezes = [False]

# %%
# Loop over all combinations of hyperparameters
for backbone in backbones:
    for batch_size in batch_sizes:
        for encoder_freeze in encoder_freezes:
            start_time = datetime.datetime.now()
            print(f"Training model with Backbone: {backbone}, Batch Size: {batch_size}, Encoder Freeze: {encoder_freeze}")
            print(f"Start Time: {start_time.strftime('%Y-%m-%d %H:%M:%S')}")

            train_model(backbone, batch_size, encoder_freeze)

            end_time = datetime.datetime.now()
            print(f"End Time: {end_time.strftime('%Y-%m-%d %H:%M:%S')}")
            print(f"Training Duration: {end_time - start_time}")
# Out:
# Training model with Backbone: resnet101, Batch Size: 4, Encoder Freeze: False
# Start Time: 2024-04-22 20:42:32
# 03 Model Training/models_256/linknet_resnet101_bs4_lr0.0001_e50_efFalse
# Epoch 1/50
# 719/719 [==============================] - ETA: 0s - loss: 0.7016 - iou_score: 0.3867 - f1-score: 0.4089
# Epoch 1: val_loss improved from inf to 0.74793, saving model to 03 Model Training/models_256/linknet_resnet101_bs4_lr0.0001_e50_efFalse/best_model.h5
# 719/719 [==============================] - 148s 140ms/step - loss: 0.7016 - iou_score: 0.3867 - f1-score: 0.4089 - val_loss: 0.7479 - val_iou_score: 0.5405 - val_f1-score: 0.5637 - lr: 1.0000e-04
# Epoch 2/50
# 719/719 [==============================] - ETA: 0s - loss: 0.6318 - iou_score: 0.4960 - f1-score: 0.5236
# Epoch 2: val_loss did not improve from 0.74793
# ...

# %% [markdown]
# ## FPN hyperparameter tuning

# %%
# Define a function to create and train the model
def train_model(backbone, batch_size, encoder_freeze, epochs=50):

    # Define directories
    NAME = f"03 Model Training/models_256/fpn_{backbone}_bs{batch_size}_lr0.0001_e{epochs}_ef{str(encoder_freeze)}"
    print(NAME)
    HISTORY_DIR = "03 Model Training/models_training_history_256"
    LR = 0.0001
    os.makedirs(NAME, exist_ok=True)
    os.makedirs(HISTORY_DIR, exist_ok=True)

    preprocess_input = sm.get_preprocessing(backbone)

    # Set up model, optimizer, evaluation metrics and compile the model
    model = sm.FPN(backbone, classes=4, activation="softmax", encoder_weights="imagenet", encoder_freeze=encoder_freeze)
    optim = keras.optimizers.Adam(LR)
    metrics = [sm.metrics.IOUScore(threshold=0.5, class_indexes=[0, 1], per_image=True), sm.metrics.FScore(threshold=0.5, class_indexes=[0, 1], per_image=True)]
    model.compile(optimizer=optim, loss=sm.losses.dice_loss, metrics=metrics)

    # Define training and validation set
    train_dataset = Dataset(
        images_dir="03 Model Training/train_validate_images_masks_reduced_256_upload/train/images",
        masks_dir="03 Model Training/train_validate_images_masks_reduced_256_upload/train/masks",
        class_values=[100, 200, 250],
        augmentation=get_training_augmentation(),
        preprocessing=get_preprocessing(preprocess_input),
    )

    val_dataset = Dataset(
        images_dir="03 Model Training/train_validate_images_masks_reduced_256_upload/val/images",
        masks_dir="03 Model Training/train_validate_images_masks_reduced_256_upload/val/masks",
        class_values=[100, 200, 250],
        augmentation=None,
        preprocessing=get_preprocessing(preprocess_input),
    )

    train_dataloader = Dataloader(train_dataset, batch_size=batch_size, shuffle=True)
    val_dataloader = Dataloader(val_dataset, batch_size=1, shuffle=False)

    # Callbacks
    callbacks = [
        keras.callbacks.ModelCheckpoint(os.path.join(NAME, "best_model.h5"), monitor="val_loss", verbose=1, save_best_only=True, mode="min"),
        keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.1, patience=5)
    ]

    # Fit model
    history = model.fit(
        train_dataloader,
        epochs=epochs,
        verbose=1,
        callbacks=callbacks,
        validation_data=val_dataloader
    )

    # Plot and save training history
    plt.figure(figsize=(30, 5))
    plt.subplot(121)
    plt.plot(history.history["iou_score"])
    plt.plot(history.history["val_iou_score"])
    plt.title("Intersection over Union score")
    plt.ylabel("iou_score")
    plt.xlabel("Epoch")
    plt.legend(["Train", "Validation"], loc="upper left")

    plt.subplot(122)
    plt.plot(history.history["loss"])
    plt.plot(history.history["val_loss"])
    plt.title("Dice loss")
    plt.ylabel("dice_loss")
    plt.xlabel("Epoch")
    plt.legend(["Train", "Validation"], loc="upper left")
    plt.savefig(os.path.join(HISTORY_DIR, f"history_fpn_{backbone}_bs{batch_size}_lr0.0001_e{epochs}_ef{str(encoder_freeze)}.png"), bbox_inches='tight')
    plt.close()

# %%
# Define possible hyperparameters
backbones = ["resnet101"]
batch_sizes = [4, 8, 16, 32]
encoder_freezes = [False]

# %%
# Loop over all combinations of hyperparameters
for backbone in backbones:
    for batch_size in batch_sizes:
        for encoder_freeze in encoder_freezes:
            start_time = datetime.datetime.now()
            print(f"Training model with Backbone: {backbone}, Batch Size: {batch_size}, Encoder Freeze: {encoder_freeze}")
            print(f"Start Time: {start_time.strftime('%Y-%m-%d %H:%M:%S')}")

            train_model(backbone, batch_size, encoder_freeze)

            end_time = datetime.datetime.now()
            print(f"End Time: {end_time.strftime('%Y-%m-%d %H:%M:%S')}")
            print(f"Training Duration: {end_time - start_time}")
# Out:
# Training model with Backbone: resnet101, Batch Size: 4, Encoder Freeze: False
# Start Time: 2024-04-23 06:30:54
# 03 Model Training/models_256/fpn_resnet101_bs4_lr0.0001_e50_efFalse
# ...
# 171164896/171164896 [==============================] - 4s 0us/step
# Epoch 1/50
# 719/719 [==============================] - ETA: 0s - loss: 0.6456 - iou_score: 0.4501 - f1-score: 0.4770
# Epoch 1: val_loss improved from inf to 0.72102, saving model to 03 Model Training/models_256/fpn_resnet101_bs4_lr0.0001_e50_efFalse/best_model.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# ...

# %% [markdown]
# ## Model evaluation

# %%
# Define the hyperparameter combinations
model_types = ["unet", "fpn", "linknet"]
backbones = ["resnet101"]
batch_sizes = [4, 8, 16, 32]
encoder_freezes = [False]

# Custom objects for loading models
custom_objects = {
    "iou_score": sm.metrics.IOUScore(threshold=0.5, class_indexes=[0,1], per_image=True), # change class indeces to calculate IoU for cars (0), trucks (1), or both (0,1)
    "f1-score": sm.metrics.FScore(threshold=0.5, class_indexes=[0,1], per_image=True), # change class indeces to calculate f1 for cars (0), trucks (1), or both (0,1)
    "dice_loss": sm.losses.dice_loss
}

# Function to evaluate the model
def evaluate_model(model, dataloader):
    results = model.evaluate(dataloader, verbose=1)
    return results

# Store model performance for sorting
model_performance = []

# Loop over all combinations of model types and hyperparameters
for model_type in model_types:
    for backbone in backbones:
        for batch_size in batch_sizes:
            for encoder_freeze in encoder_freezes:
                model_dir = f"03 Model Training/models_256/{model_type}_{backbone}_bs{batch_size}_lr0.0001_e50_ef{str(encoder_freeze)}"
                model_path = os.path.join(model_dir, "best_model.h5")

                if os.path.exists(model_path):
                    print(f"Evaluating model {model_path}")
                    loaded_model = tf.keras.models.load_model(model_path, custom_objects=custom_objects)

                    # Load validation dataset
                    val_dataset = Dataset(
                        images_dir="03 Model Training/train_validate_images_masks_reduced_256_upload/val/images",
                        masks_dir="03 Model Training/train_validate_images_masks_reduced_256_upload/val/masks",
                        class_values=[100, 200, 250],
                        augmentation=None,  # No augmentation for evaluation
                        preprocessing=get_preprocessing(sm.get_preprocessing(backbone))
                    )
                    val_dataloader = Dataloader(val_dataset, batch_size=1, shuffle=False)

                    # Evaluate the model
                    evaluation_results = evaluate_model(loaded_model, val_dataloader)
                    model_performance.append((model_path, evaluation_results[1]))
                    print(f"Results for {model_type} with {backbone}, Batch Size: {batch_size}, Encoder Freeze: {encoder_freeze}: {evaluation_results}")
                else:
                    print(f"Model file not found: {model_path}")

# Sort models by IoU score from highest to lowest
model_performance.sort(key=lambda x: x[1], reverse=True)

# Print sorted results
for model, iou_score in model_performance:
    print(f"Model {model} has IoU score: {iou_score}")
# Out:
# Evaluating model 03 Model Training/models_256/unet_resnet101_bs4_lr0.0001_e50_efFalse/best_model.h5
# 792/792 [==============================] - 313s 391ms/step - loss: 0.6746 - iou_score: 0.8022 - f1-score: 0.8265
# Results for unet with resnet101, Batch Size: 4, Encoder Freeze: False: [0.6745663285255432, 0.8022289872169495, 0.8265261650085449]
# Evaluating model 03 Model Training/models_256/unet_resnet101_bs8_lr0.0001_e50_efFalse/best_model.h5
# 792/792 [==============================] - 18s 20ms/step - loss: 0.6675 - iou_score: 0.8395 - f1-score: 0.8637
# Results for unet with resnet101, Batch Size: 8, Encoder Freeze: False: [0.6674601435661316, 0.8394753336906433, 0.8636550903320312]
# Evaluating model 03 Model Training/models_256/unet_resnet101_bs16_lr0.0001_e50_efFalse/best_model.h5
# 792/792 [==============================] - 14s 15ms/step - loss: 0.6636 - iou_score: 0.8580 - f1-score: 0.8810
# ...

# %% [markdown]
# Overall:
#
# - Model 03 Model Training/models_256/unet_resnet101_bs16_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.8579980731010437
# - Model 03 Model Training/models_256/fpn_resnet101_bs16_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.8550988435745239
# - Model 03 Model Training/models_256/linknet_resnet101_bs16_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.8520973324775696
# - Model 03 Model Training/models_256/unet_resnet101_bs32_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.8514127731323242
# - Model 03 Model Training/models_256/fpn_resnet101_bs8_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.8497991561889648
# - Model 03 Model Training/models_256/linknet_resnet101_bs8_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.841768741607666
# - Model 03 Model Training/models_256/unet_resnet101_bs8_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.8394753336906433
# - Model 03 Model Training/models_256/fpn_resnet101_bs4_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.8374873995780945
# - Model 03 Model Training/models_256/linknet_resnet101_bs4_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.8223899006843567
# - Model 03 Model Training/models_256/unet_resnet101_bs4_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.8022289872169495
#
# Cars:
#
# - Model 03 Model Training/models_256/linknet_resnet101_bs16_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.8470958471298218
# - Model 03 Model Training/models_256/fpn_resnet101_bs16_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.8454936742782593
# - Model 03 Model Training/models_256/unet_resnet101_bs16_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.845127284526825
# - Model 03 Model Training/models_256/fpn_resnet101_bs8_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.8440106511116028
# - Model 03 Model Training/models_256/unet_resnet101_bs32_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.8395872712135315
# - Model 03 Model Training/models_256/fpn_resnet101_bs4_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.8314703702926636
# - Model 03 Model Training/models_256/unet_resnet101_bs8_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.8306190967559814
# - Model 03 Model Training/models_256/linknet_resnet101_bs8_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.8303488492965698
# - Model 03 Model Training/models_256/linknet_resnet101_bs4_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.8166500329971313
# - Model 03 Model Training/models_256/unet_resnet101_bs4_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.8049671053886414
#
# Trucks:
#
# - Model 03 Model Training/models_256/unet_resnet101_bs16_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.8708688020706177
# - Model 03 Model Training/models_256/fpn_resnet101_bs16_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.8647048473358154
# - Model 03 Model Training/models_256/unet_resnet101_bs32_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.8632380366325378
# - Model 03 Model Training/models_256/linknet_resnet101_bs16_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.8570987582206726
# - Model 03 Model Training/models_256/fpn_resnet101_bs8_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.8555877208709717
# - Model 03 Model Training/models_256/linknet_resnet101_bs8_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.8531895875930786
# - Model 03 Model Training/models_256/unet_resnet101_bs8_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.8483307957649231
# - Model 03 Model Training/models_256/fpn_resnet101_bs4_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.8435053825378418
# - Model 03 Model Training/models_256/linknet_resnet101_bs4_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.8281298279762268
# - Model 03 Model Training/models_256/unet_resnet101_bs4_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.7994905114173889

# %%
# Define the hyperparameter combinations
model_types = ["unet"]
backbones = ["resnet101"]
batch_sizes = [16]
encoder_freezes = [False]

# Custom objects for loading models
custom_objects = {
    "iou_score": sm.metrics.IOUScore(threshold=0.5, class_indexes=[0,1], per_image=True), # change class indeces to calculate IoU for cars (0), trucks (1), or both (0,1)
    "f1-score": sm.metrics.FScore(threshold=0.5, class_indexes=[0,1], per_image=True), # change class indeces to calculate IoU for cars (0), trucks (1), or both (0,1)
    "dice_loss": sm.losses.dice_loss
}

# Function to evaluate the model
def evaluate_model(model, dataloader):
    results = model.evaluate(dataloader, verbose=1)
    return results

# Store model performance for sorting
model_performance = []

# Loop over all combinations of model types and hyperparameters
for model_type in model_types:
    for backbone in backbones:
        for batch_size in batch_sizes:
            for encoder_freeze in encoder_freezes:
                model_dir = f"03 Model Training/models_256/{model_type}_{backbone}_bs{batch_size}_lr0.0001_e50_ef{str(encoder_freeze)}"
                model_path = os.path.join(model_dir, "best_model.h5")

                if os.path.exists(model_path):
                    print(f"Evaluating model {model_path}")
                    loaded_model = tf.keras.models.load_model(model_path, custom_objects=custom_objects)

                    # Load test dataset
                    test_dataset = Dataset(
                        images_dir="03 Model Training/test_images_masks/images_png",
                        masks_dir="03 Model Training/test_images_masks/masks",
                        class_values=[100, 200, 250],
                        augmentation=None,  # Usually, we don't apply augmentation to validation data
                        preprocessing=get_preprocessing(sm.get_preprocessing(backbone)),
                    )
                    test_dataloader = Dataloader(test_dataset, batch_size=1, shuffle=False)

                    # Evaluate the model
                    evaluation_results = evaluate_model(loaded_model, test_dataloader)
                    model_performance.append((model_path, evaluation_results[1]))  # Assuming IoU is the second metric
                    print(f"Results for {model_type} with {backbone}, Batch Size: {batch_size}, Encoder Freeze: {encoder_freeze}: {evaluation_results}")
                else:
                    print(f"Model file not found: {model_path}")

# Sort models by IoU score from highest to lowest
model_performance.sort(key=lambda x: x[1], reverse=True)

# Print sorted results
for model, iou_score in model_performance:
    print(f"Model {model} has IoU score: {iou_score}")
# Out:
# Evaluating model 03 Model Training/models_256/unet_resnet101_bs16_lr0.0001_e50_efFalse/best_model.h5
# 23/23 [==============================] - 15s 543ms/step - loss: 0.2774 - iou_score: 0.6990 - f1-score: 0.8135
# Results for unet with resnet101, Batch Size: 16, Encoder Freeze: False: [0.2773723304271698, 0.6990471482276917, 0.813496470451355]
# Model 03 Model Training/models_256/unet_resnet101_bs16_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.6990471482276917

# %% [markdown]
# Overall:
#
# - Model 03 Model Training/models_256/unet_resnet101_bs16_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.6990471482276917
#
# Car:
#
# - Model 03 Model Training/models_256/unet_resnet101_bs16_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.5968710780143738
#
# Truck:
#
# - Model 03 Model Training/models_256/unet_resnet101_bs16_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.8012232780456543

# %% [markdown]
# # 128

# %%
# Define a function to create and train the model
def train_model(backbone, batch_size, encoder_freeze, epochs=50):

    # Define directories
    NAME = f"03 Model Training/models_128/unet_{backbone}_bs{batch_size}_lr0.0001_e{epochs}_ef{str(encoder_freeze)}"
    print(NAME)
    HISTORY_DIR = "03 Model Training/models_training_history_128"
    LR = 0.0001
    os.makedirs(NAME, exist_ok=True)
    os.makedirs(HISTORY_DIR, exist_ok=True)

    preprocess_input = sm.get_preprocessing(backbone)

    # Set up model, optimizer, evaluation metrics and compile the model
    model = Unet(backbone, classes=4, activation="softmax", encoder_weights="imagenet", encoder_freeze=encoder_freeze)
    optim = keras.optimizers.Adam(LR)
    metrics = [sm.metrics.IOUScore(threshold=0.5, class_indexes=[0, 1], per_image=True), sm.metrics.FScore(threshold=0.5, class_indexes=[0, 1], per_image=True)]
    model.compile(optimizer=optim, loss=sm.losses.dice_loss, metrics=metrics)

    # Define training and validation set
    train_dataset = Dataset(
        images_dir="03 Model Training/train_validate_images_masks_reduced_128/train/images",
        masks_dir="03 Model Training/train_validate_images_masks_reduced_128/train/masks",
        class_values=[100, 200, 250],
        augmentation=get_training_augmentation(),
        preprocessing=get_preprocessing(preprocess_input),
    )

    val_dataset = Dataset(
        images_dir="03 Model Training/train_validate_images_masks_reduced_128/val/images",
        masks_dir="03 Model Training/train_validate_images_masks_reduced_128/val/masks",
        class_values=[100, 200, 250],
        augmentation=None,
        preprocessing=get_preprocessing(preprocess_input),
    )

    train_dataloader = Dataloader(train_dataset, batch_size=batch_size, shuffle=True)
    val_dataloader = Dataloader(val_dataset, batch_size=1, shuffle=False)

    # Callbacks
    callbacks = [
        keras.callbacks.ModelCheckpoint(os.path.join(NAME, "best_model.h5"), monitor="val_loss", verbose=1, save_best_only=True, mode="min"),
        keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.1, patience=5)
    ]

    # Fit model
    history = model.fit(
        train_dataloader,
        epochs=epochs,
        verbose=1,
        callbacks=callbacks,
        validation_data=val_dataloader
    )

    # Plot and save training history
    plt.figure(figsize=(30, 5))
    plt.subplot(121)
    plt.plot(history.history["iou_score"])
    plt.plot(history.history["val_iou_score"])
    plt.title("Intersection over Union score")
    plt.ylabel("iou_score")
    plt.xlabel("Epoch")
    plt.legend(["Train", "Validation"], loc="upper left")

    plt.subplot(122)
    plt.plot(history.history["loss"])
    plt.plot(history.history["val_loss"])
    plt.title("Dice loss")
    plt.ylabel("dice_loss")
    plt.xlabel("Epoch")
    plt.legend(["Train", "Validation"], loc="upper left")
    plt.savefig(os.path.join(HISTORY_DIR, f"history_unet_{backbone}_bs{batch_size}_lr0.0001_e{epochs}_ef{str(encoder_freeze)}.png"), bbox_inches='tight')
    plt.close()

# %%
import os

def count_files(directory):
    """Counts the number of files in the specified directory."""
    return len([name for name in os.listdir(directory) if os.path.isfile(os.path.join(directory, name))])

# Directories for images and masks in the training and validation sets
train_images_dir = "03 Model Training/train_validate_images_masks_reduced_128/train/images"
train_masks_dir = "03 Model Training/train_validate_images_masks_reduced_128/train/masks"
val_images_dir = "03 Model Training/train_validate_images_masks_reduced_128/val/images"
val_masks_dir = "03 Model Training/train_validate_images_masks_reduced_128/val/masks"

# Count files in each directory
train_images_count = count_files(train_images_dir)
train_masks_count = count_files(train_masks_dir)
val_images_count = count_files(val_images_dir)
val_masks_count = count_files(val_masks_dir)

# Print the results
print(f"Number of image files in training directory: {train_images_count}")
print(f"Number of mask files in training directory: {train_masks_count}")
print(f"Number of image files in validation directory: {val_images_count}")
print(f"Number of mask files in validation directory: {val_masks_count}")
# Out:
# Number of image files in training directory: 7266
# Number of mask files in training directory: 7266
# Number of image files in validation directory: 1890
# Number of mask files in validation directory: 1890

# %%
# Define possible hyperparameters
backbones = ["resnet101"]
batch_sizes = [64, 4, 8]
encoder_freezes = [False]

# %%
# Loop over all combinations of hyperparameters
for backbone in backbones:
    for batch_size in batch_sizes:
        for encoder_freeze in encoder_freezes:
            start_time = datetime.datetime.now()
            print(f"Training model with Backbone: {backbone}, Batch Size: {batch_size}, Encoder Freeze: {encoder_freeze}")
            print(f"Start Time: {start_time.strftime('%Y-%m-%d %H:%M:%S')}")

            train_model(backbone, batch_size, encoder_freeze)

            end_time = datetime.datetime.now()
            print(f"End Time: {end_time.strftime('%Y-%m-%d %H:%M:%S')}")
            print(f"Training Duration: {end_time - start_time}")
# Out:
# Training model with Backbone: resnet101, Batch Size: 64, Encoder Freeze: False
# Start Time: 2024-04-23 22:09:40
# 03 Model Training/models_128/unet_resnet101_bs64_lr0.0001_e50_efFalse
# Epoch 1/50
# 113/113 [==============================] - ETA: 0s - loss: 0.6760 - iou_score: 0.6522 - f1-score: 0.6656
# Epoch 1: val_loss improved from inf to 0.78909, saving model to 03 Model Training/models_128/unet_resnet101_bs64_lr0.0001_e50_efFalse/best_model.h5
# 113/113 [==============================] - 235s 905ms/step - loss: 0.6760 - iou_score: 0.6522 - f1-score: 0.6656 - val_loss: 0.7891 - val_iou_score: 0.7563 - val_f1-score: 0.7714 - lr: 1.0000e-04
# Epoch 2/50
# 113/113 [==============================] - ETA: 0s - loss: 0.5398 - iou_score: 0.7519 - f1-score: 0.7717
# Epoch 2: val_loss improved from 0.78909 to 0.74909, saving model to 03 Model Training/models_128/unet_resnet101_bs64_lr0.0001_e50_efFalse/best_model.h5
# ...

# %% [markdown]
# ## LinkNet hyperparameter tuning

# %%
# Define a function to create and train the model
def train_model(backbone, batch_size, encoder_freeze, epochs=50):

    # Define directories
    NAME = f"03 Model Training/models_128/linknet_{backbone}_bs{batch_size}_lr0.0001_e{epochs}_ef{str(encoder_freeze)}"
    print(NAME)
    HISTORY_DIR = "03 Model Training/models_training_history_128"
    LR = 0.0001
    os.makedirs(NAME, exist_ok=True)
    os.makedirs(HISTORY_DIR, exist_ok=True)

    preprocess_input = sm.get_preprocessing(backbone)

    # Set up model, optimizer, evaluation metrics and compile the model
    model = sm.Linknet(backbone, classes=4, activation="softmax", encoder_weights="imagenet", encoder_freeze=encoder_freeze)
    optim = keras.optimizers.Adam(LR)
    metrics = [sm.metrics.IOUScore(threshold=0.5, class_indexes=[0, 1], per_image=True), sm.metrics.FScore(threshold=0.5, class_indexes=[0, 1], per_image=True)]
    model.compile(optimizer=optim, loss=sm.losses.dice_loss, metrics=metrics)

    # Define training and validation set
    train_dataset = Dataset(
        images_dir="03 Model Training/train_validate_images_masks_reduced_128/train/images",
        masks_dir="03 Model Training/train_validate_images_masks_reduced_128/train/masks",
        class_values=[100, 200, 250],
        augmentation=get_training_augmentation(),
        preprocessing=get_preprocessing(preprocess_input),
    )

    val_dataset = Dataset(
        images_dir="03 Model Training/train_validate_images_masks_reduced_128/val/images",
        masks_dir="03 Model Training/train_validate_images_masks_reduced_128/val/masks",
        class_values=[100, 200, 250],
        augmentation=None,
        preprocessing=get_preprocessing(preprocess_input),
    )

    train_dataloader = Dataloader(train_dataset, batch_size=batch_size, shuffle=True)
    val_dataloader = Dataloader(val_dataset, batch_size=1, shuffle=False)

    # Callbacks
    callbacks = [
        keras.callbacks.ModelCheckpoint(os.path.join(NAME, "best_model.h5"), monitor="val_loss", verbose=1, save_best_only=True, mode="min"),
        keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.1, patience=5)
    ]

    # Fit model
    history = model.fit(
        train_dataloader,
        epochs=epochs,
        verbose=1,
        callbacks=callbacks,
        validation_data=val_dataloader
    )

    # Plot and save training history
    plt.figure(figsize=(30, 5))
    plt.subplot(121)
    plt.plot(history.history["iou_score"])
    plt.plot(history.history["val_iou_score"])
    plt.title("Intersection over Union score")
    plt.ylabel("iou_score")
    plt.xlabel("Epoch")
    plt.legend(["Train", "Validation"], loc="upper left")

    plt.subplot(122)
    plt.plot(history.history["loss"])
    plt.plot(history.history["val_loss"])
    plt.title("Dice loss")
    plt.ylabel("dice_loss")
    plt.xlabel("Epoch")
    plt.legend(["Train", "Validation"], loc="upper left")
    plt.savefig(os.path.join(HISTORY_DIR, f"history_linknet_{backbone}_bs{batch_size}_lr0.0001_e{epochs}_ef{str(encoder_freeze)}.png"), bbox_inches='tight')
    plt.close()

# %%
# Define possible hyperparameters
backbones = ["resnet101"]
batch_sizes = [64]
encoder_freezes = [False]

# %%
# Loop over all combinations of hyperparameters
for backbone in backbones:
    for batch_size in batch_sizes:
        for encoder_freeze in encoder_freezes:
            start_time = datetime.datetime.now()
            print(f"Training model with Backbone: {backbone}, Batch Size: {batch_size}, Encoder Freeze: {encoder_freeze}")
            print(f"Start Time: {start_time.strftime('%Y-%m-%d %H:%M:%S')}")

            train_model(backbone, batch_size, encoder_freeze)

            end_time = datetime.datetime.now()
            print(f"End Time: {end_time.strftime('%Y-%m-%d %H:%M:%S')}")
            print(f"Training Duration: {end_time - start_time}")
# Out:
# Training model with Backbone: resnet101, Batch Size: 64, Encoder Freeze: False
# Start Time: 2024-04-24 15:39:36
# 03 Model Training/models_128/linknet_resnet101_bs64_lr0.0001_e50_efFalse
# Epoch 1/50
# 113/113 [==============================] - ETA: 0s - loss: 0.7093 - iou_score: 0.3902 - f1-score: 0.4060
# Epoch 1: val_loss improved from inf to 0.81837, saving model to 03 Model Training/models_128/linknet_resnet101_bs64_lr0.0001_e50_efFalse/best_model.h5
# 113/113 [==============================] - 225s 828ms/step - loss: 0.7093 - iou_score: 0.3902 - f1-score: 0.4060 - val_loss: 0.8184 - val_iou_score: 0.6504 - val_f1-score: 0.6733 - lr: 1.0000e-04
# Epoch 2/50
# 113/113 [==============================] - ETA: 0s - loss: 0.5452 - iou_score: 0.7421 - f1-score: 0.7621
# Epoch 2: val_loss improved from 0.81837 to 0.74936, saving model to 03 Model Training/models_128/linknet_resnet101_bs64_lr0.0001_e50_efFalse/best_model.h5
# ...

# %% [markdown]
# ## FPN hyperparameter tuning

# %%
# Define a function to create and train the model
def train_model(backbone, batch_size, encoder_freeze, epochs=50):

    # Define directories
    NAME = f"03 Model Training/models_128/fpn_{backbone}_bs{batch_size}_lr0.0001_e{epochs}_ef{str(encoder_freeze)}"
    print(NAME)
    HISTORY_DIR = "03 Model Training/models_training_history_128"
    LR = 0.0001
    os.makedirs(NAME, exist_ok=True)
    os.makedirs(HISTORY_DIR, exist_ok=True)

    preprocess_input = sm.get_preprocessing(backbone)

    # Set up model, optimizer, evaluation metrics and compile the model
    model = sm.FPN(backbone, classes=4, activation="softmax", encoder_weights="imagenet", encoder_freeze=encoder_freeze)
    optim = keras.optimizers.Adam(LR)
    metrics = [sm.metrics.IOUScore(threshold=0.5, class_indexes=[0, 1], per_image=True), sm.metrics.FScore(threshold=0.5, class_indexes=[0, 1], per_image=True)]
    model.compile(optimizer=optim, loss=sm.losses.dice_loss, metrics=metrics)

    # Define training and validation set
    train_dataset = Dataset(
        images_dir="03 Model Training/train_validate_images_masks_reduced_128/train/images",
        masks_dir="03 Model Training/train_validate_images_masks_reduced_128/train/masks",
        class_values=[100, 200, 250],
        augmentation=get_training_augmentation(),
        preprocessing=get_preprocessing(preprocess_input),
    )

    val_dataset = Dataset(
        images_dir="03 Model Training/train_validate_images_masks_reduced_128/val/images",
        masks_dir="03 Model Training/train_validate_images_masks_reduced_128/val/masks",
        class_values=[100, 200, 250],
        augmentation=None,
        preprocessing=get_preprocessing(preprocess_input),
    )

    train_dataloader = Dataloader(train_dataset, batch_size=batch_size, shuffle=True)
    val_dataloader = Dataloader(val_dataset, batch_size=1, shuffle=False)

    # Callbacks
    callbacks = [
        keras.callbacks.ModelCheckpoint(os.path.join(NAME, "best_model.h5"), monitor="val_loss", verbose=1, save_best_only=True, mode="min"),
        keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.1, patience=5)
    ]

    # Fit model
    history = model.fit(
        train_dataloader,
        epochs=epochs,
        verbose=1,
        callbacks=callbacks,
        validation_data=val_dataloader
    )

    # Plot and save training history
    plt.figure(figsize=(30, 5))
    plt.subplot(121)
    plt.plot(history.history["iou_score"])
    plt.plot(history.history["val_iou_score"])
    plt.title("Intersection over Union score")
    plt.ylabel("iou_score")
    plt.xlabel("Epoch")
    plt.legend(["Train", "Validation"], loc="upper left")

    plt.subplot(122)
    plt.plot(history.history["loss"])
    plt.plot(history.history["val_loss"])
    plt.title("Dice loss")
    plt.ylabel("dice_loss")
    plt.xlabel("Epoch")
    plt.legend(["Train", "Validation"], loc="upper left")
    plt.savefig(os.path.join(HISTORY_DIR, f"history_fpn_{backbone}_bs{batch_size}_lr0.0001_e{epochs}_ef{str(encoder_freeze)}.png"), bbox_inches='tight')
    plt.close()

# %%
# Define possible hyperparameters
backbones = ["resnet101"]
batch_sizes = [4, 8, 16, 32, 64]
encoder_freezes = [False]

# %%
# Loop over all combinations of hyperparameters
for backbone in backbones:
    for batch_size in batch_sizes:
        for encoder_freeze in encoder_freezes:
            start_time = datetime.datetime.now()
            print(f"Training model with Backbone: {backbone}, Batch Size: {batch_size}, Encoder Freeze: {encoder_freeze}")
            print(f"Start Time: {start_time.strftime('%Y-%m-%d %H:%M:%S')}")

            train_model(backbone, batch_size, encoder_freeze)

            end_time = datetime.datetime.now()
            print(f"End Time: {end_time.strftime('%Y-%m-%d %H:%M:%S')}")
            print(f"Training Duration: {end_time - start_time}")
# Out:
# Training model with Backbone: resnet101, Batch Size: 4, Encoder Freeze: False
# Start Time: 2024-04-24 23:22:53
# 03 Model Training/models_128/fpn_resnet101_bs4_lr0.0001_e50_efFalse
# ...
# 171164896/171164896 [==============================] - 0s 0us/step
# Epoch 1/50
# 1816/1816 [==============================] - ETA: 0s - loss: 0.6928 - iou_score: 0.5020 - f1-score: 0.5196
# Epoch 1: val_loss improved from inf to 0.76730, saving model to 03 Model Training/models_128/fpn_resnet101_bs4_lr0.0001_e50_efFalse/best_model.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# ...

# %% [markdown]
# ## Model evaluation

# %%
# Define the hyperparameter combinations
model_types = ["unet", "fpn", "linknet"]
backbones = ["resnet101"]
batch_sizes = [4, 8, 16, 32, 64]
encoder_freezes = [False]

# Custom objects for loading models
custom_objects = {
    "iou_score": sm.metrics.IOUScore(threshold=0.5, class_indexes=[1], per_image=True), # change class indeces to calculate IoU for cars (0), trucks (1), or both (0,1)
    "f1-score": sm.metrics.FScore(threshold=0.5, class_indexes=[1], per_image=True), # change class indeces to calculate f1 for cars (0), trucks (1), or both (0,1)
    "dice_loss": sm.losses.dice_loss
}

# Function to evaluate the model
def evaluate_model(model, dataloader):
    results = model.evaluate(dataloader, verbose=1)
    return results

# Store model performance for sorting
model_performance = []

# Loop over all combinations of model types and hyperparameters
for model_type in model_types:
    for backbone in backbones:
        for batch_size in batch_sizes:
            for encoder_freeze in encoder_freezes:
                model_dir = f"03 Model Training/models_128/{model_type}_{backbone}_bs{batch_size}_lr0.0001_e50_ef{str(encoder_freeze)}"
                model_path = os.path.join(model_dir, "best_model.h5")

                if os.path.exists(model_path):
                    print(f"Evaluating model {model_path}")
                    loaded_model = tf.keras.models.load_model(model_path, custom_objects=custom_objects)

                    # Load validation dataset
                    val_dataset = Dataset(
                        images_dir="03 Model Training/train_validate_images_masks_reduced_128/val/images",
                        masks_dir="03 Model Training/train_validate_images_masks_reduced_128/val/masks",
                        class_values=[100, 200, 250],
                        augmentation=None,  # No augmentation for evaluation
                        preprocessing=get_preprocessing(sm.get_preprocessing(backbone))
                    )
                    val_dataloader = Dataloader(val_dataset, batch_size=1, shuffle=False)

                    # Evaluate the model
                    evaluation_results = evaluate_model(loaded_model, val_dataloader)
                    model_performance.append((model_path, evaluation_results[1]))
                    print(f"Results for {model_type} with {backbone}, Batch Size: {batch_size}, Encoder Freeze: {encoder_freeze}: {evaluation_results}")
                else:
                    print(f"Model file not found: {model_path}")

# Sort models by IoU score from highest to lowest
model_performance.sort(key=lambda x: x[1], reverse=True)

# Print sorted results
for model, iou_score in model_performance:
    print(f"Model {model} has IoU score: {iou_score}")
# Out:
# Evaluating model 03 Model Training/models_128/unet_resnet101_bs4_lr0.0001_e50_efFalse/best_model.h5
# 1890/1890 [==============================] - 52s 26ms/step - loss: 0.6520 - iou_score: 0.7354 - f1-score: 0.7597
# Results for unet with resnet101, Batch Size: 4, Encoder Freeze: False: [0.6520178318023682, 0.7354452013969421, 0.7597102522850037]
# Evaluating model 03 Model Training/models_128/unet_resnet101_bs8_lr0.0001_e50_efFalse/best_model.h5
# 1890/1890 [==============================] - 36s 18ms/step - loss: 0.6905 - iou_score: 0.8242 - f1-score: 0.8465
# Results for unet with resnet101, Batch Size: 8, Encoder Freeze: False: [0.6905435919761658, 0.824179470539093, 0.8465249538421631]
# Evaluating model 03 Model Training/models_128/unet_resnet101_bs16_lr0.0001_e50_efFalse/best_model.h5
# 1890/1890 [==============================] - 36s 18ms/step - loss: 0.6886 - iou_score: 0.8444 - f1-score: 0.8651
# ...

# %% [markdown]
# Overall:

# %% [markdown]
# - Model 03 Model Training/models_128/fpn_resnet101_bs64_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.8588031530380249
# - Model 03 Model Training/models_128/fpn_resnet101_bs32_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.8579717874526978
# - Model 03 Model Training/models_128/unet_resnet101_bs64_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.8549418449401855
# - Model 03 Model Training/models_128/linknet_resnet101_bs32_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.8539568781852722
# - Model 03 Model Training/models_128/linknet_resnet101_bs64_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.8538051247596741
# - Model 03 Model Training/models_128/unet_resnet101_bs32_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.8524620532989502
# - Model 03 Model Training/models_128/fpn_resnet101_bs16_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.8511187434196472
# - Model 03 Model Training/models_128/linknet_resnet101_bs16_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.845697283744812
# - Model 03 Model Training/models_128/unet_resnet101_bs16_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.8407160043716431
# - Model 03 Model Training/models_128/linknet_resnet101_bs8_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.8224153518676758
# - Model 03 Model Training/models_128/unet_resnet101_bs8_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.8180419206619263
# - Model 03 Model Training/models_128/fpn_resnet101_bs8_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.7692951560020447
# - Model 03 Model Training/models_128/linknet_resnet101_bs4_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.7421689033508301
# - Model 03 Model Training/models_128/fpn_resnet101_bs4_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.7128113508224487
# - Model 03 Model Training/models_128/unet_resnet101_bs4_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.7094997763633728
#
# Car:
#
# - Model 03 Model Training/models_128/fpn_resnet101_bs32_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.8554699420928955
# - Model 03 Model Training/models_128/fpn_resnet101_bs64_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.85259610414505
# - Model 03 Model Training/models_128/linknet_resnet101_bs32_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.8504128456115723
# - Model 03 Model Training/models_128/unet_resnet101_bs64_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.8501023054122925
# - Model 03 Model Training/models_128/linknet_resnet101_bs64_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.8484099507331848
# - Model 03 Model Training/models_128/unet_resnet101_bs32_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.8475660681724548
# - Model 03 Model Training/models_128/fpn_resnet101_bs16_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.8473140597343445
# - Model 03 Model Training/models_128/linknet_resnet101_bs16_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.846767783164978
# - Model 03 Model Training/models_128/unet_resnet101_bs16_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.8370254635810852
# - Model 03 Model Training/models_128/linknet_resnet101_bs8_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.8304364085197449
# - Model 03 Model Training/models_128/unet_resnet101_bs8_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.8119043111801147
# - Model 03 Model Training/models_128/fpn_resnet101_bs8_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.7568256855010986
# - Model 03 Model Training/models_128/linknet_resnet101_bs4_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.7511143088340759
# - Model 03 Model Training/models_128/fpn_resnet101_bs4_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.7055169939994812
# - Model 03 Model Training/models_128/unet_resnet101_bs4_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.6835533380508423
#
# Truck:
#
# - Model 03 Model Training/models_128/fpn_resnet101_bs64_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.8650112748146057
# - Model 03 Model Training/models_128/fpn_resnet101_bs32_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.8604735136032104
# - Model 03 Model Training/models_128/unet_resnet101_bs64_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.8597806096076965
# - Model 03 Model Training/models_128/linknet_resnet101_bs64_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.8592010736465454
# - Model 03 Model Training/models_128/linknet_resnet101_bs32_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.8575008511543274
# - Model 03 Model Training/models_128/unet_resnet101_bs32_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.8573579788208008
# - Model 03 Model Training/models_128/fpn_resnet101_bs16_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.8549230098724365
# - Model 03 Model Training/models_128/linknet_resnet101_bs16_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.8446270823478699
# - Model 03 Model Training/models_128/unet_resnet101_bs16_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.8444054126739502
# - Model 03 Model Training/models_128/unet_resnet101_bs8_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.824179470539093
# - Model 03 Model Training/models_128/linknet_resnet101_bs8_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.8143935799598694
# - Model 03 Model Training/models_128/fpn_resnet101_bs8_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.7817643880844116
# - Model 03 Model Training/models_128/unet_resnet101_bs4_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.7354452013969421
# - Model 03 Model Training/models_128/linknet_resnet101_bs4_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.7332237362861633
# - Model 03 Model Training/models_128/fpn_resnet101_bs4_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.7201058268547058

# %%
# Define the hyperparameter combinations
model_types = ["fpn"]
backbones = ["resnet101"]
batch_sizes = [64]
encoder_freezes = [False]

# Custom objects for loading models
custom_objects = {
    "iou_score": sm.metrics.IOUScore(threshold=0.5, class_indexes=[1], per_image=True), # change class indeces to calculate IoU for cars (0), trucks (1), or both (0,1)
    "f1-score": sm.metrics.FScore(threshold=0.5, class_indexes=[1], per_image=True), # change class indeces to calculate IoU for cars (0), trucks (1), or both (0,1)
    "dice_loss": sm.losses.dice_loss
}

# Function to evaluate the model
def evaluate_model(model, dataloader):
    results = model.evaluate(dataloader, verbose=1)
    return results

# Store model performance for sorting
model_performance = []

# Loop over all combinations of model types and hyperparameters
for model_type in model_types:
    for backbone in backbones:
        for batch_size in batch_sizes:
            for encoder_freeze in encoder_freezes:
                model_dir = f"03 Model Training/models_128/{model_type}_{backbone}_bs{batch_size}_lr0.0001_e50_ef{str(encoder_freeze)}"
                model_path = os.path.join(model_dir, "best_model.h5")

                if os.path.exists(model_path):
                    print(f"Evaluating model {model_path}")
                    loaded_model = tf.keras.models.load_model(model_path, custom_objects=custom_objects)

                    # Load test dataset
                    test_dataset = Dataset(
                        images_dir="03 Model Training/test_images_masks/images_png",
                        masks_dir="03 Model Training/test_images_masks/masks",
                        class_values=[100, 200, 250],
                        augmentation=None,  # Usually, we don't apply augmentation to validation data
                        preprocessing=get_preprocessing(sm.get_preprocessing(backbone)),
                    )
                    test_dataloader = Dataloader(test_dataset, batch_size=1, shuffle=False)

                    # Evaluate the model
                    evaluation_results = evaluate_model(loaded_model, test_dataloader)
                    model_performance.append((model_path, evaluation_results[1]))  # Assuming IoU is the second metric
                    print(f"Results for {model_type} with {backbone}, Batch Size: {batch_size}, Encoder Freeze: {encoder_freeze}: {evaluation_results}")
                else:
                    print(f"Model file not found: {model_path}")

# Sort models by IoU score from highest to lowest
model_performance.sort(key=lambda x: x[1], reverse=True)

# Print sorted results
for model, iou_score in model_performance:
    print(f"Model {model} has IoU score: {iou_score}")
# Out:
# Evaluating model 03 Model Training/models_128/fpn_resnet101_bs64_lr0.0001_e50_efFalse/best_model.h5
# 23/23 [==============================] - 16s 568ms/step - loss: 0.2866 - iou_score: 0.7974 - f1-score: 0.8813
# Results for fpn with resnet101, Batch Size: 64, Encoder Freeze: False: [0.28659069538116455, 0.7974120378494263, 0.8813057541847229]
# Model 03 Model Training/models_128/fpn_resnet101_bs64_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.7974120378494263

# %% [markdown]
# Overall:
#
# - Model 03 Model Training/models_128/fpn_resnet101_bs64_lr0.0001_e50_efFalse/best_model.h5 has IoU score: 0.6882543563842773
